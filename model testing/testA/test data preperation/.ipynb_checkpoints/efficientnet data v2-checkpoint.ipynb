# %%
import boto3
import pandas as pd

bucket = "ai-bmi-predictor"
key = "test-data/eff_testingA.csv"

s3 = boto3.client("s3")
obj = s3.get_object(Bucket=bucket, Key=key)

data = pd.read_csv(obj["Body"])

data.head()
# Out:
#                            photo_id        f1        f2        f3        f4  \
# 0  e5ae8fe5bbdf611a1e8d06e66e849bdf  0.073159  0.085775 -0.133776  0.881202
# 1  605a5fd09058c48156b0ef518b63b2de  0.092031 -0.066016 -0.145132  0.687441
# 2  909c9277309e13ee014e347603aba620  0.057046 -0.051366 -0.148253  0.675916
# 3  bef6a68bc8dd475c124f6de2413385d3 -0.018792  0.016435 -0.148091  0.464433
# 4  6d7ed4bc4a17546447efed0ca6e2ff11  0.084419  0.065945 -0.153379  0.635377
#
#          f5        f6        f7        f8        f9  ...         hip  \
# 0  0.214236  0.016104 -0.180302 -0.100713 -0.117249  ...  106.774690
# 1  0.186508 -0.075221 -0.093846 -0.035840  0.033903  ...  102.481633
# 2  0.209973 -0.073485 -0.072783 -0.059395  0.008370  ...   99.342301
# 3  0.242849 -0.106556  0.001489 -0.083478  0.096048  ...  101.770144
# 4  0.285274 -0.056372 -0.139008 -0.120711 -0.002466  ...   94.707063
#
#    leg-length  shoulder-breadth  shoulder-to-crotch      thigh      waist  \
# 0   83.279744         39.922305           70.005128  55.945992  98.250390
# 1   84.876529         39.974203           73.591637  55.397032  88.003618
# 2   82.275874         36.059983           66.440526  53.742692  82.100598
# 3   76.081842         34.071748           62.218026  52.396573  83.999124
# 4   81.328892         36.834735           64.426273  49.895157  86.020117
#
#        wrist  gender  height_cm  weight_kg
# 0  20.187082    male     180.00      94.60
# 1  17.715785    male     188.90      86.75
# 2  17.086464    male     179.70      73.85
# 3  16.299751  female     166.95      69.05
# 4  16.531431    male     173.20      65.55
#
# [5 rows x 5138 columns]

# %%
# =========================
# Volume feature engineering
# =========================

import boto3  # AWS SDK for Python (S3 access)
import numpy as np  # fast array/mask operations
import pandas as pd  # dataframe ops
from PIL import Image  # read PNG images
from io import BytesIO  # convert S3 bytes -> file-like object
from botocore.exceptions import ClientError  # catch S3 missing-key errors

# -------------------------
# CONFIG (edit if needed)
# -------------------------

MASK_BUCKET = "amazon-bodym"            # S3 bucket that contains mask images
FRONT_MASK_PREFIX = "testA/mask/"      # front masks folder (from your 1st screenshot)
SIDE_MASK_PREFIX = "testA/mask_left/"  # side masks folder (from your 2nd screenshot)
PHOTO_ID_COL = "photo_id"              # column in your CSV that maps to mask filenames
OUTPUT_COL = "volume"                  # name for the new feature column

# -------------------------
# S3 client (reused)
# -------------------------

print("Creating S3 client...")  # track progress
s3 = boto3.client("s3")  # create an S3 client

# -----------------------------------------
# Helper: standardize photo_id -> filename
# -----------------------------------------

print("Inferring photo_id padding length...")  # track progress
photo_id_series = data[PHOTO_ID_COL].astype(str).fillna("")  # ensure string + no NaN
photo_id_series = photo_id_series.str.strip()  # remove whitespace
photo_id_series = photo_id_series.str.replace(".png", "", regex=False)  # drop extension if present
photo_id_series = photo_id_series.str.split(".", n=1).str[0]  # drop trailing ".0" etc (common if numeric CSV)
pad_len = int(photo_id_series.str.len().max()) if len(photo_id_series) else 0  # infer max length
pad_len = max(pad_len, 4)  # default to 4 (matches your example like "0021")
print(f"Using zero-pad length = {pad_len}")  # show chosen padding

def normalize_photo_id(photo_id, pad_length):  # define normalizer
    pid = str(photo_id).strip()  # convert to string and trim spaces
    pid = pid.replace(".png", "")  # remove .png if included
    pid = pid.split(".", 1)[0]  # remove any trailing decimals (e.g., "21.0" -> "21")
    if pid.isdigit():  # only pad if it's purely digits
        pid = pid.zfill(pad_length)  # left-pad with zeros
    return pid  # return normalized id like "0021"

# -----------------------------------------
# Helper: read mask PNG from S3 into boolean
# -----------------------------------------

def load_mask_bool_from_s3(bucket, key):  # function to load a mask file
    print(f"    Downloading: s3://{bucket}/{key}")  # track downloads
    obj = s3.get_object(Bucket=bucket, Key=key)  # fetch object bytes from S3
    img = Image.open(BytesIO(obj["Body"].read()))  # open image from bytes
    img = img.convert("L")  # convert to grayscale
    arr = np.array(img)  # convert to numpy array
    mask_bool = arr > 0  # treat any non-zero pixel as "body"
    return mask_bool  # return boolean mask

# -----------------------------------------
# Helper: compute mean width across rows
# -----------------------------------------

def mean_row_width(mask_bool):  # compute average body width across horizontal rows
    if mask_bool.size == 0:  # guard: empty image
        return np.nan  # cannot compute
    row_has_body = mask_bool.any(axis=1)  # rows where body exists
    if not row_has_body.any():  # guard: no body pixels
        return np.nan  # cannot compute
    first = mask_bool.argmax(axis=1)  # first True index per row (0 if none)
    last = mask_bool.shape[1] - 1 - np.flip(mask_bool, axis=1).argmax(axis=1)  # last True index per row
    widths = (last - first + 1).astype(float)  # width per row (in pixels)
    widths[~row_has_body] = np.nan  # ignore rows with no body
    return float(np.nanmean(widths))  # average width across valid rows

# -----------------------------------------
# Helper: compute height from front mask
# -----------------------------------------

def body_height(mask_bool):  # compute vertical extent (top-to-bottom)
    if mask_bool.size == 0:  # guard: empty image
        return np.nan  # cannot compute
    ys, xs = np.where(mask_bool)  # get coordinates of body pixels
    if ys.size == 0:  # guard: no body pixels
        return np.nan  # cannot compute
    h = (ys.max() - ys.min() + 1).astype(float)  # height in pixels
    return float(h)  # return height

# -----------------------------------------
# Per-record feature computation
# -----------------------------------------

def compute_volume_for_photo_id(photo_id):  # compute volume + debug parts for one record
    pid = normalize_photo_id(photo_id, pad_len)  # normalize id to match PNG filename
    front_key = f"{FRONT_MASK_PREFIX}{pid}.png"  # build front mask key
    side_key = f"{SIDE_MASK_PREFIX}{pid}.png"  # build side mask key

    try:
        front_mask = load_mask_bool_from_s3(MASK_BUCKET, front_key)  # load front mask
    except ClientError as e:  # handle missing front file
        print(f"    ERROR: missing front mask for {pid}: {e}")  # print error
        return np.nan, np.nan, np.nan, np.nan  # return NaNs

    try:
        side_mask = load_mask_bool_from_s3(MASK_BUCKET, side_key)  # load side mask
    except ClientError as e:  # handle missing side file
        print(f"    ERROR: missing side mask for {pid}: {e}")  # print error
        return np.nan, np.nan, np.nan, np.nan  # return NaNs

    front_w = mean_row_width(front_mask)  # front width (body looks wide from front)
    side_w = mean_row_width(side_mask)  # side width (body looks thick from side)
    avg_w = (front_w + side_w) / 2.0  # average width as instructed
    h = body_height(front_mask)  # height from front mask (vertical extent)

    raw_volume = avg_w * h  # volume ≈ average width × height
    norm_volume = raw_volume / (h ** 2) if (h is not None and not np.isnan(h) and h > 0) else np.nan  # normalize

    return norm_volume, front_w, side_w, h  # return volume + components for debugging

# -----------------------------------------
# Run across the dataframe and add column(s)
# -----------------------------------------

print("Starting volume computation for all records...")  # track progress
volumes = []  # store normalized volumes
front_ws = []  # store front widths (debug)
side_ws = []  # store side widths (debug)
heights = []  # store heights (debug)

n = len(data)  # total rows
print(f"Total rows to process: {n}")  # show total

for i, photo_id in enumerate(data[PHOTO_ID_COL].tolist(), start=1):  # iterate through photo_ids
    print(f"\nRecord {i}/{n} | photo_id={photo_id}")  # show per-record progress
    v, fw, sw, h = compute_volume_for_photo_id(photo_id)  # compute features
    print(f"    front_width={fw} | side_width={sw} | height={h} | volume={v}")  # print computed values
    volumes.append(v)  # append volume
    front_ws.append(fw)  # append front width
    side_ws.append(sw)  # append side width
    heights.append(h)  # append height

    if i % 50 == 0:  # every 50 rows
        print(f"\nProcessed {i}/{n} records so far...")  # periodic progress update

print("\nAttaching new feature columns to dataframe...")  # track progress
data[OUTPUT_COL] = volumes  # add normalized volume feature
data["front_width"] = front_ws  # optional debug column
data["side_width"] = side_ws  # optional debug column
data["mask_height"] = heights  # optional debug column

print("Done.")  # final status
print("Preview of updated dataframe:")  # show preview message
print(data[[PHOTO_ID_COL, OUTPUT_COL, "front_width", "side_width", "mask_height"]].head())  # preview new columns
# Out:
# Creating S3 client...
# Inferring photo_id padding length...
# Using zero-pad length = 32
# Starting volume computation for all records...
# Total rows to process: 1684
#
# Record 1/1684 | photo_id=e5ae8fe5bbdf611a1e8d06e66e849bdf
#     Downloading: s3://amazon-bodym/testA/mask/e5ae8fe5bbdf611a1e8d06e66e849bdf.png
#     Downloading: s3://amazon-bodym/testA/mask_left/e5ae8fe5bbdf611a1e8d06e66e849bdf.png
#     front_width=233.10262529832934 | side_width=108.52017448200654 | height=838.0 | volume=0.2038322194393412
#
# Record 2/1684 | photo_id=605a5fd09058c48156b0ef518b63b2de
#     Downloading: s3://amazon-bodym/testA/mask/605a5fd09058c48156b0ef518b63b2de.png
#     Downloading: s3://amazon-bodym/testA/mask_left/605a5fd09058c48156b0ef518b63b2de.png
#     front_width=163.38773006134969 | side_width=121.27625570776256 | height=815.0 | volume=0.17464048206694002
#
# Record 3/1684 | photo_id=909c9277309e13ee014e347603aba620
#     Downloading: s3://amazon-bodym/testA/mask/909c9277309e13ee014e347603aba620.png
#     Downloading: s3://amazon-bodym/testA/mask_left/909c9277309e13ee014e347603aba620.png
#     front_width=177.39048811013768 | side_width=92.15995397008055 | height=799.0 | volume=0.16867987614531801
#
# Record 4/1684 | photo_id=bef6a68bc8dd475c124f6de2413385d3
#     Downloading: s3://amazon-bodym/testA/mask/bef6a68bc8dd475c124f6de2413385d3.png
#     Downloading: s3://amazon-bodym/testA/mask_left/bef6a68bc8dd475c124f6de2413385d3.png
#     front_width=207.5169194865811 | side_width=103.89003436426117 | height=857.0 | volume=0.18168433713584728
#
# Record 5/1684 | photo_id=6d7ed4bc4a17546447efed0ca6e2ff11
#     Downloading: s3://amazon-bodym/testA/mask/6d7ed4bc4a17546447efed0ca6e2ff11.png
#     Downloading: s3://amazon-bodym/testA/mask_left/6d7ed4bc4a17546447efed0ca6e2ff11.png
#     front_width=218.20933014354068 | side_width=93.89707602339182 | height=836.0 | volume=0.18666651086539027
#
# Record 6/1684 | photo_id=4c12d6a82cb0a75ee556a54ab1afc21e
#     Downloading: s3://amazon-bodym/testA/mask/4c12d6a82cb0a75ee556a54ab1afc21e.png
#     Downloading: s3://amazon-bodym/testA/mask_left/4c12d6a82cb0a75ee556a54ab1afc21e.png
#     front_width=209.1263537906137 | side_width=110.64269911504425 | height=831.0 | volume=0.19240015216946932
#
# Record 7/1684 | photo_id=dd27be8b3d6b9c2c14c14318612ba0dc
#     Downloading: s3://amazon-bodym/testA/mask/dd27be8b3d6b9c2c14c14318612ba0dc.png
#     Downloading: s3://amazon-bodym/testA/mask_left/dd27be8b3d6b9c2c14c14318612ba0dc.png
#     front_width=224.66105499438834 | side_width=96.59164733178655 | height=891.0 | volume=0.18027648839852684
#
# Record 8/1684 | photo_id=fc65b84d8183e3a872785b4e2eecaa66
#     Downloading: s3://amazon-bodym/testA/mask/fc65b84d8183e3a872785b4e2eecaa66.png
#     Downloading: s3://amazon-bodym/testA/mask_left/fc65b84d8183e3a872785b4e2eecaa66.png
#     front_width=229.9547619047619 | side_width=94.7217598097503 | height=840.0 | volume=0.1932598343538763
#
# Record 9/1684 | photo_id=851f712c7cfc6b62b20b6f8cba65c20a
#     Downloading: s3://amazon-bodym/testA/mask/851f712c7cfc6b62b20b6f8cba65c20a.png
#     Downloading: s3://amazon-bodym/testA/mask_left/851f712c7cfc6b62b20b6f8cba65c20a.png
#     front_width=208.38505096262742 | side_width=88.98522727272727 | height=883.0 | volume=0.16838634101662214
#
# Record 10/1684 | photo_id=c9ede0a19f8e79ec7a4cd8f126129f2d
#     Downloading: s3://amazon-bodym/testA/mask/c9ede0a19f8e79ec7a4cd8f126129f2d.png
#     Downloading: s3://amazon-bodym/testA/mask_left/c9ede0a19f8e79ec7a4cd8f126129f2d.png
#     front_width=228.95710784313727 | side_width=106.46127167630058 | height=816.0 | volume=0.2055259678427928
#
# Record 11/1684 | photo_id=652500aa90597ed06ccc8f15bc9b83aa
#     Downloading: s3://amazon-bodym/testA/mask/652500aa90597ed06ccc8f15bc9b83aa.png
#     Downloading: s3://amazon-bodym/testA/mask_left/652500aa90597ed06ccc8f15bc9b83aa.png
#     front_width=221.51243781094527 | side_width=93.63058035714286 | height=805.0 | volume=0.19574100507334666
#
# Record 12/1684 | photo_id=b55e0664c7c1642cd015b5585a8d5fd3
#     Downloading: s3://amazon-bodym/testA/mask/b55e0664c7c1642cd015b5585a8d5fd3.png
#     Downloading: s3://amazon-bodym/testA/mask_left/b55e0664c7c1642cd015b5585a8d5fd3.png
#     front_width=167.661800486618 | side_width=108.87444444444445 | height=822.0 | volume=0.16820939472692364
#
# Record 13/1684 | photo_id=67194d8a47331d1f722db4f737546021
#     Downloading: s3://amazon-bodym/testA/mask/67194d8a47331d1f722db4f737546021.png
#     Downloading: s3://amazon-bodym/testA/mask_left/67194d8a47331d1f722db4f737546021.png
#     front_width=217.9051724137931 | side_width=104.03611738148985 | height=812.0 | volume=0.1982397104650757
#
# Record 14/1684 | photo_id=719fc866000f5edb56700ee0755ea109
#     Downloading: s3://amazon-bodym/testA/mask/719fc866000f5edb56700ee0755ea109.png
#     Downloading: s3://amazon-bodym/testA/mask_left/719fc866000f5edb56700ee0755ea109.png
#     front_width=231.40872560275545 | side_width=99.45804195804196 | height=871.0 | volume=0.18993499859976892
#
# Record 15/1684 | photo_id=46c5d36f10af6cf0fd2b4a02eb9a9add
#     Downloading: s3://amazon-bodym/testA/mask/46c5d36f10af6cf0fd2b4a02eb9a9add.png
#     Downloading: s3://amazon-bodym/testA/mask_left/46c5d36f10af6cf0fd2b4a02eb9a9add.png
#     front_width=208.0801944106926 | side_width=100.353616532721 | height=823.0 | volume=0.18738384625966806
#
# Record 16/1684 | photo_id=e1a3c3b6df492a58fde15be36a8371bc
#     Downloading: s3://amazon-bodym/testA/mask/e1a3c3b6df492a58fde15be36a8371bc.png
#     Downloading: s3://amazon-bodym/testA/mask_left/e1a3c3b6df492a58fde15be36a8371bc.png
#     front_width=218.93825665859563 | side_width=110.85762711864406 | height=826.0 | volume=0.19963431221382547
#
# Record 17/1684 | photo_id=7ac05db49a083076cb5ed077f16b90e0
#     Downloading: s3://amazon-bodym/testA/mask/7ac05db49a083076cb5ed077f16b90e0.png
#     Downloading: s3://amazon-bodym/testA/mask_left/7ac05db49a083076cb5ed077f16b90e0.png
#     front_width=219.70755885997522 | side_width=96.78436018957346 | height=807.0 | volume=0.1960916474904267
#
# Record 18/1684 | photo_id=7e1e1d9f8724124bcae0a945c3c324cc
#     Downloading: s3://amazon-bodym/testA/mask/7e1e1d9f8724124bcae0a945c3c324cc.png
#     Downloading: s3://amazon-bodym/testA/mask_left/7e1e1d9f8724124bcae0a945c3c324cc.png
#     front_width=224.73634204275535 | side_width=87.76733254994124 | height=842.0 | volume=0.18557225332107877
#
# Record 19/1684 | photo_id=b5876de60bcfdb5600aade28cc554c52
#     Downloading: s3://amazon-bodym/testA/mask/b5876de60bcfdb5600aade28cc554c52.png
#     Downloading: s3://amazon-bodym/testA/mask_left/b5876de60bcfdb5600aade28cc554c52.png
#     front_width=217.70742857142858 | side_width=88.58968609865471 | height=875.0 | volume=0.175026922668619
#
# Record 20/1684 | photo_id=1c6fe922a59a5b63ec8c0e2264eb49af
#     Downloading: s3://amazon-bodym/testA/mask/1c6fe922a59a5b63ec8c0e2264eb49af.png
#     Downloading: s3://amazon-bodym/testA/mask_left/1c6fe922a59a5b63ec8c0e2264eb49af.png
#     front_width=210.79106280193236 | side_width=89.07888349514563 | height=828.0 | volume=0.1810808854450954
#
# Record 21/1684 | photo_id=09735076f4d5e0fdbc4c883a3ec74072
#     Downloading: s3://amazon-bodym/testA/mask/09735076f4d5e0fdbc4c883a3ec74072.png
#     Downloading: s3://amazon-bodym/testA/mask_left/09735076f4d5e0fdbc4c883a3ec74072.png
#     front_width=200.8228155339806 | side_width=95.87155963302752 | height=824.0 | volume=0.18003299464017483
#
# Record 22/1684 | photo_id=2e2c6428f26c80bf286b854fe851b518
#     Downloading: s3://amazon-bodym/testA/mask/2e2c6428f26c80bf286b854fe851b518.png
#     Downloading: s3://amazon-bodym/testA/mask_left/2e2c6428f26c80bf286b854fe851b518.png
#     front_width=214.82415005861665 | side_width=98.44646924829158 | height=853.0 | volume=0.18362873347415487
#
# Record 23/1684 | photo_id=a7cc758a534dedded8604cea3a52b681
#     Downloading: s3://amazon-bodym/testA/mask/a7cc758a534dedded8604cea3a52b681.png
#     Downloading: s3://amazon-bodym/testA/mask_left/a7cc758a534dedded8604cea3a52b681.png
#     front_width=190.2810615199035 | side_width=106.62405200433369 | height=829.0 | volume=0.1790742542365725
#
# Record 24/1684 | photo_id=a49e4915a40d206006fe883bcada4088
#     Downloading: s3://amazon-bodym/testA/mask/a49e4915a40d206006fe883bcada4088.png
#     Downloading: s3://amazon-bodym/testA/mask_left/a49e4915a40d206006fe883bcada4088.png
#     front_width=197.09699769053117 | side_width=98.53167420814479 | height=866.0 | volume=0.1706863001724457
#
# Record 25/1684 | photo_id=6e567773d006c757fa8fb750201eecb2
#     Downloading: s3://amazon-bodym/testA/mask/6e567773d006c757fa8fb750201eecb2.png
#     Downloading: s3://amazon-bodym/testA/mask_left/6e567773d006c757fa8fb750201eecb2.png
#     front_width=200.68665850673196 | side_width=99.00951248513674 | height=817.0 | volume=0.18341258934630889
#
# Record 26/1684 | photo_id=0d89f5b1adb8b5c0d52fead18a8aca86
#     Downloading: s3://amazon-bodym/testA/mask/0d89f5b1adb8b5c0d52fead18a8aca86.png
#     Downloading: s3://amazon-bodym/testA/mask_left/0d89f5b1adb8b5c0d52fead18a8aca86.png
#     front_width=214.89320388349515 | side_width=99.2020905923345 | height=824.0 | volume=0.19059180490038208
#
# Record 27/1684 | photo_id=90e3d2a537e221c3d009bbfd76c31781
#     Downloading: s3://amazon-bodym/testA/mask/90e3d2a537e221c3d009bbfd76c31781.png
#     Downloading: s3://amazon-bodym/testA/mask_left/90e3d2a537e221c3d009bbfd76c31781.png
#     front_width=228.58053691275168 | side_width=94.02112676056338 | height=894.0 | volume=0.18042598639447152
#
# Record 28/1684 | photo_id=1ea5a5846c1e4876aeef5e5df54493fb
#     Downloading: s3://amazon-bodym/testA/mask/1ea5a5846c1e4876aeef5e5df54493fb.png
#     Downloading: s3://amazon-bodym/testA/mask_left/1ea5a5846c1e4876aeef5e5df54493fb.png
#     front_width=193.61709601873537 | side_width=110.85148514851485 | height=854.0 | volume=0.17826029342344862
#
# Record 29/1684 | photo_id=cc30e4cf064a73a33f49f98502659453
#     Downloading: s3://amazon-bodym/testA/mask/cc30e4cf064a73a33f49f98502659453.png
#     Downloading: s3://amazon-bodym/testA/mask_left/cc30e4cf064a73a33f49f98502659453.png
#     front_width=193.0035335689046 | side_width=78.3594470046083 | height=849.0 | volume=0.15981329833540217
#
# Record 30/1684 | photo_id=783223cf280aeb356e61a58a8ecfffea
#     Downloading: s3://amazon-bodym/testA/mask/783223cf280aeb356e61a58a8ecfffea.png
#     Downloading: s3://amazon-bodym/testA/mask_left/783223cf280aeb356e61a58a8ecfffea.png
#     front_width=174.5716034271726 | side_width=94.07675194660735 | height=817.0 | volume=0.16441147819692778
#
# Record 31/1684 | photo_id=0aad7e8a4987342302961aa4cc0ccbed
#     Downloading: s3://amazon-bodym/testA/mask/0aad7e8a4987342302961aa4cc0ccbed.png
#     Downloading: s3://amazon-bodym/testA/mask_left/0aad7e8a4987342302961aa4cc0ccbed.png
#     front_width=195.0815286624204 | side_width=109.57300884955752 | height=785.0 | volume=0.19404747612227893
#
# Record 32/1684 | photo_id=8bfd63f2d47016a1a03ad5dcdb11a844
#     Downloading: s3://amazon-bodym/testA/mask/8bfd63f2d47016a1a03ad5dcdb11a844.png
#     Downloading: s3://amazon-bodym/testA/mask_left/8bfd63f2d47016a1a03ad5dcdb11a844.png
#     front_width=189.60321384425217 | side_width=96.2098623853211 | height=809.0 | volume=0.17664590619874737
#
# Record 33/1684 | photo_id=5310a6a41e39c0cc8670d12c0330796a
#     Downloading: s3://amazon-bodym/testA/mask/5310a6a41e39c0cc8670d12c0330796a.png
#     Downloading: s3://amazon-bodym/testA/mask_left/5310a6a41e39c0cc8670d12c0330796a.png
#     front_width=190.54370034052212 | side_width=94.50784077201448 | height=881.0 | volume=0.16177726510359625
#
# Record 34/1684 | photo_id=33130c0719c02d71be90ddf431943b73
#     Downloading: s3://amazon-bodym/testA/mask/33130c0719c02d71be90ddf431943b73.png
#     Downloading: s3://amazon-bodym/testA/mask_left/33130c0719c02d71be90ddf431943b73.png
#     front_width=213.08690330477356 | side_width=116.4475201845444 | height=817.0 | volume=0.20167345378783233
#
# Record 35/1684 | photo_id=fe5068eb0602ffa458cd43c689ad2c94
#     Downloading: s3://amazon-bodym/testA/mask/fe5068eb0602ffa458cd43c689ad2c94.png
#     Downloading: s3://amazon-bodym/testA/mask_left/fe5068eb0602ffa458cd43c689ad2c94.png
#     front_width=239.64046242774566 | side_width=101.77038626609442 | height=865.0 | volume=0.19734731138372258
#
# Record 36/1684 | photo_id=dea8deceafe67f7dfeafcc9030cb71be
#     Downloading: s3://amazon-bodym/testA/mask/dea8deceafe67f7dfeafcc9030cb71be.png
#     Downloading: s3://amazon-bodym/testA/mask_left/dea8deceafe67f7dfeafcc9030cb71be.png
#     front_width=197.544794188862 | side_width=89.0264064293915 | height=826.0 | volume=0.1734692497689186
#
# Record 37/1684 | photo_id=cbd9cba29a166e7e53067c72dfe5a397
#     Downloading: s3://amazon-bodym/testA/mask/cbd9cba29a166e7e53067c72dfe5a397.png
#     Downloading: s3://amazon-bodym/testA/mask_left/cbd9cba29a166e7e53067c72dfe5a397.png
#     front_width=193.45397225725094 | side_width=89.78155339805825 | height=793.0 | volume=0.17858482071583176
#
# Record 38/1684 | photo_id=f5acb42eed491bba2cd7f7deeca73577
#     Downloading: s3://amazon-bodym/testA/mask/f5acb42eed491bba2cd7f7deeca73577.png
#     Downloading: s3://amazon-bodym/testA/mask_left/f5acb42eed491bba2cd7f7deeca73577.png
#     front_width=178.50669914738125 | side_width=105.0 | height=821.0 | volume=0.1726593782870775
#
# Record 39/1684 | photo_id=83c16a5818cd82c37d8f72ebbdf2938b
#     Downloading: s3://amazon-bodym/testA/mask/83c16a5818cd82c37d8f72ebbdf2938b.png
#     Downloading: s3://amazon-bodym/testA/mask_left/83c16a5818cd82c37d8f72ebbdf2938b.png
#     front_width=198.66825208085612 | side_width=90.25795053003533 | height=841.0 | volume=0.1717753879969628
#
# Record 40/1684 | photo_id=4a3d5b8a392fab125e0591960e0e0c15
#     Downloading: s3://amazon-bodym/testA/mask/4a3d5b8a392fab125e0591960e0e0c15.png
#     Downloading: s3://amazon-bodym/testA/mask_left/4a3d5b8a392fab125e0591960e0e0c15.png
#     front_width=244.40968122786305 | side_width=132.99665178571428 | height=847.0 | volume=0.22279004310128528
#
# Record 41/1684 | photo_id=8115f0ec6fa7e8fc12e918c5caaf3c9a
#     Downloading: s3://amazon-bodym/testA/mask/8115f0ec6fa7e8fc12e918c5caaf3c9a.png
#     Downloading: s3://amazon-bodym/testA/mask_left/8115f0ec6fa7e8fc12e918c5caaf3c9a.png
#     front_width=248.23556058890148 | side_width=114.03107019562715 | height=883.0 | volume=0.2051339925167206
#
# Record 42/1684 | photo_id=57adf42d38fd1a6683bf3c46a547847a
#     Downloading: s3://amazon-bodym/testA/mask/57adf42d38fd1a6683bf3c46a547847a.png
#     Downloading: s3://amazon-bodym/testA/mask_left/57adf42d38fd1a6683bf3c46a547847a.png
#     front_width=188.2851662404092 | side_width=91.07870370370371 | height=782.0 | volume=0.17862140022002107
#
# Record 43/1684 | photo_id=4e9bf0300f31f1335f938643220f81f5
#     Downloading: s3://amazon-bodym/testA/mask/4e9bf0300f31f1335f938643220f81f5.png
#     Downloading: s3://amazon-bodym/testA/mask_left/4e9bf0300f31f1335f938643220f81f5.png
#     front_width=192.86162790697674 | side_width=140.55741360089186 | height=860.0 | volume=0.19384827994643525
#
# Record 44/1684 | photo_id=d00150c491b8faa77a5cb9bd8422029e
#     Downloading: s3://amazon-bodym/testA/mask/d00150c491b8faa77a5cb9bd8422029e.png
#     Downloading: s3://amazon-bodym/testA/mask_left/d00150c491b8faa77a5cb9bd8422029e.png
#     front_width=211.7873357228196 | side_width=91.4709236031927 | height=837.0 | volume=0.18115786100717582
#
# Record 45/1684 | photo_id=71affd9167bebfa3402da73d5b02036c
#     Downloading: s3://amazon-bodym/testA/mask/71affd9167bebfa3402da73d5b02036c.png
#     Downloading: s3://amazon-bodym/testA/mask_left/71affd9167bebfa3402da73d5b02036c.png
#     front_width=243.37543859649122 | side_width=91.14665127020785 | height=855.0 | volume=0.1956269531384205
#
# Record 46/1684 | photo_id=8947ac15cbf9a90c47495d2f9aa1fe0c
#     Downloading: s3://amazon-bodym/testA/mask/8947ac15cbf9a90c47495d2f9aa1fe0c.png
#     Downloading: s3://amazon-bodym/testA/mask_left/8947ac15cbf9a90c47495d2f9aa1fe0c.png
#     front_width=204.3631713554987 | side_width=93.24381625441696 | height=782.0 | volume=0.19028579770454965
#
# Record 47/1684 | photo_id=a32ee410d093b47d1b29574593513f6e
#     Downloading: s3://amazon-bodym/testA/mask/a32ee410d093b47d1b29574593513f6e.png
#     Downloading: s3://amazon-bodym/testA/mask_left/a32ee410d093b47d1b29574593513f6e.png
#     front_width=203.0060606060606 | side_width=85.03058823529412 | height=825.0 | volume=0.17456766596445739
#
# Record 48/1684 | photo_id=98219e748c76cdb3e827505d154db8de
#     Downloading: s3://amazon-bodym/testA/mask/98219e748c76cdb3e827505d154db8de.png
#     Downloading: s3://amazon-bodym/testA/mask_left/98219e748c76cdb3e827505d154db8de.png
#     front_width=192.70898203592813 | side_width=87.85315533980582 | height=835.0 | volume=0.16800127986570895
#
# Record 49/1684 | photo_id=256a73e60cb5fa2706be990b7fc7f6f9
#     Downloading: s3://amazon-bodym/testA/mask/256a73e60cb5fa2706be990b7fc7f6f9.png
#     Downloading: s3://amazon-bodym/testA/mask_left/256a73e60cb5fa2706be990b7fc7f6f9.png
#     front_width=197.76887340301974 | side_width=109.57300884955752 | height=861.0 | volume=0.1784796064184537
#
# Record 50/1684 | photo_id=20192a081a6e6cc01e7388070cd12441
#     Downloading: s3://amazon-bodym/testA/mask/20192a081a6e6cc01e7388070cd12441.png
#     Downloading: s3://amazon-bodym/testA/mask_left/20192a081a6e6cc01e7388070cd12441.png
#     front_width=215.92557022809123 | side_width=94.02144469525959 | height=833.0 | volume=0.18604262600441226
#
# Processed 50/1684 records so far...
#
# Record 51/1684 | photo_id=824c5dbd22639b8a4f4130f3e53eaa55
#     Downloading: s3://amazon-bodym/testA/mask/824c5dbd22639b8a4f4130f3e53eaa55.png
#     Downloading: s3://amazon-bodym/testA/mask_left/824c5dbd22639b8a4f4130f3e53eaa55.png
#     front_width=230.4126984126984 | side_width=107.27542857142858 | height=819.0 | volume=0.2061588076826172
#
# Record 52/1684 | photo_id=f3fac2f83e7c2571c2769b0e9fdcf4f6
#     Downloading: s3://amazon-bodym/testA/mask/f3fac2f83e7c2571c2769b0e9fdcf4f6.png
#     Downloading: s3://amazon-bodym/testA/mask_left/f3fac2f83e7c2571c2769b0e9fdcf4f6.png
#     front_width=191.79854368932038 | side_width=89.23663253697383 | height=824.0 | volume=0.1705310535353727
#
# Record 53/1684 | photo_id=a78989815ffd2c907a4d3dd91c87364d
#     Downloading: s3://amazon-bodym/testA/mask/a78989815ffd2c907a4d3dd91c87364d.png
#     Downloading: s3://amazon-bodym/testA/mask_left/a78989815ffd2c907a4d3dd91c87364d.png
#     front_width=188.92093023255813 | side_width=83.35093896713614 | height=860.0 | volume=0.1582975983719153
#
# Record 54/1684 | photo_id=b87928100a9d9230a4623019f049184c
#     Downloading: s3://amazon-bodym/testA/mask/b87928100a9d9230a4623019f049184c.png
#     Downloading: s3://amazon-bodym/testA/mask_left/b87928100a9d9230a4623019f049184c.png
#     front_width=174.73451327433628 | side_width=93.27114716106605 | height=791.0 | volume=0.16940939344842118
#
# Record 55/1684 | photo_id=79a86609427b81242f8555822d749455
#     Downloading: s3://amazon-bodym/testA/mask/79a86609427b81242f8555822d749455.png
#     Downloading: s3://amazon-bodym/testA/mask_left/79a86609427b81242f8555822d749455.png
#     front_width=193.04142011834318 | side_width=94.11188004613611 | height=845.0 | volume=0.1699131953635972
#
# Record 56/1684 | photo_id=dd886c6903c81753f0230763eded1ff5
#     Downloading: s3://amazon-bodym/testA/mask/dd886c6903c81753f0230763eded1ff5.png
#     Downloading: s3://amazon-bodym/testA/mask_left/dd886c6903c81753f0230763eded1ff5.png
#     front_width=272.2927927927928 | side_width=98.06354515050167 | height=888.0 | volume=0.2085339740671703
#
# Record 57/1684 | photo_id=766cc99f817262d0ab3a7b15ce46b517
#     Downloading: s3://amazon-bodym/testA/mask/766cc99f817262d0ab3a7b15ce46b517.png
#     Downloading: s3://amazon-bodym/testA/mask_left/766cc99f817262d0ab3a7b15ce46b517.png
#     front_width=216.4550898203593 | side_width=89.12653975363942 | height=835.0 | volume=0.18298301172095732
#
# Record 58/1684 | photo_id=71d1954e34fc0385e30bb07837345c73
#     Downloading: s3://amazon-bodym/testA/mask/71d1954e34fc0385e30bb07837345c73.png
#     Downloading: s3://amazon-bodym/testA/mask_left/71d1954e34fc0385e30bb07837345c73.png
#     front_width=264.84260355029585 | side_width=128.17588495575222 | height=845.0 | volume=0.232555318642632
#
# Record 59/1684 | photo_id=8cb7b3074fb5fd67dc019aaddfad8995
#     Downloading: s3://amazon-bodym/testA/mask/8cb7b3074fb5fd67dc019aaddfad8995.png
#     Downloading: s3://amazon-bodym/testA/mask_left/8cb7b3074fb5fd67dc019aaddfad8995.png
#     front_width=190.6455399061033 | side_width=116.31887201735358 | height=852.0 | volume=0.18014343422738077
#
# Record 60/1684 | photo_id=1b57988171874d8fae376d94f4dc7f65
#     Downloading: s3://amazon-bodym/testA/mask/1b57988171874d8fae376d94f4dc7f65.png
#     Downloading: s3://amazon-bodym/testA/mask_left/1b57988171874d8fae376d94f4dc7f65.png
#     front_width=226.481351981352 | side_width=95.05274971941638 | height=858.0 | volume=0.1873741851403079
#
# Record 61/1684 | photo_id=c050dd0ace9a5383945212717ecdd7cb
#     Downloading: s3://amazon-bodym/testA/mask/c050dd0ace9a5383945212717ecdd7cb.png
#     Downloading: s3://amazon-bodym/testA/mask_left/c050dd0ace9a5383945212717ecdd7cb.png
#     front_width=239.6558752997602 | side_width=95.5196662693683 | height=834.0 | volume=0.20094456928604826
#
# Record 62/1684 | photo_id=36ca064832f9a878db0277152eeaac78
#     Downloading: s3://amazon-bodym/testA/mask/36ca064832f9a878db0277152eeaac78.png
#     Downloading: s3://amazon-bodym/testA/mask_left/36ca064832f9a878db0277152eeaac78.png
#     front_width=167.02173913043478 | side_width=96.720245398773 | height=782.0 | volume=0.16863298243555486
#
# Record 63/1684 | photo_id=d1fe80a5728534da8a03f07e79fda8e0
#     Downloading: s3://amazon-bodym/testA/mask/d1fe80a5728534da8a03f07e79fda8e0.png
#     Downloading: s3://amazon-bodym/testA/mask_left/d1fe80a5728534da8a03f07e79fda8e0.png
#     front_width=185.51030927835052 | side_width=89.35956416464892 | height=776.0 | volume=0.17710687721842747
#
# Record 64/1684 | photo_id=417335e9cf581a470cd91ec27728b379
#     Downloading: s3://amazon-bodym/testA/mask/417335e9cf581a470cd91ec27728b379.png
#     Downloading: s3://amazon-bodym/testA/mask_left/417335e9cf581a470cd91ec27728b379.png
#     front_width=209.07682775712516 | side_width=95.77324263038548 | height=807.0 | volume=0.18887860618804872
#
# Record 65/1684 | photo_id=472f1416a2b2a909766e386b50ca2dac
#     Downloading: s3://amazon-bodym/testA/mask/472f1416a2b2a909766e386b50ca2dac.png
#     Downloading: s3://amazon-bodym/testA/mask_left/472f1416a2b2a909766e386b50ca2dac.png
#     front_width=226.260391198044 | side_width=94.57541899441341 | height=818.0 | volume=0.19610990843059745
#
# Record 66/1684 | photo_id=ef16063594ff7d74d9feaa94ba636085
#     Downloading: s3://amazon-bodym/testA/mask/ef16063594ff7d74d9feaa94ba636085.png
#     Downloading: s3://amazon-bodym/testA/mask_left/ef16063594ff7d74d9feaa94ba636085.png
#     front_width=196.33008526187575 | side_width=90.31937799043062 | height=821.0 | volume=0.17457336373465673
#
# Record 67/1684 | photo_id=e5f5b7e98e478b23b3be8bf6678c1f0c
#     Downloading: s3://amazon-bodym/testA/mask/e5f5b7e98e478b23b3be8bf6678c1f0c.png
#     Downloading: s3://amazon-bodym/testA/mask_left/e5f5b7e98e478b23b3be8bf6678c1f0c.png
#     front_width=220.31674757281553 | side_width=90.77197149643706 | height=824.0 | volume=0.18876742661969212
#
# Record 68/1684 | photo_id=d97172a35c4ac9a3045632fb61c6cc24
#     Downloading: s3://amazon-bodym/testA/mask/d97172a35c4ac9a3045632fb61c6cc24.png
#     Downloading: s3://amazon-bodym/testA/mask_left/d97172a35c4ac9a3045632fb61c6cc24.png
#     front_width=244.67005649717515 | side_width=120.40520833333333 | height=885.0 | volume=0.20625721176864886
#
# Record 69/1684 | photo_id=3b75777e48c78b066cb696ecdb516d4c
#     Downloading: s3://amazon-bodym/testA/mask/3b75777e48c78b066cb696ecdb516d4c.png
#     Downloading: s3://amazon-bodym/testA/mask_left/3b75777e48c78b066cb696ecdb516d4c.png
#     front_width=227.152 | side_width=91.14665127020785 | height=875.0 | volume=0.18188494358297594
#
# Record 70/1684 | photo_id=90f1b79c16714fe22765b5c0961e23c3
#     Downloading: s3://amazon-bodym/testA/mask/90f1b79c16714fe22765b5c0961e23c3.png
#     Downloading: s3://amazon-bodym/testA/mask_left/90f1b79c16714fe22765b5c0961e23c3.png
#     front_width=235.85106382978722 | side_width=114.33295454545454 | height=846.0 | volume=0.20696454986716414
#
# Record 71/1684 | photo_id=10c266033125c4d63763ad2e6cebcafd
#     Downloading: s3://amazon-bodym/testA/mask/10c266033125c4d63763ad2e6cebcafd.png
#     Downloading: s3://amazon-bodym/testA/mask_left/10c266033125c4d63763ad2e6cebcafd.png
#     front_width=190.71623155505108 | side_width=99.49783080260303 | height=881.0 | volume=0.1647071863550818
#
# Record 72/1684 | photo_id=462abfea634b872431f903ccd04acdd0
#     Downloading: s3://amazon-bodym/testA/mask/462abfea634b872431f903ccd04acdd0.png
#     Downloading: s3://amazon-bodym/testA/mask_left/462abfea634b872431f903ccd04acdd0.png
#     front_width=217.98673100120627 | side_width=91.40899122807018 | height=829.0 | volume=0.18660779386566734
#
# Record 73/1684 | photo_id=42fa5fb5e0a3116a04abcfb82f7c67b1
#     Downloading: s3://amazon-bodym/testA/mask/42fa5fb5e0a3116a04abcfb82f7c67b1.png
#     Downloading: s3://amazon-bodym/testA/mask_left/42fa5fb5e0a3116a04abcfb82f7c67b1.png
#     front_width=228.04439252336448 | side_width=108.77113866967305 | height=856.0 | volume=0.19673804392116678
#
# Record 74/1684 | photo_id=dbd4a212cb17546bf43377ce79487281
#     Downloading: s3://amazon-bodym/testA/mask/dbd4a212cb17546bf43377ce79487281.png
#     Downloading: s3://amazon-bodym/testA/mask_left/dbd4a212cb17546bf43377ce79487281.png
#     front_width=198.5683192261185 | side_width=89.0264064293915 | height=827.0 | volume=0.1738783105535127
#
# Record 75/1684 | photo_id=e512188a6ea3ce68cb894778c73946b9
#     Downloading: s3://amazon-bodym/testA/mask/e512188a6ea3ce68cb894778c73946b9.png
#     Downloading: s3://amazon-bodym/testA/mask_left/e512188a6ea3ce68cb894778c73946b9.png
#     front_width=185.27926829268293 | side_width=94.97942857142857 | height=820.0 | volume=0.17088944930738506
#
# Record 76/1684 | photo_id=a9d9d3ece5dbd60aa4a297bfcd60abc6
#     Downloading: s3://amazon-bodym/testA/mask/a9d9d3ece5dbd60aa4a297bfcd60abc6.png
#     Downloading: s3://amazon-bodym/testA/mask_left/a9d9d3ece5dbd60aa4a297bfcd60abc6.png
#     front_width=214.46726572528883 | side_width=128.41230068337129 | height=779.0 | volume=0.22007674352288842
#
# Record 77/1684 | photo_id=aa9087e7bec2357318f7801ded0ba33b
#     Downloading: s3://amazon-bodym/testA/mask/aa9087e7bec2357318f7801ded0ba33b.png
#     Downloading: s3://amazon-bodym/testA/mask_left/aa9087e7bec2357318f7801ded0ba33b.png
#     front_width=212.86274509803923 | side_width=99.49307159353349 | height=816.0 | volume=0.19139449552179702
#
# Record 78/1684 | photo_id=a465c4424b48157d0403c4f46b750ed2
#     Downloading: s3://amazon-bodym/testA/mask/a465c4424b48157d0403c4f46b750ed2.png
#     Downloading: s3://amazon-bodym/testA/mask_left/a465c4424b48157d0403c4f46b750ed2.png
#     front_width=202.2315668202765 | side_width=107.00820633059789 | height=868.0 | volume=0.17813350987953594
#
# Record 79/1684 | photo_id=9167f07c4fdc74a78ace00d7cad4b699
#     Downloading: s3://amazon-bodym/testA/mask/9167f07c4fdc74a78ace00d7cad4b699.png
#     Downloading: s3://amazon-bodym/testA/mask_left/9167f07c4fdc74a78ace00d7cad4b699.png
#     front_width=206.42136854741898 | side_width=87.41914893617022 | height=833.0 | volume=0.17637486043432726
#
# Record 80/1684 | photo_id=6de8b6dd4e842884a3abf17fc6568ce2
#     Downloading: s3://amazon-bodym/testA/mask/6de8b6dd4e842884a3abf17fc6568ce2.png
#     Downloading: s3://amazon-bodym/testA/mask_left/6de8b6dd4e842884a3abf17fc6568ce2.png
#     front_width=210.95308641975308 | side_width=93.42707117852976 | height=810.0 | volume=0.18788898617177952
#
# Record 81/1684 | photo_id=bd34754520da8332a69610184f3426ac
#     Downloading: s3://amazon-bodym/testA/mask/bd34754520da8332a69610184f3426ac.png
#     Downloading: s3://amazon-bodym/testA/mask_left/bd34754520da8332a69610184f3426ac.png
#     front_width=226.4369846878681 | side_width=103.32166301969366 | height=849.0 | volume=0.19420415059338147
#
# Record 82/1684 | photo_id=27ca2b1761b82c84658f0454d071d3c0
#     Downloading: s3://amazon-bodym/testA/mask/27ca2b1761b82c84658f0454d071d3c0.png
#     Downloading: s3://amazon-bodym/testA/mask_left/27ca2b1761b82c84658f0454d071d3c0.png
#     front_width=217.02389937106918 | side_width=95.71092831962397 | height=795.0 | volume=0.19668857087464978
#
# Record 83/1684 | photo_id=a7eb01092cd1addb4dfcce418e3e0be4
#     Downloading: s3://amazon-bodym/testA/mask/a7eb01092cd1addb4dfcce418e3e0be4.png
#     Downloading: s3://amazon-bodym/testA/mask_left/a7eb01092cd1addb4dfcce418e3e0be4.png
#     front_width=233.97933409873707 | side_width=96.37005347593583 | height=871.0 | volume=0.18963799516341726
#
# Record 84/1684 | photo_id=c1366a32ee29171e3dfe3d331fa6ca22
#     Downloading: s3://amazon-bodym/testA/mask/c1366a32ee29171e3dfe3d331fa6ca22.png
#     Downloading: s3://amazon-bodym/testA/mask_left/c1366a32ee29171e3dfe3d331fa6ca22.png
#     front_width=200.8092967818832 | side_width=104.55230125523012 | height=839.0 | volume=0.18197949823427492
#
# Record 85/1684 | photo_id=97397e09649477eeed2028a6696076e7
#     Downloading: s3://amazon-bodym/testA/mask/97397e09649477eeed2028a6696076e7.png
#     Downloading: s3://amazon-bodym/testA/mask_left/97397e09649477eeed2028a6696076e7.png
#     front_width=213.77543859649123 | side_width=97.28540305010893 | height=855.0 | volume=0.18190692493953226
#
# Record 86/1684 | photo_id=211bdc1fbd34284e72f487ab01545822
#     Downloading: s3://amazon-bodym/testA/mask/211bdc1fbd34284e72f487ab01545822.png
#     Downloading: s3://amazon-bodym/testA/mask_left/211bdc1fbd34284e72f487ab01545822.png
#     front_width=257.6404761904762 | side_width=120.59471365638767 | height=840.0 | volume=0.22513999395646658
#
# Record 87/1684 | photo_id=c47fe281098b0be712e056089a810f06
#     Downloading: s3://amazon-bodym/testA/mask/c47fe281098b0be712e056089a810f06.png
#     Downloading: s3://amazon-bodym/testA/mask_left/c47fe281098b0be712e056089a810f06.png
#     front_width=232.17194570135746 | side_width=132.0628507295174 | height=884.0 | volume=0.2060151563523048
#
# Record 88/1684 | photo_id=6f0dde56568d5a4ca7e57e3087e0b17d
#     Downloading: s3://amazon-bodym/testA/mask/6f0dde56568d5a4ca7e57e3087e0b17d.png
#     Downloading: s3://amazon-bodym/testA/mask_left/6f0dde56568d5a4ca7e57e3087e0b17d.png
#     front_width=203.8831325301205 | side_width=95.4199535962877 | height=830.0 | volume=0.1803030639315712
#
# Record 89/1684 | photo_id=1dab48ac937df915756a1a0967374d55
#     Downloading: s3://amazon-bodym/testA/mask/1dab48ac937df915756a1a0967374d55.png
#     Downloading: s3://amazon-bodym/testA/mask_left/1dab48ac937df915756a1a0967374d55.png
#     front_width=227.634448574969 | side_width=102.31485849056604 | height=807.0 | volume=0.20442955828100062
#
# Record 90/1684 | photo_id=c98b8ea53680a70cfd690d7664c2f2b9
#     Downloading: s3://amazon-bodym/testA/mask/c98b8ea53680a70cfd690d7664c2f2b9.png
#     Downloading: s3://amazon-bodym/testA/mask_left/c98b8ea53680a70cfd690d7664c2f2b9.png
#     front_width=223.01221001221 | side_width=104.23700120918984 | height=819.0 | volume=0.19978584323650783
#
# Record 91/1684 | photo_id=fba6f8d8157288c7f94270c32f695db2
#     Downloading: s3://amazon-bodym/testA/mask/fba6f8d8157288c7f94270c32f695db2.png
#     Downloading: s3://amazon-bodym/testA/mask_left/fba6f8d8157288c7f94270c32f695db2.png
#     front_width=184.68632075471697 | side_width=93.78586497890295 | height=848.0 | volume=0.1641935057391627
#
# Record 92/1684 | photo_id=e27c06706baad66a89708192d868315a
#     Downloading: s3://amazon-bodym/testA/mask/e27c06706baad66a89708192d868315a.png
#     Downloading: s3://amazon-bodym/testA/mask_left/e27c06706baad66a89708192d868315a.png
#     front_width=246.86276849642005 | side_width=107.83928571428571 | height=838.0 | volume=0.21163607053144734
#
# Record 93/1684 | photo_id=879b4afda245e5373fb00b64be7f655a
#     Downloading: s3://amazon-bodym/testA/mask/879b4afda245e5373fb00b64be7f655a.png
#     Downloading: s3://amazon-bodym/testA/mask_left/879b4afda245e5373fb00b64be7f655a.png
#     front_width=226.53317535545023 | side_width=84.59878048780487 | height=844.0 | volume=0.18431987905406108
#
# Record 94/1684 | photo_id=d17a831ec8035ccf2a5383c3165fcf22
#     Downloading: s3://amazon-bodym/testA/mask/d17a831ec8035ccf2a5383c3165fcf22.png
#     Downloading: s3://amazon-bodym/testA/mask_left/d17a831ec8035ccf2a5383c3165fcf22.png
#     front_width=207.67444717444718 | side_width=89.37740112994351 | height=814.0 | volume=0.18246428028525224
#
# Record 95/1684 | photo_id=f95a847c3d8dfe6a365fe7c300f6986a
#     Downloading: s3://amazon-bodym/testA/mask/f95a847c3d8dfe6a365fe7c300f6986a.png
#     Downloading: s3://amazon-bodym/testA/mask_left/f95a847c3d8dfe6a365fe7c300f6986a.png
#     front_width=206.25383707201888 | side_width=104.03611738148985 | height=847.0 | volume=0.18316998491942663
#
# Record 96/1684 | photo_id=b825b43a54e303db71d7b495c1b122bf
#     Downloading: s3://amazon-bodym/testA/mask/b825b43a54e303db71d7b495c1b122bf.png
#     Downloading: s3://amazon-bodym/testA/mask_left/b825b43a54e303db71d7b495c1b122bf.png
#     front_width=214.97535211267606 | side_width=105.671974522293 | height=852.0 | volume=0.18817331375291613
#
# Record 97/1684 | photo_id=7a7ef55e5aff084c5410cb32e9e8db20
#     Downloading: s3://amazon-bodym/testA/mask/7a7ef55e5aff084c5410cb32e9e8db20.png
#     Downloading: s3://amazon-bodym/testA/mask_left/7a7ef55e5aff084c5410cb32e9e8db20.png
#     front_width=200.98518518518517 | side_width=94.3711111111111 | height=810.0 | volume=0.18231870141746684
#
# Record 98/1684 | photo_id=c8f58c789047d66ebab704ca4995ce91
#     Downloading: s3://amazon-bodym/testA/mask/c8f58c789047d66ebab704ca4995ce91.png
#     Downloading: s3://amazon-bodym/testA/mask_left/c8f58c789047d66ebab704ca4995ce91.png
#     front_width=225.41245593419507 | side_width=91.42099567099567 | height=851.0 | volume=0.18615361433912497
#
# Record 99/1684 | photo_id=d2b7a25c08c65a01cc47fefa1159e5c9
#     Downloading: s3://amazon-bodym/testA/mask/d2b7a25c08c65a01cc47fefa1159e5c9.png
#     Downloading: s3://amazon-bodym/testA/mask_left/d2b7a25c08c65a01cc47fefa1159e5c9.png
#     front_width=228.36823935558112 | side_width=91.89819004524887 | height=869.0 | volume=0.18427297433879747
#
# Record 100/1684 | photo_id=bfdaf91669c796c769e54660c5ae442e
#     Downloading: s3://amazon-bodym/testA/mask/bfdaf91669c796c769e54660c5ae442e.png
#     Downloading: s3://amazon-bodym/testA/mask_left/bfdaf91669c796c769e54660c5ae442e.png
#     front_width=208.51030927835052 | side_width=109.36427732079906 | height=776.0 | volume=0.2048160996128541
#
# Processed 100/1684 records so far...
#
# Record 101/1684 | photo_id=ec05f4b906c772df6742a28b2b3ca1f0
#     Downloading: s3://amazon-bodym/testA/mask/ec05f4b906c772df6742a28b2b3ca1f0.png
#     Downloading: s3://amazon-bodym/testA/mask_left/ec05f4b906c772df6742a28b2b3ca1f0.png
#     front_width=184.3957345971564 | side_width=88.74384787472036 | height=844.0 | volume=0.16181254885774693
#
# Record 102/1684 | photo_id=a73305f31827289d92a6b864a72186b9
#     Downloading: s3://amazon-bodym/testA/mask/a73305f31827289d92a6b864a72186b9.png
#     Downloading: s3://amazon-bodym/testA/mask_left/a73305f31827289d92a6b864a72186b9.png
#     front_width=235.17559863169896 | side_width=94.01912260967379 | height=877.0 | volume=0.18768228120944855
#
# Record 103/1684 | photo_id=8506f89e6006e56379244f47257c61f1
#     Downloading: s3://amazon-bodym/testA/mask/8506f89e6006e56379244f47257c61f1.png
#     Downloading: s3://amazon-bodym/testA/mask_left/8506f89e6006e56379244f47257c61f1.png
#     front_width=208.37235367372352 | side_width=97.76861397479954 | height=803.0 | volume=0.1906232675271003
#
# Record 104/1684 | photo_id=fb5c47c4cfbcb9b6d352f1bdf960f01f
#     Downloading: s3://amazon-bodym/testA/mask/fb5c47c4cfbcb9b6d352f1bdf960f01f.png
#     Downloading: s3://amazon-bodym/testA/mask_left/fb5c47c4cfbcb9b6d352f1bdf960f01f.png
#     front_width=215.00728155339806 | side_width=107.40951276102088 | height=824.0 | volume=0.19564125868593382
#
# Record 105/1684 | photo_id=8dd59b15988f0cbb701264c794a39b58
#     Downloading: s3://amazon-bodym/testA/mask/8dd59b15988f0cbb701264c794a39b58.png
#     Downloading: s3://amazon-bodym/testA/mask_left/8dd59b15988f0cbb701264c794a39b58.png
#     front_width=220.00868486352357 | side_width=88.09112426035503 | height=806.0 | volume=0.1911289138485599
#
# Record 106/1684 | photo_id=d4c357f38a4c4a45644e80585bc4a8e3
#     Downloading: s3://amazon-bodym/testA/mask/d4c357f38a4c4a45644e80585bc4a8e3.png
#     Downloading: s3://amazon-bodym/testA/mask_left/d4c357f38a4c4a45644e80585bc4a8e3.png
#     front_width=192.48588957055216 | side_width=93.27114716106605 | height=815.0 | volume=0.17531106547952036
#
# Record 107/1684 | photo_id=30c01159493adafc50c4ff1ef5bfa7cf
#     Downloading: s3://amazon-bodym/testA/mask/30c01159493adafc50c4ff1ef5bfa7cf.png
#     Downloading: s3://amazon-bodym/testA/mask_left/30c01159493adafc50c4ff1ef5bfa7cf.png
#     front_width=239.6558752997602 | side_width=95.5196662693683 | height=834.0 | volume=0.20094456928604826
#
# Record 108/1684 | photo_id=39172fcea2124599f579033909a2a69e
#     Downloading: s3://amazon-bodym/testA/mask/39172fcea2124599f579033909a2a69e.png
#     Downloading: s3://amazon-bodym/testA/mask_left/39172fcea2124599f579033909a2a69e.png
#     front_width=221.98222748815166 | side_width=96.59159859976663 | height=844.0 | volume=0.1887285699572976
#
# Record 109/1684 | photo_id=4424b600d95a2279c8750d66e8601883
#     Downloading: s3://amazon-bodym/testA/mask/4424b600d95a2279c8750d66e8601883.png
#     Downloading: s3://amazon-bodym/testA/mask_left/4424b600d95a2279c8750d66e8601883.png
#     front_width=191.0751515151515 | side_width=82.58983050847458 | height=825.0 | volume=0.16585756486280367
#
# Record 110/1684 | photo_id=81a96f56bd9d0f3dc9c5b44f8de35b28
#     Downloading: s3://amazon-bodym/testA/mask/81a96f56bd9d0f3dc9c5b44f8de35b28.png
#     Downloading: s3://amazon-bodym/testA/mask_left/81a96f56bd9d0f3dc9c5b44f8de35b28.png
#     front_width=252.96246973365618 | side_width=106.13038674033149 | height=826.0 | volume=0.2173685571876439
#
# Record 111/1684 | photo_id=bb1ceddc4ff714c59909fb8f1744fa50
#     Downloading: s3://amazon-bodym/testA/mask/bb1ceddc4ff714c59909fb8f1744fa50.png
#     Downloading: s3://amazon-bodym/testA/mask_left/bb1ceddc4ff714c59909fb8f1744fa50.png
#     front_width=189.41903584672434 | side_width=102.44370122630993 | height=809.0 | volume=0.1803848807620731
#
# Record 112/1684 | photo_id=eb688500e811d7888ebc8117ef752ed8
#     Downloading: s3://amazon-bodym/testA/mask/eb688500e811d7888ebc8117ef752ed8.png
#     Downloading: s3://amazon-bodym/testA/mask_left/eb688500e811d7888ebc8117ef752ed8.png
#     front_width=224.76184834123222 | side_width=97.4978494623656 | height=844.0 | volume=0.1909121432485769
#
# Record 113/1684 | photo_id=3195cb96f24eb881a3706cdde222b077
#     Downloading: s3://amazon-bodym/testA/mask/3195cb96f24eb881a3706cdde222b077.png
#     Downloading: s3://amazon-bodym/testA/mask_left/3195cb96f24eb881a3706cdde222b077.png
#     front_width=212.5 | side_width=97.74410774410775 | height=818.0 | volume=0.18963576267977245
#
# Record 114/1684 | photo_id=9d7d4cc8b6e6ece88ae7c258581509b6
#     Downloading: s3://amazon-bodym/testA/mask/9d7d4cc8b6e6ece88ae7c258581509b6.png
#     Downloading: s3://amazon-bodym/testA/mask_left/9d7d4cc8b6e6ece88ae7c258581509b6.png
#     front_width=160.58946078431373 | side_width=79.54431818181818 | height=816.0 | volume=0.14714079593512985
#
# Record 115/1684 | photo_id=1e5cdc686b4daa96a4c259c5dbd6a011
#     Downloading: s3://amazon-bodym/testA/mask/1e5cdc686b4daa96a4c259c5dbd6a011.png
#     Downloading: s3://amazon-bodym/testA/mask_left/1e5cdc686b4daa96a4c259c5dbd6a011.png
#     front_width=233.21309523809524 | side_width=118.55082742316785 | height=840.0 | volume=0.20938328729837088
#
# Record 116/1684 | photo_id=d1b75848f14302af9dfe848801a1b9c2
#     Downloading: s3://amazon-bodym/testA/mask/d1b75848f14302af9dfe848801a1b9c2.png
#     Downloading: s3://amazon-bodym/testA/mask_left/d1b75848f14302af9dfe848801a1b9c2.png
#     front_width=197.59331797235023 | side_width=94.77665544332211 | height=868.0 | volume=0.16841588330395874
#
# Record 117/1684 | photo_id=8a3d02d9f86a4b388a2109efb3f52b2c
#     Downloading: s3://amazon-bodym/testA/mask/8a3d02d9f86a4b388a2109efb3f52b2c.png
#     Downloading: s3://amazon-bodym/testA/mask_left/8a3d02d9f86a4b388a2109efb3f52b2c.png
#     front_width=209.61743341404357 | side_width=108.0890642615558 | height=826.0 | volume=0.19231628188595606
#
# Record 118/1684 | photo_id=0048f0d9a4d0ca697e31077bab7b2471
#     Downloading: s3://amazon-bodym/testA/mask/0048f0d9a4d0ca697e31077bab7b2471.png
#     Downloading: s3://amazon-bodym/testA/mask_left/0048f0d9a4d0ca697e31077bab7b2471.png
#     front_width=259.13226909920184 | side_width=125.57594936708861 | height=877.0 | volume=0.21933193755204697
#
# Record 119/1684 | photo_id=96be94edbe1767b7ca69b0788b611d65
#     Downloading: s3://amazon-bodym/testA/mask/96be94edbe1767b7ca69b0788b611d65.png
#     Downloading: s3://amazon-bodym/testA/mask_left/96be94edbe1767b7ca69b0788b611d65.png
#     front_width=190.2908878504673 | side_width=103.82721893491124 | height=856.0 | volume=0.1717979595708987
#
# Record 120/1684 | photo_id=21c37e676a0b0ee275978717405ab71c
#     Downloading: s3://amazon-bodym/testA/mask/21c37e676a0b0ee275978717405ab71c.png
#     Downloading: s3://amazon-bodym/testA/mask_left/21c37e676a0b0ee275978717405ab71c.png
#     front_width=193.68551236749116 | side_width=94.65405405405406 | height=849.0 | volume=0.16981128764519743
#
# Record 121/1684 | photo_id=752c4352c30387a2ad7f20636c451649
#     Downloading: s3://amazon-bodym/testA/mask/752c4352c30387a2ad7f20636c451649.png
#     Downloading: s3://amazon-bodym/testA/mask_left/752c4352c30387a2ad7f20636c451649.png
#     front_width=255.75719217491368 | side_width=115.53870625662779 | height=869.0 | volume=0.2136340037005417
#
# Record 122/1684 | photo_id=11677eada1036437abb6be3cd1a7a816
#     Downloading: s3://amazon-bodym/testA/mask/11677eada1036437abb6be3cd1a7a816.png
#     Downloading: s3://amazon-bodym/testA/mask_left/11677eada1036437abb6be3cd1a7a816.png
#     front_width=202.49690976514216 | side_width=89.47966507177034 | height=809.0 | volume=0.18045523784728834
#
# Record 123/1684 | photo_id=ff7f4b409608b24da7f6d678170e4600
#     Downloading: s3://amazon-bodym/testA/mask/ff7f4b409608b24da7f6d678170e4600.png
#     Downloading: s3://amazon-bodym/testA/mask_left/ff7f4b409608b24da7f6d678170e4600.png
#     front_width=175.04993757802745 | side_width=90.4108170310702 | height=801.0 | volume=0.16570583933152164
#
# Record 124/1684 | photo_id=575cc04b3472b3fb549bebd7f01cf5ef
#     Downloading: s3://amazon-bodym/testA/mask/575cc04b3472b3fb549bebd7f01cf5ef.png
#     Downloading: s3://amazon-bodym/testA/mask_left/575cc04b3472b3fb549bebd7f01cf5ef.png
#     front_width=174.99615877080666 | side_width=80.33915211970074 | height=781.0 | volume=0.16346690838060654
#
# Record 125/1684 | photo_id=b1860cf92d0eea264f09d74345a3559f
#     Downloading: s3://amazon-bodym/testA/mask/b1860cf92d0eea264f09d74345a3559f.png
#     Downloading: s3://amazon-bodym/testA/mask_left/b1860cf92d0eea264f09d74345a3559f.png
#     front_width=218.82151029748283 | side_width=73.28921568627452 | height=874.0 | volume=0.167111399304209
#
# Record 126/1684 | photo_id=32a8419c3f89664423ed0b43e49eabc5
#     Downloading: s3://amazon-bodym/testA/mask/32a8419c3f89664423ed0b43e49eabc5.png
#     Downloading: s3://amazon-bodym/testA/mask_left/32a8419c3f89664423ed0b43e49eabc5.png
#     front_width=214.3564476885645 | side_width=90.77197149643706 | height=822.0 | volume=0.18560122821472116
#
# Record 127/1684 | photo_id=eb71739176acae7bc31cc802ad9cdf50
#     Downloading: s3://amazon-bodym/testA/mask/eb71739176acae7bc31cc802ad9cdf50.png
#     Downloading: s3://amazon-bodym/testA/mask_left/eb71739176acae7bc31cc802ad9cdf50.png
#     front_width=232.3986332574032 | side_width=105.39024390243902 | height=878.0 | volume=0.19236268630970513
#
# Record 128/1684 | photo_id=ab95fb90ced391f15f4f32de9474942c
#     Downloading: s3://amazon-bodym/testA/mask/ab95fb90ced391f15f4f32de9474942c.png
#     Downloading: s3://amazon-bodym/testA/mask_left/ab95fb90ced391f15f4f32de9474942c.png
#     front_width=227.27413587604292 | side_width=103.77394209354121 | height=839.0 | volume=0.19728729318807162
#
# Record 129/1684 | photo_id=29f425428472d6afc8b92d6659ea2681
#     Downloading: s3://amazon-bodym/testA/mask/29f425428472d6afc8b92d6659ea2681.png
#     Downloading: s3://amazon-bodym/testA/mask_left/29f425428472d6afc8b92d6659ea2681.png
#     front_width=242.26241134751774 | side_width=124.24166666666666 | height=846.0 | volume=0.2166099751856882
#
# Record 130/1684 | photo_id=af9c6db3d592f5401459cf86f4eac1c6
#     Downloading: s3://amazon-bodym/testA/mask/af9c6db3d592f5401459cf86f4eac1c6.png
#     Downloading: s3://amazon-bodym/testA/mask_left/af9c6db3d592f5401459cf86f4eac1c6.png
#     front_width=228.58053691275168 | side_width=69.99843014128729 | height=894.0 | volume=0.16699047374386966
#
# Record 131/1684 | photo_id=eb709f90cfd20015a7db73691694082b
#     Downloading: s3://amazon-bodym/testA/mask/eb709f90cfd20015a7db73691694082b.png
#     Downloading: s3://amazon-bodym/testA/mask_left/eb709f90cfd20015a7db73691694082b.png
#     front_width=232.7698598130841 | side_width=95.5196662693683 | height=856.0 | volume=0.19175790074909604
#
# Record 132/1684 | photo_id=190fbba1e20d2ed47a7c7157454b2fd0
#     Downloading: s3://amazon-bodym/testA/mask/190fbba1e20d2ed47a7c7157454b2fd0.png
#     Downloading: s3://amazon-bodym/testA/mask_left/190fbba1e20d2ed47a7c7157454b2fd0.png
#     front_width=211.82448036951502 | side_width=96.77577045696069 | height=866.0 | volume=0.17817566444946634
#
# Record 133/1684 | photo_id=855aedec817849487bdf5cb0dc1c9a2b
#     Downloading: s3://amazon-bodym/testA/mask/855aedec817849487bdf5cb0dc1c9a2b.png
#     Downloading: s3://amazon-bodym/testA/mask_left/855aedec817849487bdf5cb0dc1c9a2b.png
#     front_width=237.8142340168878 | side_width=98.51758793969849 | height=829.0 | volume=0.20285393362882162
#
# Record 134/1684 | photo_id=40e28fbfb9d2b897c7ae9fa2c5ad09a9
#     Downloading: s3://amazon-bodym/testA/mask/40e28fbfb9d2b897c7ae9fa2c5ad09a9.png
#     Downloading: s3://amazon-bodym/testA/mask_left/40e28fbfb9d2b897c7ae9fa2c5ad09a9.png
#     front_width=183.2615193026152 | side_width=94.48620689655172 | height=803.0 | volume=0.17294378966324217
#
# Record 135/1684 | photo_id=bcfa43e611a8de45bacc68f663c55b4c
#     Downloading: s3://amazon-bodym/testA/mask/bcfa43e611a8de45bacc68f663c55b4c.png
#     Downloading: s3://amazon-bodym/testA/mask_left/bcfa43e611a8de45bacc68f663c55b4c.png
#     front_width=236.6493656286044 | side_width=113.45813397129187 | height=867.0 | volume=0.20190743921562646
#
# Record 136/1684 | photo_id=d2a226f0082b53ef41310a41299ddfc1
#     Downloading: s3://amazon-bodym/testA/mask/d2a226f0082b53ef41310a41299ddfc1.png
#     Downloading: s3://amazon-bodym/testA/mask_left/d2a226f0082b53ef41310a41299ddfc1.png
#     front_width=217.79904306220095 | side_width=95.27479091995221 | height=836.0 | volume=0.18724511601803417
#
# Record 137/1684 | photo_id=79ad346965a9fcf561bb7a3e37fd31b2
#     Downloading: s3://amazon-bodym/testA/mask/79ad346965a9fcf561bb7a3e37fd31b2.png
#     Downloading: s3://amazon-bodym/testA/mask_left/79ad346965a9fcf561bb7a3e37fd31b2.png
#     front_width=194.81123058542414 | side_width=103.14132762312634 | height=837.0 | volume=0.1779883860266132
#
# Record 138/1684 | photo_id=a278824db1e387ed1fd88616f3eeafb4
#     Downloading: s3://amazon-bodym/testA/mask/a278824db1e387ed1fd88616f3eeafb4.png
#     Downloading: s3://amazon-bodym/testA/mask_left/a278824db1e387ed1fd88616f3eeafb4.png
#     front_width=224.28571428571428 | side_width=91.27132701421802 | height=819.0 | volume=0.192647766361375
#
# Record 139/1684 | photo_id=9f3de278a2f3b57a19ead739e6a3dbf1
#     Downloading: s3://amazon-bodym/testA/mask/9f3de278a2f3b57a19ead739e6a3dbf1.png
#     Downloading: s3://amazon-bodym/testA/mask_left/9f3de278a2f3b57a19ead739e6a3dbf1.png
#     front_width=116.85493460166468 | side_width=114.33295454545454 | height=898.0 | volume=0.1287237690128726
#
# Record 140/1684 | photo_id=fa665f1f990e7a3351f71b57b7cc5676
#     Downloading: s3://amazon-bodym/testA/mask/fa665f1f990e7a3351f71b57b7cc5676.png
#     Downloading: s3://amazon-bodym/testA/mask_left/fa665f1f990e7a3351f71b57b7cc5676.png
#     front_width=223.49250288350635 | side_width=89.20044792833147 | height=867.0 | volume=0.1803304214601141
#
# Record 141/1684 | photo_id=802a7a8ef2574440936ab2ff66910478
# ...
#     Downloading: s3://amazon-bodym/testA/mask_left/ad04086c735cc3844570c809d35caba2.png
#     front_width=211.2186421173763 | side_width=104.83258928571429 | height=869.0 | volume=0.18184765903514996
#
# Record 1641/1684 | photo_id=82aa0fb7c53aaac39a63ae0a441390f2
#     Downloading: s3://amazon-bodym/testA/mask/82aa0fb7c53aaac39a63ae0a441390f2.png
#     Downloading: s3://amazon-bodym/testA/mask_left/82aa0fb7c53aaac39a63ae0a441390f2.png
#     front_width=241.64610011641443 | side_width=108.02774813233725 | height=859.0 | volume=0.2035354180726145
#
# Record 1642/1684 | photo_id=1982951758ea65ae715d9d1a95a8ecd1
#     Downloading: s3://amazon-bodym/testA/mask/1982951758ea65ae715d9d1a95a8ecd1.png
#     Downloading: s3://amazon-bodym/testA/mask_left/1982951758ea65ae715d9d1a95a8ecd1.png
#     front_width=188.2182490752158 | side_width=104.14334862385321 | height=811.0 | volume=0.1802475941424593
#
# Record 1643/1684 | photo_id=225b58cb755f97a3f659250aa272be8c
#     Downloading: s3://amazon-bodym/testA/mask/225b58cb755f97a3f659250aa272be8c.png
#     Downloading: s3://amazon-bodym/testA/mask_left/225b58cb755f97a3f659250aa272be8c.png
#     front_width=191.7139451728248 | side_width=98.93216630196936 | height=839.0 | volume=0.1732098399730597
#
# Record 1644/1684 | photo_id=ecce2b978fbbe2d9c5386ed89ef6d5ab
#     Downloading: s3://amazon-bodym/testA/mask/ecce2b978fbbe2d9c5386ed89ef6d5ab.png
#     Downloading: s3://amazon-bodym/testA/mask_left/ecce2b978fbbe2d9c5386ed89ef6d5ab.png
#     front_width=219.40113636363637 | side_width=102.6726862302483 | height=880.0 | volume=0.18299649011016172
#
# Record 1645/1684 | photo_id=37d9e7832207782784b8dc31a9c53c93
#     Downloading: s3://amazon-bodym/testA/mask/37d9e7832207782784b8dc31a9c53c93.png
#     Downloading: s3://amazon-bodym/testA/mask_left/37d9e7832207782784b8dc31a9c53c93.png
#     front_width=225.84745762711864 | side_width=98.0728476821192 | height=826.0 | volume=0.19607766665208104
#
# Record 1646/1684 | photo_id=7eb31f6d5217d64ffbf0618dbe6262d8
#     Downloading: s3://amazon-bodym/testA/mask/7eb31f6d5217d64ffbf0618dbe6262d8.png
#     Downloading: s3://amazon-bodym/testA/mask_left/7eb31f6d5217d64ffbf0618dbe6262d8.png
#     front_width=235.96321070234114 | side_width=110.42632170978628 | height=897.0 | volume=0.19308223657309223
#
# Record 1647/1684 | photo_id=4c7dd1b05254fb6bece46ac0a773c362
#     Downloading: s3://amazon-bodym/testA/mask/4c7dd1b05254fb6bece46ac0a773c362.png
#     Downloading: s3://amazon-bodym/testA/mask_left/4c7dd1b05254fb6bece46ac0a773c362.png
#     front_width=203.91325898389096 | side_width=95.49328859060402 | height=807.0 | volume=0.1855059154736648
#
# Record 1648/1684 | photo_id=b1863fa1ba14f3e5e73df720a52c2dd2
#     Downloading: s3://amazon-bodym/testA/mask/b1863fa1ba14f3e5e73df720a52c2dd2.png
#     Downloading: s3://amazon-bodym/testA/mask_left/b1863fa1ba14f3e5e73df720a52c2dd2.png
#     front_width=207.73995271867614 | side_width=101.81934112646121 | height=846.0 | volume=0.18295466539310717
#
# Record 1649/1684 | photo_id=fd9e8fea8aac2f1d1fd10ed28c0497f6
#     Downloading: s3://amazon-bodym/testA/mask/fd9e8fea8aac2f1d1fd10ed28c0497f6.png
#     Downloading: s3://amazon-bodym/testA/mask_left/fd9e8fea8aac2f1d1fd10ed28c0497f6.png
#     front_width=188.76913580246912 | side_width=94.81021087680355 | height=810.0 | volume=0.17504897943164982
#
# Record 1650/1684 | photo_id=8da2e6d9ccf30b1ebe9715c3df5e0ca6
#     Downloading: s3://amazon-bodym/testA/mask/8da2e6d9ccf30b1ebe9715c3df5e0ca6.png
#     Downloading: s3://amazon-bodym/testA/mask_left/8da2e6d9ccf30b1ebe9715c3df5e0ca6.png
#     front_width=194.9334862385321 | side_width=96.27070063694268 | height=872.0 | volume=0.16697487779557038
#
# Processed 1650/1684 records so far...
#
# Record 1651/1684 | photo_id=370377101b10f8a1c3052939f62bdc54
#     Downloading: s3://amazon-bodym/testA/mask/370377101b10f8a1c3052939f62bdc54.png
#     Downloading: s3://amazon-bodym/testA/mask_left/370377101b10f8a1c3052939f62bdc54.png
#     front_width=201.78798586572438 | side_width=83.17016574585635 | height=849.0 | volume=0.1678198772741936
#
# Record 1652/1684 | photo_id=ad6815dae0b870817d3c9f228156c55d
#     Downloading: s3://amazon-bodym/testA/mask/ad6815dae0b870817d3c9f228156c55d.png
#     Downloading: s3://amazon-bodym/testA/mask_left/ad6815dae0b870817d3c9f228156c55d.png
#     front_width=223.15320665083135 | side_width=108.5906432748538 | height=842.0 | volume=0.19699753558532374
#
# Record 1653/1684 | photo_id=4039eb33ac3d6778c1db9f265fe034ba
#     Downloading: s3://amazon-bodym/testA/mask/4039eb33ac3d6778c1db9f265fe034ba.png
#     Downloading: s3://amazon-bodym/testA/mask_left/4039eb33ac3d6778c1db9f265fe034ba.png
#     front_width=226.4323995127893 | side_width=126.71783295711062 | height=821.0 | volume=0.2150732231850791
#
# Record 1654/1684 | photo_id=9b71d41951f13dcf873565a32dae9f22
#     Downloading: s3://amazon-bodym/testA/mask/9b71d41951f13dcf873565a32dae9f22.png
#     Downloading: s3://amazon-bodym/testA/mask_left/9b71d41951f13dcf873565a32dae9f22.png
#     front_width=186.9775561097257 | side_width=83.12953995157385 | height=802.0 | volume=0.1683959451753738
#
# Record 1655/1684 | photo_id=5f4d97ef512adf1faadfe2e8e6394659
#     Downloading: s3://amazon-bodym/testA/mask/5f4d97ef512adf1faadfe2e8e6394659.png
#     Downloading: s3://amazon-bodym/testA/mask_left/5f4d97ef512adf1faadfe2e8e6394659.png
#     front_width=199.49606299212599 | side_width=98.79865771812081 | height=889.0 | volume=0.16776980917336717
#
# Record 1656/1684 | photo_id=c98e34af9c269fc90322bdf73e1b934c
#     Downloading: s3://amazon-bodym/testA/mask/c98e34af9c269fc90322bdf73e1b934c.png
#     Downloading: s3://amazon-bodym/testA/mask_left/c98e34af9c269fc90322bdf73e1b934c.png
#     front_width=205.50404624277456 | side_width=104.06179775280899 | height=865.0 | volume=0.17893979421710032
#
# Record 1657/1684 | photo_id=00f29ea96c690cb73496ebc2448bf7bc
#     Downloading: s3://amazon-bodym/testA/mask/00f29ea96c690cb73496ebc2448bf7bc.png
#     Downloading: s3://amazon-bodym/testA/mask_left/00f29ea96c690cb73496ebc2448bf7bc.png
#     front_width=177.38295165394402 | side_width=84.9220623501199 | height=786.0 | volume=0.16686069593133837
#
# Record 1658/1684 | photo_id=141279d674ee6e0254ae0a84cf6973f2
#     Downloading: s3://amazon-bodym/testA/mask/141279d674ee6e0254ae0a84cf6973f2.png
#     Downloading: s3://amazon-bodym/testA/mask_left/141279d674ee6e0254ae0a84cf6973f2.png
#     front_width=253.17741935483872 | side_width=110.42632170978628 | height=930.0 | volume=0.19548588229280914
#
# Record 1659/1684 | photo_id=fea6f5d161d85cee616837d403c06964
#     Downloading: s3://amazon-bodym/testA/mask/fea6f5d161d85cee616837d403c06964.png
#     Downloading: s3://amazon-bodym/testA/mask_left/fea6f5d161d85cee616837d403c06964.png
#     front_width=183.4716748768473 | side_width=109.43246187363835 | height=812.0 | volume=0.1803596901172941
#
# Record 1660/1684 | photo_id=caaa81f30e872b915f1cf9acfc63fd89
#     Downloading: s3://amazon-bodym/testA/mask/caaa81f30e872b915f1cf9acfc63fd89.png
#     Downloading: s3://amazon-bodym/testA/mask_left/caaa81f30e872b915f1cf9acfc63fd89.png
#     front_width=177.3953488372093 | side_width=90.55172413793103 | height=817.0 | volume=0.16398229680241147
#
# Record 1661/1684 | photo_id=423a5dea410100677846355e9a69eee4
#     Downloading: s3://amazon-bodym/testA/mask/423a5dea410100677846355e9a69eee4.png
#     Downloading: s3://amazon-bodym/testA/mask_left/423a5dea410100677846355e9a69eee4.png
#     front_width=181.31932773109244 | side_width=85.18632075471699 | height=833.0 | volume=0.15996737604190242
#
# Record 1662/1684 | photo_id=0ce1d6093159bdf11f2ec70de3507555
#     Downloading: s3://amazon-bodym/testA/mask/0ce1d6093159bdf11f2ec70de3507555.png
#     Downloading: s3://amazon-bodym/testA/mask_left/0ce1d6093159bdf11f2ec70de3507555.png
#     front_width=185.3458177278402 | side_width=94.97942857142857 | height=801.0 | volume=0.17498454825172832
#
# Record 1663/1684 | photo_id=29218250def0c4c3f35dc9eec6022337
#     Downloading: s3://amazon-bodym/testA/mask/29218250def0c4c3f35dc9eec6022337.png
#     Downloading: s3://amazon-bodym/testA/mask_left/29218250def0c4c3f35dc9eec6022337.png
#     front_width=186.4067995310668 | side_width=105.68660022148394 | height=853.0 | volume=0.171215357416501
#
# Record 1664/1684 | photo_id=cd73f28df3977892b8f652e82f556ad0
#     Downloading: s3://amazon-bodym/testA/mask/cd73f28df3977892b8f652e82f556ad0.png
#     Downloading: s3://amazon-bodym/testA/mask_left/cd73f28df3977892b8f652e82f556ad0.png
#     front_width=210.56370192307693 | side_width=99.47052518756699 | height=832.0 | volume=0.1863186461001466
#
# Record 1665/1684 | photo_id=cbcd8808f312337cb72862d709cd83db
#     Downloading: s3://amazon-bodym/testA/mask/cbcd8808f312337cb72862d709cd83db.png
#     Downloading: s3://amazon-bodym/testA/mask_left/cbcd8808f312337cb72862d709cd83db.png
#     front_width=237.71428571428572 | side_width=93.81270903010034 | height=854.0 | volume=0.19410245593933612
#
# Record 1666/1684 | photo_id=dfb26486fa942e21bd82f4d75d6a9d31
#     Downloading: s3://amazon-bodym/testA/mask/dfb26486fa942e21bd82f4d75d6a9d31.png
#     Downloading: s3://amazon-bodym/testA/mask_left/dfb26486fa942e21bd82f4d75d6a9d31.png
#     front_width=226.56431054461183 | side_width=104.50598476605005 | height=863.0 | volume=0.191813612578599
#
# Record 1667/1684 | photo_id=1eecdb9780c296b4e2b4e306369f605e
#     Downloading: s3://amazon-bodym/testA/mask/1eecdb9780c296b4e2b4e306369f605e.png
#     Downloading: s3://amazon-bodym/testA/mask_left/1eecdb9780c296b4e2b4e306369f605e.png
#     front_width=244.53846153846155 | side_width=96.60874439461884 | height=832.0 | volume=0.2050163497193993
#
# Record 1668/1684 | photo_id=92c45217a3c322364c9a923d0953cfee
#     Downloading: s3://amazon-bodym/testA/mask/92c45217a3c322364c9a923d0953cfee.png
#     Downloading: s3://amazon-bodym/testA/mask_left/92c45217a3c322364c9a923d0953cfee.png
#     front_width=170.21464019851118 | side_width=122.07986501687289 | height=806.0 | volume=0.18132413474899756
#
# Record 1669/1684 | photo_id=bb88c1c64735ea8a4dadbe036b47d315
#     Downloading: s3://amazon-bodym/testA/mask/bb88c1c64735ea8a4dadbe036b47d315.png
#     Downloading: s3://amazon-bodym/testA/mask_left/bb88c1c64735ea8a4dadbe036b47d315.png
#     front_width=235.1533180778032 | side_width=102.64798206278027 | height=874.0 | volume=0.19325017170513928
#
# Record 1670/1684 | photo_id=67ed335e7b9da7e62c18976e78465640
#     Downloading: s3://amazon-bodym/testA/mask/67ed335e7b9da7e62c18976e78465640.png
#     Downloading: s3://amazon-bodym/testA/mask_left/67ed335e7b9da7e62c18976e78465640.png
#     front_width=206.2268803945746 | side_width=99.69603524229075 | height=811.0 | volume=0.18860845600299958
#
# Record 1671/1684 | photo_id=73910f8eea7a29e34fc12152496381f5
#     Downloading: s3://amazon-bodym/testA/mask/73910f8eea7a29e34fc12152496381f5.png
#     Downloading: s3://amazon-bodym/testA/mask_left/73910f8eea7a29e34fc12152496381f5.png
#     front_width=239.6558752997602 | side_width=95.5196662693683 | height=834.0 | volume=0.20094456928604826
#
# Record 1672/1684 | photo_id=41a08708d9d5884d2032890cf41f6b12
#     Downloading: s3://amazon-bodym/testA/mask/41a08708d9d5884d2032890cf41f6b12.png
#     Downloading: s3://amazon-bodym/testA/mask_left/41a08708d9d5884d2032890cf41f6b12.png
#     front_width=193.33611442193086 | side_width=111.37729357798165 | height=839.0 | volume=0.18159321096538292
#
# Record 1673/1684 | photo_id=221fab313e9ddb1d390dd602ec427881
#     Downloading: s3://amazon-bodym/testA/mask/221fab313e9ddb1d390dd602ec427881.png
#     Downloading: s3://amazon-bodym/testA/mask_left/221fab313e9ddb1d390dd602ec427881.png
#     front_width=270.0888382687927 | side_width=95.9431554524362 | height=878.0 | volume=0.2084464656726816
#
# Record 1674/1684 | photo_id=7579f1f81944ed0d7baaebd750f730e5
#     Downloading: s3://amazon-bodym/testA/mask/7579f1f81944ed0d7baaebd750f730e5.png
#     Downloading: s3://amazon-bodym/testA/mask_left/7579f1f81944ed0d7baaebd750f730e5.png
#     front_width=199.47165259348614 | side_width=102.02224694104561 | height=829.0 | volume=0.1818419176927212
#
# Record 1675/1684 | photo_id=dc62ba8610078109d6c252d78855474d
#     Downloading: s3://amazon-bodym/testA/mask/dc62ba8610078109d6c252d78855474d.png
#     Downloading: s3://amazon-bodym/testA/mask_left/dc62ba8610078109d6c252d78855474d.png
#     front_width=226.80281690140845 | side_width=123.83854166666667 | height=852.0 | volume=0.20577544516905816
#
# Record 1676/1684 | photo_id=cb8f7dd4f3c96006eccc112b8f947a6e
#     Downloading: s3://amazon-bodym/testA/mask/cb8f7dd4f3c96006eccc112b8f947a6e.png
#     Downloading: s3://amazon-bodym/testA/mask_left/cb8f7dd4f3c96006eccc112b8f947a6e.png
#     front_width=188.97802197802199 | side_width=97.25381903642773 | height=819.0 | volume=0.17474471368403527
#
# Record 1677/1684 | photo_id=b208440bbf1075d702e013065c818fe0
#     Downloading: s3://amazon-bodym/testA/mask/b208440bbf1075d702e013065c818fe0.png
#     Downloading: s3://amazon-bodym/testA/mask_left/b208440bbf1075d702e013065c818fe0.png
#     front_width=184.9029484029484 | side_width=92.58695652173913 | height=814.0 | volume=0.17044834454833385
#
# Record 1678/1684 | photo_id=c76b7c9f7f0c3b50b66db4297af90311
#     Downloading: s3://amazon-bodym/testA/mask/c76b7c9f7f0c3b50b66db4297af90311.png
#     Downloading: s3://amazon-bodym/testA/mask_left/c76b7c9f7f0c3b50b66db4297af90311.png
#     front_width=176.78809523809525 | side_width=137.56256921373202 | height=840.0 | volume=0.18711349074513528
#
# Record 1679/1684 | photo_id=a6ae121f6099f3b4f3514d9ab917db91
#     Downloading: s3://amazon-bodym/testA/mask/a6ae121f6099f3b4f3514d9ab917db91.png
#     Downloading: s3://amazon-bodym/testA/mask_left/a6ae121f6099f3b4f3514d9ab917db91.png
#     front_width=171.13114754098362 | side_width=115.69977678571429 | height=793.0 | volume=0.18085178078606426
#
# Record 1680/1684 | photo_id=c0b37049092f4db4b20cde5cf92d05c6
#     Downloading: s3://amazon-bodym/testA/mask/c0b37049092f4db4b20cde5cf92d05c6.png
#     Downloading: s3://amazon-bodym/testA/mask_left/c0b37049092f4db4b20cde5cf92d05c6.png
#     front_width=239.64046242774566 | side_width=101.77038626609442 | height=865.0 | volume=0.19734731138372258
#
# Record 1681/1684 | photo_id=c3cc1f77d0506e6cf3391f22d67f874e
#     Downloading: s3://amazon-bodym/testA/mask/c3cc1f77d0506e6cf3391f22d67f874e.png
#     Downloading: s3://amazon-bodym/testA/mask_left/c3cc1f77d0506e6cf3391f22d67f874e.png
#     front_width=203.39015606242498 | side_width=92.6073546856465 | height=833.0 | volume=0.17766957427855432
#
# Record 1682/1684 | photo_id=3124743d6494910558170710939a3296
#     Downloading: s3://amazon-bodym/testA/mask/3124743d6494910558170710939a3296.png
#     Downloading: s3://amazon-bodym/testA/mask_left/3124743d6494910558170710939a3296.png
#     front_width=203.9709090909091 | side_width=92.21064552661382 | height=825.0 | volume=0.17950397249546846
#
# Record 1683/1684 | photo_id=8f13d3999eae0ca692676f3232bb1958
#     Downloading: s3://amazon-bodym/testA/mask/8f13d3999eae0ca692676f3232bb1958.png
#     Downloading: s3://amazon-bodym/testA/mask_left/8f13d3999eae0ca692676f3232bb1958.png
#     front_width=196.1548619447779 | side_width=107.53146853146853 | height=833.0 | volume=0.18228471217061612
#
# Record 1684/1684 | photo_id=3da44f41a65991273c3c34769ddc8f37
#     Downloading: s3://amazon-bodym/testA/mask/3da44f41a65991273c3c34769ddc8f37.png
#     Downloading: s3://amazon-bodym/testA/mask_left/3da44f41a65991273c3c34769ddc8f37.png
#     front_width=194.61290322580646 | side_width=98.38401775804661 | height=837.0 | volume=0.175028029261561
#
# Attaching new feature columns to dataframe...
# Done.
# Preview of updated dataframe:
#                            photo_id    volume  front_width  side_width  \
# 0  e5ae8fe5bbdf611a1e8d06e66e849bdf  0.203832   233.102625  108.520174
# 1  605a5fd09058c48156b0ef518b63b2de  0.174640   163.387730  121.276256
# 2  909c9277309e13ee014e347603aba620  0.168680   177.390488   92.159954
# 3  bef6a68bc8dd475c124f6de2413385d3  0.181684   207.516919  103.890034
# 4  6d7ed4bc4a17546447efed0ca6e2ff11  0.186667   218.209330   93.897076
#
#    mask_height
# 0        838.0
# 1        815.0
# 2        799.0
# 3        857.0
# 4        836.0

# %%
# Drop the intermediate/debug columns (ignore if they don't exist)
cols_to_drop = ["front_width", "side_width", "mask_height"]  # columns to remove
print("Dropping columns:", cols_to_drop)  # track process
data.drop(columns=cols_to_drop, inplace=True, errors="ignore")  # drop safely
# Out:
# Dropping columns: ['front_width', 'side_width', 'mask_height']

# %%
data.head()
# Out:
#                            photo_id        f1        f2        f3        f4  \
# 0  e5ae8fe5bbdf611a1e8d06e66e849bdf  0.073159  0.085775 -0.133776  0.881202
# 1  605a5fd09058c48156b0ef518b63b2de  0.092031 -0.066016 -0.145132  0.687441
# 2  909c9277309e13ee014e347603aba620  0.057046 -0.051366 -0.148253  0.675916
# 3  bef6a68bc8dd475c124f6de2413385d3 -0.018792  0.016435 -0.148091  0.464433
# 4  6d7ed4bc4a17546447efed0ca6e2ff11  0.084419  0.065945 -0.153379  0.635377
#
#          f5        f6        f7        f8        f9  ...  leg-length  \
# 0  0.214236  0.016104 -0.180302 -0.100713 -0.117249  ...   83.279744
# 1  0.186508 -0.075221 -0.093846 -0.035840  0.033903  ...   84.876529
# 2  0.209973 -0.073485 -0.072783 -0.059395  0.008370  ...   82.275874
# 3  0.242849 -0.106556  0.001489 -0.083478  0.096048  ...   76.081842
# 4  0.285274 -0.056372 -0.139008 -0.120711 -0.002466  ...   81.328892
#
#    shoulder-breadth  shoulder-to-crotch      thigh      waist      wrist  \
# 0         39.922305           70.005128  55.945992  98.250390  20.187082
# 1         39.974203           73.591637  55.397032  88.003618  17.715785
# 2         36.059983           66.440526  53.742692  82.100598  17.086464
# 3         34.071748           62.218026  52.396573  83.999124  16.299751
# 4         36.834735           64.426273  49.895157  86.020117  16.531431
#
#    gender  height_cm  weight_kg    volume
# 0    male     180.00      94.60  0.203832
# 1    male     188.90      86.75  0.174640
# 2    male     179.70      73.85  0.168680
# 3  female     166.95      69.05  0.181684
# 4    male     173.20      65.55  0.186667
#
# [5 rows x 5139 columns]

# %%
import boto3  # S3 client
from io import StringIO  # in-memory text buffer

print("Preparing to upload updated dataset to S3...")  # track process

s3_out_path = "s3://ai-bmi-predictor/test-data/eff_testingA_v2.csv"  # target S3 path
print("Target:", s3_out_path)  # show target

# ---- parse s3://bucket/key ----
out_bucket = s3_out_path.replace("s3://", "").split("/", 1)[0]  # extract bucket
out_key = s3_out_path.replace("s3://", "").split("/", 1)[1]     # extract key
print(f"Parsed -> bucket={out_bucket}, key={out_key}")  # confirm parsing

# ---- write CSV to memory ----
csv_buffer = StringIO()  # create in-memory buffer
print("Serializing dataframe to CSV (in-memory)...")  # track process
data.to_csv(csv_buffer, index=False)  # write dataframe as CSV text
csv_body = csv_buffer.getvalue()  # get CSV string content
print(f"CSV size (chars): {len(csv_body):,}")  # print rough size

# ---- upload to S3 ----
s3 = boto3.client("s3")  # create S3 client
print("Uploading to S3...")  # track process
s3.put_object(
    Bucket=out_bucket,                 # destination bucket
    Key=out_key,                       # destination key
    Body=csv_body.encode("utf-8"),     # file bytes
    ContentType="text/csv"             # content type
)  # upload

print("Upload complete ✅")  # done
print(f"Saved to: {s3_out_path}")  # confirm final path
# Out:
# Preparing to upload updated dataset to S3...
# Target: s3://ai-bmi-predictor/test-data/eff_testingA_v2.csv
# Parsed -> bucket=ai-bmi-predictor, key=test-data/eff_testingA_v2.csv
# Serializing dataframe to CSV (in-memory)...
# CSV size (chars): 102,270,627
# Uploading to S3...
# Upload complete ✅
# Saved to: s3://ai-bmi-predictor/test-data/eff_testingA_v2.csv
