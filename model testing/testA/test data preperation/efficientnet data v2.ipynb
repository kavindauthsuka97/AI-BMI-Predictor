# %%
import boto3
import pandas as pd

bucket = "ai-bmi-predictor-v2"
key = "test-data/eff_testingA.csv"

s3 = boto3.client("s3")
obj = s3.get_object(Bucket=bucket, Key=key)

data = pd.read_csv(obj["Body"])

data.head()
# Out:
#                            photo_id        f1        f2        f3        f4  \
# 0  e5ae8fe5bbdf611a1e8d06e66e849bdf  0.073159  0.085775 -0.133776  0.881202
# 1  605a5fd09058c48156b0ef518b63b2de  0.092031 -0.066016 -0.145132  0.687441
# 2  909c9277309e13ee014e347603aba620  0.057046 -0.051366 -0.148253  0.675916
# 3  bef6a68bc8dd475c124f6de2413385d3 -0.018792  0.016435 -0.148091  0.464433
# 4  6d7ed4bc4a17546447efed0ca6e2ff11  0.084419  0.065945 -0.153379  0.635377
#
#          f5        f6        f7        f8        f9  ...         hip  \
# 0  0.214236  0.016104 -0.180302 -0.100713 -0.117249  ...  106.774690
# 1  0.186508 -0.075221 -0.093846 -0.035840  0.033903  ...  102.481633
# 2  0.209973 -0.073485 -0.072783 -0.059395  0.008370  ...   99.342301
# 3  0.242849 -0.106556  0.001489 -0.083478  0.096048  ...  101.770144
# 4  0.285274 -0.056372 -0.139008 -0.120711 -0.002466  ...   94.707063
#
#    leg-length  shoulder-breadth  shoulder-to-crotch      thigh      waist  \
# 0   83.279744         39.922305           70.005128  55.945992  98.250390
# 1   84.876529         39.974203           73.591637  55.397032  88.003618
# 2   82.275874         36.059983           66.440526  53.742692  82.100598
# 3   76.081842         34.071748           62.218026  52.396573  83.999124
# 4   81.328892         36.834735           64.426273  49.895157  86.020117
#
#        wrist  gender  height_cm  weight_kg
# 0  20.187082    male     180.00      94.60
# 1  17.715785    male     188.90      86.75
# 2  17.086464    male     179.70      73.85
# 3  16.299751  female     166.95      69.05
# 4  16.531431    male     173.20      65.55
#
# [5 rows x 5138 columns]

# %%
# =========================
# Silhouette area features
# =========================

import boto3  # AWS SDK for Python (S3 access)
import numpy as np  # fast array operations
import pandas as pd  # dataframe operations
from PIL import Image  # read PNG images
from io import BytesIO  # convert S3 bytes -> file-like object
from botocore.exceptions import ClientError  # catch S3 missing-key errors

# -------------------------
# CONFIG (edit if needed)
# -------------------------

MASK_BUCKET = "amazon-bodym"  # S3 bucket containing the mask images
FRONT_MASK_PREFIX = "testA/mask/"  # S3 prefix/folder for front masks
SIDE_MASK_PREFIX = "testA/mask_left/"  # S3 prefix/folder for side masks
PHOTO_ID_COL = "photo_id"  # dataframe column containing photo IDs

FRONT_AREA_COL = "front_silhouette_area_norm"  # output column for normalized front area
SIDE_AREA_COL  = "side_silhouette_area_norm"   # output column for normalized side area

# optional debug columns (keep or remove)
FRONT_AREA_RAW_COL = "front_silhouette_area"  # raw (unnormalized) front pixel area
SIDE_AREA_RAW_COL  = "side_silhouette_area"   # raw (unnormalized) side pixel area
FRONT_H_COL = "front_mask_height"  # computed pixel height for front mask
SIDE_H_COL  = "side_mask_height"   # computed pixel height for side mask

# -------------------------
# S3 client (reused)
# -------------------------

print("Creating S3 client...")  # progress log
s3 = boto3.client("s3")  # create S3 client

# -----------------------------------------
# Helper: standardize photo_id -> filename
# -----------------------------------------

print("Preparing photo_id normalization...")  # progress log
photo_id_series = data[PHOTO_ID_COL].astype(str).fillna("")  # ensure string + no NaN
photo_id_series = photo_id_series.str.strip()  # remove whitespace
photo_id_series = photo_id_series.str.replace(".png", "", regex=False)  # drop .png if present
photo_id_series = photo_id_series.str.split(".", n=1).str[0]  # drop trailing decimals like ".0"

pad_len = int(photo_id_series.str.len().max()) if len(photo_id_series) else 0  # infer max length
pad_len = max(pad_len, 4)  # at least 4 (e.g., "0021")
print(f"Using zero-pad length = {pad_len}")  # show chosen pad length

def normalize_photo_id(photo_id, pad_length):  # normalize id to match PNG filenames
    pid = str(photo_id).strip()  # convert to string and trim
    pid = pid.replace(".png", "")  # remove extension if included
    pid = pid.split(".", 1)[0]  # remove any trailing decimals
    if pid.isdigit():  # pad only if numeric
        pid = pid.zfill(pad_length)  # zero-pad on the left
    return pid  # return normalized id

# -----------------------------------------
# Helper: read mask PNG from S3 into boolean
# -----------------------------------------

def load_mask_bool_from_s3(bucket, key):  # loads mask and converts to boolean array
    print(f"    Downloading mask: s3://{bucket}/{key}")  # track downloads
    obj = s3.get_object(Bucket=bucket, Key=key)  # fetch file bytes from S3
    img = Image.open(BytesIO(obj["Body"].read()))  # open image from bytes
    img = img.convert("L")  # convert to grayscale
    arr = np.array(img)  # convert image to numpy array
    return arr > 0  # True for body pixels (white), False otherwise

# -----------------------------------------
# Helper: compute height from mask
# -----------------------------------------

def mask_height(mask_bool):  # compute vertical body extent in pixels
    if mask_bool.size == 0:  # guard: empty image
        return np.nan  # cannot compute
    ys, xs = np.where(mask_bool)  # coordinates of body pixels
    if ys.size == 0:  # guard: no body pixels
        return np.nan  # cannot compute
    return float(ys.max() - ys.min() + 1)  # height = bottom - top + 1

# -----------------------------------------
# Helper: silhouette area + normalization
# -----------------------------------------

def silhouette_area(mask_bool):  # count body pixels in the mask
    if mask_bool.size == 0:  # guard: empty image
        return np.nan  # cannot compute
    return float(np.count_nonzero(mask_bool))  # number of True pixels

def normalized_silhouette_area(mask_bool):  # area normalized by height^2
    a = silhouette_area(mask_bool)  # compute raw pixel area
    h = mask_height(mask_bool)  # compute pixel height
    if np.isnan(a) or np.isnan(h) or h <= 0:  # guard: invalid values
        return np.nan, a, h  # return NaN normalized area + raw diagnostics
    return float(a / (h * h)), a, h  # normalized area, raw area, height

# -----------------------------------------
# Per-record feature computation
# -----------------------------------------

def compute_areas_for_photo_id(photo_id):  # compute front+side areas for one record
    pid = normalize_photo_id(photo_id, pad_len)  # normalize ID to match filenames
    front_key = f"{FRONT_MASK_PREFIX}{pid}.png"  # build S3 key for front mask
    side_key  = f"{SIDE_MASK_PREFIX}{pid}.png"   # build S3 key for side mask

    print(f"  Processing photo_id={photo_id} -> pid={pid}")  # per-record log

    try:
        front_mask = load_mask_bool_from_s3(MASK_BUCKET, front_key)  # load front mask
    except ClientError as e:
        print(f"    ERROR: missing front mask for pid={pid} | {e}")  # missing file log
        return (np.nan, np.nan, np.nan, np.nan, np.nan, np.nan)  # return NaNs

    try:
        side_mask = load_mask_bool_from_s3(MASK_BUCKET, side_key)  # load side mask
    except ClientError as e:
        print(f"    ERROR: missing side mask for pid={pid} | {e}")  # missing file log
        return (np.nan, np.nan, np.nan, np.nan, np.nan, np.nan)  # return NaNs

    front_norm, front_raw, front_h = normalized_silhouette_area(front_mask)  # front features
    side_norm,  side_raw,  side_h  = normalized_silhouette_area(side_mask)   # side features

    print(
        f"    front_raw_area={front_raw} | front_h={front_h} | front_norm={front_norm} "
        f"|| side_raw_area={side_raw} | side_h={side_h} | side_norm={side_norm}"
    )  # computed values log

    return front_norm, side_norm, front_raw, side_raw, front_h, side_h  # return all values

# -----------------------------------------
# Run across the dataframe and add columns
# -----------------------------------------

print("Starting silhouette area computation for all records...")  # progress log

front_norms, side_norms = [], []  # store normalized areas
front_raws, side_raws = [], []  # store raw areas (debug)
front_hs, side_hs = [], []  # store heights (debug)

n = len(data)  # total rows
print(f"Total rows to process: {n}")  # show total count

for i, photo_id in enumerate(data[PHOTO_ID_COL].tolist(), start=1):  # loop through all records
    print(f"\nRecord {i}/{n}")  # record progress
    fn, sn, fr, sr, fh, sh = compute_areas_for_photo_id(photo_id)  # compute features

    front_norms.append(fn)  # save front normalized area
    side_norms.append(sn)  # save side normalized area
    front_raws.append(fr)  # save front raw area
    side_raws.append(sr)  # save side raw area
    front_hs.append(fh)  # save front height
    side_hs.append(sh)  # save side height

    if i % 50 == 0:  # periodic update
        print(f"\nProcessed {i}/{n} records so far...")  # progress log

print("\nAttaching new feature columns to dataframe...")  # progress log
data[FRONT_AREA_COL] = front_norms  # add normalized front area feature
data[SIDE_AREA_COL]  = side_norms   # add normalized side area feature
# Out:
# Creating S3 client...
# Preparing photo_id normalization...
# Using zero-pad length = 32
# Starting silhouette area computation for all records...
# Total rows to process: 1684
#
# Record 1/1684
#   Processing photo_id=e5ae8fe5bbdf611a1e8d06e66e849bdf -> pid=e5ae8fe5bbdf611a1e8d06e66e849bdf
#     Downloading mask: s3://amazon-bodym/testA/mask/e5ae8fe5bbdf611a1e8d06e66e849bdf.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/e5ae8fe5bbdf611a1e8d06e66e849bdf.png
#     front_raw_area=136770.0 | front_h=838.0 | front_norm=0.19476136499564253 || side_raw_area=99095.0 | side_h=917.0 | side_norm=0.1178455182550848
#
# Record 2/1684
#   Processing photo_id=605a5fd09058c48156b0ef518b63b2de -> pid=605a5fd09058c48156b0ef518b63b2de
#     Downloading mask: s3://amazon-bodym/testA/mask/605a5fd09058c48156b0ef518b63b2de.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/605a5fd09058c48156b0ef518b63b2de.png
#     front_raw_area=102023.0 | front_h=815.0 | front_norm=0.15359704919266814 || side_raw_area=106077.0 | side_h=876.0 | side_norm=0.13823340839432038
#
# Record 3/1684
#   Processing photo_id=909c9277309e13ee014e347603aba620 -> pid=909c9277309e13ee014e347603aba620
#     Downloading mask: s3://amazon-bodym/testA/mask/909c9277309e13ee014e347603aba620.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/909c9277309e13ee014e347603aba620.png
#     front_raw_area=108765.0 | front_h=799.0 | front_norm=0.17037097372967774 || side_raw_area=79794.0 | side_h=869.0 | side_norm=0.10566488470670493
#
# Record 4/1684
#   Processing photo_id=bef6a68bc8dd475c124f6de2413385d3 -> pid=bef6a68bc8dd475c124f6de2413385d3
#     Downloading mask: s3://amazon-bodym/testA/mask/bef6a68bc8dd475c124f6de2413385d3.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/bef6a68bc8dd475c124f6de2413385d3.png
#     front_raw_area=128448.0 | front_h=857.0 | front_norm=0.17489029190590497 || side_raw_area=89721.0 | side_h=873.0 | side_norm=0.11772416480674532
#
# Record 5/1684
#   Processing photo_id=6d7ed4bc4a17546447efed0ca6e2ff11 -> pid=6d7ed4bc4a17546447efed0ca6e2ff11
#     Downloading mask: s3://amazon-bodym/testA/mask/6d7ed4bc4a17546447efed0ca6e2ff11.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/6d7ed4bc4a17546447efed0ca6e2ff11.png
#     front_raw_area=119811.0 | front_h=836.0 | front_norm=0.171428939355784 || side_raw_area=80226.0 | side_h=855.0 | side_norm=0.10974453678054787
#
# Record 6/1684
#   Processing photo_id=4c12d6a82cb0a75ee556a54ab1afc21e -> pid=4c12d6a82cb0a75ee556a54ab1afc21e
#     Downloading mask: s3://amazon-bodym/testA/mask/4c12d6a82cb0a75ee556a54ab1afc21e.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/4c12d6a82cb0a75ee556a54ab1afc21e.png
#     front_raw_area=128763.0 | front_h=831.0 | front_norm=0.18646144221871783 || side_raw_area=99828.0 | side_h=904.0 | side_norm=0.1221561986059989
#
# Record 7/1684
#   Processing photo_id=dd27be8b3d6b9c2c14c14318612ba0dc -> pid=dd27be8b3d6b9c2c14c14318612ba0dc
#     Downloading mask: s3://amazon-bodym/testA/mask/dd27be8b3d6b9c2c14c14318612ba0dc.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/dd27be8b3d6b9c2c14c14318612ba0dc.png
#     front_raw_area=135195.0 | front_h=891.0 | front_norm=0.17029630385410408 || side_raw_area=82982.0 | side_h=862.0 | side_norm=0.11167844703678383
#
# Record 8/1684
#   Processing photo_id=fc65b84d8183e3a872785b4e2eecaa66 -> pid=fc65b84d8183e3a872785b4e2eecaa66
#     Downloading mask: s3://amazon-bodym/testA/mask/fc65b84d8183e3a872785b4e2eecaa66.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/fc65b84d8183e3a872785b4e2eecaa66.png
#     front_raw_area=127144.0 | front_h=840.0 | front_norm=0.18019274376417233 || side_raw_area=79302.0 | side_h=841.0 | side_norm=0.11212233892894055
#
# Record 9/1684
#   Processing photo_id=851f712c7cfc6b62b20b6f8cba65c20a -> pid=851f712c7cfc6b62b20b6f8cba65c20a
#     Downloading mask: s3://amazon-bodym/testA/mask/851f712c7cfc6b62b20b6f8cba65c20a.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/851f712c7cfc6b62b20b6f8cba65c20a.png
#     front_raw_area=132768.0 | front_h=883.0 | front_norm=0.1702832796153338 || side_raw_area=78049.0 | side_h=880.0 | side_norm=0.10078641528925619
#
# Record 10/1684
#   Processing photo_id=c9ede0a19f8e79ec7a4cd8f126129f2d -> pid=c9ede0a19f8e79ec7a4cd8f126129f2d
#     Downloading mask: s3://amazon-bodym/testA/mask/c9ede0a19f8e79ec7a4cd8f126129f2d.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/c9ede0a19f8e79ec7a4cd8f126129f2d.png
#     front_raw_area=122952.0 | front_h=816.0 | front_norm=0.18465253748558247 || side_raw_area=91016.0 | side_h=865.0 | side_norm=0.12164255404457215
#
# Record 11/1684
#   Processing photo_id=652500aa90597ed06ccc8f15bc9b83aa -> pid=652500aa90597ed06ccc8f15bc9b83aa
#     Downloading mask: s3://amazon-bodym/testA/mask/652500aa90597ed06ccc8f15bc9b83aa.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/652500aa90597ed06ccc8f15bc9b83aa.png
#     front_raw_area=110595.0 | front_h=805.0 | front_norm=0.17066471200956754 || side_raw_area=83744.0 | side_h=896.0 | side_norm=0.10431281887755102
#
# Record 12/1684
#   Processing photo_id=b55e0664c7c1642cd015b5585a8d5fd3 -> pid=b55e0664c7c1642cd015b5585a8d5fd3
#     Downloading mask: s3://amazon-bodym/testA/mask/b55e0664c7c1642cd015b5585a8d5fd3.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/b55e0664c7c1642cd015b5585a8d5fd3.png
#     front_raw_area=111798.0 | front_h=822.0 | front_norm=0.16545900154510096 || side_raw_area=95804.0 | side_h=900.0 | side_norm=0.11827654320987654
#
# Record 13/1684
#   Processing photo_id=67194d8a47331d1f722db4f737546021 -> pid=67194d8a47331d1f722db4f737546021
#     Downloading mask: s3://amazon-bodym/testA/mask/67194d8a47331d1f722db4f737546021.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/67194d8a47331d1f722db4f737546021.png
#     front_raw_area=132282.0 | front_h=812.0 | front_norm=0.2006266834914703 || side_raw_area=91701.0 | side_h=886.0 | side_norm=0.11681715575620767
#
# Record 14/1684
#   Processing photo_id=719fc866000f5edb56700ee0755ea109 -> pid=719fc866000f5edb56700ee0755ea109
#     Downloading mask: s3://amazon-bodym/testA/mask/719fc866000f5edb56700ee0755ea109.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/719fc866000f5edb56700ee0755ea109.png
#     front_raw_area=132804.0 | front_h=871.0 | front_norm=0.17505513147852542 || side_raw_area=84610.0 | side_h=858.0 | side_norm=0.1149336289196429
#
# Record 15/1684
#   Processing photo_id=46c5d36f10af6cf0fd2b4a02eb9a9add -> pid=46c5d36f10af6cf0fd2b4a02eb9a9add
#     Downloading mask: s3://amazon-bodym/testA/mask/46c5d36f10af6cf0fd2b4a02eb9a9add.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/46c5d36f10af6cf0fd2b4a02eb9a9add.png
#     front_raw_area=116369.0 | front_h=823.0 | front_norm=0.17180572513505254 || side_raw_area=87330.0 | side_h=871.0 | side_norm=0.11511373627315159
#
# Record 16/1684
#   Processing photo_id=e1a3c3b6df492a58fde15be36a8371bc -> pid=e1a3c3b6df492a58fde15be36a8371bc
#     Downloading mask: s3://amazon-bodym/testA/mask/e1a3c3b6df492a58fde15be36a8371bc.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/e1a3c3b6df492a58fde15be36a8371bc.png
#     front_raw_area=130280.0 | front_h=826.0 | front_norm=0.19094911736599265 || side_raw_area=97607.0 | side_h=885.0 | side_norm=0.12462191579686552
#
# Record 17/1684
#   Processing photo_id=7ac05db49a083076cb5ed077f16b90e0 -> pid=7ac05db49a083076cb5ed077f16b90e0
#     Downloading mask: s3://amazon-bodym/testA/mask/7ac05db49a083076cb5ed077f16b90e0.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/7ac05db49a083076cb5ed077f16b90e0.png
#     front_raw_area=116391.0 | front_h=807.0 | front_norm=0.178719660222127 || side_raw_area=81439.0 | side_h=844.0 | side_norm=0.1143266660676984
#
# Record 18/1684
#   Processing photo_id=7e1e1d9f8724124bcae0a945c3c324cc -> pid=7e1e1d9f8724124bcae0a945c3c324cc
#     Downloading mask: s3://amazon-bodym/testA/mask/7e1e1d9f8724124bcae0a945c3c324cc.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/7e1e1d9f8724124bcae0a945c3c324cc.png
#     front_raw_area=126251.0 | front_h=842.0 | front_norm=0.1780781534746475 || side_raw_area=74383.0 | side_h=851.0 | side_norm=0.10271043536255818
#
# Record 19/1684
#   Processing photo_id=b5876de60bcfdb5600aade28cc554c52 -> pid=b5876de60bcfdb5600aade28cc554c52
#     Downloading mask: s3://amazon-bodym/testA/mask/b5876de60bcfdb5600aade28cc554c52.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/b5876de60bcfdb5600aade28cc554c52.png
#     front_raw_area=130184.0 | front_h=875.0 | front_norm=0.17003624489795918 || side_raw_area=78798.0 | side_h=892.0 | side_norm=0.0990342657202035
#
# Record 20/1684
#   Processing photo_id=1c6fe922a59a5b63ec8c0e2264eb49af -> pid=1c6fe922a59a5b63ec8c0e2264eb49af
#     Downloading mask: s3://amazon-bodym/testA/mask/1c6fe922a59a5b63ec8c0e2264eb49af.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/1c6fe922a59a5b63ec8c0e2264eb49af.png
#     front_raw_area=118356.0 | front_h=828.0 | front_norm=0.17263530070713434 || side_raw_area=73212.0 | side_h=824.0 | side_norm=0.10782708078046942
#
# Record 21/1684
#   Processing photo_id=09735076f4d5e0fdbc4c883a3ec74072 -> pid=09735076f4d5e0fdbc4c883a3ec74072
#     Downloading mask: s3://amazon-bodym/testA/mask/09735076f4d5e0fdbc4c883a3ec74072.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/09735076f4d5e0fdbc4c883a3ec74072.png
#     front_raw_area=118152.0 | front_h=824.0 | front_norm=0.17401498727495524 || side_raw_area=83509.0 | side_h=872.0 | side_norm=0.10982477274640182
#
# Record 22/1684
#   Processing photo_id=2e2c6428f26c80bf286b854fe851b518 -> pid=2e2c6428f26c80bf286b854fe851b518
#     Downloading mask: s3://amazon-bodym/testA/mask/2e2c6428f26c80bf286b854fe851b518.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/2e2c6428f26c80bf286b854fe851b518.png
#     front_raw_area=128199.0 | front_h=853.0 | front_norm=0.176192158150875 || side_raw_area=86108.0 | side_h=878.0 | side_norm=0.11170033364293461
#
# Record 23/1684
#   Processing photo_id=a7cc758a534dedded8604cea3a52b681 -> pid=a7cc758a534dedded8604cea3a52b681
#     Downloading mask: s3://amazon-bodym/testA/mask/a7cc758a534dedded8604cea3a52b681.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/a7cc758a534dedded8604cea3a52b681.png
#     front_raw_area=121757.0 | front_h=829.0 | front_norm=0.17716783486433435 || side_raw_area=97167.0 | side_h=923.0 | side_norm=0.11405527925449187
#
# Record 24/1684
#   Processing photo_id=a49e4915a40d206006fe883bcada4088 -> pid=a49e4915a40d206006fe883bcada4088
#     Downloading mask: s3://amazon-bodym/testA/mask/a49e4915a40d206006fe883bcada4088.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/a49e4915a40d206006fe883bcada4088.png
#     front_raw_area=130387.0 | front_h=866.0 | front_norm=0.1738595330926081 || side_raw_area=86654.0 | side_h=884.0 | side_norm=0.1108878810835159
#
# Record 25/1684
#   Processing photo_id=6e567773d006c757fa8fb750201eecb2 -> pid=6e567773d006c757fa8fb750201eecb2
#     Downloading mask: s3://amazon-bodym/testA/mask/6e567773d006c757fa8fb750201eecb2.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/6e567773d006c757fa8fb750201eecb2.png
#     front_raw_area=128710.0 | front_h=817.0 | front_norm=0.19282714771329565 || side_raw_area=83110.0 | side_h=841.0 | side_norm=0.1175063376508064
#
# Record 26/1684
#   Processing photo_id=0d89f5b1adb8b5c0d52fead18a8aca86 -> pid=0d89f5b1adb8b5c0d52fead18a8aca86
#     Downloading mask: s3://amazon-bodym/testA/mask/0d89f5b1adb8b5c0d52fead18a8aca86.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/0d89f5b1adb8b5c0d52fead18a8aca86.png
#     front_raw_area=132130.0 | front_h=824.0 | front_norm=0.19460187105287963 || side_raw_area=85222.0 | side_h=861.0 | side_norm=0.1149596463610231
#
# Record 27/1684
#   Processing photo_id=90e3d2a537e221c3d009bbfd76c31781 -> pid=90e3d2a537e221c3d009bbfd76c31781
#     Downloading mask: s3://amazon-bodym/testA/mask/90e3d2a537e221c3d009bbfd76c31781.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/90e3d2a537e221c3d009bbfd76c31781.png
#     front_raw_area=137420.0 | front_h=894.0 | front_norm=0.17193920193785064 || side_raw_area=79996.0 | side_h=852.0 | side_norm=0.11020189997575437
#
# Record 28/1684
#   Processing photo_id=1ea5a5846c1e4876aeef5e5df54493fb -> pid=1ea5a5846c1e4876aeef5e5df54493fb
#     Downloading mask: s3://amazon-bodym/testA/mask/1ea5a5846c1e4876aeef5e5df54493fb.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/1ea5a5846c1e4876aeef5e5df54493fb.png
#     front_raw_area=118014.0 | front_h=854.0 | front_norm=0.16181463179198044 || side_raw_area=99992.0 | side_h=909.0 | side_norm=0.12101452169419362
#
# Record 29/1684
#   Processing photo_id=cc30e4cf064a73a33f49f98502659453 -> pid=cc30e4cf064a73a33f49f98502659453
#     Downloading mask: s3://amazon-bodym/testA/mask/cc30e4cf064a73a33f49f98502659453.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/cc30e4cf064a73a33f49f98502659453.png
#     front_raw_area=106795.0 | front_h=849.0 | front_norm=0.1481615591543297 || side_raw_area=67516.0 | side_h=868.0 | side_norm=0.08961222366157702
#
# Record 30/1684
#   Processing photo_id=783223cf280aeb356e61a58a8ecfffea -> pid=783223cf280aeb356e61a58a8ecfffea
#     Downloading mask: s3://amazon-bodym/testA/mask/783223cf280aeb356e61a58a8ecfffea.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/783223cf280aeb356e61a58a8ecfffea.png
#     front_raw_area=107478.0 | front_h=817.0 | front_norm=0.16101838382355366 || side_raw_area=84269.0 | side_h=899.0 | side_norm=0.10426737903071141
#
# Record 31/1684
#   Processing photo_id=0aad7e8a4987342302961aa4cc0ccbed -> pid=0aad7e8a4987342302961aa4cc0ccbed
#     Downloading mask: s3://amazon-bodym/testA/mask/0aad7e8a4987342302961aa4cc0ccbed.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/0aad7e8a4987342302961aa4cc0ccbed.png
#     front_raw_area=111885.0 | front_h=785.0 | front_norm=0.18156517505781167 || side_raw_area=98795.0 | side_h=904.0 | side_norm=0.12089215091236588
#
# Record 32/1684
#   Processing photo_id=8bfd63f2d47016a1a03ad5dcdb11a844 -> pid=8bfd63f2d47016a1a03ad5dcdb11a844
#     Downloading mask: s3://amazon-bodym/testA/mask/8bfd63f2d47016a1a03ad5dcdb11a844.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/8bfd63f2d47016a1a03ad5dcdb11a844.png
#     front_raw_area=109559.0 | front_h=809.0 | front_norm=0.16739828963713232 || side_raw_area=83769.0 | side_h=872.0 | side_norm=0.11016670524366635
#
# Record 33/1684
#   Processing photo_id=5310a6a41e39c0cc8670d12c0330796a -> pid=5310a6a41e39c0cc8670d12c0330796a
#     Downloading mask: s3://amazon-bodym/testA/mask/5310a6a41e39c0cc8670d12c0330796a.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/5310a6a41e39c0cc8670d12c0330796a.png
#     front_raw_area=131022.0 | front_h=881.0 | front_norm=0.16880776024561914 || side_raw_area=77749.0 | side_h=829.0 | side_norm=0.11313207448333264
#
# Record 34/1684
#   Processing photo_id=33130c0719c02d71be90ddf431943b73 -> pid=33130c0719c02d71be90ddf431943b73
#     Downloading mask: s3://amazon-bodym/testA/mask/33130c0719c02d71be90ddf431943b73.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/33130c0719c02d71be90ddf431943b73.png
#     front_raw_area=116044.0 | front_h=817.0 | front_norm=0.17385155410800776 || side_raw_area=98529.0 | side_h=867.0 | side_norm=0.13107681501259164
#
# Record 35/1684
#   Processing photo_id=fe5068eb0602ffa458cd43c689ad2c94 -> pid=fe5068eb0602ffa458cd43c689ad2c94
#     Downloading mask: s3://amazon-bodym/testA/mask/fe5068eb0602ffa458cd43c689ad2c94.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/fe5068eb0602ffa458cd43c689ad2c94.png
#     front_raw_area=140963.0 | front_h=865.0 | front_norm=0.1883965384743894 || side_raw_area=94845.0 | side_h=932.0 | side_norm=0.1091899371880123
#
# Record 36/1684
#   Processing photo_id=dea8deceafe67f7dfeafcc9030cb71be -> pid=dea8deceafe67f7dfeafcc9030cb71be
#     Downloading mask: s3://amazon-bodym/testA/mask/dea8deceafe67f7dfeafcc9030cb71be.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/dea8deceafe67f7dfeafcc9030cb71be.png
#     front_raw_area=112300.0 | front_h=826.0 | front_norm=0.16459614584127244 || side_raw_area=77531.0 | side_h=871.0 | side_norm=0.10219721844719702
#
# Record 37/1684
#   Processing photo_id=cbd9cba29a166e7e53067c72dfe5a397 -> pid=cbd9cba29a166e7e53067c72dfe5a397
#     Downloading mask: s3://amazon-bodym/testA/mask/cbd9cba29a166e7e53067c72dfe5a397.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/cbd9cba29a166e7e53067c72dfe5a397.png
#     front_raw_area=111940.0 | front_h=793.0 | front_norm=0.17800775702911192 || side_raw_area=73262.0 | side_h=824.0 | side_norm=0.10790072108587048
#
# Record 38/1684
#   Processing photo_id=f5acb42eed491bba2cd7f7deeca73577 -> pid=f5acb42eed491bba2cd7f7deeca73577
#     Downloading mask: s3://amazon-bodym/testA/mask/f5acb42eed491bba2cd7f7deeca73577.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/f5acb42eed491bba2cd7f7deeca73577.png
#     front_raw_area=114096.0 | front_h=821.0 | front_norm=0.16927160217256815 || side_raw_area=92279.0 | side_h=887.0 | side_norm=0.11728855610731993
#
# Record 39/1684
#   Processing photo_id=83c16a5818cd82c37d8f72ebbdf2938b -> pid=83c16a5818cd82c37d8f72ebbdf2938b
#     Downloading mask: s3://amazon-bodym/testA/mask/83c16a5818cd82c37d8f72ebbdf2938b.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/83c16a5818cd82c37d8f72ebbdf2938b.png
#     front_raw_area=116167.0 | front_h=841.0 | front_norm=0.16424447991675162 || side_raw_area=76545.0 | side_h=849.0 | side_norm=0.10619435877586185
#
# Record 40/1684
#   Processing photo_id=4a3d5b8a392fab125e0591960e0e0c15 -> pid=4a3d5b8a392fab125e0591960e0e0c15
#     Downloading mask: s3://amazon-bodym/testA/mask/4a3d5b8a392fab125e0591960e0e0c15.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/4a3d5b8a392fab125e0591960e0e0c15.png
#     front_raw_area=127248.0 | front_h=847.0 | front_norm=0.1773716248332541 || side_raw_area=118449.0 | side_h=896.0 | side_norm=0.14754190250318877
#
# Record 41/1684
#   Processing photo_id=8115f0ec6fa7e8fc12e918c5caaf3c9a -> pid=8115f0ec6fa7e8fc12e918c5caaf3c9a
#     Downloading mask: s3://amazon-bodym/testA/mask/8115f0ec6fa7e8fc12e918c5caaf3c9a.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/8115f0ec6fa7e8fc12e918c5caaf3c9a.png
#     front_raw_area=160639.0 | front_h=883.0 | front_norm=0.20602958359038026 || side_raw_area=98257.0 | side_h=869.0 | side_norm=0.1301139756952491
#
# Record 42/1684
#   Processing photo_id=57adf42d38fd1a6683bf3c46a547847a -> pid=57adf42d38fd1a6683bf3c46a547847a
#     Downloading mask: s3://amazon-bodym/testA/mask/57adf42d38fd1a6683bf3c46a547847a.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/57adf42d38fd1a6683bf3c46a547847a.png
#     front_raw_area=101308.0 | front_h=782.0 | front_norm=0.16566479811094903 || side_raw_area=78649.0 | side_h=864.0 | side_norm=0.10535756387174211
#
# Record 43/1684
#   Processing photo_id=4e9bf0300f31f1335f938643220f81f5 -> pid=4e9bf0300f31f1335f938643220f81f5
#     Downloading mask: s3://amazon-bodym/testA/mask/4e9bf0300f31f1335f938643220f81f5.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/4e9bf0300f31f1335f938643220f81f5.png
#     front_raw_area=120673.0 | front_h=860.0 | front_norm=0.1631598161168199 || side_raw_area=125945.0 | side_h=897.0 | side_norm=0.15652944473651176
#
# Record 44/1684
#   Processing photo_id=d00150c491b8faa77a5cb9bd8422029e -> pid=d00150c491b8faa77a5cb9bd8422029e
#     Downloading mask: s3://amazon-bodym/testA/mask/d00150c491b8faa77a5cb9bd8422029e.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/d00150c491b8faa77a5cb9bd8422029e.png
#     front_raw_area=117100.0 | front_h=837.0 | front_norm=0.16714984534000218 || side_raw_area=79310.0 | side_h=877.0 | side_norm=0.1031166423317805
#
# Record 45/1684
#   Processing photo_id=71affd9167bebfa3402da73d5b02036c -> pid=71affd9167bebfa3402da73d5b02036c
#     Downloading mask: s3://amazon-bodym/testA/mask/71affd9167bebfa3402da73d5b02036c.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/71affd9167bebfa3402da73d5b02036c.png
#     front_raw_area=124591.0 | front_h=855.0 | front_norm=0.17043329571492083 || side_raw_area=78194.0 | side_h=866.0 | side_norm=0.10426478353396733
#
# Record 46/1684
#   Processing photo_id=8947ac15cbf9a90c47495d2f9aa1fe0c -> pid=8947ac15cbf9a90c47495d2f9aa1fe0c
#     Downloading mask: s3://amazon-bodym/testA/mask/8947ac15cbf9a90c47495d2f9aa1fe0c.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/8947ac15cbf9a90c47495d2f9aa1fe0c.png
#     front_raw_area=109605.0 | front_h=782.0 | front_norm=0.1792325403418345 || side_raw_area=78913.0 | side_h=849.0 | side_norm=0.10947959284185232
#
# Record 47/1684
#   Processing photo_id=a32ee410d093b47d1b29574593513f6e -> pid=a32ee410d093b47d1b29574593513f6e
#     Downloading mask: s3://amazon-bodym/testA/mask/a32ee410d093b47d1b29574593513f6e.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/a32ee410d093b47d1b29574593513f6e.png
#     front_raw_area=115293.0 | front_h=825.0 | front_norm=0.16939283746556474 || side_raw_area=71874.0 | side_h=850.0 | side_norm=0.0994795847750865
#
# Record 48/1684
#   Processing photo_id=98219e748c76cdb3e827505d154db8de -> pid=98219e748c76cdb3e827505d154db8de
#     Downloading mask: s3://amazon-bodym/testA/mask/98219e748c76cdb3e827505d154db8de.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/98219e748c76cdb3e827505d154db8de.png
#     front_raw_area=112894.0 | front_h=835.0 | front_norm=0.16191903617913872 || side_raw_area=71052.0 | side_h=824.0 | side_norm=0.10464581958714299
#
# Record 49/1684
#   Processing photo_id=256a73e60cb5fa2706be990b7fc7f6f9 -> pid=256a73e60cb5fa2706be990b7fc7f6f9
#     Downloading mask: s3://amazon-bodym/testA/mask/256a73e60cb5fa2706be990b7fc7f6f9.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/256a73e60cb5fa2706be990b7fc7f6f9.png
#     front_raw_area=127943.0 | front_h=861.0 | front_norm=0.17258785330511345 || side_raw_area=98795.0 | side_h=904.0 | side_norm=0.12089215091236588
#
# Record 50/1684
#   Processing photo_id=20192a081a6e6cc01e7388070cd12441 -> pid=20192a081a6e6cc01e7388070cd12441
#     Downloading mask: s3://amazon-bodym/testA/mask/20192a081a6e6cc01e7388070cd12441.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/20192a081a6e6cc01e7388070cd12441.png
#     front_raw_area=118684.0 | front_h=833.0 | front_norm=0.17104176604615437 || side_raw_area=83283.0 | side_h=886.0 | side_norm=0.10609353423456935
#
# Processed 50/1684 records so far...
#
# Record 51/1684
#   Processing photo_id=824c5dbd22639b8a4f4130f3e53eaa55 -> pid=824c5dbd22639b8a4f4130f3e53eaa55
#     Downloading mask: s3://amazon-bodym/testA/mask/824c5dbd22639b8a4f4130f3e53eaa55.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/824c5dbd22639b8a4f4130f3e53eaa55.png
#     front_raw_area=123360.0 | front_h=819.0 | front_norm=0.18391051358084326 || side_raw_area=93055.0 | side_h=875.0 | side_norm=0.12154122448979592
#
# Record 52/1684
#   Processing photo_id=f3fac2f83e7c2571c2769b0e9fdcf4f6 -> pid=f3fac2f83e7c2571c2769b0e9fdcf4f6
#     Downloading mask: s3://amazon-bodym/testA/mask/f3fac2f83e7c2571c2769b0e9fdcf4f6.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/f3fac2f83e7c2571c2769b0e9fdcf4f6.png
#     front_raw_area=113220.0 | front_h=824.0 | front_norm=0.16675110755019323 || side_raw_area=78360.0 | side_h=879.0 | side_norm=0.1014183818875778
#
# Record 53/1684
#   Processing photo_id=a78989815ffd2c907a4d3dd91c87364d -> pid=a78989815ffd2c907a4d3dd91c87364d
#     Downloading mask: s3://amazon-bodym/testA/mask/a78989815ffd2c907a4d3dd91c87364d.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/a78989815ffd2c907a4d3dd91c87364d.png
#     front_raw_area=116403.0 | front_h=860.0 | front_norm=0.15738642509464576 || side_raw_area=70725.0 | side_h=852.0 | side_norm=0.09743023870925081
#
# Record 54/1684
#   Processing photo_id=b87928100a9d9230a4623019f049184c -> pid=b87928100a9d9230a4623019f049184c
#     Downloading mask: s3://amazon-bodym/testA/mask/b87928100a9d9230a4623019f049184c.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/b87928100a9d9230a4623019f049184c.png
#     front_raw_area=112455.0 | front_h=791.0 | front_norm=0.17973216383428617 || side_raw_area=80404.0 | side_h=863.0 | side_norm=0.10795830653531498
#
# Record 55/1684
#   Processing photo_id=79a86609427b81242f8555822d749455 -> pid=79a86609427b81242f8555822d749455
#     Downloading mask: s3://amazon-bodym/testA/mask/79a86609427b81242f8555822d749455.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/79a86609427b81242f8555822d749455.png
#     front_raw_area=127493.0 | front_h=845.0 | front_norm=0.17855537271103952 || side_raw_area=81190.0 | side_h=867.0 | side_norm=0.10801009460029347
#
# Record 56/1684
#   Processing photo_id=dd886c6903c81753f0230763eded1ff5 -> pid=dd886c6903c81753f0230763eded1ff5
#     Downloading mask: s3://amazon-bodym/testA/mask/dd886c6903c81753f0230763eded1ff5.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/dd886c6903c81753f0230763eded1ff5.png
#     front_raw_area=140787.0 | front_h=888.0 | front_norm=0.1785404492330168 || side_raw_area=87297.0 | side_h=897.0 | side_norm=0.10849617640369422
#
# Record 57/1684
#   Processing photo_id=766cc99f817262d0ab3a7b15ce46b517 -> pid=766cc99f817262d0ab3a7b15ce46b517
#     Downloading mask: s3://amazon-bodym/testA/mask/766cc99f817262d0ab3a7b15ce46b517.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/766cc99f817262d0ab3a7b15ce46b517.png
#     front_raw_area=118551.0 | front_h=835.0 | front_norm=0.1700326293520743 || side_raw_area=79578.0 | side_h=893.0 | side_norm=0.09979070761891982
#
# Record 58/1684
#   Processing photo_id=71d1954e34fc0385e30bb07837345c73 -> pid=71d1954e34fc0385e30bb07837345c73
#     Downloading mask: s3://amazon-bodym/testA/mask/71d1954e34fc0385e30bb07837345c73.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/71d1954e34fc0385e30bb07837345c73.png
#     front_raw_area=154019.0 | front_h=845.0 | front_norm=0.2157053324463429 || side_raw_area=115051.0 | side_h=904.0 | side_norm=0.1407840766700603
#
# Record 59/1684
#   Processing photo_id=8cb7b3074fb5fd67dc019aaddfad8995 -> pid=8cb7b3074fb5fd67dc019aaddfad8995
#     Downloading mask: s3://amazon-bodym/testA/mask/8cb7b3074fb5fd67dc019aaddfad8995.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/8cb7b3074fb5fd67dc019aaddfad8995.png
#     front_raw_area=114693.0 | front_h=852.0 | front_norm=0.15800023143556172 || side_raw_area=107091.0 | side_h=922.0 | side_norm=0.12597696227666913
#
# Record 60/1684
#   Processing photo_id=1b57988171874d8fae376d94f4dc7f65 -> pid=1b57988171874d8fae376d94f4dc7f65
#     Downloading mask: s3://amazon-bodym/testA/mask/1b57988171874d8fae376d94f4dc7f65.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/1b57988171874d8fae376d94f4dc7f65.png
#     front_raw_area=126063.0 | front_h=858.0 | front_norm=0.1712430925717639 || side_raw_area=84317.0 | side_h=891.0 | side_norm=0.10620861312967561
#
# Record 61/1684
#   Processing photo_id=c050dd0ace9a5383945212717ecdd7cb -> pid=c050dd0ace9a5383945212717ecdd7cb
#     Downloading mask: s3://amazon-bodym/testA/mask/c050dd0ace9a5383945212717ecdd7cb.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/c050dd0ace9a5383945212717ecdd7cb.png
#     front_raw_area=117149.0 | front_h=834.0 | front_norm=0.1684249722524139 || side_raw_area=78131.0 | side_h=839.0 | side_norm=0.11099398938233125
#
# Record 62/1684
#   Processing photo_id=36ca064832f9a878db0277152eeaac78 -> pid=36ca064832f9a878db0277152eeaac78
#     Downloading mask: s3://amazon-bodym/testA/mask/36ca064832f9a878db0277152eeaac78.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/36ca064832f9a878db0277152eeaac78.png
#     front_raw_area=101180.0 | front_h=782.0 | front_norm=0.16545548498505375 || side_raw_area=77182.0 | side_h=815.0 | side_norm=0.11619857728932215
#
# Record 63/1684
#   Processing photo_id=d1fe80a5728534da8a03f07e79fda8e0 -> pid=d1fe80a5728534da8a03f07e79fda8e0
#     Downloading mask: s3://amazon-bodym/testA/mask/d1fe80a5728534da8a03f07e79fda8e0.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/d1fe80a5728534da8a03f07e79fda8e0.png
#     front_raw_area=100514.0 | front_h=776.0 | front_norm=0.16691797746838133 || side_raw_area=73285.0 | side_h=826.0 | side_norm=0.10741254272464516
#
# Record 64/1684
#   Processing photo_id=417335e9cf581a470cd91ec27728b379 -> pid=417335e9cf581a470cd91ec27728b379
#     Downloading mask: s3://amazon-bodym/testA/mask/417335e9cf581a470cd91ec27728b379.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/417335e9cf581a470cd91ec27728b379.png
#     front_raw_area=111438.0 | front_h=807.0 | front_norm=0.17111427426376086 || side_raw_area=84289.0 | side_h=882.0 | side_norm=0.10835120140270772
#
# Record 65/1684
#   Processing photo_id=472f1416a2b2a909766e386b50ca2dac -> pid=472f1416a2b2a909766e386b50ca2dac
#     Downloading mask: s3://amazon-bodym/testA/mask/472f1416a2b2a909766e386b50ca2dac.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/472f1416a2b2a909766e386b50ca2dac.png
#     front_raw_area=114784.0 | front_h=818.0 | front_norm=0.1715436899588118 || side_raw_area=84502.0 | side_h=895.0 | side_norm=0.1054923379420118
#
# Record 66/1684
#   Processing photo_id=ef16063594ff7d74d9feaa94ba636085 -> pid=ef16063594ff7d74d9feaa94ba636085
#     Downloading mask: s3://amazon-bodym/testA/mask/ef16063594ff7d74d9feaa94ba636085.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/ef16063594ff7d74d9feaa94ba636085.png
#     front_raw_area=114424.0 | front_h=821.0 | front_norm=0.16975821945549308 || side_raw_area=75163.0 | side_h=836.0 | side_norm=0.10754532863258626
#
# Record 67/1684
#   Processing photo_id=e5f5b7e98e478b23b3be8bf6678c1f0c -> pid=e5f5b7e98e478b23b3be8bf6678c1f0c
#     Downloading mask: s3://amazon-bodym/testA/mask/e5f5b7e98e478b23b3be8bf6678c1f0c.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/e5f5b7e98e478b23b3be8bf6678c1f0c.png
#     front_raw_area=123928.0 | front_h=824.0 | front_norm=0.18252191535488735 || side_raw_area=76186.0 | side_h=842.0 | side_norm=0.10746102764033152
#
# Record 68/1684
#   Processing photo_id=d97172a35c4ac9a3045632fb61c6cc24 -> pid=d97172a35c4ac9a3045632fb61c6cc24
#     Downloading mask: s3://amazon-bodym/testA/mask/d97172a35c4ac9a3045632fb61c6cc24.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/d97172a35c4ac9a3045632fb61c6cc24.png
#     front_raw_area=142025.0 | front_h=885.0 | front_norm=0.18133358868779725 || side_raw_area=114318.0 | side_h=960.0 | side_norm=0.12404296875
#
# Record 69/1684
#   Processing photo_id=3b75777e48c78b066cb696ecdb516d4c -> pid=3b75777e48c78b066cb696ecdb516d4c
#     Downloading mask: s3://amazon-bodym/testA/mask/3b75777e48c78b066cb696ecdb516d4c.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/3b75777e48c78b066cb696ecdb516d4c.png
#     front_raw_area=128989.0 | front_h=875.0 | front_norm=0.16847542857142858 || side_raw_area=78194.0 | side_h=866.0 | side_norm=0.10426478353396733
#
# Record 70/1684
#   Processing photo_id=90f1b79c16714fe22765b5c0961e23c3 -> pid=90f1b79c16714fe22765b5c0961e23c3
#     Downloading mask: s3://amazon-bodym/testA/mask/90f1b79c16714fe22765b5c0961e23c3.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/90f1b79c16714fe22765b5c0961e23c3.png
#     front_raw_area=138079.0 | front_h=846.0 | front_norm=0.19292428840489803 || side_raw_area=100264.0 | side_h=880.0 | side_norm=0.12947314049586778
#
# Record 71/1684
#   Processing photo_id=10c266033125c4d63763ad2e6cebcafd -> pid=10c266033125c4d63763ad2e6cebcafd
#     Downloading mask: s3://amazon-bodym/testA/mask/10c266033125c4d63763ad2e6cebcafd.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/10c266033125c4d63763ad2e6cebcafd.png
#     front_raw_area=120186.0 | front_h=881.0 | front_norm=0.15484673927187786 || side_raw_area=91004.0 | side_h=922.0 | side_norm=0.1070529500614057
#
# Record 72/1684
#   Processing photo_id=462abfea634b872431f903ccd04acdd0 -> pid=462abfea634b872431f903ccd04acdd0
#     Downloading mask: s3://amazon-bodym/testA/mask/462abfea634b872431f903ccd04acdd0.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/462abfea634b872431f903ccd04acdd0.png
#     front_raw_area=110951.0 | front_h=829.0 | front_norm=0.16144409312017183 || side_raw_area=83336.0 | side_h=912.0 | side_norm=0.10019429055093874
#
# Record 73/1684
#   Processing photo_id=42fa5fb5e0a3116a04abcfb82f7c67b1 -> pid=42fa5fb5e0a3116a04abcfb82f7c67b1
#     Downloading mask: s3://amazon-bodym/testA/mask/42fa5fb5e0a3116a04abcfb82f7c67b1.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/42fa5fb5e0a3116a04abcfb82f7c67b1.png
#     front_raw_area=138147.0 | front_h=856.0 | front_norm=0.1885358437418115 || side_raw_area=96247.0 | side_h=887.0 | side_norm=0.12233196783299799
#
# Record 74/1684
#   Processing photo_id=dbd4a212cb17546bf43377ce79487281 -> pid=dbd4a212cb17546bf43377ce79487281
#     Downloading mask: s3://amazon-bodym/testA/mask/dbd4a212cb17546bf43377ce79487281.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/dbd4a212cb17546bf43377ce79487281.png
#     front_raw_area=113456.0 | front_h=827.0 | front_norm=0.16588856445625202 || side_raw_area=77531.0 | side_h=871.0 | side_norm=0.10219721844719702
#
# Record 75/1684
#   Processing photo_id=e512188a6ea3ce68cb894778c73946b9 -> pid=e512188a6ea3ce68cb894778c73946b9
#     Downloading mask: s3://amazon-bodym/testA/mask/e512188a6ea3ce68cb894778c73946b9.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/e512188a6ea3ce68cb894778c73946b9.png
#     front_raw_area=110787.0 | front_h=820.0 | front_norm=0.16476353361094587 || side_raw_area=83021.0 | side_h=875.0 | side_norm=0.1084355918367347
#
# Record 76/1684
#   Processing photo_id=a9d9d3ece5dbd60aa4a297bfcd60abc6 -> pid=a9d9d3ece5dbd60aa4a297bfcd60abc6
#     Downloading mask: s3://amazon-bodym/testA/mask/a9d9d3ece5dbd60aa4a297bfcd60abc6.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/a9d9d3ece5dbd60aa4a297bfcd60abc6.png
#     front_raw_area=123890.0 | front_h=779.0 | front_norm=0.20415561901717255 || side_raw_area=112017.0 | side_h=878.0 | side_norm=0.1453098001774586
#
# Record 77/1684
#   Processing photo_id=aa9087e7bec2357318f7801ded0ba33b -> pid=aa9087e7bec2357318f7801ded0ba33b
#     Downloading mask: s3://amazon-bodym/testA/mask/aa9087e7bec2357318f7801ded0ba33b.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/aa9087e7bec2357318f7801ded0ba33b.png
#     front_raw_area=118482.0 | front_h=816.0 | front_norm=0.1779393742791234 || side_raw_area=85870.0 | side_h=866.0 | side_norm=0.11450005066963928
#
# Record 78/1684
#   Processing photo_id=a465c4424b48157d0403c4f46b750ed2 -> pid=a465c4424b48157d0403c4f46b750ed2
#     Downloading mask: s3://amazon-bodym/testA/mask/a465c4424b48157d0403c4f46b750ed2.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/a465c4424b48157d0403c4f46b750ed2.png
#     front_raw_area=137956.0 | front_h=868.0 | front_norm=0.1831053961647094 || side_raw_area=88752.0 | side_h=853.0 | side_norm=0.12197760060691938
#
# Record 79/1684
#   Processing photo_id=9167f07c4fdc74a78ace00d7cad4b699 -> pid=9167f07c4fdc74a78ace00d7cad4b699
#     Downloading mask: s3://amazon-bodym/testA/mask/9167f07c4fdc74a78ace00d7cad4b699.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/9167f07c4fdc74a78ace00d7cad4b699.png
#     front_raw_area=110934.0 | front_h=833.0 | front_norm=0.15987283268649596 || side_raw_area=81647.0 | side_h=940.0 | side_norm=0.09240267089180625
#
# Record 80/1684
#   Processing photo_id=6de8b6dd4e842884a3abf17fc6568ce2 -> pid=6de8b6dd4e842884a3abf17fc6568ce2
#     Downloading mask: s3://amazon-bodym/testA/mask/6de8b6dd4e842884a3abf17fc6568ce2.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/6de8b6dd4e842884a3abf17fc6568ce2.png
#     front_raw_area=120695.0 | front_h=810.0 | front_norm=0.1839582380734644 || side_raw_area=79582.0 | side_h=857.0 | side_norm=0.10835606012126098
#
# Record 81/1684
#   Processing photo_id=bd34754520da8332a69610184f3426ac -> pid=bd34754520da8332a69610184f3426ac
#     Downloading mask: s3://amazon-bodym/testA/mask/bd34754520da8332a69610184f3426ac.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/bd34754520da8332a69610184f3426ac.png
#     front_raw_area=127124.0 | front_h=849.0 | front_norm=0.17636490515412714 || side_raw_area=93589.0 | side_h=914.0 | side_norm=0.11202950457028762
#
# Record 82/1684
#   Processing photo_id=27ca2b1761b82c84658f0454d071d3c0 -> pid=27ca2b1761b82c84658f0454d071d3c0
#     Downloading mask: s3://amazon-bodym/testA/mask/27ca2b1761b82c84658f0454d071d3c0.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/27ca2b1761b82c84658f0454d071d3c0.png
#     front_raw_area=114509.0 | front_h=795.0 | front_norm=0.1811779597326055 || side_raw_area=81087.0 | side_h=851.0 | side_norm=0.11196753387526391
#
# Record 83/1684
#   Processing photo_id=a7eb01092cd1addb4dfcce418e3e0be4 -> pid=a7eb01092cd1addb4dfcce418e3e0be4
#     Downloading mask: s3://amazon-bodym/testA/mask/a7eb01092cd1addb4dfcce418e3e0be4.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/a7eb01092cd1addb4dfcce418e3e0be4.png
#     front_raw_area=129601.0 | front_h=871.0 | front_norm=0.17083310814996816 || side_raw_area=89996.0 | side_h=935.0 | side_norm=0.10294375017872973
#
# Record 84/1684
#   Processing photo_id=c1366a32ee29171e3dfe3d331fa6ca22 -> pid=c1366a32ee29171e3dfe3d331fa6ca22
#     Downloading mask: s3://amazon-bodym/testA/mask/c1366a32ee29171e3dfe3d331fa6ca22.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/c1366a32ee29171e3dfe3d331fa6ca22.png
#     front_raw_area=115117.0 | front_h=839.0 | front_norm=0.16353681734171874 || side_raw_area=99838.0 | side_h=956.0 | side_norm=0.10923959664571699
#
# Record 85/1684
#   Processing photo_id=97397e09649477eeed2028a6696076e7 -> pid=97397e09649477eeed2028a6696076e7
#     Downloading mask: s3://amazon-bodym/testA/mask/97397e09649477eeed2028a6696076e7.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/97397e09649477eeed2028a6696076e7.png
#     front_raw_area=122123.0 | front_h=855.0 | front_norm=0.16705721418556138 || side_raw_area=88257.0 | side_h=918.0 | side_norm=0.1047282384268159
#
# Record 86/1684
#   Processing photo_id=211bdc1fbd34284e72f487ab01545822 -> pid=211bdc1fbd34284e72f487ab01545822
#     Downloading mask: s3://amazon-bodym/testA/mask/211bdc1fbd34284e72f487ab01545822.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/211bdc1fbd34284e72f487ab01545822.png
#     front_raw_area=151546.0 | front_h=840.0 | front_norm=0.21477607709750568 || side_raw_area=108796.0 | side_h=908.0 | side_norm=0.13195967319373555
#
# Record 87/1684
#   Processing photo_id=c47fe281098b0be712e056089a810f06 -> pid=c47fe281098b0be712e056089a810f06
#     Downloading mask: s3://amazon-bodym/testA/mask/c47fe281098b0be712e056089a810f06.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/c47fe281098b0be712e056089a810f06.png
#     front_raw_area=133183.0 | front_h=884.0 | front_norm=0.1704293012018591 || side_raw_area=114460.0 | side_h=891.0 | side_norm=0.14417777979319318
#
# Record 88/1684
#   Processing photo_id=6f0dde56568d5a4ca7e57e3087e0b17d -> pid=6f0dde56568d5a4ca7e57e3087e0b17d
#     Downloading mask: s3://amazon-bodym/testA/mask/6f0dde56568d5a4ca7e57e3087e0b17d.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/6f0dde56568d5a4ca7e57e3087e0b17d.png
#     front_raw_area=114444.0 | front_h=830.0 | front_norm=0.1661257076498766 || side_raw_area=81715.0 | side_h=862.0 | side_norm=0.10997329902401473
#
# Record 89/1684
#   Processing photo_id=1dab48ac937df915756a1a0967374d55 -> pid=1dab48ac937df915756a1a0967374d55
#     Downloading mask: s3://amazon-bodym/testA/mask/1dab48ac937df915756a1a0967374d55.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/1dab48ac937df915756a1a0967374d55.png
#     front_raw_area=122822.0 | front_h=807.0 | front_norm=0.18859453143114233 || side_raw_area=86625.0 | side_h=848.0 | side_norm=0.1204624087753649
#
# Record 90/1684
#   Processing photo_id=c98b8ea53680a70cfd690d7664c2f2b9 -> pid=c98b8ea53680a70cfd690d7664c2f2b9
#     Downloading mask: s3://amazon-bodym/testA/mask/c98b8ea53680a70cfd690d7664c2f2b9.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/c98b8ea53680a70cfd690d7664c2f2b9.png
#     front_raw_area=131202.0 | front_h=819.0 | front_norm=0.19560171208522856 || side_raw_area=85740.0 | side_h=827.0 | side_norm=0.12536389011140045
#
# Record 91/1684
#   Processing photo_id=fba6f8d8157288c7f94270c32f695db2 -> pid=fba6f8d8157288c7f94270c32f695db2
#     Downloading mask: s3://amazon-bodym/testA/mask/fba6f8d8157288c7f94270c32f695db2.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/fba6f8d8157288c7f94270c32f695db2.png
#     front_raw_area=108982.0 | front_h=848.0 | front_norm=0.15155248754004985 || side_raw_area=88781.0 | side_h=948.0 | side_norm=0.09878781000195838
#
# Record 92/1684
#   Processing photo_id=e27c06706baad66a89708192d868315a -> pid=e27c06706baad66a89708192d868315a
#     Downloading mask: s3://amazon-bodym/testA/mask/e27c06706baad66a89708192d868315a.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/e27c06706baad66a89708192d868315a.png
#     front_raw_area=129757.0 | front_h=838.0 | front_norm=0.18477480761672582 || side_raw_area=96322.0 | side_h=896.0 | side_norm=0.11998016980229592
#
# Record 93/1684
#   Processing photo_id=879b4afda245e5373fb00b64be7f655a -> pid=879b4afda245e5373fb00b64be7f655a
#     Downloading mask: s3://amazon-bodym/testA/mask/879b4afda245e5373fb00b64be7f655a.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/879b4afda245e5373fb00b64be7f655a.png
#     front_raw_area=123793.0 | front_h=844.0 | front_norm=0.173784562341367 || side_raw_area=69210.0 | side_h=820.0 | side_norm=0.10292980368828078
#
# Record 94/1684
#   Processing photo_id=d17a831ec8035ccf2a5383c3165fcf22 -> pid=d17a831ec8035ccf2a5383c3165fcf22
#     Downloading mask: s3://amazon-bodym/testA/mask/d17a831ec8035ccf2a5383c3165fcf22.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/d17a831ec8035ccf2a5383c3165fcf22.png
#     front_raw_area=110676.0 | front_h=814.0 | front_norm=0.16703390904865106 || side_raw_area=78585.0 | side_h=885.0 | side_norm=0.10033515273388872
#
# Record 95/1684
#   Processing photo_id=f95a847c3d8dfe6a365fe7c300f6986a -> pid=f95a847c3d8dfe6a365fe7c300f6986a
#     Downloading mask: s3://amazon-bodym/testA/mask/f95a847c3d8dfe6a365fe7c300f6986a.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/f95a847c3d8dfe6a365fe7c300f6986a.png
#     front_raw_area=136480.0 | front_h=847.0 | front_norm=0.19024015589433643 || side_raw_area=91701.0 | side_h=886.0 | side_norm=0.11681715575620767
#
# Record 96/1684
#   Processing photo_id=b825b43a54e303db71d7b495c1b122bf -> pid=b825b43a54e303db71d7b495c1b122bf
#     Downloading mask: s3://amazon-bodym/testA/mask/b825b43a54e303db71d7b495c1b122bf.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/b825b43a54e303db71d7b495c1b122bf.png
#     front_raw_area=128086.0 | front_h=852.0 | front_norm=0.17645032952015693 || side_raw_area=99122.0 | side_h=942.0 | side_norm=0.11170387800271366
#
# Record 97/1684
#   Processing photo_id=7a7ef55e5aff084c5410cb32e9e8db20 -> pid=7a7ef55e5aff084c5410cb32e9e8db20
#     Downloading mask: s3://amazon-bodym/testA/mask/7a7ef55e5aff084c5410cb32e9e8db20.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/7a7ef55e5aff084c5410cb32e9e8db20.png
#     front_raw_area=117733.0 | front_h=810.0 | front_norm=0.17944368236549307 || side_raw_area=84733.0 | side_h=900.0 | side_norm=0.10460864197530864
#
# Record 98/1684
#   Processing photo_id=c8f58c789047d66ebab704ca4995ce91 -> pid=c8f58c789047d66ebab704ca4995ce91
#     Downloading mask: s3://amazon-bodym/testA/mask/c8f58c789047d66ebab704ca4995ce91.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/c8f58c789047d66ebab704ca4995ce91.png
#     front_raw_area=123670.0 | front_h=851.0 | front_norm=0.17076750791562012 || side_raw_area=83961.0 | side_h=924.0 | side_norm=0.09834078259402934
#
# Record 99/1684
#   Processing photo_id=d2b7a25c08c65a01cc47fefa1159e5c9 -> pid=d2b7a25c08c65a01cc47fefa1159e5c9
#     Downloading mask: s3://amazon-bodym/testA/mask/d2b7a25c08c65a01cc47fefa1159e5c9.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/d2b7a25c08c65a01cc47fefa1159e5c9.png
#     front_raw_area=125714.0 | front_h=869.0 | front_norm=0.1664731097077312 || side_raw_area=81238.0 | side_h=884.0 | side_norm=0.10395722855797383
#
# Record 100/1684
#   Processing photo_id=bfdaf91669c796c769e54660c5ae442e -> pid=bfdaf91669c796c769e54660c5ae442e
#     Downloading mask: s3://amazon-bodym/testA/mask/bfdaf91669c796c769e54660c5ae442e.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/bfdaf91669c796c769e54660c5ae442e.png
#     front_raw_area=125622.0 | front_h=776.0 | front_norm=0.2086134286321607 || side_raw_area=92943.0 | side_h=851.0 | side_norm=0.12833867945501318
#
# Processed 100/1684 records so far...
#
# Record 101/1684
#   Processing photo_id=ec05f4b906c772df6742a28b2b3ca1f0 -> pid=ec05f4b906c772df6742a28b2b3ca1f0
#     Downloading mask: s3://amazon-bodym/testA/mask/ec05f4b906c772df6742a28b2b3ca1f0.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/ec05f4b906c772df6742a28b2b3ca1f0.png
#     front_raw_area=117434.0 | front_h=844.0 | front_norm=0.16485759529210933 || side_raw_area=78198.0 | side_h=894.0 | side_norm=0.09784093809588157
#
# Record 102/1684
#   Processing photo_id=a73305f31827289d92a6b864a72186b9 -> pid=a73305f31827289d92a6b864a72186b9
#     Downloading mask: s3://amazon-bodym/testA/mask/a73305f31827289d92a6b864a72186b9.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/a73305f31827289d92a6b864a72186b9.png
#     front_raw_area=129333.0 | front_h=877.0 | front_norm=0.1681551469259383 || side_raw_area=82072.0 | side_h=889.0 | side_norm=0.10384641177445621
#
# Record 103/1684
#   Processing photo_id=8506f89e6006e56379244f47257c61f1 -> pid=8506f89e6006e56379244f47257c61f1
#     Downloading mask: s3://amazon-bodym/testA/mask/8506f89e6006e56379244f47257c61f1.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/8506f89e6006e56379244f47257c61f1.png
#     front_raw_area=115230.0 | front_h=803.0 | front_norm=0.17870408136362861 || side_raw_area=85247.0 | side_h=873.0 | side_norm=0.11185376753804147
#
# Record 104/1684
#   Processing photo_id=fb5c47c4cfbcb9b6d352f1bdf960f01f -> pid=fb5c47c4cfbcb9b6d352f1bdf960f01f
#     Downloading mask: s3://amazon-bodym/testA/mask/fb5c47c4cfbcb9b6d352f1bdf960f01f.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/fb5c47c4cfbcb9b6d352f1bdf960f01f.png
#     front_raw_area=134720.0 | front_h=824.0 | front_norm=0.19841643887265528 || side_raw_area=92352.0 | side_h=862.0 | side_norm=0.12428873660240847
#
# Record 105/1684
#   Processing photo_id=8dd59b15988f0cbb701264c794a39b58 -> pid=8dd59b15988f0cbb701264c794a39b58
#     Downloading mask: s3://amazon-bodym/testA/mask/8dd59b15988f0cbb701264c794a39b58.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/8dd59b15988f0cbb701264c794a39b58.png
#     front_raw_area=117262.0 | front_h=806.0 | front_norm=0.18050415925225818 || side_raw_area=74138.0 | side_h=845.0 | side_norm=0.10383109835089807
#
# Record 106/1684
#   Processing photo_id=d4c357f38a4c4a45644e80585bc4a8e3 -> pid=d4c357f38a4c4a45644e80585bc4a8e3
#     Downloading mask: s3://amazon-bodym/testA/mask/d4c357f38a4c4a45644e80585bc4a8e3.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/d4c357f38a4c4a45644e80585bc4a8e3.png
#     front_raw_area=117347.0 | front_h=815.0 | front_norm=0.1766675448831345 || side_raw_area=80404.0 | side_h=863.0 | side_norm=0.10795830653531498
#
# Record 107/1684
#   Processing photo_id=30c01159493adafc50c4ff1ef5bfa7cf -> pid=30c01159493adafc50c4ff1ef5bfa7cf
#     Downloading mask: s3://amazon-bodym/testA/mask/30c01159493adafc50c4ff1ef5bfa7cf.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/30c01159493adafc50c4ff1ef5bfa7cf.png
#     front_raw_area=117149.0 | front_h=834.0 | front_norm=0.1684249722524139 || side_raw_area=78131.0 | side_h=839.0 | side_norm=0.11099398938233125
#
# Record 108/1684
#   Processing photo_id=39172fcea2124599f579033909a2a69e -> pid=39172fcea2124599f579033909a2a69e
#     Downloading mask: s3://amazon-bodym/testA/mask/39172fcea2124599f579033909a2a69e.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/39172fcea2124599f579033909a2a69e.png
#     front_raw_area=124859.0 | front_h=844.0 | front_norm=0.1752810471462905 || side_raw_area=82406.0 | side_h=857.0 | side_norm=0.11220111947868402
#
# Record 109/1684
#   Processing photo_id=4424b600d95a2279c8750d66e8601883 -> pid=4424b600d95a2279c8750d66e8601883
# ...
#     Downloading mask: s3://amazon-bodym/testA/mask/fd9e8fea8aac2f1d1fd10ed28c0497f6.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/fd9e8fea8aac2f1d1fd10ed28c0497f6.png
#     front_raw_area=116653.0 | front_h=810.0 | front_norm=0.17779759183051363 || side_raw_area=85246.0 | side_h=901.0 | side_norm=0.10500849346083585
#
# Record 1650/1684
#   Processing photo_id=8da2e6d9ccf30b1ebe9715c3df5e0ca6 -> pid=8da2e6d9ccf30b1ebe9715c3df5e0ca6
#     Downloading mask: s3://amazon-bodym/testA/mask/8da2e6d9ccf30b1ebe9715c3df5e0ca6.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/8da2e6d9ccf30b1ebe9715c3df5e0ca6.png
#     front_raw_area=119245.0 | front_h=872.0 | front_norm=0.15682207937042336 || side_raw_area=90511.0 | side_h=942.0 | side_norm=0.10199985575254349
#
# Processed 1650/1684 records so far...
#
# Record 1651/1684
#   Processing photo_id=370377101b10f8a1c3052939f62bdc54 -> pid=370377101b10f8a1c3052939f62bdc54
#     Downloading mask: s3://amazon-bodym/testA/mask/370377101b10f8a1c3052939f62bdc54.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/370377101b10f8a1c3052939f62bdc54.png
#     front_raw_area=110756.0 | front_h=849.0 | front_norm=0.15365683454934165 || side_raw_area=75034.0 | side_h=905.0 | side_norm=0.09161380910228625
#
# Record 1652/1684
#   Processing photo_id=ad6815dae0b870817d3c9f228156c55d -> pid=ad6815dae0b870817d3c9f228156c55d
#     Downloading mask: s3://amazon-bodym/testA/mask/ad6815dae0b870817d3c9f228156c55d.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/ad6815dae0b870817d3c9f228156c55d.png
#     front_raw_area=115283.0 | front_h=842.0 | front_norm=0.16260769235109257 || side_raw_area=92145.0 | side_h=855.0 | side_norm=0.12604904073048118
#
# Record 1653/1684
#   Processing photo_id=4039eb33ac3d6778c1db9f265fe034ba -> pid=4039eb33ac3d6778c1db9f265fe034ba
#     Downloading mask: s3://amazon-bodym/testA/mask/4039eb33ac3d6778c1db9f265fe034ba.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/4039eb33ac3d6778c1db9f265fe034ba.png
#     front_raw_area=140137.0 | front_h=821.0 | front_norm=0.2079057505403974 || side_raw_area=112077.0 | side_h=886.0 | side_norm=0.14277397591834862
#
# Record 1654/1684
#   Processing photo_id=9b71d41951f13dcf873565a32dae9f22 -> pid=9b71d41951f13dcf873565a32dae9f22
#     Downloading mask: s3://amazon-bodym/testA/mask/9b71d41951f13dcf873565a32dae9f22.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/9b71d41951f13dcf873565a32dae9f22.png
#     front_raw_area=112322.0 | front_h=802.0 | front_norm=0.17462888912382385 || side_raw_area=68537.0 | side_h=826.0 | side_norm=0.10045348216850658
#
# Record 1655/1684
#   Processing photo_id=5f4d97ef512adf1faadfe2e8e6394659 -> pid=5f4d97ef512adf1faadfe2e8e6394659
#     Downloading mask: s3://amazon-bodym/testA/mask/5f4d97ef512adf1faadfe2e8e6394659.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/5f4d97ef512adf1faadfe2e8e6394659.png
#     front_raw_area=130703.0 | front_h=889.0 | front_norm=0.16537963688172275 || side_raw_area=88273.0 | side_h=894.0 | side_norm=0.11044672662392585
#
# Record 1656/1684
#   Processing photo_id=c98e34af9c269fc90322bdf73e1b934c -> pid=c98e34af9c269fc90322bdf73e1b934c
#     Downloading mask: s3://amazon-bodym/testA/mask/c98e34af9c269fc90322bdf73e1b934c.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/c98e34af9c269fc90322bdf73e1b934c.png
#     front_raw_area=127925.0 | front_h=865.0 | front_norm=0.17097129874035216 || side_raw_area=92424.0 | side_h=890.0 | side_norm=0.11668223709127636
#
# Record 1657/1684
#   Processing photo_id=00f29ea96c690cb73496ebc2448bf7bc -> pid=00f29ea96c690cb73496ebc2448bf7bc
#     Downloading mask: s3://amazon-bodym/testA/mask/00f29ea96c690cb73496ebc2448bf7bc.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/00f29ea96c690cb73496ebc2448bf7bc.png
#     front_raw_area=93999.0 | front_h=786.0 | front_norm=0.15215216673465026 || side_raw_area=68808.0 | side_h=834.0 | side_norm=0.09892517640563808
#
# Record 1658/1684
#   Processing photo_id=141279d674ee6e0254ae0a84cf6973f2 -> pid=141279d674ee6e0254ae0a84cf6973f2
#     Downloading mask: s3://amazon-bodym/testA/mask/141279d674ee6e0254ae0a84cf6973f2.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/141279d674ee6e0254ae0a84cf6973f2.png
#     front_raw_area=164597.0 | front_h=930.0 | front_norm=0.190307550005781 || side_raw_area=97821.0 | side_h=889.0 | side_norm=0.12377375775159713
#
# Record 1659/1684
#   Processing photo_id=fea6f5d161d85cee616837d403c06964 -> pid=fea6f5d161d85cee616837d403c06964
#     Downloading mask: s3://amazon-bodym/testA/mask/fea6f5d161d85cee616837d403c06964.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/fea6f5d161d85cee616837d403c06964.png
#     front_raw_area=110577.0 | front_h=812.0 | front_norm=0.1677076002814919 || side_raw_area=100022.0 | side_h=918.0 | side_norm=0.11868891831726638
#
# Record 1660/1684
#   Processing photo_id=caaa81f30e872b915f1cf9acfc63fd89 -> pid=caaa81f30e872b915f1cf9acfc63fd89
#     Downloading mask: s3://amazon-bodym/testA/mask/caaa81f30e872b915f1cf9acfc63fd89.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/caaa81f30e872b915f1cf9acfc63fd89.png
#     front_raw_area=109863.0 | front_h=817.0 | front_norm=0.16459147641384353 || side_raw_area=78742.0 | side_h=870.0 | side_norm=0.10403223675518562
#
# Record 1661/1684
#   Processing photo_id=423a5dea410100677846355e9a69eee4 -> pid=423a5dea410100677846355e9a69eee4
#     Downloading mask: s3://amazon-bodym/testA/mask/423a5dea410100677846355e9a69eee4.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/423a5dea410100677846355e9a69eee4.png
#     front_raw_area=112775.0 | front_h=833.0 | front_norm=0.16252599479167418 || side_raw_area=71944.0 | side_h=848.0 | side_norm=0.10004672481310074
#
# Record 1662/1684
#   Processing photo_id=0ce1d6093159bdf11f2ec70de3507555 -> pid=0ce1d6093159bdf11f2ec70de3507555
#     Downloading mask: s3://amazon-bodym/testA/mask/0ce1d6093159bdf11f2ec70de3507555.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/0ce1d6093159bdf11f2ec70de3507555.png
#     front_raw_area=106572.0 | front_h=801.0 | front_norm=0.16610323238274255 || side_raw_area=83021.0 | side_h=875.0 | side_norm=0.1084355918367347
#
# Record 1663/1684
#   Processing photo_id=29218250def0c4c3f35dc9eec6022337 -> pid=29218250def0c4c3f35dc9eec6022337
#     Downloading mask: s3://amazon-bodym/testA/mask/29218250def0c4c3f35dc9eec6022337.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/29218250def0c4c3f35dc9eec6022337.png
#     front_raw_area=131065.0 | front_h=853.0 | front_norm=0.18013108688869983 || side_raw_area=94959.0 | side_h=903.0 | side_norm=0.11645566825973223
#
# Record 1664/1684
#   Processing photo_id=cd73f28df3977892b8f652e82f556ad0 -> pid=cd73f28df3977892b8f652e82f556ad0
#     Downloading mask: s3://amazon-bodym/testA/mask/cd73f28df3977892b8f652e82f556ad0.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/cd73f28df3977892b8f652e82f556ad0.png
#     front_raw_area=121853.0 | front_h=832.0 | front_norm=0.17603116910133135 || side_raw_area=92263.0 | side_h=933.0 | side_norm=0.10598985168106662
#
# Record 1665/1684
#   Processing photo_id=cbcd8808f312337cb72862d709cd83db -> pid=cbcd8808f312337cb72862d709cd83db
#     Downloading mask: s3://amazon-bodym/testA/mask/cbcd8808f312337cb72862d709cd83db.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/cbcd8808f312337cb72862d709cd83db.png
#     front_raw_area=118322.0 | front_h=854.0 | front_norm=0.16223694530217353 || side_raw_area=82574.0 | side_h=897.0 | side_norm=0.10262624454859441
#
# Record 1666/1684
#   Processing photo_id=dfb26486fa942e21bd82f4d75d6a9d31 -> pid=dfb26486fa942e21bd82f4d75d6a9d31
#     Downloading mask: s3://amazon-bodym/testA/mask/dfb26486fa942e21bd82f4d75d6a9d31.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/dfb26486fa942e21bd82f4d75d6a9d31.png
#     front_raw_area=131368.0 | front_h=863.0 | front_norm=0.17638757789327966 || side_raw_area=95089.0 | side_h=919.0 | side_norm=0.11258985437404759
#
# Record 1667/1684
#   Processing photo_id=1eecdb9780c296b4e2b4e306369f605e -> pid=1eecdb9780c296b4e2b4e306369f605e
#     Downloading mask: s3://amazon-bodym/testA/mask/1eecdb9780c296b4e2b4e306369f605e.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/1eecdb9780c296b4e2b4e306369f605e.png
#     front_raw_area=127568.0 | front_h=832.0 | front_norm=0.18428716715976332 || side_raw_area=85845.0 | side_h=892.0 | side_norm=0.10789101932474009
#
# Record 1668/1684
#   Processing photo_id=92c45217a3c322364c9a923d0953cfee -> pid=92c45217a3c322364c9a923d0953cfee
#     Downloading mask: s3://amazon-bodym/testA/mask/92c45217a3c322364c9a923d0953cfee.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/92c45217a3c322364c9a923d0953cfee.png
#     front_raw_area=103410.0 | front_h=806.0 | front_norm=0.1591814493039179 || side_raw_area=108222.0 | side_h=889.0 | side_norm=0.1369342330521396
#
# Record 1669/1684
#   Processing photo_id=bb88c1c64735ea8a4dadbe036b47d315 -> pid=bb88c1c64735ea8a4dadbe036b47d315
#     Downloading mask: s3://amazon-bodym/testA/mask/bb88c1c64735ea8a4dadbe036b47d315.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/bb88c1c64735ea8a4dadbe036b47d315.png
#     front_raw_area=134926.0 | front_h=874.0 | front_norm=0.17663338028685285 || side_raw_area=91255.0 | side_h=892.0 | side_norm=0.1146903718152386
#
# Record 1670/1684
#   Processing photo_id=67ed335e7b9da7e62c18976e78465640 -> pid=67ed335e7b9da7e62c18976e78465640
#     Downloading mask: s3://amazon-bodym/testA/mask/67ed335e7b9da7e62c18976e78465640.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/67ed335e7b9da7e62c18976e78465640.png
#     front_raw_area=110649.0 | front_h=811.0 | front_norm=0.1682309064177668 || side_raw_area=90074.0 | side_h=908.0 | side_norm=0.10925158648528013
#
# Record 1671/1684
#   Processing photo_id=73910f8eea7a29e34fc12152496381f5 -> pid=73910f8eea7a29e34fc12152496381f5
#     Downloading mask: s3://amazon-bodym/testA/mask/73910f8eea7a29e34fc12152496381f5.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/73910f8eea7a29e34fc12152496381f5.png
#     front_raw_area=117149.0 | front_h=834.0 | front_norm=0.1684249722524139 || side_raw_area=78131.0 | side_h=839.0 | side_norm=0.11099398938233125
#
# Record 1672/1684
#   Processing photo_id=41a08708d9d5884d2032890cf41f6b12 -> pid=41a08708d9d5884d2032890cf41f6b12
#     Downloading mask: s3://amazon-bodym/testA/mask/41a08708d9d5884d2032890cf41f6b12.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/41a08708d9d5884d2032890cf41f6b12.png
#     front_raw_area=120820.0 | front_h=839.0 | front_norm=0.1716385787609689 || side_raw_area=96342.0 | side_h=872.0 | side_norm=0.12670177173638583
#
# Record 1673/1684
#   Processing photo_id=221fab313e9ddb1d390dd602ec427881 -> pid=221fab313e9ddb1d390dd602ec427881
#     Downloading mask: s3://amazon-bodym/testA/mask/221fab313e9ddb1d390dd602ec427881.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/221fab313e9ddb1d390dd602ec427881.png
#     front_raw_area=140880.0 | front_h=878.0 | front_norm=0.18275123105421828 || side_raw_area=82603.0 | side_h=862.0 | side_norm=0.11116838302980712
#
# Record 1674/1684
#   Processing photo_id=7579f1f81944ed0d7baaebd750f730e5 -> pid=7579f1f81944ed0d7baaebd750f730e5
#     Downloading mask: s3://amazon-bodym/testA/mask/7579f1f81944ed0d7baaebd750f730e5.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/7579f1f81944ed0d7baaebd750f730e5.png
#     front_raw_area=127191.0 | front_h=829.0 | front_norm=0.1850748136388836 || side_raw_area=91670.0 | side_h=899.0 | side_norm=0.1134247544855797
#
# Record 1675/1684
#   Processing photo_id=dc62ba8610078109d6c252d78855474d -> pid=dc62ba8610078109d6c252d78855474d
#     Downloading mask: s3://amazon-bodym/testA/mask/dc62ba8610078109d6c252d78855474d.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/dc62ba8610078109d6c252d78855474d.png
#     front_raw_area=131078.0 | front_h=852.0 | front_norm=0.1805720866671075 || side_raw_area=116887.0 | side_h=960.0 | side_norm=0.12683051215277777
#
# Record 1676/1684
#   Processing photo_id=cb8f7dd4f3c96006eccc112b8f947a6e -> pid=cb8f7dd4f3c96006eccc112b8f947a6e
#     Downloading mask: s3://amazon-bodym/testA/mask/cb8f7dd4f3c96006eccc112b8f947a6e.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/cb8f7dd4f3c96006eccc112b8f947a6e.png
#     front_raw_area=121733.0 | front_h=819.0 | front_norm=0.18148491042263937 || side_raw_area=82339.0 | side_h=851.0 | side_norm=0.11369633568581099
#
# Record 1677/1684
#   Processing photo_id=b208440bbf1075d702e013065c818fe0 -> pid=b208440bbf1075d702e013065c818fe0
#     Downloading mask: s3://amazon-bodym/testA/mask/b208440bbf1075d702e013065c818fe0.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/b208440bbf1075d702e013065c818fe0.png
#     front_raw_area=105994.0 | front_h=814.0 | front_norm=0.15996776316186637 || side_raw_area=80748.0 | side_h=874.0 | side_norm=0.10570825631385199
#
# Record 1678/1684
#   Processing photo_id=c76b7c9f7f0c3b50b66db4297af90311 -> pid=c76b7c9f7f0c3b50b66db4297af90311
#     Downloading mask: s3://amazon-bodym/testA/mask/c76b7c9f7f0c3b50b66db4297af90311.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/c76b7c9f7f0c3b50b66db4297af90311.png
#     front_raw_area=111517.0 | front_h=840.0 | front_norm=0.15804563492063492 || side_raw_area=124107.0 | side_h=903.0 | side_norm=0.15220214640750837
#
# Record 1679/1684
#   Processing photo_id=a6ae121f6099f3b4f3514d9ab917db91 -> pid=a6ae121f6099f3b4f3514d9ab917db91
#     Downloading mask: s3://amazon-bodym/testA/mask/a6ae121f6099f3b4f3514d9ab917db91.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/a6ae121f6099f3b4f3514d9ab917db91.png
#     front_raw_area=106141.0 | front_h=793.0 | front_norm=0.16878614738991396 || side_raw_area=102923.0 | side_h=896.0 | side_norm=0.1282024772799745
#
# Record 1680/1684
#   Processing photo_id=c0b37049092f4db4b20cde5cf92d05c6 -> pid=c0b37049092f4db4b20cde5cf92d05c6
#     Downloading mask: s3://amazon-bodym/testA/mask/c0b37049092f4db4b20cde5cf92d05c6.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/c0b37049092f4db4b20cde5cf92d05c6.png
#     front_raw_area=140963.0 | front_h=865.0 | front_norm=0.1883965384743894 || side_raw_area=94845.0 | side_h=932.0 | side_norm=0.1091899371880123
#
# Record 1681/1684
#   Processing photo_id=c3cc1f77d0506e6cf3391f22d67f874e -> pid=c3cc1f77d0506e6cf3391f22d67f874e
#     Downloading mask: s3://amazon-bodym/testA/mask/c3cc1f77d0506e6cf3391f22d67f874e.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/c3cc1f77d0506e6cf3391f22d67f874e.png
#     front_raw_area=122519.0 | front_h=833.0 | front_norm=0.1765685866183208 || side_raw_area=77815.0 | side_h=843.0 | side_norm=0.10949850066629237
#
# Record 1682/1684
#   Processing photo_id=3124743d6494910558170710939a3296 -> pid=3124743d6494910558170710939a3296
#     Downloading mask: s3://amazon-bodym/testA/mask/3124743d6494910558170710939a3296.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/3124743d6494910558170710939a3296.png
#     front_raw_area=110782.0 | front_h=825.0 | front_norm=0.16276510560146923 || side_raw_area=79896.0 | side_h=883.0 | side_norm=0.10247162650749209
#
# Record 1683/1684
#   Processing photo_id=8f13d3999eae0ca692676f3232bb1958 -> pid=8f13d3999eae0ca692676f3232bb1958
#     Downloading mask: s3://amazon-bodym/testA/mask/8f13d3999eae0ca692676f3232bb1958.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/8f13d3999eae0ca692676f3232bb1958.png
#     front_raw_area=119329.0 | front_h=833.0 | front_norm=0.17197130953221626 || side_raw_area=90704.0 | side_h=858.0 | side_norm=0.12321167565922811
#
# Record 1684/1684
#   Processing photo_id=3da44f41a65991273c3c34769ddc8f37 -> pid=3da44f41a65991273c3c34769ddc8f37
#     Downloading mask: s3://amazon-bodym/testA/mask/3da44f41a65991273c3c34769ddc8f37.png
#     Downloading mask: s3://amazon-bodym/testA/mask_left/3da44f41a65991273c3c34769ddc8f37.png
#     front_raw_area=118088.0 | front_h=837.0 | front_norm=0.16856012755346012 || side_raw_area=88267.0 | side_h=901.0 | side_norm=0.10872984881762895
#
# Attaching new feature columns to dataframe...

# %%
data.head()
# Out:
#                            photo_id        f1        f2        f3        f4  \
# 0  e5ae8fe5bbdf611a1e8d06e66e849bdf  0.073159  0.085775 -0.133776  0.881202
# 1  605a5fd09058c48156b0ef518b63b2de  0.092031 -0.066016 -0.145132  0.687441
# 2  909c9277309e13ee014e347603aba620  0.057046 -0.051366 -0.148253  0.675916
# 3  bef6a68bc8dd475c124f6de2413385d3 -0.018792  0.016435 -0.148091  0.464433
# 4  6d7ed4bc4a17546447efed0ca6e2ff11  0.084419  0.065945 -0.153379  0.635377
#
#          f5        f6        f7        f8        f9  ...  shoulder-breadth  \
# 0  0.214236  0.016104 -0.180302 -0.100713 -0.117249  ...         39.922305
# 1  0.186508 -0.075221 -0.093846 -0.035840  0.033903  ...         39.974203
# 2  0.209973 -0.073485 -0.072783 -0.059395  0.008370  ...         36.059983
# 3  0.242849 -0.106556  0.001489 -0.083478  0.096048  ...         34.071748
# 4  0.285274 -0.056372 -0.139008 -0.120711 -0.002466  ...         36.834735
#
#    shoulder-to-crotch      thigh      waist      wrist  gender  height_cm  \
# 0           70.005128  55.945992  98.250390  20.187082    male     180.00
# 1           73.591637  55.397032  88.003618  17.715785    male     188.90
# 2           66.440526  53.742692  82.100598  17.086464    male     179.70
# 3           62.218026  52.396573  83.999124  16.299751  female     166.95
# 4           64.426273  49.895157  86.020117  16.531431    male     173.20
#
#    weight_kg  front_silhouette_area_norm  side_silhouette_area_norm
# 0      94.60                    0.194761                   0.117846
# 1      86.75                    0.153597                   0.138233
# 2      73.85                    0.170371                   0.105665
# 3      69.05                    0.174890                   0.117724
# 4      65.55                    0.171429                   0.109745
#
# [5 rows x 5140 columns]

# %%
import boto3  # S3 client
from io import StringIO  # in-memory text buffer

print("Preparing to upload updated dataset to S3...")  # track process

s3_out_path = "s3://ai-bmi-predictor-v2/test-data/eff_testingA_v3.csv"  # target S3 path
print("Target:", s3_out_path)  # show target

# ---- parse s3://bucket/key ----
out_bucket = s3_out_path.replace("s3://", "").split("/", 1)[0]  # extract bucket
out_key = s3_out_path.replace("s3://", "").split("/", 1)[1]     # extract key
print(f"Parsed -> bucket={out_bucket}, key={out_key}")  # confirm parsing

# ---- write CSV to memory ----
csv_buffer = StringIO()  # create in-memory buffer
print("Serializing dataframe to CSV (in-memory)...")  # track process
data.to_csv(csv_buffer, index=False)  # write dataframe as CSV text
csv_body = csv_buffer.getvalue()  # get CSV string content
print(f"CSV size (chars): {len(csv_body):,}")  # print rough size

# ---- upload to S3 ----
s3 = boto3.client("s3")  # create S3 client
print("Uploading to S3...")  # track process
s3.put_object(
    Bucket=out_bucket,                 # destination bucket
    Key=out_key,                       # destination key
    Body=csv_body.encode("utf-8"),     # file bytes
    ContentType="text/csv"             # content type
)  # upload

print("Upload complete ✅")  # done
print(f"Saved to: {s3_out_path}")  # confirm final path
# Out:
# Preparing to upload updated dataset to S3...
# Target: s3://ai-bmi-predictor-v2/test-data/eff_testingA_v3.csv
# Parsed -> bucket=ai-bmi-predictor-v2, key=test-data/eff_testingA_v3.csv
# Serializing dataframe to CSV (in-memory)...
# CSV size (chars): 102,304,060
# Uploading to S3...
# Upload complete ✅
# Saved to: s3://ai-bmi-predictor-v2/test-data/eff_testingA_v3.csv
