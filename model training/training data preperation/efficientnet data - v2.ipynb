# %% [markdown]
# 1. load the dataset

# %%
import boto3
import pandas as pd

bucket = "ai-bmi-predictor"
key = "data/eff_training.csv"

s3 = boto3.client("s3")
obj = s3.get_object(Bucket=bucket, Key=key)

data = pd.read_csv(obj["Body"])

data.head()
# Out:
#                            photo_id        f1        f2        f3        f4  \
# 0  6ab1d061f51c6079633aeceed2faeb0b  0.000068  0.108145 -0.138813  0.633156
# 1  e94e2e05fb8b099955bbc4fa5ce81e22  0.020843  0.026005 -0.093442  0.736929
# 2  ba6951a4f37fc9302243370e927a02e2  0.014542 -0.071332 -0.154407  0.577781
# 3  947d16539d4702427aa74f737329ffb9  0.041775  0.075746 -0.128497  0.485010
# 4  9326695bf62926ec22690f576a633bba  0.004397  0.058590 -0.154224  0.528140
#
#          f5        f6        f7        f8        f9  ...         hip  \
# 0  0.346266 -0.046055  0.016021 -0.058632  0.097968  ...  105.333900
# 1  0.240569  0.089982 -0.112391  0.000435 -0.076110  ...  101.478989
# 2  0.196485 -0.125341 -0.056713 -0.027295  0.094879  ...   97.488243
# 3  0.120409  0.011227  0.017852 -0.089796 -0.011273  ...  120.586845
# 4  0.290956 -0.108486 -0.021441 -0.099909  0.080770  ...  110.543564
#
#    leg-length  shoulder-breadth  shoulder-to-crotch      thigh       waist  \
# 0   76.817467         35.362858           65.993683  54.459591   88.813789
# 1   85.154358         37.256760           65.861588  52.773052   89.176338
# 2   81.410393         37.503147           66.042679  57.059261   82.201988
# 3   69.361534         34.084633           60.413330  65.000000  102.323845
# 4   77.160583         38.086231           68.400543  57.172279  107.378578
#
#        wrist  gender  height_cm  weight_kg
# 0  16.764332  female     170.50       72.0
# 1  15.690955    male     178.30       71.8
# 2  16.686253    male     176.25       76.5
# 3  17.693762  female     152.10       88.9
# 4  16.594791    male     171.50       88.4
#
# [5 rows x 5138 columns]

# %% [markdown]
# 2 calculate the body volume

# %%
# =========================
# Volume feature engineering
# =========================

import boto3  # AWS SDK for Python (S3 access)
import numpy as np  # fast array/mask operations
import pandas as pd  # dataframe ops
from PIL import Image  # read PNG images
from io import BytesIO  # convert S3 bytes -> file-like object
from botocore.exceptions import ClientError  # catch S3 missing-key errors

# -------------------------
# CONFIG (edit if needed)
# -------------------------

MASK_BUCKET = "amazon-bodym"            # S3 bucket that contains mask images
FRONT_MASK_PREFIX = "train/mask/"      # front masks folder (from your 1st screenshot)
SIDE_MASK_PREFIX = "train/mask_left/"  # side masks folder (from your 2nd screenshot)
PHOTO_ID_COL = "photo_id"              # column in your CSV that maps to mask filenames
OUTPUT_COL = "volume"                  # name for the new feature column

# -------------------------
# S3 client (reused)
# -------------------------

print("Creating S3 client...")  # track progress
s3 = boto3.client("s3")  # create an S3 client

# -----------------------------------------
# Helper: standardize photo_id -> filename
# -----------------------------------------

print("Inferring photo_id padding length...")  # track progress
photo_id_series = data[PHOTO_ID_COL].astype(str).fillna("")  # ensure string + no NaN
photo_id_series = photo_id_series.str.strip()  # remove whitespace
photo_id_series = photo_id_series.str.replace(".png", "", regex=False)  # drop extension if present
photo_id_series = photo_id_series.str.split(".", n=1).str[0]  # drop trailing ".0" etc (common if numeric CSV)
pad_len = int(photo_id_series.str.len().max()) if len(photo_id_series) else 0  # infer max length
pad_len = max(pad_len, 4)  # default to 4 (matches your example like "0021")
print(f"Using zero-pad length = {pad_len}")  # show chosen padding

def normalize_photo_id(photo_id, pad_length):  # define normalizer
    pid = str(photo_id).strip()  # convert to string and trim spaces
    pid = pid.replace(".png", "")  # remove .png if included
    pid = pid.split(".", 1)[0]  # remove any trailing decimals (e.g., "21.0" -> "21")
    if pid.isdigit():  # only pad if it's purely digits
        pid = pid.zfill(pad_length)  # left-pad with zeros
    return pid  # return normalized id like "0021"

# -----------------------------------------
# Helper: read mask PNG from S3 into boolean
# -----------------------------------------

def load_mask_bool_from_s3(bucket, key):  # function to load a mask file
    print(f"    Downloading: s3://{bucket}/{key}")  # track downloads
    obj = s3.get_object(Bucket=bucket, Key=key)  # fetch object bytes from S3
    img = Image.open(BytesIO(obj["Body"].read()))  # open image from bytes
    img = img.convert("L")  # convert to grayscale
    arr = np.array(img)  # convert to numpy array
    mask_bool = arr > 0  # treat any non-zero pixel as "body"
    return mask_bool  # return boolean mask

# -----------------------------------------
# Helper: compute mean width across rows
# -----------------------------------------

def mean_row_width(mask_bool):  # compute average body width across horizontal rows
    if mask_bool.size == 0:  # guard: empty image
        return np.nan  # cannot compute
    row_has_body = mask_bool.any(axis=1)  # rows where body exists
    if not row_has_body.any():  # guard: no body pixels
        return np.nan  # cannot compute
    first = mask_bool.argmax(axis=1)  # first True index per row (0 if none)
    last = mask_bool.shape[1] - 1 - np.flip(mask_bool, axis=1).argmax(axis=1)  # last True index per row
    widths = (last - first + 1).astype(float)  # width per row (in pixels)
    widths[~row_has_body] = np.nan  # ignore rows with no body
    return float(np.nanmean(widths))  # average width across valid rows

# -----------------------------------------
# Helper: compute height from front mask
# -----------------------------------------

def body_height(mask_bool):  # compute vertical extent (top-to-bottom)
    if mask_bool.size == 0:  # guard: empty image
        return np.nan  # cannot compute
    ys, xs = np.where(mask_bool)  # get coordinates of body pixels
    if ys.size == 0:  # guard: no body pixels
        return np.nan  # cannot compute
    h = (ys.max() - ys.min() + 1).astype(float)  # height in pixels
    return float(h)  # return height

# -----------------------------------------
# Per-record feature computation
# -----------------------------------------

def compute_volume_for_photo_id(photo_id):  # compute volume + debug parts for one record
    pid = normalize_photo_id(photo_id, pad_len)  # normalize id to match PNG filename
    front_key = f"{FRONT_MASK_PREFIX}{pid}.png"  # build front mask key
    side_key = f"{SIDE_MASK_PREFIX}{pid}.png"  # build side mask key

    try:
        front_mask = load_mask_bool_from_s3(MASK_BUCKET, front_key)  # load front mask
    except ClientError as e:  # handle missing front file
        print(f"    ERROR: missing front mask for {pid}: {e}")  # print error
        return np.nan, np.nan, np.nan, np.nan  # return NaNs

    try:
        side_mask = load_mask_bool_from_s3(MASK_BUCKET, side_key)  # load side mask
    except ClientError as e:  # handle missing side file
        print(f"    ERROR: missing side mask for {pid}: {e}")  # print error
        return np.nan, np.nan, np.nan, np.nan  # return NaNs

    front_w = mean_row_width(front_mask)  # front width (body looks wide from front)
    side_w = mean_row_width(side_mask)  # side width (body looks thick from side)
    avg_w = (front_w + side_w) / 2.0  # average width as instructed
    h = body_height(front_mask)  # height from front mask (vertical extent)

    raw_volume = avg_w * h  # volume ≈ average width × height
    norm_volume = raw_volume / (h ** 2) if (h is not None and not np.isnan(h) and h > 0) else np.nan  # normalize

    return norm_volume, front_w, side_w, h  # return volume + components for debugging

# -----------------------------------------
# Run across the dataframe and add column(s)
# -----------------------------------------

print("Starting volume computation for all records...")  # track progress
volumes = []  # store normalized volumes
front_ws = []  # store front widths (debug)
side_ws = []  # store side widths (debug)
heights = []  # store heights (debug)

n = len(data)  # total rows
print(f"Total rows to process: {n}")  # show total

for i, photo_id in enumerate(data[PHOTO_ID_COL].tolist(), start=1):  # iterate through photo_ids
    print(f"\nRecord {i}/{n} | photo_id={photo_id}")  # show per-record progress
    v, fw, sw, h = compute_volume_for_photo_id(photo_id)  # compute features
    print(f"    front_width={fw} | side_width={sw} | height={h} | volume={v}")  # print computed values
    volumes.append(v)  # append volume
    front_ws.append(fw)  # append front width
    side_ws.append(sw)  # append side width
    heights.append(h)  # append height

    if i % 50 == 0:  # every 50 rows
        print(f"\nProcessed {i}/{n} records so far...")  # periodic progress update

print("\nAttaching new feature columns to dataframe...")  # track progress
data[OUTPUT_COL] = volumes  # add normalized volume feature
data["front_width"] = front_ws  # optional debug column
data["side_width"] = side_ws  # optional debug column
data["mask_height"] = heights  # optional debug column

print("Done.")  # final status
print("Preview of updated dataframe:")  # show preview message
print(data[[PHOTO_ID_COL, OUTPUT_COL, "front_width", "side_width", "mask_height"]].head())  # preview new columns
# Out:
# Creating S3 client...
# Inferring photo_id padding length...
# Using zero-pad length = 32
# Starting volume computation for all records...
# Total rows to process: 6134
#
# Record 1/6134 | photo_id=6ab1d061f51c6079633aeceed2faeb0b
#     Downloading: s3://amazon-bodym/train/mask/6ab1d061f51c6079633aeceed2faeb0b.png
#     Downloading: s3://amazon-bodym/train/mask_left/6ab1d061f51c6079633aeceed2faeb0b.png
#     front_width=199.62155688622755 | side_width=113.00723763570566 | height=835.0 | volume=0.18720287097121752
#
# Record 2/6134 | photo_id=e94e2e05fb8b099955bbc4fa5ce81e22
#     Downloading: s3://amazon-bodym/train/mask/e94e2e05fb8b099955bbc4fa5ce81e22.png
#     Downloading: s3://amazon-bodym/train/mask_left/e94e2e05fb8b099955bbc4fa5ce81e22.png
#     front_width=203.3661971830986 | side_width=93.07472527472528 | height=852.0 | volume=0.17396767749872294
#
# Record 3/6134 | photo_id=ba6951a4f37fc9302243370e927a02e2
#     Downloading: s3://amazon-bodym/train/mask/ba6951a4f37fc9302243370e927a02e2.png
#     Downloading: s3://amazon-bodym/train/mask_left/ba6951a4f37fc9302243370e927a02e2.png
#     front_width=197.4977728285078 | side_width=115.56328392246294 | height=898.0 | volume=0.1743101652288256
#
# Record 4/6134 | photo_id=947d16539d4702427aa74f737329ffb9
#     Downloading: s3://amazon-bodym/train/mask/947d16539d4702427aa74f737329ffb9.png
#     Downloading: s3://amazon-bodym/train/mask_left/947d16539d4702427aa74f737329ffb9.png
#     front_width=212.3380829015544 | side_width=113.29676674364896 | height=772.0 | volume=0.21090340002927677
#
# Record 65/6134 | photo_id=ed54e147e1cc64428cea566997bfdb74
#     Downloading: s3://amazon-bodym/train/mask/ed54e147e1cc64428cea566997bfdb74.png
#     Downloading: s3://amazon-bodym/train/mask_left/ed54e147e1cc64428cea566997bfdb74.png
#     front_width=201.4145199063232 | side_width=106.99672131147541 | height=854.0 | volume=0.18056864239917952
#
# Record 66/6134 | photo_id=06c9f3b7dbcc25dbd6a16b1703be3d1e
#     Downloading: s3://amazon-bodym/train/mask/06c9f3b7dbcc25dbd6a16b1703be3d1e.png
#     Downloading: s3://amazon-bodym/train/mask_left/06c9f3b7dbcc25dbd6a16b1703be3d1e.png
#     front_width=238.54824063564132 | side_width=97.66442953020135 | height=881.0 | volume=0.19081309317017178
#
# Record 67/6134 | photo_id=2c077a299093054544094cfcc2297c60
#     Downloading: s3://amazon-bodym/train/mask/2c077a299093054544094cfcc2297c60.png
#     Downloading: s3://amazon-bodym/train/mask_left/2c077a299093054544094cfcc2297c60.png
#     front_width=201.6 | side_width=92.52768361581921 | height=875.0 | volume=0.16807296206618239
#
# Record 68/6134 | photo_id=53305d261184b860ede220b1ee52e4f4
#     Downloading: s3://amazon-bodym/train/mask/53305d261184b860ede220b1ee52e4f4.png
#     Downloading: s3://amazon-bodym/train/mask_left/53305d261184b860ede220b1ee52e4f4.png
#     front_width=193.86396181384248 | side_width=88.1412680756396 | height=838.0 | volume=0.168260877022364
#
# Record 69/6134 | photo_id=d12f51536fddf5bdf7cf22cdfaf1c9bd
#     Downloading: s3://amazon-bodym/train/mask/d12f51536fddf5bdf7cf22cdfaf1c9bd.png
#     Downloading: s3://amazon-bodym/train/mask_left/d12f51536fddf5bdf7cf22cdfaf1c9bd.png
#     front_width=251.16132858837486 | side_width=105.72716488730724 | height=843.0 | volume=0.2116776355134532
#
# Record 70/6134 | photo_id=5a16b5c4f7d9ef8335e22e022efd9cdd
#     Downloading: s3://amazon-bodym/train/mask/5a16b5c4f7d9ef8335e22e022efd9cdd.png
#     Downloading: s3://amazon-bodym/train/mask_left/5a16b5c4f7d9ef8335e22e022efd9cdd.png
#     front_width=229.83218390804598 | side_width=100.94818081587651 | height=870.0 | volume=0.19010365788731176
#
# Record 71/6134 | photo_id=3327f5ded6979666d773085c18030bf9
#     Downloading: s3://amazon-bodym/train/mask/3327f5ded6979666d773085c18030bf9.png
#     Downloading: s3://amazon-bodym/train/mask_left/3327f5ded6979666d773085c18030bf9.png
#     front_width=211.25487804878048 | side_width=85.44761904761904 | height=820.0 | volume=0.18091615676609724
#
# Record 72/6134 | photo_id=487a083073439a24a4e570f835deaa83
#     Downloading: s3://amazon-bodym/train/mask/487a083073439a24a4e570f835deaa83.png
#     Downloading: s3://amazon-bodym/train/mask_left/487a083073439a24a4e570f835deaa83.png
#     front_width=228.37227949599082 | side_width=86.14861751152074 | height=873.0 | volume=0.18013797079468016
#
# Record 73/6134 | photo_id=84459093d515b2e465524aad777b514e
#     Downloading: s3://amazon-bodym/train/mask/84459093d515b2e465524aad777b514e.png
#     Downloading: s3://amazon-bodym/train/mask_left/84459093d515b2e465524aad777b514e.png
#     front_width=218.07542579075425 | side_width=86.71481481481482 | height=822.0 | volume=0.18539552348270624
#
# Record 74/6134 | photo_id=f273826345c4384e432fa9b55d4bfeec
#     Downloading: s3://amazon-bodym/train/mask/f273826345c4384e432fa9b55d4bfeec.png
#     Downloading: s3://amazon-bodym/train/mask_left/f273826345c4384e432fa9b55d4bfeec.png
#     front_width=213.7632552404439 | side_width=101.79752530933634 | height=811.0 | volume=0.19455041957446376
#
# Record 75/6134 | photo_id=41307385ee6c1a5d2825773844352664
#     Downloading: s3://amazon-bodym/train/mask/41307385ee6c1a5d2825773844352664.png
#     Downloading: s3://amazon-bodym/train/mask_left/41307385ee6c1a5d2825773844352664.png
#     front_width=198.53836784409256 | side_width=92.21388577827548 | height=821.0 | volume=0.177072018040419
#
# Record 76/6134 | photo_id=636e9e33323c628783f2c87077a450aa
#     Downloading: s3://amazon-bodym/train/mask/636e9e33323c628783f2c87077a450aa.png
#     Downloading: s3://amazon-bodym/train/mask_left/636e9e33323c628783f2c87077a450aa.png
#     front_width=189.69987228607917 | side_width=102.04827586206896 | height=783.0 | volume=0.1863014994560333
#
# Record 77/6134 | photo_id=858411976933aebe469f58339333929b
#     Downloading: s3://amazon-bodym/train/mask/858411976933aebe469f58339333929b.png
#     Downloading: s3://amazon-bodym/train/mask_left/858411976933aebe469f58339333929b.png
#     front_width=196.91100702576114 | side_width=115.74583333333334 | height=854.0 | volume=0.18305435618213964
#
# Record 78/6134 | photo_id=ce9cd8e60a306b0e72cca3bc1cb41f80
#     Downloading: s3://amazon-bodym/train/mask/ce9cd8e60a306b0e72cca3bc1cb41f80.png
#     Downloading: s3://amazon-bodym/train/mask_left/ce9cd8e60a306b0e72cca3bc1cb41f80.png
#     front_width=221.43300248138956 | side_width=108.56324324324325 | height=806.0 | volume=0.2047123112435687
#
# Record 79/6134 | photo_id=0b16380bc9ca269804868f718dd6ff95
#     Downloading: s3://amazon-bodym/train/mask/0b16380bc9ca269804868f718dd6ff95.png
#     Downloading: s3://amazon-bodym/train/mask_left/0b16380bc9ca269804868f718dd6ff95.png
#     front_width=249.2923076923077 | side_width=124.73281596452328 | height=910.0 | volume=0.20550830970155548
#
# Record 80/6134 | photo_id=c2dfcd222d6d8a0a2c14e933a7925b21
#     Downloading: s3://amazon-bodym/train/mask/c2dfcd222d6d8a0a2c14e933a7925b21.png
#     Downloading: s3://amazon-bodym/train/mask_left/c2dfcd222d6d8a0a2c14e933a7925b21.png
#     front_width=202.0484429065744 | side_width=93.00801832760595 | height=867.0 | volume=0.17015943554451002
#
# Record 81/6134 | photo_id=730b3b6949b3f594886663dd51540920
#     Downloading: s3://amazon-bodym/train/mask/730b3b6949b3f594886663dd51540920.png
#     Downloading: s3://amazon-bodym/train/mask_left/730b3b6949b3f594886663dd51540920.png
#     front_width=236.23480333730632 | side_width=103.47374301675978 | height=839.0 | volume=0.20244847816094527
#
# Record 82/6134 | photo_id=77ac76d38a33e9a6b658ff8608aea9cd
#     front_width=186.45731707317074 | side_width=84.58879618593564 | height=820.0 | volume=0.16527202027994292
#
# Record 91/6134 | photo_id=f4adbff5364b3d9cdef70bdd014bd06e
#     Downloading: s3://amazon-bodym/train/mask/f4adbff5364b3d9cdef70bdd014bd06e.png
#     Downloading: s3://amazon-bodym/train/mask_left/f4adbff5364b3d9cdef70bdd014bd06e.png
#     front_width=195.89605734767025 | side_width=88.63565022421524 | height=837.0 | volume=0.1699711514766341
#
# Record 92/6134 | photo_id=b0a220118a5770b2c821d008764ee870
#     Downloading: s3://amazon-bodym/train/mask/b0a220118a5770b2c821d008764ee870.png
#     Downloading: s3://amazon-bodym/train/mask_left/b0a220118a5770b2c821d008764ee870.png
#     front_width=206.46031746031747 | side_width=121.16342857142857 | height=882.0 | volume=0.18572774718352947
#
# Record 93/6134 | photo_id=dbfa59c0ed28d10177a3fb403022ff9a
#     Downloading: s3://amazon-bodym/train/mask/dbfa59c0ed28d10177a3fb403022ff9a.png
#     Downloading: s3://amazon-bodym/train/mask_left/dbfa59c0ed28d10177a3fb403022ff9a.png
#     front_width=272.4369266055046 | side_width=126.30296610169492 | height=872.0 | volume=0.22863525957981623
#
# Record 94/6134 | photo_id=7a163f40051975527e53e34630713866
#     Downloading: s3://amazon-bodym/train/mask/7a163f40051975527e53e34630713866.png
#     Downloading: s3://amazon-bodym/train/mask_left/7a163f40051975527e53e34630713866.png
#     front_width=210.450563204005 | side_width=108.25082146768894 | height=799.0 | volume=0.1994376624979311
#
# Record 95/6134 | photo_id=ce338c3b6a2b9d4858560dd670d1a46e
#     Downloading: s3://amazon-bodym/train/mask/ce338c3b6a2b9d4858560dd670d1a46e.png
#     Downloading: s3://amazon-bodym/train/mask_left/ce338c3b6a2b9d4858560dd670d1a46e.png
#     front_width=199.00749063670412 | side_width=92.86549707602339 | height=801.0 | volume=0.18219287622517324
#
# Record 96/6134 | photo_id=ab55d6c3fbe0eed7605410e0aa2ac61c
#     Downloading: s3://amazon-bodym/train/mask/ab55d6c3fbe0eed7605410e0aa2ac61c.png
#     Downloading: s3://amazon-bodym/train/mask_left/ab55d6c3fbe0eed7605410e0aa2ac61c.png
#     front_width=218.7384066587396 | side_width=109.15600448933782 | height=841.0 | volume=0.194943169529178
#
# Record 97/6134 | photo_id=26bb1ff022792a9e8cb0dba3abc31ab3
#     Downloading: s3://amazon-bodym/train/mask/26bb1ff022792a9e8cb0dba3abc31ab3.png
#     Downloading: s3://amazon-bodym/train/mask_left/26bb1ff022792a9e8cb0dba3abc31ab3.png
#     front_width=193.02608695652174 | side_width=61.15151515151515 | height=805.0 | volume=0.1578742870236254
#
# Record 98/6134 | photo_id=a17d109ffb52659c34a7b2f6e43a48f9
#     Downloading: s3://amazon-bodym/train/mask/a17d109ffb52659c34a7b2f6e43a48f9.png
#     Downloading: s3://amazon-bodym/train/mask_left/a17d109ffb52659c34a7b2f6e43a48f9.png
#     front_width=200.45618247298918 | side_width=94.72800925925925 | height=833.0 | volume=0.1771813875943868
#
# Record 99/6134 | photo_id=7f6d63b0e646a8adf40f44ec6bd3edc8
#     Downloading: s3://amazon-bodym/train/mask_left/6cea484ab9b966d1b4b508e896f64384.png
#     front_width=236.4189675870348 | side_width=127.64850427350427 | height=833.0 | volume=0.21852789427403307
#
# Record 108/6134 | photo_id=43e97fcc024569b60f40032bc33b3d24
#     Downloading: s3://amazon-bodym/train/mask/43e97fcc024569b60f40032bc33b3d24.png
#     Downloading: s3://amazon-bodym/train/mask_left/43e97fcc024569b60f40032bc33b3d24.png
#     front_width=187.63659793814432 | side_width=81.07940161104717 | height=776.0 | volume=0.1731417522868502
#
# Record 109/6134 | photo_id=2144495dcdfef034267dfb3d69523867
#     Downloading: s3://amazon-bodym/train/mask/2144495dcdfef034267dfb3d69523867.png
#     Downloading: s3://amazon-bodym/train/mask_left/2144495dcdfef034267dfb3d69523867.png
#     front_width=225.26309523809525 | side_width=118.13581599123768 | height=840.0 | volume=0.20440411382698392
#
# Record 110/6134 | photo_id=9e183a8176fb381da920af304aea2ee2
#     Downloading: s3://amazon-bodym/train/mask/9e183a8176fb381da920af304aea2ee2.png
#     Downloading: s3://amazon-bodym/train/mask_left/9e183a8176fb381da920af304aea2ee2.png
#     front_width=250.79294117647058 | side_width=125.20171673819742 | height=850.0 | volume=0.2211733281850988
#
# Record 111/6134 | photo_id=e11aba0e28f584bfd984fe72817b2da5
#     Downloading: s3://amazon-bodym/train/mask/e11aba0e28f584bfd984fe72817b2da5.png
#     Downloading: s3://amazon-bodym/train/mask_left/e11aba0e28f584bfd984fe72817b2da5.png
#     front_width=197.45 | side_width=117.51378169790519 | height=840.0 | volume=0.1874784414868483
#
# Record 112/6134 | photo_id=c869bf4f0103c640f205835484842708
#     Downloading: s3://amazon-bodym/train/mask/c869bf4f0103c640f205835484842708.png
#     Downloading: s3://amazon-bodym/train/mask_left/c869bf4f0103c640f205835484842708.png
#     front_width=188.1720297029703 | side_width=97.48095756256801 | height=808.0 | volume=0.1767654624167935
#
# Record 113/6134 | photo_id=baf4c8ad6774a33ac5e94f3065aca5cf
#     Downloading: s3://amazon-bodym/train/mask/baf4c8ad6774a33ac5e94f3065aca5cf.png
#     Downloading: s3://amazon-bodym/train/mask_left/baf4c8ad6774a33ac5e94f3065aca5cf.png
#     front_width=200.68055555555554 | side_width=88.75829383886256 | height=792.0 | volume=0.1827265463348599
#
# Record 114/6134 | photo_id=560d8242feeb561da2cab3c3203cadc6
#     Downloading: s3://amazon-bodym/train/mask/560d8242feeb561da2cab3c3203cadc6.png
#     Downloading: s3://amazon-bodym/train/mask_left/560d8242feeb561da2cab3c3203cadc6.png
#     front_width=202.4018691588785 | side_width=95.48672566371681 | height=856.0 | volume=0.17400034744310475
#
# Record 115/6134 | photo_id=a5cd523d1dac3280c803e4ef18560ca1
#     Downloading: s3://amazon-bodym/train/mask/a5cd523d1dac3280c803e4ef18560ca1.png
#     Downloading: s3://amazon-bodym/train/mask_left/a5cd523d1dac3280c803e4ef18560ca1.png
#     front_width=223.13203214695753 | side_width=93.51135005973715 | height=871.0 | volume=0.1817700242288718
#
# Record 116/6134 | photo_id=4afa3f5dcfbd3f03311c8876193793cc
# Record 6091/6134 | photo_id=a8958d49c28d9e586e8107f23a36bdbd
#     Downloading: s3://amazon-bodym/train/mask/a8958d49c28d9e586e8107f23a36bdbd.png
#     Downloading: s3://amazon-bodym/train/mask_left/a8958d49c28d9e586e8107f23a36bdbd.png
#     front_width=202.52493765586036 | side_width=110.84364060676779 | height=802.0 | volume=0.19536694405400756
#
# Record 6092/6134 | photo_id=d796cc9ca2cfa1ec55cb25c803bfa593
#     Downloading: s3://amazon-bodym/train/mask/d796cc9ca2cfa1ec55cb25c803bfa593.png
#     Downloading: s3://amazon-bodym/train/mask_left/d796cc9ca2cfa1ec55cb25c803bfa593.png
#     front_width=208.87185628742515 | side_width=108.50845546786923 | height=835.0 | volume=0.19004809087143376
#
# Record 6093/6134 | photo_id=63226828b2190f32f2767c18dd4e78cf
#     Downloading: s3://amazon-bodym/train/mask/63226828b2190f32f2767c18dd4e78cf.png
#     Downloading: s3://amazon-bodym/train/mask_left/63226828b2190f32f2767c18dd4e78cf.png
#     front_width=238.74468085106383 | side_width=112.51724137931035 | height=846.0 | volume=0.2076016088831999
#
# Record 6094/6134 | photo_id=5b01fac82c495e2f3ec2e92244ce70da
#     Downloading: s3://amazon-bodym/train/mask/5b01fac82c495e2f3ec2e92244ce70da.png
#     Downloading: s3://amazon-bodym/train/mask_left/5b01fac82c495e2f3ec2e92244ce70da.png
#     front_width=204.9208037825059 | side_width=100.76763005780347 | height=846.0 | volume=0.18066692307346888
#
# Record 6095/6134 | photo_id=3bdbc3016f1f9a05a5152f20537ed392
#     Downloading: s3://amazon-bodym/train/mask/3bdbc3016f1f9a05a5152f20537ed392.png
#     Downloading: s3://amazon-bodym/train/mask_left/3bdbc3016f1f9a05a5152f20537ed392.png
#     front_width=207.281807372176 | side_width=100.21540178571429 | height=841.0 | volume=0.18281641448150432
#
# Record 6096/6134 | photo_id=a3ab4ec1f28352982b89f10e362eba78
#     Downloading: s3://amazon-bodym/train/mask/a3ab4ec1f28352982b89f10e362eba78.png
#     Downloading: s3://amazon-bodym/train/mask_left/a3ab4ec1f28352982b89f10e362eba78.png
#     front_width=194.9066496163683 | side_width=85.47447073474471 | height=782.0 | volume=0.1792718160812743
#
# Record 6097/6134 | photo_id=171bdc5468884754a0f7d5f3a16d7925
#     Downloading: s3://amazon-bodym/train/mask/171bdc5468884754a0f7d5f3a16d7925.png
#     Downloading: s3://amazon-bodym/train/mask_left/171bdc5468884754a0f7d5f3a16d7925.png
#     front_width=218.61163895486936 | side_width=118.3030303030303 | height=842.0 | volume=0.2000680933835509
#
# Record 6098/6134 | photo_id=6c79b5ff1f12ae522531f63ecec96eef
#     Downloading: s3://amazon-bodym/train/mask/6c79b5ff1f12ae522531f63ecec96eef.png
#     Downloading: s3://amazon-bodym/train/mask_left/6c79b5ff1f12ae522531f63ecec96eef.png
#     front_width=202.41596130592504 | side_width=97.01020408163265 | height=827.0 | volume=0.1810315389283904
#
# Record 6099/6134 | photo_id=ab798c74408f489aef68491c911cc376
#     Downloading: s3://amazon-bodym/train/mask/ab798c74408f489aef68491c911cc376.png
#     Downloading: s3://amazon-bodym/train/mask_left/ab798c74408f489aef68491c911cc376.png
#     front_width=235.76564277588167 | side_width=106.40578158458244 | height=879.0 | volume=0.1946367601595359
#
# Record 6100/6134 | photo_id=acc2df580c02098505ac7035fb9873ee
#     Downloading: s3://amazon-bodym/train/mask/acc2df580c02098505ac7035fb9873ee.png
#     Downloading: s3://amazon-bodym/train/mask_left/acc2df580c02098505ac7035fb9873ee.png
#     front_width=215.72382048331414 | side_width=86.0506329113924 | height=869.0 | volume=0.17363317226392783
#
# Processed 6100/6134 records so far...
#
# Record 6101/6134 | photo_id=a54da6ac80b02c90fe2af85d8a409440
#     Downloading: s3://amazon-bodym/train/mask/a54da6ac80b02c90fe2af85d8a409440.png
#     Downloading: s3://amazon-bodym/train/mask_left/a54da6ac80b02c90fe2af85d8a409440.png
#     front_width=189.83031088082902 | side_width=94.22274325908558 | height=772.0 | volume=0.18397218532377888
#
# Record 6102/6134 | photo_id=95671418db4c9ed5a9e0a2df00881b78
#     Downloading: s3://amazon-bodym/train/mask/95671418db4c9ed5a9e0a2df00881b78.png
#     Downloading: s3://amazon-bodym/train/mask_left/95671418db4c9ed5a9e0a2df00881b78.png
#     front_width=230.87430478309233 | side_width=89.45823927765237 | height=899.0 | volume=0.17816048056771117
#
# Record 6103/6134 | photo_id=7c375a83b03a363501533d50652bb2ef
#     Downloading: s3://amazon-bodym/train/mask/7c375a83b03a363501533d50652bb2ef.png
#     Downloading: s3://amazon-bodym/train/mask_left/7c375a83b03a363501533d50652bb2ef.png
#     front_width=188.86889460154242 | side_width=91.30292397660818 | height=778.0 | volume=0.18005900936899136
#
# Record 6104/6134 | photo_id=864e1acedbe55aa0eee4dd4537bb0027
#     Downloading: s3://amazon-bodym/train/mask/864e1acedbe55aa0eee4dd4537bb0027.png
#     Downloading: s3://amazon-bodym/train/mask_left/864e1acedbe55aa0eee4dd4537bb0027.png
#     front_width=246.18453038674033 | side_width=98.38302752293578 | height=905.0 | volume=0.19036881652468293
#
# Record 6105/6134 | photo_id=2391b1ee32555ca42fb4da1603b57fb4
#     Downloading: s3://amazon-bodym/train/mask/2391b1ee32555ca42fb4da1603b57fb4.png
#     Downloading: s3://amazon-bodym/train/mask_left/2391b1ee32555ca42fb4da1603b57fb4.png
#     front_width=182.3165137614679 | side_width=78.84692597239649 | height=872.0 | volume=0.14974967874648187
#
# Record 6106/6134 | photo_id=78bd87141c24819e2ca35a5cff8acc6f
#     Downloading: s3://amazon-bodym/train/mask/78bd87141c24819e2ca35a5cff8acc6f.png
#     Downloading: s3://amazon-bodym/train/mask_left/78bd87141c24819e2ca35a5cff8acc6f.png
#     front_width=214.14705882352942 | side_width=109.50489662676823 | height=850.0 | volume=0.19038350320605743
#
# Record 6107/6134 | photo_id=fca5b2262dd464b82ed29e3610bdeadd
#     Downloading: s3://amazon-bodym/train/mask/fca5b2262dd464b82ed29e3610bdeadd.png
#     Downloading: s3://amazon-bodym/train/mask_left/fca5b2262dd464b82ed29e3610bdeadd.png
#     front_width=186.7956577266922 | side_width=88.05939393939394 | height=783.0 | volume=0.17551408152368211
# Record 6125/6134 | photo_id=9b0d2b834a483b5f0e41956bcfaac5d2
#     Downloading: s3://amazon-bodym/train/mask/9b0d2b834a483b5f0e41956bcfaac5d2.png
#     Downloading: s3://amazon-bodym/train/mask_left/9b0d2b834a483b5f0e41956bcfaac5d2.png
#     front_width=212.792759051186 | side_width=90.39805825242719 | height=801.0 | volume=0.18925768870387838
#
# Record 6126/6134 | photo_id=677092e97dec6bc0998b6b9ddba46c8d
#     Downloading: s3://amazon-bodym/train/mask/677092e97dec6bc0998b6b9ddba46c8d.png
#     Downloading: s3://amazon-bodym/train/mask_left/677092e97dec6bc0998b6b9ddba46c8d.png
#     front_width=214.82333333333332 | side_width=88.69222096956031 | height=900.0 | volume=0.16861975239049648
#
# Record 6127/6134 | photo_id=b5a74a706f853f7ba39918badb625abf
#     Downloading: s3://amazon-bodym/train/mask/b5a74a706f853f7ba39918badb625abf.png
#     Downloading: s3://amazon-bodym/train/mask_left/b5a74a706f853f7ba39918badb625abf.png
#     front_width=238.931151241535 | side_width=100.26488456865128 | height=886.0 | volume=0.19141988476872818
#
# Record 6128/6134 | photo_id=625c2587242cc9b56f067175a9d53b8d
#     Downloading: s3://amazon-bodym/train/mask/625c2587242cc9b56f067175a9d53b8d.png
#     Downloading: s3://amazon-bodym/train/mask_left/625c2587242cc9b56f067175a9d53b8d.png
#     front_width=231.99647887323943 | side_width=108.31567567567568 | height=852.0 | volume=0.1997137057211943
#
# Record 6129/6134 | photo_id=995f026a55d23f229fd3b7623e46b470
#     Downloading: s3://amazon-bodym/train/mask/995f026a55d23f229fd3b7623e46b470.png
#     Downloading: s3://amazon-bodym/train/mask_left/995f026a55d23f229fd3b7623e46b470.png
#     front_width=194.55115089514067 | side_width=84.14598540145985 | height=782.0 | volume=0.1781950999338878
#
# Record 6130/6134 | photo_id=4925817167cc5dd9ece5248ed33a114d
#     Downloading: s3://amazon-bodym/train/mask/4925817167cc5dd9ece5248ed33a114d.png
#     Downloading: s3://amazon-bodym/train/mask_left/4925817167cc5dd9ece5248ed33a114d.png
#     front_width=201.16949152542372 | side_width=82.12257281553399 | height=767.0 | volume=0.18467540048302328
#
# Record 6131/6134 | photo_id=1a2bbdb164468cdae81ba230edebcd54
#     Downloading: s3://amazon-bodym/train/mask/1a2bbdb164468cdae81ba230edebcd54.png
#     Downloading: s3://amazon-bodym/train/mask_left/1a2bbdb164468cdae81ba230edebcd54.png
#     front_width=172.92660550458714 | side_width=112.31455399061034 | height=763.0 | volume=0.18692081225111237
#
# Record 6132/6134 | photo_id=7444c75f5ebf4a098401cddf2d0c1197
#     Downloading: s3://amazon-bodym/train/mask/7444c75f5ebf4a098401cddf2d0c1197.png
#     Downloading: s3://amazon-bodym/train/mask_left/7444c75f5ebf4a098401cddf2d0c1197.png
#     front_width=229.3283767038414 | side_width=90.2158273381295 | height=807.0 | volume=0.19798277821683452
#
# Record 6133/6134 | photo_id=73482a4b918314248eea94cc6353b48c
#     Downloading: s3://amazon-bodym/train/mask/73482a4b918314248eea94cc6353b48c.png
#     Downloading: s3://amazon-bodym/train/mask_left/73482a4b918314248eea94cc6353b48c.png
#     front_width=177.29308176100628 | side_width=89.3760092272203 | height=795.0 | volume=0.1677164094265576
#
# Record 6134/6134 | photo_id=b5074e2cef42298f49d724afd154034e
#     Downloading: s3://amazon-bodym/train/mask/b5074e2cef42298f49d724afd154034e.png
#     Downloading: s3://amazon-bodym/train/mask_left/b5074e2cef42298f49d724afd154034e.png
#     front_width=228.64182692307693 | side_width=106.09497206703911 | height=832.0 | volume=0.20116394170079085
#
# Attaching new feature columns to dataframe...
# Done.
# Preview of updated dataframe:
#                            photo_id    volume  front_width  side_width  \
# 0  6ab1d061f51c6079633aeceed2faeb0b  0.187203   199.621557  113.007238
# 1  e94e2e05fb8b099955bbc4fa5ce81e22  0.173968   203.366197   93.074725
# 2  ba6951a4f37fc9302243370e927a02e2  0.174310   197.497773  115.563284
# 3  947d16539d4702427aa74f737329ffb9  0.237156   280.037037  142.574353
# 4  9326695bf62926ec22690f576a633bba  0.198802   206.658344   95.918660
#
#    mask_height
# 0        835.0
# 1        852.0
# 2        898.0
# 3        891.0
# 4        761.0

# %%
data.head()
# Out:
#                            photo_id        f1        f2        f3        f4  \
# 0  6ab1d061f51c6079633aeceed2faeb0b  0.000068  0.108145 -0.138813  0.633156
# 1  e94e2e05fb8b099955bbc4fa5ce81e22  0.020843  0.026005 -0.093442  0.736929
# 2  ba6951a4f37fc9302243370e927a02e2  0.014542 -0.071332 -0.154407  0.577781
# 3  947d16539d4702427aa74f737329ffb9  0.041775  0.075746 -0.128497  0.485010
# 4  9326695bf62926ec22690f576a633bba  0.004397  0.058590 -0.154224  0.528140
#
#          f5        f6        f7        f8        f9  ...      thigh  \
# 0  0.346266 -0.046055  0.016021 -0.058632  0.097968  ...  54.459591
# 1  0.240569  0.089982 -0.112391  0.000435 -0.076110  ...  52.773052
# 2  0.196485 -0.125341 -0.056713 -0.027295  0.094879  ...  57.059261
# 3  0.120409  0.011227  0.017852 -0.089796 -0.011273  ...  65.000000
# 4  0.290956 -0.108486 -0.021441 -0.099909  0.080770  ...  57.172279
#
#         waist      wrist  gender  height_cm  weight_kg    volume  front_width  \
# 0   88.813789  16.764332  female     170.50       72.0  0.187203   199.621557
# 1   89.176338  15.690955    male     178.30       71.8  0.173968   203.366197
# 2   82.201988  16.686253    male     176.25       76.5  0.174310   197.497773
# 3  102.323845  17.693762  female     152.10       88.9  0.237156   280.037037
# 4  107.378578  16.594791    male     171.50       88.4  0.198802   206.658344
#
#    side_width  mask_height
# 0  113.007238        835.0
# 1   93.074725        852.0
# 2  115.563284        898.0
# 3  142.574353        891.0
# 4   95.918660        761.0
#
# [5 rows x 5142 columns]

# %%
data.shape
# Out:
# (6134, 5142)

# %%
# Drop the intermediate/debug columns (ignore if they don't exist)
cols_to_drop = ["front_width", "side_width", "mask_height"]  # columns to remove
print("Dropping columns:", cols_to_drop)  # track process
data.drop(columns=cols_to_drop, inplace=True, errors="ignore")  # drop safely
# Out:
# Dropping columns: ['front_width', 'side_width', 'mask_height']

# %%
data.shape
# Out:
# (6134, 5139)

# %%
data.head()
# Out:
#                            photo_id        f1        f2        f3        f4  \
# 0  6ab1d061f51c6079633aeceed2faeb0b  0.000068  0.108145 -0.138813  0.633156
# 1  e94e2e05fb8b099955bbc4fa5ce81e22  0.020843  0.026005 -0.093442  0.736929
# 2  ba6951a4f37fc9302243370e927a02e2  0.014542 -0.071332 -0.154407  0.577781
# 3  947d16539d4702427aa74f737329ffb9  0.041775  0.075746 -0.128497  0.485010
# 4  9326695bf62926ec22690f576a633bba  0.004397  0.058590 -0.154224  0.528140
#
#          f5        f6        f7        f8        f9  ...  leg-length  \
# 0  0.346266 -0.046055  0.016021 -0.058632  0.097968  ...   76.817467
# 1  0.240569  0.089982 -0.112391  0.000435 -0.076110  ...   85.154358
# 2  0.196485 -0.125341 -0.056713 -0.027295  0.094879  ...   81.410393
# 3  0.120409  0.011227  0.017852 -0.089796 -0.011273  ...   69.361534
# 4  0.290956 -0.108486 -0.021441 -0.099909  0.080770  ...   77.160583
#
#    shoulder-breadth  shoulder-to-crotch      thigh       waist      wrist  \
# 0         35.362858           65.993683  54.459591   88.813789  16.764332
# 1         37.256760           65.861588  52.773052   89.176338  15.690955
# 2         37.503147           66.042679  57.059261   82.201988  16.686253
# 3         34.084633           60.413330  65.000000  102.323845  17.693762
# 4         38.086231           68.400543  57.172279  107.378578  16.594791
#
#    gender  height_cm  weight_kg    volume
# 0  female     170.50       72.0  0.187203
# 1    male     178.30       71.8  0.173968
# 2    male     176.25       76.5  0.174310
# 3  female     152.10       88.9  0.237156
# 4    male     171.50       88.4  0.198802
#
# [5 rows x 5139 columns]

# %%
import boto3  # S3 client
from io import StringIO  # in-memory text buffer

print("Preparing to upload updated dataset to S3...")  # track process

s3_out_path = "s3://ai-bmi-predictor/data/eff_training_v2.csv"  # target S3 path
print("Target:", s3_out_path)  # show target

# ---- parse s3://bucket/key ----
out_bucket = s3_out_path.replace("s3://", "").split("/", 1)[0]  # extract bucket
out_key = s3_out_path.replace("s3://", "").split("/", 1)[1]     # extract key
print(f"Parsed -> bucket={out_bucket}, key={out_key}")  # confirm parsing

# ---- write CSV to memory ----
csv_buffer = StringIO()  # create in-memory buffer
print("Serializing dataframe to CSV (in-memory)...")  # track process
data.to_csv(csv_buffer, index=False)  # write dataframe as CSV text
csv_body = csv_buffer.getvalue()  # get CSV string content
print(f"CSV size (chars): {len(csv_body):,}")  # print rough size

# ---- upload to S3 ----
s3 = boto3.client("s3")  # create S3 client
print("Uploading to S3...")  # track process
s3.put_object(
    Bucket=out_bucket,                 # destination bucket
    Key=out_key,                       # destination key
    Body=csv_body.encode("utf-8"),     # file bytes
    ContentType="text/csv"             # content type
)  # upload

print("Upload complete ✅")  # done
print(f"Saved to: {s3_out_path}")  # confirm final path
# Out:
# Preparing to upload updated dataset to S3...
# Target: s3://ai-bmi-predictor/data/eff_training_v2.csv
# Parsed -> bucket=ai-bmi-predictor, key=data/eff_training_v2.csv
# Serializing dataframe to CSV (in-memory)...
# CSV size (chars): 372,619,770
# Uploading to S3...
# Upload complete ✅
# Saved to: s3://ai-bmi-predictor/data/eff_training_v2.csv
