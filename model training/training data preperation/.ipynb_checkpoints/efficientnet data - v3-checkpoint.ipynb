# %% [markdown]
# 1. load the dataset

# %%
import boto3
import pandas as pd

bucket = "ai-bmi-predictor-v2"
key = "data/eff_training.csv"

s3 = boto3.client("s3")
obj = s3.get_object(Bucket=bucket, Key=key)

data = pd.read_csv(obj["Body"])

data.head()
# Out:
#                            photo_id        f1        f2        f3        f4  \
# 0  6ab1d061f51c6079633aeceed2faeb0b  0.000068  0.108145 -0.138813  0.633156
# 1  e94e2e05fb8b099955bbc4fa5ce81e22  0.020843  0.026005 -0.093442  0.736929
# 2  ba6951a4f37fc9302243370e927a02e2  0.014542 -0.071332 -0.154407  0.577781
# 3  947d16539d4702427aa74f737329ffb9  0.041775  0.075746 -0.128497  0.485010
# 4  9326695bf62926ec22690f576a633bba  0.004397  0.058590 -0.154224  0.528140
#
#          f5        f6        f7        f8        f9  ...         hip  \
# 0  0.346266 -0.046055  0.016021 -0.058632  0.097968  ...  105.333900
# 1  0.240569  0.089982 -0.112391  0.000435 -0.076110  ...  101.478989
# 2  0.196485 -0.125341 -0.056713 -0.027295  0.094879  ...   97.488243
# 3  0.120409  0.011227  0.017852 -0.089796 -0.011273  ...  120.586845
# 4  0.290956 -0.108486 -0.021441 -0.099909  0.080770  ...  110.543564
#
#    leg-length  shoulder-breadth  shoulder-to-crotch      thigh       waist  \
# 0   76.817467         35.362858           65.993683  54.459591   88.813789
# 1   85.154358         37.256760           65.861588  52.773052   89.176338
# 2   81.410393         37.503147           66.042679  57.059261   82.201988
# 3   69.361534         34.084633           60.413330  65.000000  102.323845
# 4   77.160583         38.086231           68.400543  57.172279  107.378578
#
#        wrist  gender  height_cm  weight_kg
# 0  16.764332  female     170.50       72.0
# 1  15.690955    male     178.30       71.8
# 2  16.686253    male     176.25       76.5
# 3  17.693762  female     152.10       88.9
# 4  16.594791    male     171.50       88.4
#
# [5 rows x 5138 columns]

# %% [markdown]
# 2 calculate normalized silhoutte area

# %%
# =========================
# Silhouette area features
# =========================

import boto3  # AWS SDK for Python (S3 access)
import numpy as np  # fast array operations
import pandas as pd  # dataframe operations
from PIL import Image  # read PNG images
from io import BytesIO  # convert S3 bytes -> file-like object
from botocore.exceptions import ClientError  # catch S3 missing-key errors

# -------------------------
# CONFIG (edit if needed)
# -------------------------

MASK_BUCKET = "amazon-bodym"  # S3 bucket containing the mask images
FRONT_MASK_PREFIX = "train/mask/"  # S3 prefix/folder for front masks
SIDE_MASK_PREFIX = "train/mask_left/"  # S3 prefix/folder for side masks
PHOTO_ID_COL = "photo_id"  # dataframe column containing photo IDs

FRONT_AREA_COL = "front_silhouette_area_norm"  # output column for normalized front area
SIDE_AREA_COL  = "side_silhouette_area_norm"   # output column for normalized side area

# optional debug columns (keep or remove)
FRONT_AREA_RAW_COL = "front_silhouette_area"  # raw (unnormalized) front pixel area
SIDE_AREA_RAW_COL  = "side_silhouette_area"   # raw (unnormalized) side pixel area
FRONT_H_COL = "front_mask_height"  # computed pixel height for front mask
SIDE_H_COL  = "side_mask_height"   # computed pixel height for side mask

# -------------------------
# S3 client (reused)
# -------------------------

print("Creating S3 client...")  # progress log
s3 = boto3.client("s3")  # create S3 client

# -----------------------------------------
# Helper: standardize photo_id -> filename
# -----------------------------------------

print("Preparing photo_id normalization...")  # progress log
photo_id_series = data[PHOTO_ID_COL].astype(str).fillna("")  # ensure string + no NaN
photo_id_series = photo_id_series.str.strip()  # remove whitespace
photo_id_series = photo_id_series.str.replace(".png", "", regex=False)  # drop .png if present
photo_id_series = photo_id_series.str.split(".", n=1).str[0]  # drop trailing decimals like ".0"

pad_len = int(photo_id_series.str.len().max()) if len(photo_id_series) else 0  # infer max length
pad_len = max(pad_len, 4)  # at least 4 (e.g., "0021")
print(f"Using zero-pad length = {pad_len}")  # show chosen pad length

def normalize_photo_id(photo_id, pad_length):  # normalize id to match PNG filenames
    pid = str(photo_id).strip()  # convert to string and trim
    pid = pid.replace(".png", "")  # remove extension if included
    pid = pid.split(".", 1)[0]  # remove any trailing decimals
    if pid.isdigit():  # pad only if numeric
        pid = pid.zfill(pad_length)  # zero-pad on the left
    return pid  # return normalized id

# -----------------------------------------
# Helper: read mask PNG from S3 into boolean
# -----------------------------------------

def load_mask_bool_from_s3(bucket, key):  # loads mask and converts to boolean array
    print(f"    Downloading mask: s3://{bucket}/{key}")  # track downloads
    obj = s3.get_object(Bucket=bucket, Key=key)  # fetch file bytes from S3
    img = Image.open(BytesIO(obj["Body"].read()))  # open image from bytes
    img = img.convert("L")  # convert to grayscale
    arr = np.array(img)  # convert image to numpy array
    return arr > 0  # True for body pixels (white), False otherwise

# -----------------------------------------
# Helper: compute height from mask
# -----------------------------------------

def mask_height(mask_bool):  # compute vertical body extent in pixels
    if mask_bool.size == 0:  # guard: empty image
        return np.nan  # cannot compute
    ys, xs = np.where(mask_bool)  # coordinates of body pixels
    if ys.size == 0:  # guard: no body pixels
        return np.nan  # cannot compute
    return float(ys.max() - ys.min() + 1)  # height = bottom - top + 1

# -----------------------------------------
# Helper: silhouette area + normalization
# -----------------------------------------

def silhouette_area(mask_bool):  # count body pixels in the mask
    if mask_bool.size == 0:  # guard: empty image
        return np.nan  # cannot compute
    return float(np.count_nonzero(mask_bool))  # number of True pixels

def normalized_silhouette_area(mask_bool):  # area normalized by height^2
    a = silhouette_area(mask_bool)  # compute raw pixel area
    h = mask_height(mask_bool)  # compute pixel height
    if np.isnan(a) or np.isnan(h) or h <= 0:  # guard: invalid values
        return np.nan, a, h  # return NaN normalized area + raw diagnostics
    return float(a / (h * h)), a, h  # normalized area, raw area, height

# -----------------------------------------
# Per-record feature computation
# -----------------------------------------

def compute_areas_for_photo_id(photo_id):  # compute front+side areas for one record
    pid = normalize_photo_id(photo_id, pad_len)  # normalize ID to match filenames
    front_key = f"{FRONT_MASK_PREFIX}{pid}.png"  # build S3 key for front mask
    side_key  = f"{SIDE_MASK_PREFIX}{pid}.png"   # build S3 key for side mask

    print(f"  Processing photo_id={photo_id} -> pid={pid}")  # per-record log

    try:
        front_mask = load_mask_bool_from_s3(MASK_BUCKET, front_key)  # load front mask
    except ClientError as e:
        print(f"    ERROR: missing front mask for pid={pid} | {e}")  # missing file log
        return (np.nan, np.nan, np.nan, np.nan, np.nan, np.nan)  # return NaNs

    try:
        side_mask = load_mask_bool_from_s3(MASK_BUCKET, side_key)  # load side mask
    except ClientError as e:
        print(f"    ERROR: missing side mask for pid={pid} | {e}")  # missing file log
        return (np.nan, np.nan, np.nan, np.nan, np.nan, np.nan)  # return NaNs

    front_norm, front_raw, front_h = normalized_silhouette_area(front_mask)  # front features
    side_norm,  side_raw,  side_h  = normalized_silhouette_area(side_mask)   # side features

    print(
        f"    front_raw_area={front_raw} | front_h={front_h} | front_norm={front_norm} "
        f"|| side_raw_area={side_raw} | side_h={side_h} | side_norm={side_norm}"
    )  # computed values log

    return front_norm, side_norm, front_raw, side_raw, front_h, side_h  # return all values

# -----------------------------------------
# Run across the dataframe and add columns
# -----------------------------------------

print("Starting silhouette area computation for all records...")  # progress log

front_norms, side_norms = [], []  # store normalized areas
front_raws, side_raws = [], []  # store raw areas (debug)
front_hs, side_hs = [], []  # store heights (debug)

n = len(data)  # total rows
print(f"Total rows to process: {n}")  # show total count

for i, photo_id in enumerate(data[PHOTO_ID_COL].tolist(), start=1):  # loop through all records
    print(f"\nRecord {i}/{n}")  # record progress
    fn, sn, fr, sr, fh, sh = compute_areas_for_photo_id(photo_id)  # compute features

    front_norms.append(fn)  # save front normalized area
    side_norms.append(sn)  # save side normalized area
    front_raws.append(fr)  # save front raw area
    side_raws.append(sr)  # save side raw area
    front_hs.append(fh)  # save front height
    side_hs.append(sh)  # save side height

    if i % 50 == 0:  # periodic update
        print(f"\nProcessed {i}/{n} records so far...")  # progress log

print("\nAttaching new feature columns to dataframe...")  # progress log
data[FRONT_AREA_COL] = front_norms  # add normalized front area feature
data[SIDE_AREA_COL]  = side_norms   # add normalized side area feature
# Out:
# Creating S3 client...
# Preparing photo_id normalization...
# Using zero-pad length = 32
# Starting silhouette area computation for all records...
# Total rows to process: 6134
#
# Record 1/6134
#   Processing photo_id=6ab1d061f51c6079633aeceed2faeb0b -> pid=6ab1d061f51c6079633aeceed2faeb0b
#     Downloading mask: s3://amazon-bodym/train/mask/6ab1d061f51c6079633aeceed2faeb0b.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/6ab1d061f51c6079633aeceed2faeb0b.png
#     front_raw_area=121535.0 | front_h=835.0 | front_norm=0.1743124529384345 || side_raw_area=93270.0 | side_h=829.0 | side_norm=0.13571658268351278
#
# Record 2/6134
#   Processing photo_id=e94e2e05fb8b099955bbc4fa5ce81e22 -> pid=e94e2e05fb8b099955bbc4fa5ce81e22
#     Downloading mask: s3://amazon-bodym/train/mask/e94e2e05fb8b099955bbc4fa5ce81e22.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/e94e2e05fb8b099955bbc4fa5ce81e22.png
#     front_raw_area=124875.0 | front_h=852.0 | front_norm=0.17202687958738347 || side_raw_area=84668.0 | side_h=910.0 | side_norm=0.10224369037555851
#
# Record 3/6134
#   Processing photo_id=ba6951a4f37fc9302243370e927a02e2 -> pid=ba6951a4f37fc9302243370e927a02e2
#     Downloading mask: s3://amazon-bodym/train/mask/ba6951a4f37fc9302243370e927a02e2.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/ba6951a4f37fc9302243370e927a02e2.png
#     front_raw_area=135763.0 | front_h=898.0 | front_norm=0.16835605974176715 || side_raw_area=88249.0 | side_h=877.0 | side_norm=0.11473887995381789
#
# Record 4/6134
#   Processing photo_id=947d16539d4702427aa74f737329ffb9 -> pid=947d16539d4702427aa74f737329ffb9
#     Downloading mask: s3://amazon-bodym/train/mask/947d16539d4702427aa74f737329ffb9.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/947d16539d4702427aa74f737329ffb9.png
#     front_raw_area=179893.0 | front_h=891.0 | front_norm=0.22659945256278963 || side_raw_area=132301.0 | side_h=928.0 | side_norm=0.15362686719678953
#
# Record 5/6134
#   Processing photo_id=9326695bf62926ec22690f576a633bba -> pid=9326695bf62926ec22690f576a633bba
#     Downloading mask: s3://amazon-bodym/train/mask/9326695bf62926ec22690f576a633bba.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/9326695bf62926ec22690f576a633bba.png
#     front_raw_area=106178.0 | front_h=761.0 | front_norm=0.18334337729075617 || side_raw_area=80156.0 | side_h=836.0 | side_norm=0.11468945308028662
#
# Record 6/6134
#   Processing photo_id=660ac3433f472e9bbaeed8b0e5e35254 -> pid=660ac3433f472e9bbaeed8b0e5e35254
#     Downloading mask: s3://amazon-bodym/train/mask/660ac3433f472e9bbaeed8b0e5e35254.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/660ac3433f472e9bbaeed8b0e5e35254.png
#     front_raw_area=153587.0 | front_h=900.0 | front_norm=0.18961358024691358 || side_raw_area=110516.0 | side_h=880.0 | side_norm=0.14271177685950412
#
# Record 7/6134
#   Processing photo_id=bfc13bbdf0bf989d003df2a30b8582cd -> pid=bfc13bbdf0bf989d003df2a30b8582cd
#     Downloading mask: s3://amazon-bodym/train/mask/bfc13bbdf0bf989d003df2a30b8582cd.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/bfc13bbdf0bf989d003df2a30b8582cd.png
#     front_raw_area=102864.0 | front_h=815.0 | front_norm=0.15486318642026423 || side_raw_area=65744.0 | side_h=837.0 | side_norm=0.09384371846313497
#
# Record 8/6134
#   Processing photo_id=2993db3b9046e13aed7fa00b73c17ed9 -> pid=2993db3b9046e13aed7fa00b73c17ed9
#     Downloading mask: s3://amazon-bodym/train/mask/2993db3b9046e13aed7fa00b73c17ed9.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/2993db3b9046e13aed7fa00b73c17ed9.png
#     front_raw_area=116033.0 | front_h=807.0 | front_norm=0.17816994728590754 || side_raw_area=90322.0 | side_h=846.0 | side_norm=0.12619810092271236
#
# Record 9/6134
#   Processing photo_id=942918cc56a7a197a486742587fe6b3d -> pid=942918cc56a7a197a486742587fe6b3d
#     Downloading mask: s3://amazon-bodym/train/mask/942918cc56a7a197a486742587fe6b3d.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/942918cc56a7a197a486742587fe6b3d.png
#     front_raw_area=112876.0 | front_h=832.0 | front_norm=0.16306282359467456 || side_raw_area=74450.0 | side_h=843.0 | side_norm=0.10476339233573818
#
# Record 10/6134
#   Processing photo_id=9e7a4cc6611782335695d76dc4ffa2ad -> pid=9e7a4cc6611782335695d76dc4ffa2ad
#     Downloading mask: s3://amazon-bodym/train/mask/9e7a4cc6611782335695d76dc4ffa2ad.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/9e7a4cc6611782335695d76dc4ffa2ad.png
#     front_raw_area=113929.0 | front_h=833.0 | front_norm=0.1641890849977446 || side_raw_area=65141.0 | side_h=818.0 | side_norm=0.09735265810223516
#
# Record 11/6134
#   Processing photo_id=32bf6b6289f7b9268ca5e15093687d76 -> pid=32bf6b6289f7b9268ca5e15093687d76
#     Downloading mask: s3://amazon-bodym/train/mask/32bf6b6289f7b9268ca5e15093687d76.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/32bf6b6289f7b9268ca5e15093687d76.png
#     front_raw_area=136736.0 | front_h=882.0 | front_norm=0.17577038373928558 || side_raw_area=94789.0 | side_h=916.0 | side_norm=0.11297100551095517
#
# Record 12/6134
#   Processing photo_id=f5d290f1a7f39452b41c89bd0f40ee58 -> pid=f5d290f1a7f39452b41c89bd0f40ee58
#     Downloading mask: s3://amazon-bodym/train/mask/f5d290f1a7f39452b41c89bd0f40ee58.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/f5d290f1a7f39452b41c89bd0f40ee58.png
#     front_raw_area=119312.0 | front_h=860.0 | front_norm=0.1613196322336398 || side_raw_area=66002.0 | side_h=815.0 | side_norm=0.09936693138620196
#
# Record 13/6134
#   Processing photo_id=c15896db70e5a9591bbc336d7972a487 -> pid=c15896db70e5a9591bbc336d7972a487
#     Downloading mask: s3://amazon-bodym/train/mask/c15896db70e5a9591bbc336d7972a487.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/c15896db70e5a9591bbc336d7972a487.png
#     front_raw_area=126208.0 | front_h=856.0 | front_norm=0.17224211721547733 || side_raw_area=88492.0 | side_h=903.0 | side_norm=0.10852467902610836
#
# Record 14/6134
#   Processing photo_id=45108038273e7fb409461e9a52b2d21a -> pid=45108038273e7fb409461e9a52b2d21a
#     Downloading mask: s3://amazon-bodym/train/mask/45108038273e7fb409461e9a52b2d21a.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/45108038273e7fb409461e9a52b2d21a.png
#     front_raw_area=135191.0 | front_h=849.0 | front_norm=0.18755662103687426 || side_raw_area=92081.0 | side_h=878.0 | side_norm=0.1194485811094795
#
# Record 15/6134
#   Processing photo_id=f2f5ad8df0d6d8d958db3608b7f38ee9 -> pid=f2f5ad8df0d6d8d958db3608b7f38ee9
#     Downloading mask: s3://amazon-bodym/train/mask/f2f5ad8df0d6d8d958db3608b7f38ee9.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/f2f5ad8df0d6d8d958db3608b7f38ee9.png
#     front_raw_area=142364.0 | front_h=883.0 | front_norm=0.18259075092761345 || side_raw_area=110209.0 | side_h=928.0 | side_norm=0.12797381279726516
#
# Record 16/6134
#   Processing photo_id=44d2ce61ba5f0cbc6476b13e7307758a -> pid=44d2ce61ba5f0cbc6476b13e7307758a
#     Downloading mask: s3://amazon-bodym/train/mask/44d2ce61ba5f0cbc6476b13e7307758a.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/44d2ce61ba5f0cbc6476b13e7307758a.png
#     front_raw_area=139649.0 | front_h=831.0 | front_norm=0.20222543699977266 || side_raw_area=91843.0 | side_h=857.0 | side_norm=0.1250502077067298
#
# Record 17/6134
#   Processing photo_id=25da35d9a3e04ce905427bf81aee32a5 -> pid=25da35d9a3e04ce905427bf81aee32a5
#     Downloading mask: s3://amazon-bodym/train/mask/25da35d9a3e04ce905427bf81aee32a5.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/25da35d9a3e04ce905427bf81aee32a5.png
#     front_raw_area=119445.0 | front_h=784.0 | front_norm=0.19432820960016658 || side_raw_area=88293.0 | side_h=831.0 | side_norm=0.12785691633324212
#
# Record 18/6134
#   Processing photo_id=cd754dd3dc074689bacbd098c3ef32ea -> pid=cd754dd3dc074689bacbd098c3ef32ea
#     Downloading mask: s3://amazon-bodym/train/mask/cd754dd3dc074689bacbd098c3ef32ea.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/cd754dd3dc074689bacbd098c3ef32ea.png
#     front_raw_area=151904.0 | front_h=919.0 | front_norm=0.17986149017063302 || side_raw_area=91895.0 | side_h=860.0 | side_norm=0.12424959437533802
#
# Record 19/6134
#   Processing photo_id=4c8c6330303cd5551a2f6619f4e03dd4 -> pid=4c8c6330303cd5551a2f6619f4e03dd4
#     Downloading mask: s3://amazon-bodym/train/mask/4c8c6330303cd5551a2f6619f4e03dd4.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/4c8c6330303cd5551a2f6619f4e03dd4.png
#     front_raw_area=129256.0 | front_h=831.0 | front_norm=0.18717535453059178 || side_raw_area=80673.0 | side_h=837.0 | side_norm=0.11515353948005122
#
# Record 20/6134
#   Processing photo_id=5308d29d64d0be74f0c465d42fadeae0 -> pid=5308d29d64d0be74f0c465d42fadeae0
#     Downloading mask: s3://amazon-bodym/train/mask/5308d29d64d0be74f0c465d42fadeae0.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/5308d29d64d0be74f0c465d42fadeae0.png
#     front_raw_area=143560.0 | front_h=887.0 | front_norm=0.18246778914776765 || side_raw_area=94725.0 | side_h=930.0 | side_norm=0.1095213319458897
#
# Record 21/6134
#   Processing photo_id=1f73d63f02d6b01b5d4cb97af70d702d -> pid=1f73d63f02d6b01b5d4cb97af70d702d
#     Downloading mask: s3://amazon-bodym/train/mask/1f73d63f02d6b01b5d4cb97af70d702d.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/1f73d63f02d6b01b5d4cb97af70d702d.png
#     front_raw_area=133377.0 | front_h=880.0 | front_norm=0.17223269628099175 || side_raw_area=93844.0 | side_h=878.0 | side_norm=0.12173556592172104
#
# Record 22/6134
#   Processing photo_id=1c37a82435a63c22ff49c2ddbdf18e21 -> pid=1c37a82435a63c22ff49c2ddbdf18e21
#     Downloading mask: s3://amazon-bodym/train/mask/1c37a82435a63c22ff49c2ddbdf18e21.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/1c37a82435a63c22ff49c2ddbdf18e21.png
#     front_raw_area=145330.0 | front_h=871.0 | front_norm=0.19156623488580238 || side_raw_area=99476.0 | side_h=869.0 | side_norm=0.13172820100614305
#
# Record 23/6134
#   Processing photo_id=d54caf752e5d31f4d8e0f3539f702635 -> pid=d54caf752e5d31f4d8e0f3539f702635
#     Downloading mask: s3://amazon-bodym/train/mask/d54caf752e5d31f4d8e0f3539f702635.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/d54caf752e5d31f4d8e0f3539f702635.png
#     front_raw_area=114409.0 | front_h=800.0 | front_norm=0.1787640625 || side_raw_area=86159.0 | side_h=853.0 | side_norm=0.11841387338529348
#
# Record 24/6134
#   Processing photo_id=86d3696c8858379f4d5aefab188e72fc -> pid=86d3696c8858379f4d5aefab188e72fc
#     Downloading mask: s3://amazon-bodym/train/mask/86d3696c8858379f4d5aefab188e72fc.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/86d3696c8858379f4d5aefab188e72fc.png
#     front_raw_area=139643.0 | front_h=854.0 | front_norm=0.19147118670096364 || side_raw_area=104419.0 | side_h=881.0 | side_norm=0.13453265495174327
#
# Record 25/6134
#   Processing photo_id=107be51f63daba5190c1d3aa2f0ca215 -> pid=107be51f63daba5190c1d3aa2f0ca215
#     Downloading mask: s3://amazon-bodym/train/mask/107be51f63daba5190c1d3aa2f0ca215.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/107be51f63daba5190c1d3aa2f0ca215.png
#     front_raw_area=100333.0 | front_h=772.0 | front_norm=0.1683484791538028 || side_raw_area=74281.0 | side_h=836.0 | side_norm=0.10628333829353724
#
# Record 26/6134
#   Processing photo_id=ba5e12a57f589e566c079517b6c8e7ef -> pid=ba5e12a57f589e566c079517b6c8e7ef
#     Downloading mask: s3://amazon-bodym/train/mask/ba5e12a57f589e566c079517b6c8e7ef.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/ba5e12a57f589e566c079517b6c8e7ef.png
#     front_raw_area=102636.0 | front_h=769.0 | front_norm=0.17355895975554694 || side_raw_area=65256.0 | side_h=784.0 | side_norm=0.10616670137442732
#
# Record 27/6134
#   Processing photo_id=6996e6ef198179b867d532a9f7198188 -> pid=6996e6ef198179b867d532a9f7198188
#     Downloading mask: s3://amazon-bodym/train/mask/6996e6ef198179b867d532a9f7198188.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/6996e6ef198179b867d532a9f7198188.png
#     front_raw_area=114883.0 | front_h=783.0 | front_norm=0.18738388716809468 || side_raw_area=91177.0 | side_h=842.0 | side_norm=0.12860596588825385
#
# Record 28/6134
#   Processing photo_id=b719e1522dbd6c04d0575f5508f932f7 -> pid=b719e1522dbd6c04d0575f5508f932f7
#     Downloading mask: s3://amazon-bodym/train/mask/b719e1522dbd6c04d0575f5508f932f7.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/b719e1522dbd6c04d0575f5508f932f7.png
#     front_raw_area=109138.0 | front_h=811.0 | front_norm=0.16593357973973766 || side_raw_area=83483.0 | side_h=853.0 | side_norm=0.11473607390782686
#
# Record 29/6134
#   Processing photo_id=6c54439b39186ab8d406fb0cbb7f2b95 -> pid=6c54439b39186ab8d406fb0cbb7f2b95
#     Downloading mask: s3://amazon-bodym/train/mask/6c54439b39186ab8d406fb0cbb7f2b95.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/6c54439b39186ab8d406fb0cbb7f2b95.png
#     front_raw_area=142633.0 | front_h=878.0 | front_norm=0.1850252437461408 || side_raw_area=143157.0 | side_h=917.0 | side_norm=0.17024482422769235
#
# Record 30/6134
#   Processing photo_id=e001372394208a4510770d63781f2ef3 -> pid=e001372394208a4510770d63781f2ef3
#     Downloading mask: s3://amazon-bodym/train/mask/e001372394208a4510770d63781f2ef3.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/e001372394208a4510770d63781f2ef3.png
#     front_raw_area=116518.0 | front_h=856.0 | front_norm=0.15901770897021575 || side_raw_area=96368.0 | side_h=960.0 | side_norm=0.10456597222222222
#
# Record 31/6134
#   Processing photo_id=38289095fcdde13d1b7ea558dbed28ad -> pid=38289095fcdde13d1b7ea558dbed28ad
#     Downloading mask: s3://amazon-bodym/train/mask/38289095fcdde13d1b7ea558dbed28ad.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/38289095fcdde13d1b7ea558dbed28ad.png
#     front_raw_area=126968.0 | front_h=839.0 | front_norm=0.1803725133928381 || side_raw_area=100984.0 | side_h=912.0 | side_norm=0.12141235764850723
#
# Record 32/6134
#   Processing photo_id=5505605be894894795cfa99e41e7754c -> pid=5505605be894894795cfa99e41e7754c
#     Downloading mask: s3://amazon-bodym/train/mask/5505605be894894795cfa99e41e7754c.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/5505605be894894795cfa99e41e7754c.png
#     front_raw_area=118211.0 | front_h=831.0 | front_norm=0.17118111216822265 || side_raw_area=99121.0 | side_h=904.0 | side_norm=0.12129106625420942
#
# Record 33/6134
#   Processing photo_id=f387a4a12bc5cef559cbafaa119b08c6 -> pid=f387a4a12bc5cef559cbafaa119b08c6
#     Downloading mask: s3://amazon-bodym/train/mask/f387a4a12bc5cef559cbafaa119b08c6.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/f387a4a12bc5cef559cbafaa119b08c6.png
#     front_raw_area=122986.0 | front_h=830.0 | front_norm=0.17852518507766005 || side_raw_area=97511.0 | side_h=885.0 | side_norm=0.12449934565418622
#
# Record 34/6134
#   Processing photo_id=846166b2b6d6b05808a918a2aa1f14d4 -> pid=846166b2b6d6b05808a918a2aa1f14d4
#     Downloading mask: s3://amazon-bodym/train/mask/846166b2b6d6b05808a918a2aa1f14d4.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/846166b2b6d6b05808a918a2aa1f14d4.png
#     front_raw_area=132357.0 | front_h=842.0 | front_norm=0.18669072054434357 || side_raw_area=103755.0 | side_h=953.0 | side_norm=0.11424132550987713
#
# Record 35/6134
#   Processing photo_id=c661cfd0f0673b6c4410b1b17f58dbc3 -> pid=c661cfd0f0673b6c4410b1b17f58dbc3
#     Downloading mask: s3://amazon-bodym/train/mask/c661cfd0f0673b6c4410b1b17f58dbc3.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/c661cfd0f0673b6c4410b1b17f58dbc3.png
#     front_raw_area=120396.0 | front_h=859.0 | front_norm=0.1631645211084172 || side_raw_area=98864.0 | side_h=890.0 | side_norm=0.12481252367125363
#
# Record 36/6134
#   Processing photo_id=1d4222ecbfb00a8e7c9632dc55faeb6a -> pid=1d4222ecbfb00a8e7c9632dc55faeb6a
#     Downloading mask: s3://amazon-bodym/train/mask/1d4222ecbfb00a8e7c9632dc55faeb6a.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/1d4222ecbfb00a8e7c9632dc55faeb6a.png
#     front_raw_area=140261.0 | front_h=879.0 | front_norm=0.18153450308746236 || side_raw_area=94675.0 | side_h=901.0 | side_norm=0.1166234089388902
#
# Record 37/6134
#   Processing photo_id=4543d6263ef9268549e4cb4f595eb0dc -> pid=4543d6263ef9268549e4cb4f595eb0dc
#     Downloading mask: s3://amazon-bodym/train/mask/4543d6263ef9268549e4cb4f595eb0dc.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/4543d6263ef9268549e4cb4f595eb0dc.png
#     front_raw_area=110931.0 | front_h=814.0 | front_norm=0.16741875894210045 || side_raw_area=75106.0 | side_h=819.0 | side_norm=0.11197132808854421
#
# Record 38/6134
#   Processing photo_id=8477cda98e31da67f542ff6b6babe9e2 -> pid=8477cda98e31da67f542ff6b6babe9e2
#     Downloading mask: s3://amazon-bodym/train/mask/8477cda98e31da67f542ff6b6babe9e2.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/8477cda98e31da67f542ff6b6babe9e2.png
#     front_raw_area=129998.0 | front_h=833.0 | front_norm=0.18734696759856403 || side_raw_area=92271.0 | side_h=855.0 | side_norm=0.12622140145685853
#
# Record 39/6134
#   Processing photo_id=062eae309555bef2b5ed2086d01aac70 -> pid=062eae309555bef2b5ed2086d01aac70
#     Downloading mask: s3://amazon-bodym/train/mask/062eae309555bef2b5ed2086d01aac70.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/062eae309555bef2b5ed2086d01aac70.png
#     front_raw_area=119196.0 | front_h=837.0 | front_norm=0.170141699104585 || side_raw_area=98883.0 | side_h=949.0 | side_norm=0.1097966802168774
#
# Record 40/6134
#   Processing photo_id=4aabb1da4fd8da76f0d3eca53908aa35 -> pid=4aabb1da4fd8da76f0d3eca53908aa35
#     Downloading mask: s3://amazon-bodym/train/mask/4aabb1da4fd8da76f0d3eca53908aa35.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/4aabb1da4fd8da76f0d3eca53908aa35.png
#     front_raw_area=107412.0 | front_h=813.0 | front_norm=0.16250686492104774 || side_raw_area=71625.0 | side_h=848.0 | side_norm=0.09960311721253115
#
# Record 41/6134
#   Processing photo_id=f7f1e1e737531d004ebc17b9efb9c615 -> pid=f7f1e1e737531d004ebc17b9efb9c615
#     Downloading mask: s3://amazon-bodym/train/mask/f7f1e1e737531d004ebc17b9efb9c615.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/f7f1e1e737531d004ebc17b9efb9c615.png
#     front_raw_area=146219.0 | front_h=840.0 | front_norm=0.2072264739229025 || side_raw_area=93042.0 | side_h=850.0 | side_norm=0.12877785467128028
#
# Record 42/6134
#   Processing photo_id=41c1c77374510f53022d94ebaae9be66 -> pid=41c1c77374510f53022d94ebaae9be66
#     Downloading mask: s3://amazon-bodym/train/mask/41c1c77374510f53022d94ebaae9be66.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/41c1c77374510f53022d94ebaae9be66.png
#     front_raw_area=106121.0 | front_h=794.0 | front_norm=0.16832953701882505 || side_raw_area=71802.0 | side_h=824.0 | side_norm=0.10575042416815911
#
# Record 43/6134
#   Processing photo_id=2f33089bd08c604d676e82a580c3a217 -> pid=2f33089bd08c604d676e82a580c3a217
#     Downloading mask: s3://amazon-bodym/train/mask/2f33089bd08c604d676e82a580c3a217.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/2f33089bd08c604d676e82a580c3a217.png
#     front_raw_area=130118.0 | front_h=827.0 | front_norm=0.19025074240162357 || side_raw_area=88563.0 | side_h=851.0 | side_norm=0.12229063478233253
#
# Record 44/6134
#   Processing photo_id=2b3d50485b617c3a5adee746c7278f77 -> pid=2b3d50485b617c3a5adee746c7278f77
#     Downloading mask: s3://amazon-bodym/train/mask/2b3d50485b617c3a5adee746c7278f77.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/2b3d50485b617c3a5adee746c7278f77.png
#     front_raw_area=150542.0 | front_h=870.0 | front_norm=0.19889285242436253 || side_raw_area=100353.0 | side_h=907.0 | side_norm=0.12198762777320582
#
# Record 45/6134
#   Processing photo_id=0137443ba49903cceede13e710c77634 -> pid=0137443ba49903cceede13e710c77634
#     Downloading mask: s3://amazon-bodym/train/mask/0137443ba49903cceede13e710c77634.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/0137443ba49903cceede13e710c77634.png
#     front_raw_area=105679.0 | front_h=799.0 | front_norm=0.16553702140190882 || side_raw_area=79922.0 | side_h=842.0 | side_norm=0.1127306887232638
#
# Record 46/6134
#   Processing photo_id=188ff766c8009e788fb1ca9a3392388d -> pid=188ff766c8009e788fb1ca9a3392388d
#     Downloading mask: s3://amazon-bodym/train/mask/188ff766c8009e788fb1ca9a3392388d.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/188ff766c8009e788fb1ca9a3392388d.png
#     front_raw_area=135615.0 | front_h=828.0 | front_norm=0.19780945879717146 || side_raw_area=104118.0 | side_h=872.0 | side_norm=0.13692818365457454
#
# Record 47/6134
#   Processing photo_id=41d450e60e5fff57166b786a9e85858d -> pid=41d450e60e5fff57166b786a9e85858d
#     Downloading mask: s3://amazon-bodym/train/mask/41d450e60e5fff57166b786a9e85858d.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/41d450e60e5fff57166b786a9e85858d.png
#     front_raw_area=114634.0 | front_h=818.0 | front_norm=0.1713195162630544 || side_raw_area=88437.0 | side_h=903.0 | side_norm=0.10845722821308079
#
# Record 48/6134
#   Processing photo_id=159d85b482993d3c72c3f936b053b541 -> pid=159d85b482993d3c72c3f936b053b541
#     Downloading mask: s3://amazon-bodym/train/mask/159d85b482993d3c72c3f936b053b541.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/159d85b482993d3c72c3f936b053b541.png
#     front_raw_area=113637.0 | front_h=828.0 | front_norm=0.16575211790240146 || side_raw_area=67863.0 | side_h=833.0 | side_norm=0.09780094510793513
#
# Record 49/6134
#   Processing photo_id=0f6cd39a0ecd228141a87ac1f0c76d8e -> pid=0f6cd39a0ecd228141a87ac1f0c76d8e
#     Downloading mask: s3://amazon-bodym/train/mask/0f6cd39a0ecd228141a87ac1f0c76d8e.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/0f6cd39a0ecd228141a87ac1f0c76d8e.png
#     front_raw_area=138382.0 | front_h=860.0 | front_norm=0.18710383991346674 || side_raw_area=144685.0 | side_h=960.0 | side_norm=0.15699327256944445
#
# Record 50/6134
#   Processing photo_id=319c8c5da5c408d2801130adeee5d339 -> pid=319c8c5da5c408d2801130adeee5d339
#     Downloading mask: s3://amazon-bodym/train/mask/319c8c5da5c408d2801130adeee5d339.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/319c8c5da5c408d2801130adeee5d339.png
#     front_raw_area=113514.0 | front_h=805.0 | front_norm=0.1751691678561784 || side_raw_area=77240.0 | side_h=821.0 | side_norm=0.11459243577171122
#
# Processed 50/6134 records so far...
#
# Record 51/6134
#   Processing photo_id=a8ba42bde687be57aab50e49f7cbf9b5 -> pid=a8ba42bde687be57aab50e49f7cbf9b5
#     Downloading mask: s3://amazon-bodym/train/mask/a8ba42bde687be57aab50e49f7cbf9b5.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/a8ba42bde687be57aab50e49f7cbf9b5.png
#     front_raw_area=109110.0 | front_h=801.0 | front_norm=0.17005896187817662 || side_raw_area=77576.0 | side_h=856.0 | side_norm=0.10587169185081667
#
# Record 52/6134
#   Processing photo_id=158cf3e74cb18ae55e9f522f52128e7a -> pid=158cf3e74cb18ae55e9f522f52128e7a
#     Downloading mask: s3://amazon-bodym/train/mask/158cf3e74cb18ae55e9f522f52128e7a.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/158cf3e74cb18ae55e9f522f52128e7a.png
#     front_raw_area=113717.0 | front_h=813.0 | front_norm=0.17204589020059943 || side_raw_area=109262.0 | side_h=960.0 | side_norm=0.11855685763888889
#
# Record 53/6134
#   Processing photo_id=4b014f85c420b2d52d9e9a81788a407e -> pid=4b014f85c420b2d52d9e9a81788a407e
#     Downloading mask: s3://amazon-bodym/train/mask/4b014f85c420b2d52d9e9a81788a407e.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/4b014f85c420b2d52d9e9a81788a407e.png
#     front_raw_area=131813.0 | front_h=824.0 | front_norm=0.19413499151663682 || side_raw_area=120149.0 | side_h=960.0 | side_norm=0.13037000868055557
#
# Record 54/6134
#   Processing photo_id=ef2122dab67731879592a0e81d2b7466 -> pid=ef2122dab67731879592a0e81d2b7466
#     Downloading mask: s3://amazon-bodym/train/mask/ef2122dab67731879592a0e81d2b7466.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/ef2122dab67731879592a0e81d2b7466.png
#     front_raw_area=136867.0 | front_h=884.0 | front_norm=0.1751435781413157 || side_raw_area=94661.0 | side_h=930.0 | side_norm=0.10944733495201757
#
# Record 55/6134
#   Processing photo_id=356f5c6f652e32c75198509a002f852c -> pid=356f5c6f652e32c75198509a002f852c
#     Downloading mask: s3://amazon-bodym/train/mask/356f5c6f652e32c75198509a002f852c.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/356f5c6f652e32c75198509a002f852c.png
#     front_raw_area=131223.0 | front_h=877.0 | front_norm=0.1706124720300496 || side_raw_area=89181.0 | side_h=929.0 | side_norm=0.103333445340372
#
# Record 56/6134
#   Processing photo_id=bc0346f8906bb928f90296e0eb6712c1 -> pid=bc0346f8906bb928f90296e0eb6712c1
#     Downloading mask: s3://amazon-bodym/train/mask/bc0346f8906bb928f90296e0eb6712c1.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/bc0346f8906bb928f90296e0eb6712c1.png
#     front_raw_area=125603.0 | front_h=842.0 | front_norm=0.1771641437364944 || side_raw_area=76607.0 | side_h=819.0 | side_norm=0.1142090849050556
#
# Record 57/6134
#   Processing photo_id=fe5ba70367827357d352ee0691669b93 -> pid=fe5ba70367827357d352ee0691669b93
#     Downloading mask: s3://amazon-bodym/train/mask/fe5ba70367827357d352ee0691669b93.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/fe5ba70367827357d352ee0691669b93.png
#     front_raw_area=137785.0 | front_h=832.0 | front_norm=0.19904684032914202 || side_raw_area=100117.0 | side_h=925.0 | side_norm=0.11701037253469686
#
# Record 58/6134
#   Processing photo_id=255ae73bb772c644629bb4a9b03c39e7 -> pid=255ae73bb772c644629bb4a9b03c39e7
#     Downloading mask: s3://amazon-bodym/train/mask/255ae73bb772c644629bb4a9b03c39e7.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/255ae73bb772c644629bb4a9b03c39e7.png
#     front_raw_area=150453.0 | front_h=864.0 | front_norm=0.2015456211419753 || side_raw_area=139920.0 | side_h=952.0 | side_norm=0.15438528352517478
#
# Record 59/6134
#   Processing photo_id=d2f5e4af6eebfad9bae98361c4b34ac0 -> pid=d2f5e4af6eebfad9bae98361c4b34ac0
#     Downloading mask: s3://amazon-bodym/train/mask/d2f5e4af6eebfad9bae98361c4b34ac0.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/d2f5e4af6eebfad9bae98361c4b34ac0.png
#     front_raw_area=130817.0 | front_h=866.0 | front_norm=0.1744329000634704 || side_raw_area=83376.0 | side_h=863.0 | side_norm=0.11194880560281108
#
# Record 60/6134
#   Processing photo_id=14861c06aef6d4a4a20ddfb113cfa529 -> pid=14861c06aef6d4a4a20ddfb113cfa529
#     Downloading mask: s3://amazon-bodym/train/mask/14861c06aef6d4a4a20ddfb113cfa529.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/14861c06aef6d4a4a20ddfb113cfa529.png
#     front_raw_area=120856.0 | front_h=835.0 | front_norm=0.1733385922765248 || side_raw_area=93639.0 | side_h=898.0 | side_norm=0.11611921567849366
#
# Record 61/6134
#   Processing photo_id=ff0d41d2e381206890077044293d0155 -> pid=ff0d41d2e381206890077044293d0155
#     Downloading mask: s3://amazon-bodym/train/mask/ff0d41d2e381206890077044293d0155.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/ff0d41d2e381206890077044293d0155.png
#     front_raw_area=112264.0 | front_h=806.0 | front_norm=0.17281062010110276 || side_raw_area=73906.0 | side_h=837.0 | side_norm=0.10549424824678226
#
# Record 62/6134
#   Processing photo_id=7ffad8c80b48bcc54fcac74503cbbbca -> pid=7ffad8c80b48bcc54fcac74503cbbbca
#     Downloading mask: s3://amazon-bodym/train/mask/7ffad8c80b48bcc54fcac74503cbbbca.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/7ffad8c80b48bcc54fcac74503cbbbca.png
#     front_raw_area=125615.0 | front_h=831.0 | front_norm=0.18190282972829339 || side_raw_area=93464.0 | side_h=924.0 | side_norm=0.10947133674406402
#
# Record 63/6134
#   Processing photo_id=a909c6c217c7c1f465bd9f2ce0bb3043 -> pid=a909c6c217c7c1f465bd9f2ce0bb3043
#     Downloading mask: s3://amazon-bodym/train/mask/a909c6c217c7c1f465bd9f2ce0bb3043.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/a909c6c217c7c1f465bd9f2ce0bb3043.png
#     front_raw_area=115563.0 | front_h=829.0 | front_norm=0.16815498493250547 || side_raw_area=70075.0 | side_h=825.0 | side_norm=0.10295684113865933
#
# Record 64/6134
#   Processing photo_id=7d9a317279581caa2b49f6de6e06332d -> pid=7d9a317279581caa2b49f6de6e06332d
#     Downloading mask: s3://amazon-bodym/train/mask/7d9a317279581caa2b49f6de6e06332d.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/7d9a317279581caa2b49f6de6e06332d.png
#     front_raw_area=117808.0 | front_h=772.0 | front_norm=0.197669736100298 || side_raw_area=97989.0 | side_h=866.0 | side_norm=0.13065966536703486
#
# Record 65/6134
#   Processing photo_id=ed54e147e1cc64428cea566997bfdb74 -> pid=ed54e147e1cc64428cea566997bfdb74
#     Downloading mask: s3://amazon-bodym/train/mask/ed54e147e1cc64428cea566997bfdb74.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/ed54e147e1cc64428cea566997bfdb74.png
#     front_raw_area=134622.0 | front_h=854.0 | front_norm=0.18458665379615968 || side_raw_area=97557.0 | side_h=915.0 | side_norm=0.11652423183731972
#
# Record 66/6134
#   Processing photo_id=06c9f3b7dbcc25dbd6a16b1703be3d1e -> pid=06c9f3b7dbcc25dbd6a16b1703be3d1e
#     Downloading mask: s3://amazon-bodym/train/mask/06c9f3b7dbcc25dbd6a16b1703be3d1e.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/06c9f3b7dbcc25dbd6a16b1703be3d1e.png
#     front_raw_area=134286.0 | front_h=881.0 | front_norm=0.17301307331855117 || side_raw_area=87114.0 | side_h=894.0 | side_norm=0.10899659174511658
#
# Record 67/6134
#   Processing photo_id=2c077a299093054544094cfcc2297c60 -> pid=2c077a299093054544094cfcc2297c60
#     Downloading mask: s3://amazon-bodym/train/mask/2c077a299093054544094cfcc2297c60.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/2c077a299093054544094cfcc2297c60.png
#     front_raw_area=123437.0 | front_h=875.0 | front_norm=0.16122383673469387 || side_raw_area=81446.0 | side_h=885.0 | side_norm=0.10398799834019598
#
# Record 68/6134
#   Processing photo_id=53305d261184b860ede220b1ee52e4f4 -> pid=53305d261184b860ede220b1ee52e4f4
#     Downloading mask: s3://amazon-bodym/train/mask/53305d261184b860ede220b1ee52e4f4.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/53305d261184b860ede220b1ee52e4f4.png
#     front_raw_area=114705.0 | front_h=838.0 | front_norm=0.16334066221996912 || side_raw_area=78428.0 | side_h=899.0 | side_norm=0.09704021648080119
#
# Record 69/6134
#   Processing photo_id=d12f51536fddf5bdf7cf22cdfaf1c9bd -> pid=d12f51536fddf5bdf7cf22cdfaf1c9bd
#     Downloading mask: s3://amazon-bodym/train/mask/d12f51536fddf5bdf7cf22cdfaf1c9bd.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/d12f51536fddf5bdf7cf22cdfaf1c9bd.png
#     front_raw_area=141286.0 | front_h=843.0 | front_norm=0.19881263464804708 || side_raw_area=88942.0 | side_h=843.0 | side_norm=0.125156019356954
#
# Record 70/6134
#   Processing photo_id=5a16b5c4f7d9ef8335e22e022efd9cdd -> pid=5a16b5c4f7d9ef8335e22e022efd9cdd
#     Downloading mask: s3://amazon-bodym/train/mask/5a16b5c4f7d9ef8335e22e022efd9cdd.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/5a16b5c4f7d9ef8335e22e022efd9cdd.png
#     front_raw_area=134918.0 | front_h=870.0 | front_norm=0.17825075967763246 || side_raw_area=90964.0 | side_h=907.0 | side_norm=0.11057449775055947
#
# Record 71/6134
#   Processing photo_id=3327f5ded6979666d773085c18030bf9 -> pid=3327f5ded6979666d773085c18030bf9
#     Downloading mask: s3://amazon-bodym/train/mask/3327f5ded6979666d773085c18030bf9.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/3327f5ded6979666d773085c18030bf9.png
#     front_raw_area=114115.0 | front_h=820.0 | front_norm=0.1697129684711481 || side_raw_area=71663.0 | side_h=840.0 | side_norm=0.10156320861678005
#
# Record 72/6134
#   Processing photo_id=487a083073439a24a4e570f835deaa83 -> pid=487a083073439a24a4e570f835deaa83
#     Downloading mask: s3://amazon-bodym/train/mask/487a083073439a24a4e570f835deaa83.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/487a083073439a24a4e570f835deaa83.png
#     front_raw_area=132730.0 | front_h=873.0 | front_norm=0.17415686845665235 || side_raw_area=74439.0 | side_h=868.0 | side_norm=0.09880094077173013
#
# Record 73/6134
#   Processing photo_id=84459093d515b2e465524aad777b514e -> pid=84459093d515b2e465524aad777b514e
#     Downloading mask: s3://amazon-bodym/train/mask/84459093d515b2e465524aad777b514e.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/84459093d515b2e465524aad777b514e.png
#     front_raw_area=120354.0 | front_h=822.0 | front_norm=0.17812172554034134 || side_raw_area=70198.0 | side_h=810.0 | side_norm=0.10699283645785704
#
# Record 74/6134
#   Processing photo_id=f273826345c4384e432fa9b55d4bfeec -> pid=f273826345c4384e432fa9b55d4bfeec
#     Downloading mask: s3://amazon-bodym/train/mask/f273826345c4384e432fa9b55d4bfeec.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/f273826345c4384e432fa9b55d4bfeec.png
#     front_raw_area=120242.0 | front_h=811.0 | front_norm=0.1828161180804627 || side_raw_area=90233.0 | side_h=889.0 | side_norm=0.11417259569213016
#
# Record 75/6134
#   Processing photo_id=41307385ee6c1a5d2825773844352664 -> pid=41307385ee6c1a5d2825773844352664
#     Downloading mask: s3://amazon-bodym/train/mask/41307385ee6c1a5d2825773844352664.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/41307385ee6c1a5d2825773844352664.png
#     front_raw_area=110865.0 | front_h=821.0 | front_norm=0.16447812521790217 || side_raw_area=81882.0 | side_h=893.0 | side_norm=0.10267992059680306
#
# Record 76/6134
#   Processing photo_id=636e9e33323c628783f2c87077a450aa -> pid=636e9e33323c628783f2c87077a450aa
#     Downloading mask: s3://amazon-bodym/train/mask/636e9e33323c628783f2c87077a450aa.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/636e9e33323c628783f2c87077a450aa.png
#     front_raw_area=113725.0 | front_h=783.0 | front_norm=0.18549509125102553 || side_raw_area=88182.0 | side_h=870.0 | side_norm=0.11650416171224733
#
# Record 77/6134
#   Processing photo_id=858411976933aebe469f58339333929b -> pid=858411976933aebe469f58339333929b
#     Downloading mask: s3://amazon-bodym/train/mask/858411976933aebe469f58339333929b.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/858411976933aebe469f58339333929b.png
#     front_raw_area=133241.0 | front_h=854.0 | front_norm=0.1826930987390925 || side_raw_area=110508.0 | side_h=960.0 | side_norm=0.11990885416666666
#
# Record 78/6134
#   Processing photo_id=ce9cd8e60a306b0e72cca3bc1cb41f80 -> pid=ce9cd8e60a306b0e72cca3bc1cb41f80
#     Downloading mask: s3://amazon-bodym/train/mask/ce9cd8e60a306b0e72cca3bc1cb41f80.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/ce9cd8e60a306b0e72cca3bc1cb41f80.png
#     front_raw_area=116379.0 | front_h=806.0 | front_norm=0.17914493654908287 || side_raw_area=99870.0 | side_h=925.0 | side_norm=0.11672169466764061
#
# Record 79/6134
#   Processing photo_id=0b16380bc9ca269804868f718dd6ff95 -> pid=0b16380bc9ca269804868f718dd6ff95
#     Downloading mask: s3://amazon-bodym/train/mask/0b16380bc9ca269804868f718dd6ff95.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/0b16380bc9ca269804868f718dd6ff95.png
#     front_raw_area=171723.0 | front_h=910.0 | front_norm=0.20736988286438837 || side_raw_area=111737.0 | side_h=902.0 | side_norm=0.13733585380602847
#
# Record 80/6134
#   Processing photo_id=c2dfcd222d6d8a0a2c14e933a7925b21 -> pid=c2dfcd222d6d8a0a2c14e933a7925b21
#     Downloading mask: s3://amazon-bodym/train/mask/c2dfcd222d6d8a0a2c14e933a7925b21.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/c2dfcd222d6d8a0a2c14e933a7925b21.png
#     front_raw_area=119076.0 | front_h=867.0 | front_norm=0.15841125784732782 || side_raw_area=81137.0 | side_h=873.0 | side_norm=0.10646097970291118
#
# Record 81/6134
#   Processing photo_id=730b3b6949b3f594886663dd51540920 -> pid=730b3b6949b3f594886663dd51540920
#     Downloading mask: s3://amazon-bodym/train/mask/730b3b6949b3f594886663dd51540920.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/730b3b6949b3f594886663dd51540920.png
#     front_raw_area=122736.0 | front_h=839.0 | front_norm=0.17436047511013308 || side_raw_area=91552.0 | side_h=895.0 | side_norm=0.11429356137448894
#
# Record 82/6134
#   Processing photo_id=77ac76d38a33e9a6b658ff8608aea9cd -> pid=77ac76d38a33e9a6b658ff8608aea9cd
#     Downloading mask: s3://amazon-bodym/train/mask/77ac76d38a33e9a6b658ff8608aea9cd.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/77ac76d38a33e9a6b658ff8608aea9cd.png
#     front_raw_area=131712.0 | front_h=830.0 | front_norm=0.191191754971694 || side_raw_area=86685.0 | side_h=827.0 | side_norm=0.12674561248316712
#
# Record 83/6134
#   Processing photo_id=f7ac8f3ee0645855f088cc8d213198a0 -> pid=f7ac8f3ee0645855f088cc8d213198a0
#     Downloading mask: s3://amazon-bodym/train/mask/f7ac8f3ee0645855f088cc8d213198a0.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/f7ac8f3ee0645855f088cc8d213198a0.png
#     front_raw_area=162508.0 | front_h=853.0 | front_norm=0.22334523074893245 || side_raw_area=131073.0 | side_h=923.0 | side_norm=0.15385437049331577
#
# Record 84/6134
#   Processing photo_id=003d4db18f3359c8ed8410817b726539 -> pid=003d4db18f3359c8ed8410817b726539
#     Downloading mask: s3://amazon-bodym/train/mask/003d4db18f3359c8ed8410817b726539.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/003d4db18f3359c8ed8410817b726539.png
#     front_raw_area=130171.0 | front_h=845.0 | front_norm=0.1823059416687091 || side_raw_area=122517.0 | side_h=924.0 | side_norm=0.1435001686625063
#
# Record 85/6134
#   Processing photo_id=435d224b3b8118a15bc2ca9b81080867 -> pid=435d224b3b8118a15bc2ca9b81080867
#     Downloading mask: s3://amazon-bodym/train/mask/435d224b3b8118a15bc2ca9b81080867.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/435d224b3b8118a15bc2ca9b81080867.png
#     front_raw_area=126489.0 | front_h=865.0 | front_norm=0.16905208994620602 || side_raw_area=84950.0 | side_h=854.0 | side_norm=0.11647900224319774
#
# Record 86/6134
#   Processing photo_id=cf42e48ba90c01e64b1635588e920eb1 -> pid=cf42e48ba90c01e64b1635588e920eb1
#     Downloading mask: s3://amazon-bodym/train/mask/cf42e48ba90c01e64b1635588e920eb1.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/cf42e48ba90c01e64b1635588e920eb1.png
#     front_raw_area=116611.0 | front_h=857.0 | front_norm=0.1587734478500209 || side_raw_area=72503.0 | side_h=868.0 | side_norm=0.09623133852916817
#
# Record 87/6134
#   Processing photo_id=e9f0f724658d3f8f5df8607be9fcd77d -> pid=e9f0f724658d3f8f5df8607be9fcd77d
#     Downloading mask: s3://amazon-bodym/train/mask/e9f0f724658d3f8f5df8607be9fcd77d.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/e9f0f724658d3f8f5df8607be9fcd77d.png
#     front_raw_area=128783.0 | front_h=866.0 | front_norm=0.17172074095013573 || side_raw_area=79358.0 | side_h=855.0 | side_norm=0.10855716288772614
#
# Record 88/6134
#   Processing photo_id=3c15b9ae57616011a16be6f881b86de1 -> pid=3c15b9ae57616011a16be6f881b86de1
#     Downloading mask: s3://amazon-bodym/train/mask/3c15b9ae57616011a16be6f881b86de1.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/3c15b9ae57616011a16be6f881b86de1.png
#     front_raw_area=105616.0 | front_h=811.0 | front_norm=0.16057872562986433 || side_raw_area=77280.0 | side_h=852.0 | side_norm=0.10646035839449845
#
# Record 89/6134
#   Processing photo_id=bcf8864dc6ec0c88507c389c4ad26f21 -> pid=bcf8864dc6ec0c88507c389c4ad26f21
#     Downloading mask: s3://amazon-bodym/train/mask/bcf8864dc6ec0c88507c389c4ad26f21.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/bcf8864dc6ec0c88507c389c4ad26f21.png
#     front_raw_area=141394.0 | front_h=863.0 | front_norm=0.1898494701041531 || side_raw_area=94082.0 | side_h=894.0 | side_norm=0.11771491774644786
#
# Record 90/6134
#   Processing photo_id=74d68a677f8cd35278fca17cdf4b6a33 -> pid=74d68a677f8cd35278fca17cdf4b6a33
#     Downloading mask: s3://amazon-bodym/train/mask/74d68a677f8cd35278fca17cdf4b6a33.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/74d68a677f8cd35278fca17cdf4b6a33.png
#     front_raw_area=107361.0 | front_h=820.0 | front_norm=0.1596683521713266 || side_raw_area=70905.0 | side_h=839.0 | side_norm=0.10072863290056697
#
# Record 91/6134
#   Processing photo_id=f4adbff5364b3d9cdef70bdd014bd06e -> pid=f4adbff5364b3d9cdef70bdd014bd06e
#     Downloading mask: s3://amazon-bodym/train/mask/f4adbff5364b3d9cdef70bdd014bd06e.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/f4adbff5364b3d9cdef70bdd014bd06e.png
#     front_raw_area=110854.0 | front_h=837.0 | front_norm=0.15823423531443725 || side_raw_area=78876.0 | side_h=892.0 | side_norm=0.09913229705001106
#
# Record 92/6134
#   Processing photo_id=b0a220118a5770b2c821d008764ee870 -> pid=b0a220118a5770b2c821d008764ee870
#     Downloading mask: s3://amazon-bodym/train/mask/b0a220118a5770b2c821d008764ee870.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/b0a220118a5770b2c821d008764ee870.png
#     front_raw_area=131275.0 | front_h=882.0 | front_norm=0.16875041777860048 || side_raw_area=105939.0 | side_h=875.0 | side_norm=0.138369306122449
#
# Record 93/6134
#   Processing photo_id=dbfa59c0ed28d10177a3fb403022ff9a -> pid=dbfa59c0ed28d10177a3fb403022ff9a
#     Downloading mask: s3://amazon-bodym/train/mask/dbfa59c0ed28d10177a3fb403022ff9a.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/dbfa59c0ed28d10177a3fb403022ff9a.png
#     front_raw_area=150767.0 | front_h=872.0 | front_norm=0.1982774492887804 || side_raw_area=117195.0 | side_h=944.0 | side_norm=0.13151191288422867
#
# Record 94/6134
#   Processing photo_id=7a163f40051975527e53e34630713866 -> pid=7a163f40051975527e53e34630713866
#     Downloading mask: s3://amazon-bodym/train/mask/7a163f40051975527e53e34630713866.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/7a163f40051975527e53e34630713866.png
#     front_raw_area=120829.0 | front_h=799.0 | front_norm=0.1892681872365488 || side_raw_area=98822.0 | side_h=913.0 | side_norm=0.11855287324744562
#
# Record 95/6134
#   Processing photo_id=ce338c3b6a2b9d4858560dd670d1a46e -> pid=ce338c3b6a2b9d4858560dd670d1a46e
#     Downloading mask: s3://amazon-bodym/train/mask/ce338c3b6a2b9d4858560dd670d1a46e.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/ce338c3b6a2b9d4858560dd670d1a46e.png
#     front_raw_area=113034.0 | front_h=801.0 | front_norm=0.17617491244558534 || side_raw_area=79358.0 | side_h=855.0 | side_norm=0.10855716288772614
#
# Record 96/6134
#   Processing photo_id=ab55d6c3fbe0eed7605410e0aa2ac61c -> pid=ab55d6c3fbe0eed7605410e0aa2ac61c
#     Downloading mask: s3://amazon-bodym/train/mask/ab55d6c3fbe0eed7605410e0aa2ac61c.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/ab55d6c3fbe0eed7605410e0aa2ac61c.png
#     front_raw_area=131067.0 | front_h=841.0 | front_norm=0.18531107155430443 || side_raw_area=97189.0 | side_h=891.0 | side_norm=0.12242263009191554
#
# Record 97/6134
#   Processing photo_id=26bb1ff022792a9e8cb0dba3abc31ab3 -> pid=26bb1ff022792a9e8cb0dba3abc31ab3
#     Downloading mask: s3://amazon-bodym/train/mask/26bb1ff022792a9e8cb0dba3abc31ab3.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/26bb1ff022792a9e8cb0dba3abc31ab3.png
#     front_raw_area=113643.0 | front_h=805.0 | front_norm=0.17536823425022183 || side_raw_area=36314.0 | side_h=594.0 | side_norm=0.10292033692707094
#
# Record 98/6134
#   Processing photo_id=a17d109ffb52659c34a7b2f6e43a48f9 -> pid=a17d109ffb52659c34a7b2f6e43a48f9
#     Downloading mask: s3://amazon-bodym/train/mask/a17d109ffb52659c34a7b2f6e43a48f9.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/a17d109ffb52659c34a7b2f6e43a48f9.png
#     front_raw_area=110863.0 | front_h=833.0 | front_norm=0.1597705108453946 || side_raw_area=81704.0 | side_h=864.0 | side_norm=0.10945001714677641
#
# Record 99/6134
#   Processing photo_id=7f6d63b0e646a8adf40f44ec6bd3edc8 -> pid=7f6d63b0e646a8adf40f44ec6bd3edc8
#     Downloading mask: s3://amazon-bodym/train/mask/7f6d63b0e646a8adf40f44ec6bd3edc8.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/7f6d63b0e646a8adf40f44ec6bd3edc8.png
#     front_raw_area=137903.0 | front_h=866.0 | front_norm=0.18388145437865688 || side_raw_area=94581.0 | side_h=886.0 | side_norm=0.12048596425969049
#
# Record 100/6134
#   Processing photo_id=b81b11089946e1de85246d8c17d944c0 -> pid=b81b11089946e1de85246d8c17d944c0
#     Downloading mask: s3://amazon-bodym/train/mask/b81b11089946e1de85246d8c17d944c0.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/b81b11089946e1de85246d8c17d944c0.png
#     front_raw_area=103426.0 | front_h=791.0 | front_norm=0.16530148749922086 || side_raw_area=72505.0 | side_h=829.0 | side_norm=0.10550156349810329
#
# Processed 100/6134 records so far...
#
# Record 101/6134
#   Processing photo_id=6a17eebe870d783c48583e098be33b1c -> pid=6a17eebe870d783c48583e098be33b1c
#     Downloading mask: s3://amazon-bodym/train/mask/6a17eebe870d783c48583e098be33b1c.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/6a17eebe870d783c48583e098be33b1c.png
#     front_raw_area=101682.0 | front_h=788.0 | front_norm=0.1637538972918653 || side_raw_area=40298.0 | side_h=633.0 | side_norm=0.10057176513455572
#
# Record 102/6134
#   Processing photo_id=54b0722f090a4729c9a5067701580c9f -> pid=54b0722f090a4729c9a5067701580c9f
#     Downloading mask: s3://amazon-bodym/train/mask/54b0722f090a4729c9a5067701580c9f.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/54b0722f090a4729c9a5067701580c9f.png
#     front_raw_area=143742.0 | front_h=910.0 | front_norm=0.17358048544861732 || side_raw_area=88456.0 | side_h=860.0 | side_norm=0.11959978366684694
#
# Record 103/6134
#   Processing photo_id=b4457439345fccf95d1f0e07e2901839 -> pid=b4457439345fccf95d1f0e07e2901839
#     Downloading mask: s3://amazon-bodym/train/mask/b4457439345fccf95d1f0e07e2901839.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/b4457439345fccf95d1f0e07e2901839.png
#     front_raw_area=127174.0 | front_h=869.0 | front_norm=0.16840647226220634 || side_raw_area=70747.0 | side_h=834.0 | side_norm=0.10171287430487265
#
# Record 104/6134
#   Processing photo_id=02cd1b8abd5505481ee0d1b88d62d73d -> pid=02cd1b8abd5505481ee0d1b88d62d73d
#     Downloading mask: s3://amazon-bodym/train/mask/02cd1b8abd5505481ee0d1b88d62d73d.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/02cd1b8abd5505481ee0d1b88d62d73d.png
#     front_raw_area=120135.0 | front_h=838.0 | front_norm=0.17107301735579086 || side_raw_area=79925.0 | side_h=865.0 | side_norm=0.10681947275218016
#
# Record 105/6134
#   Processing photo_id=3b00475f6d44bf6ff3a0ba1c16ea90c9 -> pid=3b00475f6d44bf6ff3a0ba1c16ea90c9
#     Downloading mask: s3://amazon-bodym/train/mask/3b00475f6d44bf6ff3a0ba1c16ea90c9.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/3b00475f6d44bf6ff3a0ba1c16ea90c9.png
#     front_raw_area=139858.0 | front_h=872.0 | front_norm=0.183930750778554 || side_raw_area=103942.0 | side_h=942.0 | side_norm=0.11713569628698031
#
# Record 106/6134
#   Processing photo_id=120a5f9ffc24ae4d1ec89f6d82b9c833 -> pid=120a5f9ffc24ae4d1ec89f6d82b9c833
#     Downloading mask: s3://amazon-bodym/train/mask/120a5f9ffc24ae4d1ec89f6d82b9c833.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/120a5f9ffc24ae4d1ec89f6d82b9c833.png
#     front_raw_area=127296.0 | front_h=844.0 | front_norm=0.17870218548550124 || side_raw_area=75104.0 | side_h=835.0 | side_norm=0.10771845530495894
#
# Record 107/6134
#   Processing photo_id=6cea484ab9b966d1b4b508e896f64384 -> pid=6cea484ab9b966d1b4b508e896f64384
#     Downloading mask: s3://amazon-bodym/train/mask/6cea484ab9b966d1b4b508e896f64384.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/6cea484ab9b966d1b4b508e896f64384.png
#     front_raw_area=140842.0 | front_h=833.0 | front_norm=0.20297482738593636 || side_raw_area=119233.0 | side_h=936.0 | side_norm=0.1360958159836365
#
# Record 108/6134
#   Processing photo_id=43e97fcc024569b60f40032bc33b3d24 -> pid=43e97fcc024569b60f40032bc33b3d24
#     Downloading mask: s3://amazon-bodym/train/mask/43e97fcc024569b60f40032bc33b3d24.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/43e97fcc024569b60f40032bc33b3d24.png
#     front_raw_area=92293.0 | front_h=776.0 | front_norm=0.15326582261664365 || side_raw_area=70260.0 | side_h=869.0 | side_norm=0.09303976238179673
#
# Record 109/6134
#   Processing photo_id=2144495dcdfef034267dfb3d69523867 -> pid=2144495dcdfef034267dfb3d69523867
# ...
#     Downloading mask: s3://amazon-bodym/train/mask/ab798c74408f489aef68491c911cc376.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/ab798c74408f489aef68491c911cc376.png
#     front_raw_area=140595.0 | front_h=879.0 | front_norm=0.18196678664476776 || side_raw_area=98089.0 | side_h=934.0 | side_norm=0.1124414803130832
#
# Record 6100/6134
#   Processing photo_id=acc2df580c02098505ac7035fb9873ee -> pid=acc2df580c02098505ac7035fb9873ee
#     Downloading mask: s3://amazon-bodym/train/mask/acc2df580c02098505ac7035fb9873ee.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/acc2df580c02098505ac7035fb9873ee.png
#     front_raw_area=122215.0 | front_h=869.0 | front_norm=0.16183966068162947 || side_raw_area=74521.0 | side_h=869.0 | side_norm=0.09868226775482314
#
# Processed 6100/6134 records so far...
#
# Record 6101/6134
#   Processing photo_id=a54da6ac80b02c90fe2af85d8a409440 -> pid=a54da6ac80b02c90fe2af85d8a409440
#     Downloading mask: s3://amazon-bodym/train/mask/a54da6ac80b02c90fe2af85d8a409440.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/a54da6ac80b02c90fe2af85d8a409440.png
#     front_raw_area=101326.0 | front_h=772.0 | front_norm=0.17001463126526886 || side_raw_area=80059.0 | side_h=853.0 | side_norm=0.11003024976326571
#
# Record 6102/6134
#   Processing photo_id=95671418db4c9ed5a9e0a2df00881b78 -> pid=95671418db4c9ed5a9e0a2df00881b78
#     Downloading mask: s3://amazon-bodym/train/mask/95671418db4c9ed5a9e0a2df00881b78.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/95671418db4c9ed5a9e0a2df00881b78.png
#     front_raw_area=136180.0 | front_h=899.0 | front_norm=0.16849768807511992 || side_raw_area=79054.0 | side_h=886.0 | side_norm=0.10070624563692045
#
# Record 6103/6134
#   Processing photo_id=7c375a83b03a363501533d50652bb2ef -> pid=7c375a83b03a363501533d50652bb2ef
#     Downloading mask: s3://amazon-bodym/train/mask/7c375a83b03a363501533d50652bb2ef.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/7c375a83b03a363501533d50652bb2ef.png
#     front_raw_area=102863.0 | front_h=778.0 | front_norm=0.1699417133114373 || side_raw_area=78001.0 | side_h=855.0 | side_norm=0.10670086522348757
#
# Record 6104/6134
#   Processing photo_id=864e1acedbe55aa0eee4dd4537bb0027 -> pid=864e1acedbe55aa0eee4dd4537bb0027
#     Downloading mask: s3://amazon-bodym/train/mask/864e1acedbe55aa0eee4dd4537bb0027.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/864e1acedbe55aa0eee4dd4537bb0027.png
#     front_raw_area=146569.0 | front_h=905.0 | front_norm=0.17895546533988585 || side_raw_area=85708.0 | side_h=872.0 | side_norm=0.11271673259826614
#
# Record 6105/6134
#   Processing photo_id=2391b1ee32555ca42fb4da1603b57fb4 -> pid=2391b1ee32555ca42fb4da1603b57fb4
#     Downloading mask: s3://amazon-bodym/train/mask/2391b1ee32555ca42fb4da1603b57fb4.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/2391b1ee32555ca42fb4da1603b57fb4.png
#     front_raw_area=121237.0 | front_h=872.0 | front_norm=0.15944180834946553 || side_raw_area=62370.0 | side_h=797.0 | side_norm=0.09818815539452369
#
# Record 6106/6134
#   Processing photo_id=78bd87141c24819e2ca35a5cff8acc6f -> pid=78bd87141c24819e2ca35a5cff8acc6f
#     Downloading mask: s3://amazon-bodym/train/mask/78bd87141c24819e2ca35a5cff8acc6f.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/78bd87141c24819e2ca35a5cff8acc6f.png
#     front_raw_area=134400.0 | front_h=850.0 | front_norm=0.18602076124567474 || side_raw_area=99226.0 | side_h=919.0 | side_norm=0.1174882572129189
#
# Record 6107/6134
#   Processing photo_id=fca5b2262dd464b82ed29e3610bdeadd -> pid=fca5b2262dd464b82ed29e3610bdeadd
#     Downloading mask: s3://amazon-bodym/train/mask/fca5b2262dd464b82ed29e3610bdeadd.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/fca5b2262dd464b82ed29e3610bdeadd.png
#     front_raw_area=101423.0 | front_h=783.0 | front_norm=0.16542948903014082 || side_raw_area=72432.0 | side_h=825.0 | side_norm=0.1064198347107438
#
# Record 6108/6134
#   Processing photo_id=61116880ef75ff2803222709bca7e3bf -> pid=61116880ef75ff2803222709bca7e3bf
#     Downloading mask: s3://amazon-bodym/train/mask/61116880ef75ff2803222709bca7e3bf.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/61116880ef75ff2803222709bca7e3bf.png
#     front_raw_area=109318.0 | front_h=826.0 | front_norm=0.16022548059729494 || side_raw_area=77356.0 | side_h=867.0 | side_norm=0.10290958095701813
#
# Record 6109/6134
#   Processing photo_id=afa31dc96adeeb119ded192deb070eb1 -> pid=afa31dc96adeeb119ded192deb070eb1
#     Downloading mask: s3://amazon-bodym/train/mask/afa31dc96adeeb119ded192deb070eb1.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/afa31dc96adeeb119ded192deb070eb1.png
#     front_raw_area=115095.0 | front_h=805.0 | front_norm=0.1776088885459666 || side_raw_area=82402.0 | side_h=872.0 | side_norm=0.10836892938304857
#
# Record 6110/6134
#   Processing photo_id=ef25cc1b3e1f458c857b7d6d9fc8ce49 -> pid=ef25cc1b3e1f458c857b7d6d9fc8ce49
#     Downloading mask: s3://amazon-bodym/train/mask/ef25cc1b3e1f458c857b7d6d9fc8ce49.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/ef25cc1b3e1f458c857b7d6d9fc8ce49.png
#     front_raw_area=141578.0 | front_h=869.0 | front_norm=0.18748055050512408 || side_raw_area=91163.0 | side_h=881.0 | side_norm=0.11745372416289919
#
# Record 6111/6134
#   Processing photo_id=91099b99653b0cb4459e328c38b4b09c -> pid=91099b99653b0cb4459e328c38b4b09c
#     Downloading mask: s3://amazon-bodym/train/mask/91099b99653b0cb4459e328c38b4b09c.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/91099b99653b0cb4459e328c38b4b09c.png
#     front_raw_area=111904.0 | front_h=797.0 | front_norm=0.17616878854046464 || side_raw_area=74040.0 | side_h=810.0 | side_norm=0.11284865112025606
#
# Record 6112/6134
#   Processing photo_id=5f06c99e1b75853a7a37779b3c27d598 -> pid=5f06c99e1b75853a7a37779b3c27d598
#     Downloading mask: s3://amazon-bodym/train/mask/5f06c99e1b75853a7a37779b3c27d598.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/5f06c99e1b75853a7a37779b3c27d598.png
#     front_raw_area=125236.0 | front_h=861.0 | front_norm=0.16893626377776969 || side_raw_area=97601.0 | side_h=946.0 | side_norm=0.10906163260015465
#
# Record 6113/6134
#   Processing photo_id=b8e596fb8eec0215543bad6746b10060 -> pid=b8e596fb8eec0215543bad6746b10060
#     Downloading mask: s3://amazon-bodym/train/mask/b8e596fb8eec0215543bad6746b10060.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/b8e596fb8eec0215543bad6746b10060.png
#     front_raw_area=135743.0 | front_h=844.0 | front_norm=0.19056035354102557 || side_raw_area=72321.0 | side_h=772.0 | side_norm=0.12134721737496308
#
# Record 6114/6134
#   Processing photo_id=ff8f246b5a1747314287c8f4fa912166 -> pid=ff8f246b5a1747314287c8f4fa912166
#     Downloading mask: s3://amazon-bodym/train/mask/ff8f246b5a1747314287c8f4fa912166.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/ff8f246b5a1747314287c8f4fa912166.png
#     front_raw_area=166856.0 | front_h=901.0 | front_norm=0.2055380567405066 || side_raw_area=140006.0 | side_h=895.0 | side_norm=0.17478355856558783
#
# Record 6115/6134
#   Processing photo_id=073a2e9f5b21609553cfd1ef10e5817f -> pid=073a2e9f5b21609553cfd1ef10e5817f
#     Downloading mask: s3://amazon-bodym/train/mask/073a2e9f5b21609553cfd1ef10e5817f.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/073a2e9f5b21609553cfd1ef10e5817f.png
#     front_raw_area=125491.0 | front_h=846.0 | front_norm=0.1753363065797048 || side_raw_area=102373.0 | side_h=933.0 | side_norm=0.1176040133763896
#
# Record 6116/6134
#   Processing photo_id=7a61daacf9fcfacd0c5b705e0d03531b -> pid=7a61daacf9fcfacd0c5b705e0d03531b
#     Downloading mask: s3://amazon-bodym/train/mask/7a61daacf9fcfacd0c5b705e0d03531b.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/7a61daacf9fcfacd0c5b705e0d03531b.png
#     front_raw_area=103763.0 | front_h=833.0 | front_norm=0.14953832673525594 || side_raw_area=63553.0 | side_h=804.0 | side_norm=0.09831594514987253
#
# Record 6117/6134
#   Processing photo_id=d5f30d541569a4850ad95e25b4cb0302 -> pid=d5f30d541569a4850ad95e25b4cb0302
#     Downloading mask: s3://amazon-bodym/train/mask/d5f30d541569a4850ad95e25b4cb0302.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/d5f30d541569a4850ad95e25b4cb0302.png
#     front_raw_area=101844.0 | front_h=785.0 | front_norm=0.16527080206093553 || side_raw_area=69456.0 | side_h=832.0 | side_norm=0.10033746301775148
#
# Record 6118/6134
#   Processing photo_id=cdac7d3cd58014a020db3563aa60b7d2 -> pid=cdac7d3cd58014a020db3563aa60b7d2
#     Downloading mask: s3://amazon-bodym/train/mask/cdac7d3cd58014a020db3563aa60b7d2.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/cdac7d3cd58014a020db3563aa60b7d2.png
#     front_raw_area=169247.0 | front_h=885.0 | front_norm=0.21608988477129815 || side_raw_area=123137.0 | side_h=947.0 | side_norm=0.1373057139257077
#
# Record 6119/6134
#   Processing photo_id=49d29ed1e94c2c77001845cf1e69f413 -> pid=49d29ed1e94c2c77001845cf1e69f413
#     Downloading mask: s3://amazon-bodym/train/mask/49d29ed1e94c2c77001845cf1e69f413.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/49d29ed1e94c2c77001845cf1e69f413.png
#     front_raw_area=104451.0 | front_h=817.0 | front_norm=0.15648347763034298 || side_raw_area=59783.0 | side_h=815.0 | side_norm=0.09000414016334826
#
# Record 6120/6134
#   Processing photo_id=f9184b1bdc9196025d61acaa69eab983 -> pid=f9184b1bdc9196025d61acaa69eab983
#     Downloading mask: s3://amazon-bodym/train/mask/f9184b1bdc9196025d61acaa69eab983.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/f9184b1bdc9196025d61acaa69eab983.png
#     front_raw_area=115352.0 | front_h=807.0 | front_norm=0.1771242642982945 || side_raw_area=97207.0 | side_h=926.0 | side_norm=0.11336410581753892
#
# Record 6121/6134
#   Processing photo_id=3cec0d533d4744a6c4ec323e3ce3b30e -> pid=3cec0d533d4744a6c4ec323e3ce3b30e
#     Downloading mask: s3://amazon-bodym/train/mask/3cec0d533d4744a6c4ec323e3ce3b30e.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/3cec0d533d4744a6c4ec323e3ce3b30e.png
#     front_raw_area=115555.0 | front_h=808.0 | front_norm=0.17699704685815115 || side_raw_area=82358.0 | side_h=860.0 | side_norm=0.11135478637101136
#
# Record 6122/6134
#   Processing photo_id=7af4087fe354a3d2577499d2fc424009 -> pid=7af4087fe354a3d2577499d2fc424009
#     Downloading mask: s3://amazon-bodym/train/mask/7af4087fe354a3d2577499d2fc424009.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/7af4087fe354a3d2577499d2fc424009.png
#     front_raw_area=140785.0 | front_h=838.0 | front_norm=0.20047875097544443 || side_raw_area=113366.0 | side_h=960.0 | side_norm=0.12300998263888889
#
# Record 6123/6134
#   Processing photo_id=4a84ba084cb4617baabc4c7a7c0e5899 -> pid=4a84ba084cb4617baabc4c7a7c0e5899
#     Downloading mask: s3://amazon-bodym/train/mask/4a84ba084cb4617baabc4c7a7c0e5899.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/4a84ba084cb4617baabc4c7a7c0e5899.png
#     front_raw_area=127685.0 | front_h=802.0 | front_norm=0.1985140017785959 || side_raw_area=114410.0 | side_h=886.0 | side_norm=0.145745965584538
#
# Record 6124/6134
#   Processing photo_id=c70f83c44d5ec60abc37a26b31c531dc -> pid=c70f83c44d5ec60abc37a26b31c531dc
#     Downloading mask: s3://amazon-bodym/train/mask/c70f83c44d5ec60abc37a26b31c531dc.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/c70f83c44d5ec60abc37a26b31c531dc.png
#     front_raw_area=111233.0 | front_h=783.0 | front_norm=0.18143042853484567 || side_raw_area=79906.0 | side_h=851.0 | side_norm=0.11033677114502742
#
# Record 6125/6134
#   Processing photo_id=9b0d2b834a483b5f0e41956bcfaac5d2 -> pid=9b0d2b834a483b5f0e41956bcfaac5d2
#     Downloading mask: s3://amazon-bodym/train/mask/9b0d2b834a483b5f0e41956bcfaac5d2.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/9b0d2b834a483b5f0e41956bcfaac5d2.png
#     front_raw_area=112371.0 | front_h=801.0 | front_norm=0.17514155994145894 || side_raw_area=74360.0 | side_h=824.0 | side_norm=0.10951786219247808
#
# Record 6126/6134
#   Processing photo_id=677092e97dec6bc0998b6b9ddba46c8d -> pid=677092e97dec6bc0998b6b9ddba46c8d
#     Downloading mask: s3://amazon-bodym/train/mask/677092e97dec6bc0998b6b9ddba46c8d.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/677092e97dec6bc0998b6b9ddba46c8d.png
#     front_raw_area=131107.0 | front_h=900.0 | front_norm=0.1618604938271605 || side_raw_area=77560.0 | side_h=887.0 | side_norm=0.09858039653316285
#
# Record 6127/6134
#   Processing photo_id=b5a74a706f853f7ba39918badb625abf -> pid=b5a74a706f853f7ba39918badb625abf
#     Downloading mask: s3://amazon-bodym/train/mask/b5a74a706f853f7ba39918badb625abf.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/b5a74a706f853f7ba39918badb625abf.png
#     front_raw_area=154664.0 | front_h=886.0 | front_norm=0.19702520777175936 || side_raw_area=82276.0 | side_h=823.0 | side_norm=0.12147124957000217
#
# Record 6128/6134
#   Processing photo_id=625c2587242cc9b56f067175a9d53b8d -> pid=625c2587242cc9b56f067175a9d53b8d
#     Downloading mask: s3://amazon-bodym/train/mask/625c2587242cc9b56f067175a9d53b8d.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/625c2587242cc9b56f067175a9d53b8d.png
#     front_raw_area=147592.0 | front_h=852.0 | front_norm=0.20332165134783664 || side_raw_area=100117.0 | side_h=925.0 | side_norm=0.11701037253469686
#
# Record 6129/6134
#   Processing photo_id=995f026a55d23f229fd3b7623e46b470 -> pid=995f026a55d23f229fd3b7623e46b470
#     Downloading mask: s3://amazon-bodym/train/mask/995f026a55d23f229fd3b7623e46b470.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/995f026a55d23f229fd3b7623e46b470.png
#     front_raw_area=103708.0 | front_h=782.0 | front_norm=0.169589419221486 || side_raw_area=68971.0 | side_h=822.0 | side_norm=0.10207582242586771
#
# Record 6130/6134
#   Processing photo_id=4925817167cc5dd9ece5248ed33a114d -> pid=4925817167cc5dd9ece5248ed33a114d
#     Downloading mask: s3://amazon-bodym/train/mask/4925817167cc5dd9ece5248ed33a114d.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/4925817167cc5dd9ece5248ed33a114d.png
#     front_raw_area=97910.0 | front_h=767.0 | front_norm=0.16643180477622393 || side_raw_area=67333.0 | side_h=824.0 | side_norm=0.09916845367141107
#
# Record 6131/6134
#   Processing photo_id=1a2bbdb164468cdae81ba230edebcd54 -> pid=1a2bbdb164468cdae81ba230edebcd54
#     Downloading mask: s3://amazon-bodym/train/mask/1a2bbdb164468cdae81ba230edebcd54.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/1a2bbdb164468cdae81ba230edebcd54.png
#     front_raw_area=109779.0 | front_h=763.0 | front_norm=0.18856895506287694 || side_raw_area=95460.0 | side_h=852.0 | side_norm=0.1315049923956887
#
# Record 6132/6134
#   Processing photo_id=7444c75f5ebf4a098401cddf2d0c1197 -> pid=7444c75f5ebf4a098401cddf2d0c1197
#     Downloading mask: s3://amazon-bodym/train/mask/7444c75f5ebf4a098401cddf2d0c1197.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/7444c75f5ebf4a098401cddf2d0c1197.png
#     front_raw_area=116210.0 | front_h=807.0 | front_norm=0.17844173273202724 || side_raw_area=74820.0 | side_h=834.0 | side_norm=0.10756862136190329
#
# Record 6133/6134
#   Processing photo_id=73482a4b918314248eea94cc6353b48c -> pid=73482a4b918314248eea94cc6353b48c
#     Downloading mask: s3://amazon-bodym/train/mask/73482a4b918314248eea94cc6353b48c.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/73482a4b918314248eea94cc6353b48c.png
#     front_raw_area=100560.0 | front_h=795.0 | front_norm=0.15910763023614571 || side_raw_area=77299.0 | side_h=867.0 | side_norm=0.10283375172444988
#
# Record 6134/6134
#   Processing photo_id=b5074e2cef42298f49d724afd154034e -> pid=b5074e2cef42298f49d724afd154034e
#     Downloading mask: s3://amazon-bodym/train/mask/b5074e2cef42298f49d724afd154034e.png
#     Downloading mask: s3://amazon-bodym/train/mask_left/b5074e2cef42298f49d724afd154034e.png
#     front_raw_area=130307.0 | front_h=832.0 | front_norm=0.18824397882766272 || side_raw_area=94375.0 | side_h=895.0 | side_norm=0.11781779594894042
#
# Attaching new feature columns to dataframe...

# %%
data.head()
# Out:
#                            photo_id        f1        f2        f3        f4  \
# 0  6ab1d061f51c6079633aeceed2faeb0b  0.000068  0.108145 -0.138813  0.633156
# 1  e94e2e05fb8b099955bbc4fa5ce81e22  0.020843  0.026005 -0.093442  0.736929
# 2  ba6951a4f37fc9302243370e927a02e2  0.014542 -0.071332 -0.154407  0.577781
# 3  947d16539d4702427aa74f737329ffb9  0.041775  0.075746 -0.128497  0.485010
# 4  9326695bf62926ec22690f576a633bba  0.004397  0.058590 -0.154224  0.528140
#
#          f5        f6        f7        f8        f9  ...  shoulder-breadth  \
# 0  0.346266 -0.046055  0.016021 -0.058632  0.097968  ...         35.362858
# 1  0.240569  0.089982 -0.112391  0.000435 -0.076110  ...         37.256760
# 2  0.196485 -0.125341 -0.056713 -0.027295  0.094879  ...         37.503147
# 3  0.120409  0.011227  0.017852 -0.089796 -0.011273  ...         34.084633
# 4  0.290956 -0.108486 -0.021441 -0.099909  0.080770  ...         38.086231
#
#    shoulder-to-crotch      thigh       waist      wrist  gender  height_cm  \
# 0           65.993683  54.459591   88.813789  16.764332  female     170.50
# 1           65.861588  52.773052   89.176338  15.690955    male     178.30
# 2           66.042679  57.059261   82.201988  16.686253    male     176.25
# 3           60.413330  65.000000  102.323845  17.693762  female     152.10
# 4           68.400543  57.172279  107.378578  16.594791    male     171.50
#
#    weight_kg  front_silhouette_area_norm  side_silhouette_area_norm
# 0       72.0                    0.174312                   0.135717
# 1       71.8                    0.172027                   0.102244
# 2       76.5                    0.168356                   0.114739
# 3       88.9                    0.226599                   0.153627
# 4       88.4                    0.183343                   0.114689
#
# [5 rows x 5140 columns]

# %%
import boto3  # S3 client
from io import StringIO  # in-memory text buffer

print("Preparing to upload updated dataset to S3...")  # track process

s3_out_path = "s3://ai-bmi-predictor-v2/data/eff_training_v3.csv"  # target S3 path
print("Target:", s3_out_path)  # show target

# ---- parse s3://bucket/key ----
out_bucket = s3_out_path.replace("s3://", "").split("/", 1)[0]  # extract bucket
out_key = s3_out_path.replace("s3://", "").split("/", 1)[1]     # extract key
print(f"Parsed -> bucket={out_bucket}, key={out_key}")  # confirm parsing

# ---- write CSV to memory ----
csv_buffer = StringIO()  # create in-memory buffer
print("Serializing dataframe to CSV (in-memory)...")  # track process
data.to_csv(csv_buffer, index=False)  # write dataframe as CSV text
csv_body = csv_buffer.getvalue()  # get CSV string content
print(f"CSV size (chars): {len(csv_body):,}")  # print rough size

# ---- upload to S3 ----
s3 = boto3.client("s3")  # create S3 client
print("Uploading to S3...")  # track process
s3.put_object(
    Bucket=out_bucket,                 # destination bucket
    Key=out_key,                       # destination key
    Body=csv_body.encode("utf-8"),     # file bytes
    ContentType="text/csv"             # content type
)  # upload

print("Upload complete ✅")  # done
print(f"Saved to: {s3_out_path}")  # confirm final path
# Out:
# Preparing to upload updated dataset to S3...
# Target: s3://ai-bmi-predictor-v2/data/eff_training_v3.csv
# Parsed -> bucket=ai-bmi-predictor-v2, key=data/eff_training_v3.csv
# Serializing dataframe to CSV (in-memory)...
# CSV size (chars): 372,740,797
# Uploading to S3...
# Upload complete ✅
# Saved to: s3://ai-bmi-predictor-v2/data/eff_training_v3.csv
