# %%
import base64

# Path to your image
image_path = "man.png"

with open(image_path, "rb") as f:
    image_bytes = f.read()

image_b64 = base64.b64encode(image_bytes).decode("utf-8")

print(image_b64)
# Out:
# ...
