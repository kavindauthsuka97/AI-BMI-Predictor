# %% [markdown]
# Step 1 – Imports

# %%
# !pip install transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 164.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 72.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 194.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 151.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [transformers] [transformers]ub]
# ...

# %%
# Step 1 - Imports

# If you don't have 'transformers' installed, run the next line once in a separate cell:
# !pip install transformers

import os  # Work with file paths and folders
import shutil  # Remove folders such as .ipynb_checkpoints
import pickle  # Save and load Python objects (like dictionaries)

from tensorflow.keras.preprocessing.image import load_img  # Load images from disk as PIL images
from transformers import AutoImageProcessor, TFViTModel  # Pretrained ViT model and its image preprocessor
# Out:
# Transformers is only compatible with Keras 2, but you have explicitly set `TF_USE_LEGACY_KERAS` to `0`. This may result in unexpected behaviour or errors if Keras 3 objects are passed to Transformers models.

# %% [markdown]
# Step 2 – Load the ViT model

# %%
# Step 2 - Load the Vision Transformer (ViT) model

vit_model_name = "google/vit-base-patch16-224-in21k"  # Name of the pretrained ViT checkpoint

image_processor = AutoImageProcessor.from_pretrained(vit_model_name)  # Create image preprocessor for this ViT

vit_model = TFViTModel.from_pretrained(vit_model_name)  # Load the ViT model with pretrained weights
# Out:
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# 2025-12-04 13:09:00.340206: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-04 13:09:00.341269: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...
