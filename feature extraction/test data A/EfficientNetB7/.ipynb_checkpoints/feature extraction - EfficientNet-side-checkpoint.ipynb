# %% [markdown]
# 1. load EfficientNetB7 model
# 2. restructure the model by removing final classification layer
# 3. set feature storage and image directory
# 4. loop through every file name in the image directory
# 5. resize the image to 600*600 pixels because of the requirenment of the model
# 6. preprocess the image according to the requirenments of the model
# 7. apply the image to the restructured mmodel
# 8. stored the extracted features in a dictionary

# %% [markdown]
# Step 1 – Imports

# %%
# Import the 'os' module to interact with the operating system (e.g., list files in a folder)
import os

# Import the EfficientNetB7 model and its preprocessing function from Keras applications
from tensorflow.keras.applications.efficientnet import EfficientNetB7, preprocess_input

# Import utility functions to load an image file and convert it to a NumPy array
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Import the Model class to create a custom model that outputs features instead of class predictions
from tensorflow.keras.models import Model

# Import the 'pickle' module to save and load Python objects (like dictionaries) to/from a file
import pickle
# Out:
# 2025-11-25 11:33:48.152430: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-25 11:33:57.942750: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-25 11:34:03.997309: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-25 11:34:04.081560: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-25 11:34:11.987666: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-25 11:34:19.930036: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Step 2 - Load the EfficientNet-B7 model

# %%
# Load the EfficientNet-B7 model with pre-trained ImageNet weights
# By default, include_top=True, so the final classification layers are included
base_model = EfficientNetB7(weights='imagenet')
# Out:
# 2025-11-25 11:34:33.266493: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-25 11:34:39.546330: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-25 11:34:39.549573: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-25 11:34:39.552698: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-25 11:34:39.555291: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-25 11:34:39.557825: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-25 11:34:40.204566: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-25 11:34:40.205644: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-25 11:34:40.206618: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-25 11:34:40.208496: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13760 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7.h5
# 268326632/268326632 [==============================] - 9s 0us/step

# %% [markdown]
# Step 3 - Restructure the model

# %%
# Create a new model that has the same input as the original EfficientNet-B7 model
# but uses the second-to-last layer's output (before the final classification layer) as the output
feature_extractor_model = Model(
    inputs=base_model.inputs,            # Use the same input tensor as EfficientNet-B7
    outputs=base_model.layers[-2].output # Use the layer just before the final prediction layer
)

# %% [markdown]
# Step 4 - Show model summary

# %%
# Print a summary of the modified model architecture to verify the output shapes and layers
print(feature_extractor_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 600, 600, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 600, 600, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 600, 600, 3)          7         ['rescaling[0][0]']
#  on)
#
#  tf.math.multiply (TFOpLamb  (None, 600, 600, 3)          0         ['normalization[0][0]']
#  da)
#
#  stem_conv_pad (ZeroPadding  (None, 601, 601, 3)          0         ['tf.math.multiply[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 300, 300, 64)         1728      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 300, 300, 64)         256       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 300, 300, 64)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 300, 300, 64)         576       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 300, 300, 64)         256       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 300, 300, 64)         0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 64)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 64)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 16)             1040      ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 64)             1088      ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 300, 300, 64)         0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 300, 300, 32)         2048      ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 300, 300, 32)         128       ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 300, 300, 32)         288       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 300, 300, 32)         128       ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 300, 300, 32)         0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 32)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 300, 300, 32)         0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 300, 300, 32)         1024      ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 300, 300, 32)         128       ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 300, 300, 32)         0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 300, 300, 32)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseC  (None, 300, 300, 32)         288       ['block1b_add[0][0]']
#  onv2D)
#
#  block1c_bn (BatchNormaliza  (None, 300, 300, 32)         128       ['block1c_dwconv[0][0]']
#  tion)
#
#  block1c_activation (Activa  (None, 300, 300, 32)         0         ['block1c_bn[0][0]']
#  tion)
#
#  block1c_se_squeeze (Global  (None, 32)                   0         ['block1c_activation[0][0]']
#  AveragePooling2D)
#
#  block1c_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1c_se_squeeze[0][0]']
#  e)
#
#  block1c_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multipl  (None, 300, 300, 32)         0         ['block1c_activation[0][0]',
#  y)                                                                  'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv  (None, 300, 300, 32)         1024      ['block1c_se_excite[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 300, 300, 32)         128       ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_drop (Dropout)      (None, 300, 300, 32)         0         ['block1c_project_bn[0][0]']
#
#  block1c_add (Add)           (None, 300, 300, 32)         0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseC  (None, 300, 300, 32)         288       ['block1c_add[0][0]']
#  onv2D)
#
#  block1d_bn (BatchNormaliza  (None, 300, 300, 32)         128       ['block1d_dwconv[0][0]']
#  tion)
#
#  block1d_activation (Activa  (None, 300, 300, 32)         0         ['block1d_bn[0][0]']
#  tion)
#
#  block1d_se_squeeze (Global  (None, 32)                   0         ['block1d_activation[0][0]']
#  AveragePooling2D)
#
#  block1d_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1d_se_squeeze[0][0]']
#  e)
#
#  block1d_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multipl  (None, 300, 300, 32)         0         ['block1d_activation[0][0]',
#  y)                                                                  'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv  (None, 300, 300, 32)         1024      ['block1d_se_excite[0][0]']
#  2D)
#
#  block1d_project_bn (BatchN  (None, 300, 300, 32)         128       ['block1d_project_conv[0][0]']
#  ormalization)
#
#  block1d_drop (Dropout)      (None, 300, 300, 32)         0         ['block1d_project_bn[0][0]']
#
#  block1d_add (Add)           (None, 300, 300, 32)         0         ['block1d_drop[0][0]',
#                                                                      'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 300, 300, 192)        6144      ['block1d_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 300, 300, 192)        768       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 300, 300, 192)        0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 301, 301, 192)        0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 150, 150, 192)        1728      ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 150, 150, 192)        768       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 150, 150, 192)        0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 192)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 150, 150, 192)        0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 150, 150, 48)         9216      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 150, 150, 48)         192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 150, 150, 288)        13824     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 150, 150, 288)        1152      ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 150, 150, 288)        0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 150, 150, 288)        2592      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 150, 150, 288)        1152      ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 150, 150, 288)        0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 288)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 150, 150, 288)        0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 150, 150, 48)         13824     ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 150, 150, 48)         192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 150, 150, 48)         0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 150, 150, 48)         0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 150, 150, 288)        13824     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 150, 150, 288)        1152      ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 150, 150, 288)        0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 150, 150, 288)        2592      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 150, 150, 288)        1152      ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 150, 150, 288)        0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 288)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 150, 150, 288)        0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 150, 150, 48)         13824     ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 150, 150, 48)         192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 150, 150, 48)         0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 150, 150, 48)         0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 150, 150, 288)        13824     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 150, 150, 288)        1152      ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 150, 150, 288)        0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_dwconv (DepthwiseC  (None, 150, 150, 288)        2592      ['block2d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2d_bn (BatchNormaliza  (None, 150, 150, 288)        1152      ['block2d_dwconv[0][0]']
#  tion)
#
#  block2d_activation (Activa  (None, 150, 150, 288)        0         ['block2d_bn[0][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 288)                  0         ['block2d_activation[0][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2d_se_squeeze[0][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multipl  (None, 150, 150, 288)        0         ['block2d_activation[0][0]',
#  y)                                                                  'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv  (None, 150, 150, 48)         13824     ['block2d_se_excite[0][0]']
#  2D)
#
#  block2d_project_bn (BatchN  (None, 150, 150, 48)         192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 150, 150, 48)         0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 150, 150, 48)         0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 150, 150, 288)        13824     ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 150, 150, 288)        1152      ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 150, 150, 288)        0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_dwconv (DepthwiseC  (None, 150, 150, 288)        2592      ['block2e_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2e_bn (BatchNormaliza  (None, 150, 150, 288)        1152      ['block2e_dwconv[0][0]']
#  tion)
#
#  block2e_activation (Activa  (None, 150, 150, 288)        0         ['block2e_bn[0][0]']
#  tion)
#
#  block2e_se_squeeze (Global  (None, 288)                  0         ['block2e_activation[0][0]']
#  AveragePooling2D)
#
#  block2e_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2e_se_squeeze[0][0]']
#  e)
#
#  block2e_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multipl  (None, 150, 150, 288)        0         ['block2e_activation[0][0]',
#  y)                                                                  'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv  (None, 150, 150, 48)         13824     ['block2e_se_excite[0][0]']
#  2D)
#
#  block2e_project_bn (BatchN  (None, 150, 150, 48)         192       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (Dropout)      (None, 150, 150, 48)         0         ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)           (None, 150, 150, 48)         0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2  (None, 150, 150, 288)        13824     ['block2e_add[0][0]']
#  D)
#
#  block2f_expand_bn (BatchNo  (None, 150, 150, 288)        1152      ['block2f_expand_conv[0][0]']
#  rmalization)
#
#  block2f_expand_activation   (None, 150, 150, 288)        0         ['block2f_expand_bn[0][0]']
#  (Activation)
#
#  block2f_dwconv (DepthwiseC  (None, 150, 150, 288)        2592      ['block2f_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2f_bn (BatchNormaliza  (None, 150, 150, 288)        1152      ['block2f_dwconv[0][0]']
#  tion)
#
#  block2f_activation (Activa  (None, 150, 150, 288)        0         ['block2f_bn[0][0]']
#  tion)
#
#  block2f_se_squeeze (Global  (None, 288)                  0         ['block2f_activation[0][0]']
#  AveragePooling2D)
#
#  block2f_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2f_se_squeeze[0][0]']
#  e)
#
#  block2f_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multipl  (None, 150, 150, 288)        0         ['block2f_activation[0][0]',
#  y)                                                                  'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv  (None, 150, 150, 48)         13824     ['block2f_se_excite[0][0]']
#  2D)
#
#  block2f_project_bn (BatchN  (None, 150, 150, 48)         192       ['block2f_project_conv[0][0]']
#  ormalization)
#
#  block2f_drop (Dropout)      (None, 150, 150, 48)         0         ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)           (None, 150, 150, 48)         0         ['block2f_drop[0][0]',
#                                                                      'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2  (None, 150, 150, 288)        13824     ['block2f_add[0][0]']
#  D)
#
#  block2g_expand_bn (BatchNo  (None, 150, 150, 288)        1152      ['block2g_expand_conv[0][0]']
#  rmalization)
#
#  block2g_expand_activation   (None, 150, 150, 288)        0         ['block2g_expand_bn[0][0]']
#  (Activation)
#
#  block2g_dwconv (DepthwiseC  (None, 150, 150, 288)        2592      ['block2g_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2g_bn (BatchNormaliza  (None, 150, 150, 288)        1152      ['block2g_dwconv[0][0]']
#  tion)
#
#  block2g_activation (Activa  (None, 150, 150, 288)        0         ['block2g_bn[0][0]']
#  tion)
#
#  block2g_se_squeeze (Global  (None, 288)                  0         ['block2g_activation[0][0]']
#  AveragePooling2D)
#
#  block2g_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block2g_se_squeeze[0][0]']
#  e)
#
#  block2g_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multipl  (None, 150, 150, 288)        0         ['block2g_activation[0][0]',
#  y)                                                                  'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv  (None, 150, 150, 48)         13824     ['block2g_se_excite[0][0]']
#  2D)
#
#  block2g_project_bn (BatchN  (None, 150, 150, 48)         192       ['block2g_project_conv[0][0]']
#  ormalization)
#
#  block2g_drop (Dropout)      (None, 150, 150, 48)         0         ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)           (None, 150, 150, 48)         0         ['block2g_drop[0][0]',
#                                                                      'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 150, 150, 288)        13824     ['block2g_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 150, 150, 288)        1152      ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 150, 150, 288)        0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 153, 153, 288)        0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 75, 75, 288)          7200      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 75, 75, 288)          1152      ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 75, 75, 288)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 288)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 75, 75, 288)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 75, 75, 80)           23040     ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 75, 75, 80)           320       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 75, 75, 480)          38400     ['block3a_project_bn[0][0]']
# ...
#  block7a_se_squeeze (Global  (None, 2304)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 2304)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 96)             221280    ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 2304)           223488    ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 19, 19, 2304)         0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 19, 19, 640)          1474560   ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 19, 19, 640)          2560      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 19, 19, 3840)         2457600   ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 19, 19, 3840)         15360     ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 19, 19, 3840)         0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 19, 19, 3840)         34560     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 19, 19, 3840)         15360     ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 19, 19, 3840)         0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 3840)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 19, 19, 3840)         0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 19, 19, 640)          2457600   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 19, 19, 640)          2560      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 19, 19, 640)          0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 19, 19, 640)          0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2  (None, 19, 19, 3840)         2457600   ['block7b_add[0][0]']
#  D)
#
#  block7c_expand_bn (BatchNo  (None, 19, 19, 3840)         15360     ['block7c_expand_conv[0][0]']
#  rmalization)
#
#  block7c_expand_activation   (None, 19, 19, 3840)         0         ['block7c_expand_bn[0][0]']
#  (Activation)
#
#  block7c_dwconv (DepthwiseC  (None, 19, 19, 3840)         34560     ['block7c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7c_bn (BatchNormaliza  (None, 19, 19, 3840)         15360     ['block7c_dwconv[0][0]']
#  tion)
#
#  block7c_activation (Activa  (None, 19, 19, 3840)         0         ['block7c_bn[0][0]']
#  tion)
#
#  block7c_se_squeeze (Global  (None, 3840)                 0         ['block7c_activation[0][0]']
#  AveragePooling2D)
#
#  block7c_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7c_se_squeeze[0][0]']
#  e)
#
#  block7c_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multipl  (None, 19, 19, 3840)         0         ['block7c_activation[0][0]',
#  y)                                                                  'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv  (None, 19, 19, 640)          2457600   ['block7c_se_excite[0][0]']
#  2D)
#
#  block7c_project_bn (BatchN  (None, 19, 19, 640)          2560      ['block7c_project_conv[0][0]']
#  ormalization)
#
#  block7c_drop (Dropout)      (None, 19, 19, 640)          0         ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)           (None, 19, 19, 640)          0         ['block7c_drop[0][0]',
#                                                                      'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2  (None, 19, 19, 3840)         2457600   ['block7c_add[0][0]']
#  D)
#
#  block7d_expand_bn (BatchNo  (None, 19, 19, 3840)         15360     ['block7d_expand_conv[0][0]']
#  rmalization)
#
#  block7d_expand_activation   (None, 19, 19, 3840)         0         ['block7d_expand_bn[0][0]']
#  (Activation)
#
#  block7d_dwconv (DepthwiseC  (None, 19, 19, 3840)         34560     ['block7d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7d_bn (BatchNormaliza  (None, 19, 19, 3840)         15360     ['block7d_dwconv[0][0]']
#  tion)
#
#  block7d_activation (Activa  (None, 19, 19, 3840)         0         ['block7d_bn[0][0]']
#  tion)
#
#  block7d_se_squeeze (Global  (None, 3840)                 0         ['block7d_activation[0][0]']
#  AveragePooling2D)
#
#  block7d_se_reshape (Reshap  (None, 1, 1, 3840)           0         ['block7d_se_squeeze[0][0]']
#  e)
#
#  block7d_se_reduce (Conv2D)  (None, 1, 1, 160)            614560    ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)  (None, 1, 1, 3840)           618240    ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multipl  (None, 19, 19, 3840)         0         ['block7d_activation[0][0]',
#  y)                                                                  'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv  (None, 19, 19, 640)          2457600   ['block7d_se_excite[0][0]']
#  2D)
#
#  block7d_project_bn (BatchN  (None, 19, 19, 640)          2560      ['block7d_project_conv[0][0]']
#  ormalization)
#
#  block7d_drop (Dropout)      (None, 19, 19, 640)          0         ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)           (None, 19, 19, 640)          0         ['block7d_drop[0][0]',
#                                                                      'block7c_add[0][0]']
#
#  top_conv (Conv2D)           (None, 19, 19, 2560)         1638400   ['block7d_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 19, 19, 2560)         10240     ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 19, 19, 2560)         0         ['top_bn[0][0]']
#  )
#
#  avg_pool (GlobalAveragePoo  (None, 2560)                 0         ['top_activation[0][0]']
#  ling2D)
#
#  top_dropout (Dropout)       (None, 2560)                 0         ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 64097687 (244.51 MB)
# Trainable params: 63786960 (243.33 MB)
# Non-trainable params: 310727 (1.19 MB)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Step 5 - Prepare feature storage and image directory

# %%
# Create an empty dictionary to store extracted features for each image
# The keys will be image paths and the values will be the corresponding feature vectors
features = {}

# Define the directory that contains the input images
# This is the full Windows path to your "front masked images" training data folder
directory = r'test - front masked images'

# %% [markdown]
# Step 6 - Loop through images, preprocess, and extract features

# %%
# Get a list of all files in the directory
file_list = os.listdir(directory)

# Print how many images were found before starting the loop
print(f"Found {len(file_list)} files in directory: {directory}")

# Loop through every file name in the specified image directory
for idx, image_name in enumerate(file_list, start=1):
    # Build the full path to the current image file by joining directory and file name
    image_path = os.path.join(directory, image_name)
    
    # Load the image from disk and resize it to 600x600 pixels (required size for EfficientNet-B7)
    img = load_img(image_path, target_size=(600, 600))
    
    # Convert the loaded PIL image to a NumPy array (height, width, channels)
    img = img_to_array(img)
    
    # Add a batch dimension so the array shape becomes (1, height, width, channels)
    # This matches the expected input shape for the model
    img = img.reshape(1, img.shape[0], img.shape[1], img.shape[2])
    
    # Preprocess the image using EfficientNet's preprocessing (scaling, normalization, etc.)
    img = preprocess_input(img)
    
    # Pass the preprocessed image through the feature extractor model to get the feature vector
    # verbose=0 disables progress bar output
    feature_vector = feature_extractor_model.predict(img, verbose=0)
    
    # Store the extracted feature vector in the dictionary using the image path as the key
    features[image_path] = feature_vector

    # Print progress information for this image
    print(f"Processed {idx}/{len(file_list)}: {image_name}")
# Out:
# Found 1685 files in directory: test - front masked images
# 2025-11-25 11:35:57.435013: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# Processed 1/1685: e5ae8fe5bbdf611a1e8d06e66e849bdf.png
# Processed 2/1685: 605a5fd09058c48156b0ef518b63b2de.png
# Processed 3/1685: 909c9277309e13ee014e347603aba620.png
# Processed 4/1685: bef6a68bc8dd475c124f6de2413385d3.png
# Processed 5/1685: 6d7ed4bc4a17546447efed0ca6e2ff11.png
# Processed 6/1685: 4c12d6a82cb0a75ee556a54ab1afc21e.png
# Processed 7/1685: dd27be8b3d6b9c2c14c14318612ba0dc.png
# Processed 8/1685: fc65b84d8183e3a872785b4e2eecaa66.png
# Processed 9/1685: 851f712c7cfc6b62b20b6f8cba65c20a.png
# Processed 10/1685: c9ede0a19f8e79ec7a4cd8f126129f2d.png
# Processed 11/1685: 652500aa90597ed06ccc8f15bc9b83aa.png
# Processed 12/1685: b55e0664c7c1642cd015b5585a8d5fd3.png
# Processed 13/1685: 67194d8a47331d1f722db4f737546021.png
# Processed 14/1685: 719fc866000f5edb56700ee0755ea109.png
# Processed 15/1685: 46c5d36f10af6cf0fd2b4a02eb9a9add.png
# Processed 16/1685: e1a3c3b6df492a58fde15be36a8371bc.png
# Processed 17/1685: 7ac05db49a083076cb5ed077f16b90e0.png
# Processed 18/1685: 7e1e1d9f8724124bcae0a945c3c324cc.png
# Processed 19/1685: b5876de60bcfdb5600aade28cc554c52.png
# Processed 20/1685: 1c6fe922a59a5b63ec8c0e2264eb49af.png
# Processed 21/1685: 09735076f4d5e0fdbc4c883a3ec74072.png
# Processed 22/1685: 2e2c6428f26c80bf286b854fe851b518.png
# Processed 23/1685: a7cc758a534dedded8604cea3a52b681.png
# Processed 24/1685: a49e4915a40d206006fe883bcada4088.png
# Processed 25/1685: 6e567773d006c757fa8fb750201eecb2.png
# Processed 26/1685: 0d89f5b1adb8b5c0d52fead18a8aca86.png
# Processed 27/1685: 90e3d2a537e221c3d009bbfd76c31781.png
# Processed 28/1685: 1ea5a5846c1e4876aeef5e5df54493fb.png
# Processed 29/1685: cc30e4cf064a73a33f49f98502659453.png
# Processed 30/1685: 783223cf280aeb356e61a58a8ecfffea.png
# Processed 31/1685: 0aad7e8a4987342302961aa4cc0ccbed.png
# Processed 32/1685: 8bfd63f2d47016a1a03ad5dcdb11a844.png
# Processed 33/1685: 5310a6a41e39c0cc8670d12c0330796a.png
# Processed 34/1685: 33130c0719c02d71be90ddf431943b73.png
# Processed 35/1685: fe5068eb0602ffa458cd43c689ad2c94.png
# Processed 36/1685: dea8deceafe67f7dfeafcc9030cb71be.png
# Processed 37/1685: cbd9cba29a166e7e53067c72dfe5a397.png
# Processed 38/1685: f5acb42eed491bba2cd7f7deeca73577.png
# Processed 39/1685: 83c16a5818cd82c37d8f72ebbdf2938b.png
# Processed 40/1685: 4a3d5b8a392fab125e0591960e0e0c15.png
# Processed 41/1685: 8115f0ec6fa7e8fc12e918c5caaf3c9a.png
# Processed 42/1685: 57adf42d38fd1a6683bf3c46a547847a.png
# Processed 43/1685: 4e9bf0300f31f1335f938643220f81f5.png
# Processed 44/1685: d00150c491b8faa77a5cb9bd8422029e.png
# Processed 45/1685: 71affd9167bebfa3402da73d5b02036c.png
# Processed 46/1685: 8947ac15cbf9a90c47495d2f9aa1fe0c.png
# Processed 47/1685: a32ee410d093b47d1b29574593513f6e.png
# Processed 48/1685: 98219e748c76cdb3e827505d154db8de.png
# Processed 49/1685: 256a73e60cb5fa2706be990b7fc7f6f9.png
# Processed 50/1685: 20192a081a6e6cc01e7388070cd12441.png
# Processed 51/1685: 824c5dbd22639b8a4f4130f3e53eaa55.png
# Processed 52/1685: f3fac2f83e7c2571c2769b0e9fdcf4f6.png
# Processed 53/1685: a78989815ffd2c907a4d3dd91c87364d.png
# Processed 54/1685: b87928100a9d9230a4623019f049184c.png
# Processed 55/1685: 79a86609427b81242f8555822d749455.png
# Processed 56/1685: dd886c6903c81753f0230763eded1ff5.png
# Processed 57/1685: 766cc99f817262d0ab3a7b15ce46b517.png
# Processed 58/1685: 71d1954e34fc0385e30bb07837345c73.png
# Processed 59/1685: 8cb7b3074fb5fd67dc019aaddfad8995.png
# Processed 60/1685: 1b57988171874d8fae376d94f4dc7f65.png
# Processed 61/1685: c050dd0ace9a5383945212717ecdd7cb.png
# Processed 62/1685: 36ca064832f9a878db0277152eeaac78.png
# Processed 63/1685: d1fe80a5728534da8a03f07e79fda8e0.png
# Processed 64/1685: 417335e9cf581a470cd91ec27728b379.png
# Processed 65/1685: 472f1416a2b2a909766e386b50ca2dac.png
# Processed 66/1685: ef16063594ff7d74d9feaa94ba636085.png
# Processed 67/1685: e5f5b7e98e478b23b3be8bf6678c1f0c.png
# Processed 68/1685: d97172a35c4ac9a3045632fb61c6cc24.png
# Processed 69/1685: 3b75777e48c78b066cb696ecdb516d4c.png
# Processed 70/1685: 90f1b79c16714fe22765b5c0961e23c3.png
# Processed 71/1685: 10c266033125c4d63763ad2e6cebcafd.png
# Processed 72/1685: 462abfea634b872431f903ccd04acdd0.png
# Processed 73/1685: 42fa5fb5e0a3116a04abcfb82f7c67b1.png
# Processed 74/1685: dbd4a212cb17546bf43377ce79487281.png
# Processed 75/1685: e512188a6ea3ce68cb894778c73946b9.png
# Processed 76/1685: a9d9d3ece5dbd60aa4a297bfcd60abc6.png
# Processed 77/1685: aa9087e7bec2357318f7801ded0ba33b.png
# Processed 78/1685: a465c4424b48157d0403c4f46b750ed2.png
# Processed 79/1685: 9167f07c4fdc74a78ace00d7cad4b699.png
# Processed 80/1685: 6de8b6dd4e842884a3abf17fc6568ce2.png
# Processed 81/1685: bd34754520da8332a69610184f3426ac.png
# Processed 82/1685: 27ca2b1761b82c84658f0454d071d3c0.png
# Processed 83/1685: a7eb01092cd1addb4dfcce418e3e0be4.png
# Processed 84/1685: c1366a32ee29171e3dfe3d331fa6ca22.png
# Processed 85/1685: 97397e09649477eeed2028a6696076e7.png
# Processed 86/1685: 211bdc1fbd34284e72f487ab01545822.png
# Processed 87/1685: c47fe281098b0be712e056089a810f06.png
# Processed 88/1685: 6f0dde56568d5a4ca7e57e3087e0b17d.png
# Processed 89/1685: 1dab48ac937df915756a1a0967374d55.png
# Processed 90/1685: c98b8ea53680a70cfd690d7664c2f2b9.png
# Processed 91/1685: fba6f8d8157288c7f94270c32f695db2.png
# Processed 92/1685: e27c06706baad66a89708192d868315a.png
# Processed 93/1685: 879b4afda245e5373fb00b64be7f655a.png
# Processed 94/1685: d17a831ec8035ccf2a5383c3165fcf22.png
# Processed 95/1685: f95a847c3d8dfe6a365fe7c300f6986a.png
# Processed 96/1685: b825b43a54e303db71d7b495c1b122bf.png
# Processed 97/1685: 7a7ef55e5aff084c5410cb32e9e8db20.png
# Processed 98/1685: c8f58c789047d66ebab704ca4995ce91.png
# Processed 99/1685: d2b7a25c08c65a01cc47fefa1159e5c9.png
# Processed 100/1685: bfdaf91669c796c769e54660c5ae442e.png
# Processed 101/1685: ec05f4b906c772df6742a28b2b3ca1f0.png
# Processed 102/1685: a73305f31827289d92a6b864a72186b9.png
# Processed 103/1685: 8506f89e6006e56379244f47257c61f1.png
# Processed 104/1685: fb5c47c4cfbcb9b6d352f1bdf960f01f.png
# Processed 105/1685: 8dd59b15988f0cbb701264c794a39b58.png
# Processed 106/1685: d4c357f38a4c4a45644e80585bc4a8e3.png
# Processed 107/1685: 30c01159493adafc50c4ff1ef5bfa7cf.png
# Processed 108/1685: 39172fcea2124599f579033909a2a69e.png
# Processed 109/1685: 4424b600d95a2279c8750d66e8601883.png
# Processed 110/1685: 81a96f56bd9d0f3dc9c5b44f8de35b28.png
# Processed 111/1685: bb1ceddc4ff714c59909fb8f1744fa50.png
# Processed 112/1685: eb688500e811d7888ebc8117ef752ed8.png
# Processed 113/1685: 3195cb96f24eb881a3706cdde222b077.png
# Processed 114/1685: 9d7d4cc8b6e6ece88ae7c258581509b6.png
# Processed 115/1685: 1e5cdc686b4daa96a4c259c5dbd6a011.png
# Processed 116/1685: d1b75848f14302af9dfe848801a1b9c2.png
# Processed 117/1685: 8a3d02d9f86a4b388a2109efb3f52b2c.png
# Processed 118/1685: 0048f0d9a4d0ca697e31077bab7b2471.png
# Processed 119/1685: 96be94edbe1767b7ca69b0788b611d65.png
# Processed 120/1685: 21c37e676a0b0ee275978717405ab71c.png
# Processed 121/1685: 752c4352c30387a2ad7f20636c451649.png
# Processed 122/1685: 11677eada1036437abb6be3cd1a7a816.png
# Processed 123/1685: ff7f4b409608b24da7f6d678170e4600.png
# Processed 124/1685: 575cc04b3472b3fb549bebd7f01cf5ef.png
# Processed 125/1685: b1860cf92d0eea264f09d74345a3559f.png
# Processed 126/1685: 32a8419c3f89664423ed0b43e49eabc5.png
# Processed 127/1685: eb71739176acae7bc31cc802ad9cdf50.png
# Processed 128/1685: ab95fb90ced391f15f4f32de9474942c.png
# Processed 129/1685: 29f425428472d6afc8b92d6659ea2681.png
# Processed 130/1685: af9c6db3d592f5401459cf86f4eac1c6.png
# Processed 131/1685: eb709f90cfd20015a7db73691694082b.png
# Processed 132/1685: 190fbba1e20d2ed47a7c7157454b2fd0.png
# Processed 133/1685: 855aedec817849487bdf5cb0dc1c9a2b.png
# Processed 134/1685: 40e28fbfb9d2b897c7ae9fa2c5ad09a9.png
# Processed 135/1685: bcfa43e611a8de45bacc68f663c55b4c.png
# Processed 136/1685: d2a226f0082b53ef41310a41299ddfc1.png
# Processed 137/1685: 79ad346965a9fcf561bb7a3e37fd31b2.png
# Processed 138/1685: a278824db1e387ed1fd88616f3eeafb4.png
# Processed 139/1685: 9f3de278a2f3b57a19ead739e6a3dbf1.png
# Processed 140/1685: fa665f1f990e7a3351f71b57b7cc5676.png
# Processed 141/1685: 802a7a8ef2574440936ab2ff66910478.png
# Processed 142/1685: 653658d0a0f1e3605ce923cd7686fddd.png
# Processed 143/1685: 7ccc4295f208c37c1a9d716ea89f0689.png
# Processed 144/1685: 492dbb0caf40e0191a5893ba446340b1.png
# Processed 145/1685: ff8346ed1a1cc3f5e032c74eedacb67b.png
# Processed 146/1685: 2b96bed2eb5f31b4e23a182ea9b64668.png
# Processed 147/1685: f79521c177bb7a789c52895f657bbd68.png
# Processed 148/1685: fbc57b8ab7b9bdcfb4fa3b8057375e5b.png
# Processed 149/1685: 2f1bb64aa1ee2738934749a75ca781a3.png
# Processed 150/1685: 627e11b81dbd7b674317c617297fc1c9.png
# Processed 151/1685: 2703b5446db4c0e6a879a0a956b0ea3c.png
# Processed 152/1685: 9324e632fc6dc3e131f8afbe1980d351.png
# Processed 153/1685: bbe01bee36de324a915cb410e0258ca4.png
# Processed 154/1685: c1a7add22560adeaa7b46eadbb2e817d.png
# Processed 155/1685: 552ad40b51b37d62dd3d81aa920884ac.png
# Processed 156/1685: bc9bf096dfa85c157d143e1a1a785a5c.png
# Processed 157/1685: 5125503dbef7250f2ee8ec90398a8dc1.png
# Processed 158/1685: 88f7c247ea15ab0f83b5467370eea0fd.png
# Processed 159/1685: 069110c97a0e41150a796b102ea2fc34.png
# Processed 160/1685: a2816558f4b77c94a00d32bb4ef3e1fd.png
# Processed 161/1685: 0bb67025dd6bf440b3b449079e9f669e.png
# Processed 162/1685: 20aa75de1f51616798f339898110cc9e.png
# Processed 163/1685: 9dbf86fdcce1718d44070ab28e606d15.png
# Processed 164/1685: 9a9d249f2bc4275073b2db717f7c6c85.png
# Processed 165/1685: 488cc65802a42dde45d0de1288047572.png
# Processed 166/1685: 0d1ad1c54cdc7c08cd6653c0fff4e015.png
# Processed 167/1685: 286cfa7cd878c0fd8c7f648533079591.png
# Processed 168/1685: 5a2fda1dcc8ee071f0751d37dca4a02f.png
# Processed 169/1685: 8b81fd94c8c5647422f90b2af69f2385.png
# Processed 170/1685: f59aa199212f45ccf873dc419e5d3364.png
# Processed 171/1685: 7e6acb71fbd7adda43221a926980f555.png
# Processed 172/1685: 8be274d24389e5b505ed2092d667465b.png
# Processed 173/1685: ecdbb52c57fcf539684c347f00eda3c3.png
# Processed 174/1685: fd4be7654c1c4787f013f05597c80fe2.png
# Processed 175/1685: bf95e9462d06359006364c8d995b9ef5.png
# Processed 176/1685: 4ebe692544d6324dbfcb5b9a080993ae.png
# Processed 177/1685: dcef50d19b8caf6ef6c35e2331cbe8cb.png
# Processed 178/1685: 785c77ab2bb34f03247846c2513fcce8.png
# Processed 179/1685: 6c57d31c45e9a1c7e6ce87d65b351bf0.png
# Processed 180/1685: fdc14280d25dfa3023714d5742998651.png
# Processed 181/1685: c3e1b09acc589509cad22820c2d52c4b.png
# Processed 182/1685: 2a3e9fdb39379765a98d8ea9807647ff.png
# Processed 183/1685: 9d06e94da6506cbb2b6e6135033becd7.png
# Processed 184/1685: 96f8e47426bd49c283f55ecd62d8835a.png
# Processed 185/1685: b4030d21758c33a0a809cc13eddaeacf.png
# Processed 186/1685: 0ac042b94e0869b35bd437fc6eb05b04.png
# Processed 187/1685: f4d59c99f8079e63730ae8b2fb534d13.png
# Processed 188/1685: c0bcbf305026de0f2c098d91920cfd08.png
# Processed 189/1685: b6ff8c41417e8a826abca0b373a2b9ca.png
# Processed 190/1685: bf8eba1a2fa6b940a8c5a244bd776456.png
# Processed 191/1685: 037011efaa50680c6a2b79c6a6ed86a4.png
# Processed 192/1685: c367aab9720de01cc1ba5970806f7a6d.png
# Processed 193/1685: bbef2241ea1ac71aacb2d0b6d6610565.png
# Processed 194/1685: 161faa60c553941923f72d7399f43ca1.png
# Processed 195/1685: c28e9150751cc201a2cd05c54fd54d12.png
# Processed 196/1685: 4dc79c2af500c2ffa5808c26f23f1a02.png
# Processed 197/1685: c6dca5ec8b7ef324c6f0a36d68b2c458.png
# Processed 198/1685: 5790ce68d207cd0cc10ac49fd2b96346.png
# Processed 199/1685: 63b2e77adad6a70714a4d5442b8a262d.png
# Processed 200/1685: 02669c3d6ecee7a8599a75cd5a928773.png
# Processed 201/1685: df2ccc2f68d7ef938f6f2bba5c451398.png
# Processed 202/1685: 2d66a730d8b339d5ebf9c40c83bd3399.png
# Processed 203/1685: a26d6de966fa2ff973a1d5896137347e.png
# Processed 204/1685: c0f8aed2361f80bbd8e0071cda89bd79.png
# Processed 205/1685: 6bf18e66305adeb3fa4aa36f67a0efd5.png
# Processed 206/1685: c103e26d1b69dd330ecd07d636e86d8d.png
# Processed 207/1685: e5ea13f94a1658e5fdc6ac8d61724d8f.png
# Processed 208/1685: 2d8064b4a85e8960b0d1ad7397d7d0fe.png
# Processed 209/1685: 2e8a9f1b8a6841486906cc5ac5c17dec.png
# Processed 210/1685: 78056f8ec7e0ec4d6ccfd230f0b50a5a.png
# Processed 211/1685: 3743c766445b8be99d1ecbe80b384f5c.png
# Processed 212/1685: 40968671ff00463bd75ef4ed5d598909.png
# Processed 213/1685: 9986e16c6f16a2e0055852fcaced22ce.png
# Processed 214/1685: 2cdc729ca88ad1283fba138282402f8c.png
# Processed 215/1685: 397306c3550cdc38c5be7b912af9cc76.png
# Processed 216/1685: ecb589267360ed5296d567c064d7baf2.png
# Processed 217/1685: cf5fdb1dc898bbad98057d7f3806868c.png
# Processed 218/1685: 3eb44faf9c0f3d0d54382ec8cd4660c8.png
# Processed 219/1685: 755eb5087083251f4c23d9760b3d734a.png
# Processed 220/1685: 03b72c7a6c098a3bf74b6c8b374862d7.png
# Processed 221/1685: d12008e55e8a160add781650c7538f9f.png
# Processed 222/1685: 7ffa6e0af481a82e7effaba723358744.png
# Processed 223/1685: bd8af3c7f1bf29dea1d7444140574679.png
# Processed 224/1685: b01f38fcd073ae4d2a01f190ceba50db.png
# Processed 225/1685: ec52f9ab3f55793bdfa38392e7aa9b4b.png
# Processed 226/1685: d157b4e3079350200f31142b33e0da76.png
# Processed 227/1685: 6819284bd22b11b3ca449d705ca50acc.png
# Processed 228/1685: c58f667e1222cd0ed0c75e519fa317f8.png
# Processed 229/1685: 1f23261fa02c007a8cd02b0e6bdad49b.png
# Processed 230/1685: cc26f63c5618e305e1f07c2cc6b76407.png
# Processed 231/1685: 59af0134404b9b1cd816ac00d510e5c1.png
# Processed 232/1685: 83d784fd6480dfb713475859e16192e6.png
# Processed 233/1685: c1d67e3d1c7c735d690b362c4fa7a0d8.png
# Processed 234/1685: c576aaf8e29b6059a0745ad8ab78cf05.png
# Processed 235/1685: 160f4c0bba99834d43037a23e709bf85.png
# Processed 236/1685: ab71b1c5c2ed8aa14da8d22291db96d7.png
# Processed 237/1685: ddd99be8701188cfcf3ffe639f527bea.png
# Processed 238/1685: f4df8ecbbdb67a2cc7ffaee999f0b97b.png
# Processed 239/1685: 0a15c19f92b0471622bc7251d9e1a603.png
# Processed 240/1685: b5bb3a5e8391065143147aab3abefe38.png
# Processed 241/1685: 93624e1dfb36d5c65fb3e06eb746ac09.png
# Processed 242/1685: 34275c448cca28277bd5f7e954a3b1c0.png
# Processed 243/1685: 949ce3d764de874a56a82f8196676a5f.png
# Processed 244/1685: cf209c3e246f290e0f11da0f6c00d568.png
# Processed 245/1685: ef565d5759c9fa758984c6dcc25f6b2d.png
# Processed 246/1685: 485eb8e75bb7b45c0b562ab810e1986a.png
# Processed 247/1685: 0af21e68710cfa7c354e3a6187398755.png
# Processed 248/1685: e49184085d8039e512fce58e0eb21865.png
# Processed 249/1685: 92f442b60313ef8890baad7fb20766f6.png
# Processed 250/1685: 7f23af8b5aedefcd5f70b9dfcdd6ad96.png
# Processed 251/1685: e755fe20b6e6b955b8a49dd25a8c095b.png
# Processed 252/1685: 87aef4c59494a194edf28483567c92bd.png
# Processed 253/1685: 4aa6e1af5e800af50b5a423ca0cd0a43.png
# Processed 254/1685: b40fdd1cb070a5cf4c8809978b0b50e5.png
# Processed 255/1685: c7283f44613f014f67fa714adfd3ec1a.png
# Processed 256/1685: 325aa50c277e5ddb5706a9ec6d61cc7d.png
# Processed 257/1685: 79e52232ac5ef79362fe5f48529e8798.png
# Processed 258/1685: 15721dd77038a50f15a08207a305f61c.png
# Processed 259/1685: 3498b68ec0f0d5f758aeadcccdf9a8aa.png
# Processed 260/1685: 2c31fc56ee9edb5094dd7eb52815d768.png
# Processed 261/1685: 57a8bfa6b7d0f3fdb0210331df1f2c41.png
# Processed 262/1685: 5843f1b81674a36b53c31d7072b57984.png
# Processed 263/1685: de8c45e243443a2ddb8c8e9ba5ced037.png
# Processed 264/1685: 73f4b76f1a2a7fc95d4f7b5e725e625e.png
# Processed 265/1685: 548286e2e4595e3924e403c03e50e2b3.png
# Processed 266/1685: ffc0f3dc8a700e4044d56a4af3e119bb.png
# Processed 267/1685: 8e786627aba9d56fe5525249cccb6fbd.png
# Processed 268/1685: cb608554776d5ed94343f8b5a16c819a.png
# Processed 269/1685: 88bff99f65b925fd2a91ad86db17a669.png
# Processed 270/1685: de90f1bc71fa544765b61a2766eb7fda.png
# Processed 271/1685: b993d893484fe5dc22dedcb22693fbab.png
# Processed 272/1685: 5e9dab314895508b3ed1083d58f3d1b6.png
# Processed 273/1685: eea18821fd633f55c49a140feae18bcd.png
# Processed 274/1685: 167bc1808c9f63207b13db6f099f6805.png
# Processed 275/1685: 56f18d69ff981de165b1b1b2286770d2.png
# Processed 276/1685: 15e0faf3bfe27f0f7b15597dffee3bdf.png
# Processed 277/1685: 9e597fb898e4de02cd984c1dc342dff6.png
# Processed 278/1685: df63c062f1a00d3523d85e78083e4747.png
# Processed 279/1685: 379253103e4f0df969a3dffbcb15b8f7.png
# Processed 280/1685: e9ecebfb89254d71d9e62fb150d3b755.png
# Processed 281/1685: 9ab26cb15339985722a9a39bb1c3ab37.png
# Processed 282/1685: 8f1bf5322897aa7ee247563ff300124f.png
# Processed 283/1685: ab4dc25e399ee2e351acf87f5898f1c1.png
# Processed 284/1685: 9bae77fb75422324bde7a25097bd6e6c.png
# Processed 285/1685: 7d31849d6bb12812934d2420f7b489b7.png
# Processed 286/1685: 27489efb50985545a576e0a6de565937.png
# Processed 287/1685: d718497958d720483b8185b0691af5a4.png
# Processed 288/1685: cdd375ee41e90703da52e047fd8fb628.png
# Processed 289/1685: ed3da27d430427bdfaf9b35d0e10b3d2.png
# Processed 290/1685: 973d2cb05b4870bb5924bb84e98fa236.png
# Processed 291/1685: bd8c2ed1a4ad7dd95620bf6eed5a7c6c.png
# Processed 292/1685: 59b31004351c9c4eccb693736c3805b3.png
# Processed 293/1685: b9c076778e4ac2d410ad5d60e59c47de.png
# Processed 294/1685: f67f5c5a79447cd23df45dce71ae9a57.png
# Processed 295/1685: b1c6ab3c41071995c88346479c92fbd6.png
# Processed 296/1685: 5dc6dc9e9cf28be2b97df3968c9052c8.png
# Processed 297/1685: 10bbe1476b74829c154c21a052c71afb.png
# Processed 298/1685: 8c0ffd9724615660a5a15ecf75b32fae.png
# Processed 299/1685: 8d3125fff6ff3bf91861751db5ddcf95.png
# Processed 300/1685: 28198cb55d6696a7d5f6cf68ec9df159.png
# Processed 301/1685: 41b5a3eeafd392dc808fd7eb4475f033.png
# Processed 302/1685: ff6423a2acc28152075ee024cff9ae38.png
# Processed 303/1685: bddbba4d513be6a6bfa5386ac7ee52de.png
# Processed 304/1685: 2f3c3ffd479253edae14549292caeeef.png
# Processed 305/1685: d6b80dc0494736c96b6655db1aeb8e57.png
# Processed 306/1685: 36dada13ed0bd1f9e72472c5cb2e49e4.png
# Processed 307/1685: 153710e4668b168cb601ded5b7415507.png
# Processed 308/1685: b0a9bb8fd61debeb386f20e5851b22fb.png
# Processed 309/1685: e2fb8400a78623c7ebb932000e912650.png
# Processed 310/1685: c2b42a28e6de9578ae93722cb6f9a081.png
# Processed 311/1685: 8ff6cdf633ad56b2f70bad1cdef64b08.png
# Processed 312/1685: a546ae081467e6aadd4073d2b0770a46.png
# Processed 313/1685: ce8d2c9132b3bb0173de55063efe3eea.png
# Processed 314/1685: fc88eae4f0e03aaeda5624777f5c971a.png
# Processed 315/1685: 8ccc25680c6a964de335928f957b8a85.png
# Processed 316/1685: d5ff0016a59515d00fa77e1ab5d01519.png
# Processed 317/1685: 606a19935f7225eb67df90f830ac2f8e.png
# Processed 318/1685: b60dba3890affcf3608832290c07b49c.png
# Processed 319/1685: 57114c24ef0f544702fb5402a8d0043c.png
# Processed 320/1685: fa9eeb81726b3ec4705848d0f577d5f5.png
# Processed 321/1685: 4dea45c4626227a6a9fbf445705b0dd4.png
# Processed 322/1685: 4b637cfbcb24de2ee43de49fd96546dd.png
# Processed 323/1685: 215a3bb020099c9267be23cca69b73af.png
# Processed 324/1685: 89e44f418d90e87d86f161b7c09d37f8.png
# Processed 325/1685: 3b360a6d55c27c3205c2fa3e55e81f3d.png
# Processed 326/1685: da9279f6de24f3168555ec34f1e80073.png
# Processed 327/1685: f5509032119f3f49abbfd83c05a4a2fc.png
# Processed 328/1685: a8d857fc1d2e5cec1bb6847771a343cd.png
# Processed 329/1685: 626993159f03603c1b3d09ebed91ed68.png
# Processed 330/1685: bdd67c43ff2fe8bdcd0af285460cd779.png
# Processed 331/1685: bf83640466008629b80be860355cdd95.png
# Processed 332/1685: 49a9d2b92f6bfd38ffaa7b22d5d1dc34.png
# Processed 333/1685: 9afc5dfe7df570de896c3842f6f77281.png
# Processed 334/1685: 78f414a21b87a75f202b036466e9beb1.png
# Processed 335/1685: 5d75ed1aa2d070c0db29aa080c378282.png
# Processed 336/1685: e60efad54896b7e53250cfdb69d17778.png
# Processed 337/1685: c697fccdab8ed8ebc9f92880c1269c33.png
# Processed 338/1685: b93fbd3b2e8cb0b313f7f277a2c306ca.png
# Processed 339/1685: 4e4c58647739c3f405abc005dd3f9f3c.png
# Processed 340/1685: 5d9f80dd9c6a1f73ff15c9d21100cf86.png
# Processed 341/1685: 87c9b38ce9c5df01a667e68be7ade391.png
# Processed 342/1685: 62e17151a797df1dcc84545a96e2f173.png
# Processed 343/1685: 3d6ecc079138b4641dcb6883199ac2c7.png
# Processed 344/1685: 0b822daba6492d4ba392b4cecf7b2bec.png
# Processed 345/1685: 1f97f4aaee7b564c6d1089a61f29706b.png
# Processed 346/1685: 449a68d6df87ec4ccf4fe22b6750d1ba.png
# Processed 347/1685: bb6bc3f135447ca2d5a35aa4d522208b.png
# Processed 348/1685: 6f13e7e719eef49a878f4c7b65ba0647.png
# Processed 349/1685: 781d7cdb74f68eb1c988b8286fc712d9.png
# Processed 350/1685: eee703f7a9c378478989c7de72dfe545.png
# Processed 351/1685: 47f0dc47eb53279d1669efd0e3124864.png
# Processed 352/1685: c5cdf4e0abc3890c23bd54324c5dcf05.png
# Processed 353/1685: 76e8c02635b7683b4172c6039bd1b726.png
# Processed 354/1685: 13d080ddca94def7de1aa13603187899.png
# Processed 355/1685: 6b1477ccbffdc54ce5adaaced9f39a75.png
# Processed 356/1685: 512a38c920312bd5fa90e90362e9975c.png
# Processed 357/1685: 83cb7e5ffa2232398367138cc24bfd22.png
# Processed 358/1685: 7470380cbbeeced8ed9b48d07e291969.png
# Processed 359/1685: ba3660a742bafd25a8fad81dc26e5eff.png
# Processed 360/1685: bc485f4b083e1b72bf2570ec94ef94a5.png
# Processed 361/1685: 88a788a07a1c46b836f8d8c0c990428d.png
# Processed 362/1685: 8b10c204473895575b8c5954d9494c87.png
# Processed 363/1685: 384cc0482e6761bea7629fb9295b3076.png
# Processed 364/1685: 534e80debf31948b07877c51e88c61cd.png
# Processed 365/1685: 2947a2a776c51657a8956f92382e8d49.png
# Processed 366/1685: a037ccd895daa3afeb7a81643bee4d45.png
# Processed 367/1685: 5afc09db0c9abe977e50c671618a8347.png
# Processed 368/1685: 4c2587db4d0ce9b298c59637f625d259.png
# Processed 369/1685: 763dded6dd2e32052374af718bc634f5.png
# Processed 370/1685: a17be37643ae192502d2296ed74b9600.png
# Processed 371/1685: c139107a84f7c37c927be8e618ee3619.png
# Processed 372/1685: ec64270ea2857c65e838165054661709.png
# Processed 373/1685: 49dcfe9d61d0c8ce45d868a7ee5f9184.png
# Processed 374/1685: 255c1696e18c714d0045bc2bbda06147.png
# Processed 375/1685: 43bd37d83fc737323bdb52e121039158.png
# Processed 376/1685: a7cd79e76f988bc17716b3e12a4e166b.png
# Processed 377/1685: aebe86dba818e68647ea9037640b6ec6.png
# Processed 378/1685: 2dead5a8d24cbae03e801cac3f00f32f.png
# Processed 379/1685: 3f234edc1f6ed81fbc0ad1b75c932811.png
# Processed 380/1685: e0b1ee3e5dccdb39da3a90cd0ef6bbd4.png
# Processed 381/1685: 25ba0b189c02019e41c8af90191a09dc.png
# Processed 382/1685: 34e404415fffb50a26f7ddabe157b678.png
# Processed 383/1685: 1a7cef1e42678cf622cd26af55fe47fb.png
# Processed 384/1685: 15976feac857bc336d1f7913f1e59874.png
# Processed 385/1685: 7552c79011a9fa638537b874c3ab5acf.png
# Processed 386/1685: b25ccf81f220d0b7c077ca85c2f42e14.png
# Processed 387/1685: c55be9fa3208fbbbddbae751783854a6.png
# Processed 388/1685: acbfe068796d16231dd43eb846814a5b.png
# Processed 389/1685: 1ff023a65bef1439e7269e98749485c4.png
# Processed 390/1685: 74765e4410ab7a058aa463030e3b249e.png
# Processed 391/1685: dc084f43879b1b9c8fdf92be8a582c0b.png
# Processed 392/1685: 78676fe9bcb128728e59cdc1a060c14f.png
# Processed 393/1685: 004a5121131d22f1c1d9f63828442577.png
# Processed 394/1685: 35a636cc7233dc08f9e1d029140af57f.png
# Processed 395/1685: 96aa03863eb6fcf09f45d6b1e6b5e1d5.png
# Processed 396/1685: ae80f183144a43e2e172ec2daa122754.png
# Processed 397/1685: 10a2be84b70fd9d999d8ed74613cdc55.png
# Processed 398/1685: 2ebd110ce6e3d1f4204dbdd88c5aee98.png
# Processed 399/1685: 543c7fa85fe385d3175a85326df15178.png
# Processed 400/1685: 5d94f870fe78f425b77127059ea79c39.png
# Processed 401/1685: d67398bc5f9b65d5b30b0cc06daada3d.png
# Processed 402/1685: b0a2deca2c5be991a0a2f20c4b2a8254.png
# Processed 403/1685: 06e8b5f8ea5aa29958fdb640f8a568aa.png
# Processed 404/1685: d7a95ec0088dfd9d654028ccf1542e1c.png
# Processed 405/1685: 502d1b145ed3747d148eec8609bef786.png
# Processed 406/1685: 99647b94ea0797c347d66bc6c4d6efb4.png
# Processed 407/1685: e9bb02b92851b0af304b86c04fd11d66.png
# Processed 408/1685: 168ba8a45eac2b8b8eacc5d8609edd37.png
# Processed 409/1685: a05f9dee95efb23091bc16a002ee4ee9.png
# Processed 410/1685: ecb1e4c4d6516beea661cbadd7216ca7.png
# Processed 411/1685: 7ba1a41759b1d449a4ff9648ff3477dc.png
# Processed 412/1685: 08c23af5e9d96ffb8e6a60736d33486a.png
# Processed 413/1685: d49a15583913dfa11ef7922a5d70631a.png
# Processed 414/1685: 233cc4a72d1daaa4bd520c099ee620c1.png
# Processed 415/1685: d7f2f29686f264b81ccff086df1291e8.png
# Processed 416/1685: f0b374fd249a39a136855f6c3123a9c8.png
# Processed 417/1685: 595717cea5972cfa46151afe13b9448e.png
# Processed 418/1685: 08319b4397090ed675ef926bae1d349b.png
# Processed 419/1685: 7e8432070dad71c917cbea7e375fde35.png
# Processed 420/1685: e9f3446580bf2424a77681110d27b74d.png
# Processed 421/1685: 121a7f93a0f91ed1d810f5534921ab69.png
# Processed 422/1685: 7cb170a6b62067c6a8db277f7d16f7c5.png
# Processed 423/1685: 0d3cd4eb2251604e10d7c05d1b1c1b38.png
# Processed 424/1685: 83200b70fa7c69f212c5a19377a21058.png
# Processed 425/1685: ee70da6d8545a66d35f4dc5b4d2d5ed5.png
# Processed 426/1685: 8a5d83f07e233c9ab068e196c08ee6c5.png
# Processed 427/1685: bfebcd6902c074268330a12bd331b722.png
# Processed 428/1685: 9d85023eec7409f8a791b8a9f6d1bb91.png
# Processed 429/1685: ccbd2b25230432093131126621298fe5.png
# Processed 430/1685: b985a2855c1290d51fa468981e3e3aba.png
# Processed 431/1685: bf4bea3b7b1363ac29a4d90fb6b9e2c6.png
# Processed 432/1685: a2e131f0f956d101b97aadccd6c4b82a.png
# Processed 433/1685: e14cdcde3205ecbb02369b350bdad7d9.png
# Processed 434/1685: cc883f7c617720066316c6b63a8e5c30.png
# Processed 435/1685: 73cd55c39e3a48bd638732bffd6d5782.png
# Processed 436/1685: af032fd4020bde9ddd2d763237231c04.png
# Processed 437/1685: 4c10c69d36a4b45d3d3b9f23810d9f9a.png
# Processed 438/1685: 4e360d8b0ccceeef5d275e44f18bff5b.png
# Processed 439/1685: 4dace0822bda4c8d42c58172a543c636.png
# Processed 440/1685: 8cb3215848792be76c42f5f53e84d429.png
# Processed 441/1685: 312fb2fd2815f314d82e54bace909cc5.png
# Processed 442/1685: 245f415f0c1676c8d32498b5baf981d3.png
# Processed 443/1685: a49f1fe406e211e11a6e05583b198a02.png
# Processed 444/1685: 988ef18a130fca5b137158c61bbe3318.png
# Processed 445/1685: 2df7762767062c6475c3c607d5dd2259.png
# Processed 446/1685: db18db0774633c1eabfae2b4de2a5da5.png
# Processed 447/1685: 404495b0798486816c59307f954109fa.png
# Processed 448/1685: 6d3dff4ed0da94ad63d7331b5c988118.png
# Processed 449/1685: 4082b79e28bee2b375af7c75b02f093c.png
# Processed 450/1685: 00eb5c77f79af6aea1fcf21184c1bf52.png
# Processed 451/1685: 8ad86851dac865e1f30a7077bda45c35.png
# Processed 452/1685: 9a43ab1cccd6121945b2358d29bf9ab5.png
# Processed 453/1685: 4b8bd107c9c250e73b64668abf5c7288.png
# Processed 454/1685: 28718f83bfc7b73233eb932cedd80559.png
# Processed 455/1685: af2970e7eef096d8ff992e60c56597df.png
# Processed 456/1685: b5ad481eb3b23c19db344357ca0114b1.png
# Processed 457/1685: f8e9031cacf69ab44ebb5db40483166d.png
# Processed 458/1685: a25776482a3501d50ce581450c899c92.png
# Processed 459/1685: c3e88f4b1659424baa9d33fd52e4914d.png
# Processed 460/1685: 6a37862985ab33dda18aa6743efbac17.png
# Processed 461/1685: bbf76efce1f4ca2a0dee50a439b31900.png
# Processed 462/1685: ed3a90cef0a8fae1d2cd87ce57294a93.png
# Processed 463/1685: d45930c86dcc37768b36306682b74d23.png
# Processed 464/1685: dc567997daef596835cce05a0c6f770f.png
# Processed 465/1685: 5dc846e222f8753f85954e7e278562d0.png
# Processed 466/1685: 1ce46c28e856b4c3598d0add4b37e856.png
# Processed 467/1685: d7e23b2f00d29d0a3abe26d021d3c113.png
# Processed 468/1685: 994fda1a11de04ebfcad96df1140b4fd.png
# Processed 469/1685: 3d83340cc5ec57ec2e362a908886fbc0.png
# Processed 470/1685: 255f607850cfc30661c587cf176b49de.png
# Processed 471/1685: 8115bf15d80905afdf503123ed72b237.png
# Processed 472/1685: 53a93fbfca4c94798d98d8a4d9fc893f.png
# Processed 473/1685: d1934a0686f64c5a9683ffc37d9555ae.png
# Processed 474/1685: 1794cd1190b6fdaee9916423c44999bb.png
# Processed 475/1685: a94d8df8078213b1effc5607e9322b3e.png
# Processed 476/1685: 05d0675bdef881dd918f023dd82d1d3f.png
# Processed 477/1685: ebc86d015742479ddfbbbdb3ac331262.png
# Processed 478/1685: 958684efb22b7f75d7128d415d67f32e.png
# Processed 479/1685: 73c891024dd0da3a58c1938dbb9c4858.png
# Processed 480/1685: e19bf1fb9cda9422d4b46509e1e87b0e.png
# Processed 481/1685: 44105e0dafc15bb50db8da9ef6e9eadb.png
# Processed 482/1685: fa60eee68b52956afd57c4fc13c9e310.png
# Processed 483/1685: fd0b224acb0013906f087ecd0990fc21.png
# Processed 484/1685: 96db72d493fe8476b6bea10764a143e9.png
# Processed 485/1685: b19e173cda4594e4ec3436460250a13e.png
# Processed 486/1685: aad3b972b7d0f93a4be222dc42c6a753.png
# Processed 487/1685: 3e1ddee659c761698241ac80bbe7058b.png
# Processed 488/1685: 17a8c94bb42dc5f76da774b98c4b0955.png
# Processed 489/1685: 6f5e958e37db4d90f0452366a20b78a0.png
# Processed 490/1685: c9aa8e5b6e2f633cc56c315e4dd3e9c1.png
# Processed 491/1685: 7cf77c3340cf3eb7ff037fd34cae682a.png
# Processed 492/1685: b4a08583cd98ed1ff83f5f502c34d33f.png
# Processed 493/1685: 51dbd5a1dda2db7a1c09cc75eb892a00.png
# Processed 494/1685: 2487263389b22f6d3c7614984abe0f81.png
# Processed 495/1685: d8d30acf3cb642b6387f371b59d20c35.png
# Processed 496/1685: 9a4c02f61b3cddae196d96e0699f0e59.png
# Processed 497/1685: f4d3a6342766aec30ea474a03ca0e6ba.png
# Processed 498/1685: 07cef07cafff0a43440b664809454ab9.png
# Processed 499/1685: 7acc9546db48cc3097f2a1fe2a2e893c.png
# Processed 500/1685: 4042e11326a3b4d70c39122d49c84b45.png
# Processed 501/1685: 74ca8e60ec28026a3d677953bf1b5fa7.png
# Processed 502/1685: 592f7f5f53071024e69d4fb39a9eb0c9.png
# Processed 503/1685: dd2740c76bd0ebceb9170dfc7491ef67.png
# Processed 504/1685: 12f6a4300d826d637259e69026a68271.png
# Processed 505/1685: 4403edb61d8fb544fc3379d4d08e238d.png
# Processed 506/1685: 8a2658779b85b0ac7066cd46a5200bf4.png
# Processed 507/1685: 3ec79b27b8ad6588e5a2a05e8e846daf.png
# Processed 508/1685: 652c2f4c5bec9aed22deb5f6b734dd77.png
# Processed 509/1685: 756a9df10a4f14068f0d9fc6d04c3c51.png
# Processed 510/1685: eea23fc55c40435efcd548920f7b65e5.png
# Processed 511/1685: a7fd9dbaa33063b9d6e4b7ca86974254.png
# Processed 512/1685: 520be6ba7ad72848ce6d5b545758bbc0.png
# Processed 513/1685: a1531cf54394494ef329d8b2074ac3ff.png
# Processed 514/1685: ed523b54322590b818dd3c5a5b296e61.png
# Processed 515/1685: c48b9881ff23e81454bac55fdc908405.png
# Processed 516/1685: d7cf74087fae286bd72d0f50563f2cf3.png
# Processed 517/1685: 9442914dac18e6e79994b25c6fa86607.png
# Processed 518/1685: 479cc96084eeba4ffa4dc75873c7a748.png
# Processed 519/1685: a1980f90bddf01a580e2663c4d317e02.png
# Processed 520/1685: bb6bb014a971d78d7876545ccc353d80.png
# Processed 521/1685: 18fe2711fdb4ea379e30be70f9f8e2c1.png
# Processed 522/1685: 40529fe74961b21791aae9b043a0bfab.png
# Processed 523/1685: 065c62c0b4940fcba5b8ebca1fd3ae85.png
# Processed 524/1685: 11921ca147282e9960766ff469a0b91e.png
# Processed 525/1685: 5be123205de5dc72ba0bdf4fade4224b.png
# Processed 526/1685: 7b3bc51e35f575928024d5e3d46db9f5.png
# Processed 527/1685: f1fc23a15c66752aa87b8efd4f397e0f.png
# Processed 528/1685: a87e98f7a098255fc70291e60bf59083.png
# Processed 529/1685: fd741e7bb681c0f5920dfbfe1ee01488.png
# Processed 530/1685: 00e11c860f7b081a01e9c7f04405c40f.png
# Processed 531/1685: 70e569fd7311ab3f1d994300d64ce2db.png
# Processed 532/1685: cbdeb8c1c8bf13f59029a51a68edfc54.png
# Processed 533/1685: 90877c2bc5283b235e23ab16f5f2105a.png
# Processed 534/1685: e3b03e63eb441cfdb6fccda75c5978a0.png
# Processed 535/1685: 3a1c117e1a548737d896a2a4003690be.png
# Processed 536/1685: 53cd15a06b9548668c7e25d19d21e84b.png
# Processed 537/1685: 223d6034c7ce5082a53fb79f7cc84eb9.png
# Processed 538/1685: a2215b9a9331ad8febcb2e731fafaa64.png
# Processed 539/1685: 7904511a8427d2de8db19c35bcc00665.png
# Processed 540/1685: c060e037ebad24acbf52101f9295d1f5.png
# Processed 541/1685: 1842326bea39ddab5b958563df80ade3.png
# Processed 542/1685: 8b8b9863b9d07cd1a35ed5bd6583b5cb.png
# Processed 543/1685: 637e823c0998574e7982ba4f97c740c6.png
# Processed 544/1685: 059cc8bb024e0461a6b7e5fb5ac44d0a.png
# Processed 545/1685: eeb969636e82308ae3c4c26148be99a5.png
# Processed 546/1685: e81ee044cb29340f3a89ec65a9d56b25.png
# Processed 547/1685: 00112158c308d48307e95b841f678df8.png
# Processed 548/1685: f478bc2504e7db10b81e33df63a4408e.png
# Processed 549/1685: 617b529552b5439d966ce5abcddeab87.png
# Processed 550/1685: bb8995a93da46544afc1b9d2192d0bff.png
# Processed 551/1685: 71ba47294903f25a7a746a1e4538f7bc.png
# Processed 552/1685: bd62ae4ef96520bfdf1f86f3e2adfa31.png
# Processed 553/1685: 2f3813795c12219b4939ff8b521993b5.png
# Processed 554/1685: e779f1fe24d2912bffc5fe1370fde3d0.png
# Processed 555/1685: f8b23ad9d22f09e5e1b3e2649094ea2b.png
# Processed 556/1685: 09c62f1ac6fd201afa468632995b7a89.png
# Processed 557/1685: e013e913ef7fe198e30e8d5a9371b379.png
# Processed 558/1685: e1ac216c9bd7206a51fe44234c551287.png
# Processed 559/1685: 2290fb75108790c0e73c4e3d29943841.png
# Processed 560/1685: 10cfc2133d17cb891e652b6dbf3d8d6b.png
# Processed 561/1685: 5ca8b76c337a8c1eb7f4f41a17927848.png
# Processed 562/1685: f7f4a5507267d5c61f8ceddebbf73e66.png
# Processed 563/1685: e932c3cab71f6c1c1f4f544305404281.png
# Processed 564/1685: 40e8f59458cf0762b892ca4621a60b56.png
# Processed 565/1685: 387179df3d3cfc9ce2ebecf34cf57cd4.png
# Processed 566/1685: 4346c29723a6234d5606983896ab2852.png
# Processed 567/1685: 519af90d9fe8f0d55240707a4b8a8696.png
# Processed 568/1685: cef8c35f3aa5ed6076de8b5747451715.png
# Processed 569/1685: aeeef7a71c01d4b5f5fa82cfac93f33f.png
# Processed 570/1685: c3cb50dcd980349df8ec8929c9df357b.png
# Processed 571/1685: b291268f8e1eec729a343b4fba7ad64c.png
# Processed 572/1685: beace18dae008fcd5e229aaa20c1d3d1.png
# Processed 573/1685: 1b7ddf225ed6af9f9abee261e4f19ae7.png
# Processed 574/1685: 4c1002674bbda0a031873074fef598af.png
# Processed 575/1685: 40084a7df2648b3843b6feb06a2c079f.png
# Processed 576/1685: eb13152cfdaf6367ec5dd2ebf75f121a.png
# Processed 577/1685: 255b3ccc8bb781fb25687ccfd0775668.png
# Processed 578/1685: 156c03c547a2f35dcd8b849ea7219cff.png
# Processed 579/1685: 338b820a2077242d52b79c4cdbe56404.png
# Processed 580/1685: 5635f5bb70d4fece5f8210d7ed50f0b1.png
# Processed 581/1685: 2e8d0b7c08fdff515a14f52438c316b2.png
# Processed 582/1685: c176cf3baf526d399b5d151dc6cf722a.png
# Processed 583/1685: 41e9db9ce1bb9a0c7130e7b398c94f02.png
# Processed 584/1685: 2b8357aee7986fa0e94e8a511ab9785f.png
# Processed 585/1685: e5ed9c4a1650a2cf8fdd1645fbe75da0.png
# Processed 586/1685: efa2d4f0c8a6d519e4a8344d55802d6d.png
# Processed 587/1685: 989bff59428e03641ed1b021946755ef.png
# Processed 588/1685: 1b292812faf2544b1a7e7dc20b0d342e.png
# Processed 589/1685: a7468e6580d6519f282dace244bb1ae5.png
# Processed 590/1685: 95b501e7ee56f7e15d528fb94cc4ecdd.png
# Processed 591/1685: d04150fc6d844a80a6e60ca7fd452f3d.png
# Processed 592/1685: 8397d10dd76d1973523028a249e7f897.png
# Processed 593/1685: 2808bd97b6db9ede24687e7e6db454b6.png
# Processed 594/1685: 7f235f1637225a05e3afc2972e946fd6.png
# Processed 595/1685: 004e3469daa569584c9d56200fb93374.png
# Processed 596/1685: a20bf98908bf014e22c8cc0a23fe8a2f.png
# Processed 597/1685: d93dc85ec830dad17d276d50fc573ff5.png
# Processed 598/1685: c0765d1872d9be5f992588bc02e080e7.png
# Processed 599/1685: ffdeb035c2be539c6756bc3ba345bc47.png
# Processed 600/1685: 824a1467d6395a18225035781a005f5a.png
# Processed 601/1685: a2eb96337322a92761c472f0ee8e46fd.png
# Processed 602/1685: b3560c477f9a7fa45f71fe2da386349c.png
# Processed 603/1685: 415db3506fd69bd90835f5793c3b4d71.png
# Processed 604/1685: f001cb14be39484b281bb4bdc571483b.png
# Processed 605/1685: ab1dcab9ba233027f5598e62a5d5a237.png
# Processed 606/1685: ff1fedf7d131cfd046b8bc0ff719357b.png
# Processed 607/1685: a2bb6dcf1e0ce2f895934a80e5dc4b43.png
# Processed 608/1685: f8eac00927534ed8ed92d4289ec5f075.png
# Processed 609/1685: 35836c4b08276f0975ada4b9ad29d539.png
# Processed 610/1685: dec49c852c7ed3cc2749ac4842f091bf.png
# Processed 611/1685: 4d6aecddd4cd82594603171e2b20f803.png
# Processed 612/1685: 8e1767ef5b972d5004ff28ccb3a194a5.png
# Processed 613/1685: c8999132e7315e556f25ab67e4ba3443.png
# Processed 614/1685: da0c673cdc5d61da1f20821e4ab0216d.png
# Processed 615/1685: 02fee323c8dc9369ff27d2b31c085bb1.png
# Processed 616/1685: b37857bd390aa5513134ba5318890336.png
# Processed 617/1685: 2adecc5aa1fc38b73cfdeebb8fee46df.png
# Processed 618/1685: 283f8963fc79a6e33c844f368de409e8.png
# Processed 619/1685: 2acb1e6871621263fe77567fcdcbb622.png
# Processed 620/1685: d45584eb7a9a3d18da400a2a6b668202.png
# Processed 621/1685: 51bafa0b25e5de342f2fb1a4c35154de.png
# Processed 622/1685: 7fbaa0039294141c3b100766f688a3fc.png
# Processed 623/1685: 667e143b177d57afa84410c60893e65b.png
# Processed 624/1685: bd658b37374fc12ec8ebcc5e18a3d586.png
# Processed 625/1685: cd72001cda18cffd762e801e37bd5bf3.png
# Processed 626/1685: 20f7d56a4f6960eb4c5b0aedeafe437f.png
# Processed 627/1685: 2bd64834d2c82c1f53873da73e9f4860.png
# Processed 628/1685: 11c57ab8acb98db3ac1690263f571963.png
# Processed 629/1685: 24ede86a910ae1ff658feee7b934a6ca.png
# Processed 630/1685: 03df3cb5f07e1df317fbe5e91c68e8f1.png
# Processed 631/1685: 0b73679eb89c7015f1e976f6ae1f36c5.png
# Processed 632/1685: 22eb4e453876203d9f412db49b4d1c19.png
# Processed 633/1685: 3bf8f3d8ff76fb5aecdca217e30af9e2.png
# Processed 634/1685: 5d40fc88ab434654113b8d808670dd60.png
# Processed 635/1685: bd943c51252945cf2234291a784161f7.png
# Processed 636/1685: 52ecbb4d6fe71ca4c0bd26f3a78d11e6.png
# Processed 637/1685: 8b2aa9158874568d16b429039c83ac37.png
# Processed 638/1685: effb2f832d2b3c1f80f8d364dd839369.png
# Processed 639/1685: c460b2c0cf14830a73d82dbdb6012619.png
# Processed 640/1685: 9255578186a2e43c1f2d661ea588b128.png
# Processed 641/1685: 6a3fb8feb8a82b803081a1ffeebe15ce.png
# Processed 642/1685: b6172d726a29b03b557eb22ea24be855.png
# Processed 643/1685: ea9ac9dfe1ba58b28eaf2eccb7c3a14e.png
# Processed 644/1685: 0b7e1ee5cdbafb61fcdffc50981b1993.png
# Processed 645/1685: c2702983a656ea51b8ff6a392ccbddda.png
# Processed 646/1685: 401227853a450a533bbe8ade5233e266.png
# Processed 647/1685: e12a6010b92b734c558276e09a8bac6d.png
# Processed 648/1685: 309a6d9e3d918059bc0b730dc044af54.png
# Processed 649/1685: e926247cce45d99f5a67b42483e6647d.png
# Processed 650/1685: f05ab6af719ad917e5f296a3b4a25120.png
# Processed 651/1685: c5ff2eb4bddf65d6521de4af59d7670a.png
# Processed 652/1685: c81c2d51ff5c420a4e49d5a35eb604d7.png
# Processed 653/1685: fa5e3d125f822d912edf0c6574a379c5.png
# Processed 654/1685: b5f75fd9564faf38296fa0fb536fc503.png
# Processed 655/1685: 80d42776914e984ab8ff5bf0490aab6f.png
# Processed 656/1685: 3988347092893b849a381dcd3e10c9eb.png
# Processed 657/1685: 7e5b4c6d8fc62cf6961c69d16bb30b89.png
# Processed 658/1685: 5c9365e6878e6e735a4e781c270ace19.png
# Processed 659/1685: d02ac34f05fe028f35419d144cc8bf6d.png
# Processed 660/1685: 5b216a514766e1f1a7c0ea844c52a51a.png
# Processed 661/1685: 46ffcf1e956e0e34734eaa6922796402.png
# Processed 662/1685: 8b812a965ab1350c8468116c630c8c36.png
# Processed 663/1685: 8ce835b2339bd42b4bf25859dd7effdd.png
# Processed 664/1685: 04907501ae7c1c4168fbcf1fb7695769.png
# Processed 665/1685: ff6a6fd1f4073c54e8d1f802ecb16d20.png
# Processed 666/1685: 69a1203af3e186820139c7aaecf84fa2.png
# Processed 667/1685: 4fb9f926947609bb5256346796e3ed17.png
# Processed 668/1685: 713c43d58c19946cc6fd0f7a0ac4b2d6.png
# Processed 669/1685: e2c6ca198ab91430a0ac42c037ca839e.png
# Processed 670/1685: 2f499f4e7c61075f2a3e93c3595026a5.png
# Processed 671/1685: 4eb4b7101a3d3023e61f8f24265b4455.png
# Processed 672/1685: d6e4d45a17f4405180e38e593ea00f10.png
# Processed 673/1685: 47b20023638b46a6708110ddad2bd8c8.png
# Processed 674/1685: ff4499cb94dbd7c301e47749b53195f1.png
# Processed 675/1685: a7d38eb6163f7b88fb28f0e4b5d06245.png
# Processed 676/1685: 8b5cc1193cfe2ae2f52818e851d2268d.png
# Processed 677/1685: b269a291c6308e1d179d3100f834e073.png
# Processed 678/1685: 17695a959936cd1e924a99d86aff34a6.png
# Processed 679/1685: 0fff8ba1e2b76cf9359ef14d353841dd.png
# Processed 680/1685: 14c12d34cad63a099db78ecc52433323.png
# Processed 681/1685: dcd66797e476b7279edf645eb4b24414.png
# Processed 682/1685: 69afcb230089b796e6a5d1b188bc1ca3.png
# Processed 683/1685: 4d5fbf8f76654155b61e131262b5016a.png
# Processed 684/1685: 3d1266d552eb3c394defa057dc61b299.png
# Processed 685/1685: b591ca4a4d01eb0ceb7cda66bc4507cf.png
# Processed 686/1685: 28becf9e5d25a33fd38e8e8a6ee3eef4.png
# Processed 687/1685: 5c9d3085ea832530056d9ec4ae70b548.png
# Processed 688/1685: f772200e9e6dc0e4df5b1d5a55e3fd46.png
# Processed 689/1685: 08551c76f595acf3e83fb78ca95cf657.png
# Processed 690/1685: 3973dd1684c0f2cca44855bdb3b39268.png
# Processed 691/1685: 8958be13c51ab30e409a6d959ac7b071.png
# Processed 692/1685: 2cb9a90a04c48257f10ad6094a702b81.png
# Processed 693/1685: 9f8b422330b6f52f2aa6fb2b0c922fe0.png
# Processed 694/1685: f5721a1f3cc4f1731d1991b9a286b1bc.png
# Processed 695/1685: ac15e38ec265eba95d10b5b4bacb2a2d.png
# Processed 696/1685: 92bb9838af5b25c5679a3f9a4afe836c.png
# Processed 697/1685: 0cbe9be612128f3d394acfba8ca99cff.png
# Processed 698/1685: a6f1663f7efb37cfd39f2ee6d562a13a.png
# Processed 699/1685: 2b0ca2d0c57335e4cdeedc524c06e039.png
# Processed 700/1685: 89db211ff13c5bc9e86c7cb3f2dfe451.png
# Processed 701/1685: 4cb2bb8cb4249f22b2e003e2d490bfe7.png
# Processed 702/1685: 77ea5b5a2f189fb95a0f5e14efaaee51.png
# Processed 703/1685: 41e187222c28824d675a169e3ea136ef.png
# Processed 704/1685: f95c71c46b2b0a50161572b4c9a7c529.png
# Processed 705/1685: 00aefca158a6b773b8c466c9b715ac25.png
# Processed 706/1685: 382000015a51049f32d7b20a52e20ae2.png
# Processed 707/1685: f8cd66639e70716ae373290915797b63.png
# Processed 708/1685: f075a9d5adf95fcc384ae21459c6ad09.png
# Processed 709/1685: 669cd00bc20b275886ba813df82716b5.png
# Processed 710/1685: 01f677be480a55c0d93ab446ec22270c.png
# Processed 711/1685: 47a191a7b5cfe50445d22363f830ba16.png
# Processed 712/1685: 8b3e8d8bbf7e3fe959b88d4c54086581.png
# Processed 713/1685: c3379f1bdd707cd03120bb578a57376f.png
# Processed 714/1685: 1c5a5997210b5239c8abef2bb5450f1d.png
# Processed 715/1685: e0cd8ac90b26e7fa611ee8c79510e9f1.png
# Processed 716/1685: b087d28202cce0124349288c8f7ba6d6.png
# Processed 717/1685: 7868c1cde496830f253d380f76f17498.png
# Processed 718/1685: 45539c6e036c9d389e1181e88ec5405f.png
# Processed 719/1685: 5efb2048e3fd13d39428dfda1ff17776.png
# Processed 720/1685: 5ca44588ad2c2f1f79911e74e9aa4f1b.png
# Processed 721/1685: 5e77b8f358f849152591621f71e89e2d.png
# Processed 722/1685: 7ab95c7d7e11db8cb9c8b57ffa959297.png
# Processed 723/1685: f9424260cec3f88acb8e4afe29ae592f.png
# Processed 724/1685: 97044466069da7c63efbafd2ba0f02ac.png
# Processed 725/1685: 7c4d5e8d6b0b2003491178a33ad5e713.png
# Processed 726/1685: 467c5067b253a6b6ca3bca50b62a8246.png
# Processed 727/1685: 5734c27b8195fe781502fa94ab76854d.png
# Processed 728/1685: 3afff421fe34e556b6c156084f7c6d24.png
# Processed 729/1685: a09fd21f7942c1c59752deda4c27615e.png
# Processed 730/1685: e9d581bf2943c8f8bf1f9d15772b2d3d.png
# Processed 731/1685: ee2df76ed985690ba8f23d377b5ff273.png
# Processed 732/1685: c8fd3d2185b1da397330b5a923df910b.png
# Processed 733/1685: f8af988cf0468f627b211d8e8ac8e9ef.png
# Processed 734/1685: 2c739cd7a0e4f2ae017fdf2dde9fa234.png
# Processed 735/1685: 0ee7cb2c87559c63b733fb88f57f38fb.png
# Processed 736/1685: b52fbbb5fabfff273450109d18820da8.png
# Processed 737/1685: fd5605427dd8a648717fcf236ddb8a4b.png
# Processed 738/1685: 60ad4494035956d6ad0c23031c8f719b.png
# Processed 739/1685: 3aff484f69a914e6b5805adaf27d2b53.png
# Processed 740/1685: 6d32bb157f5e2ecfaad29b3f3637ace5.png
# Processed 741/1685: f943a369d651f02dd842bebead0d588f.png
# Processed 742/1685: ad64a2c2ff09972b97819897dfae2e60.png
# Processed 743/1685: 72c0073bfd425bcd91f8bdaae5e6a531.png
# Processed 744/1685: 28e62dd94ee6f8f4b63d6baf9e1083d9.png
# Processed 745/1685: c3ee58d770c2aa15dc78b83a4cd31a4e.png
# Processed 746/1685: 5af6fdb3bc6e598ec11ab7bf982f98b6.png
# Processed 747/1685: 7eb4234987e68433f8879f8701738187.png
# Processed 748/1685: 4d0c3bcff31bcb226f41067e656eeb8b.png
# Processed 749/1685: cafcccd726f33d2d0303a360e79f7651.png
# Processed 750/1685: de10958be0415162b0cb32010ec60779.png
# Processed 751/1685: b73260c6cc28553e39a2d55e77175e6f.png
# Processed 752/1685: d9e30aaadbdc3d9916e7c1f930c07b92.png
# Processed 753/1685: 360b8acee1993eca0460be5b722ada2b.png
# Processed 754/1685: 8edaa6090fbc4ee8fe4ea2bb15343a89.png
# Processed 755/1685: 608d7593ff722f056d1c8596c2f2543a.png
# Processed 756/1685: 7587c7edee852ee2740220a721413c76.png
# Processed 757/1685: 5a640e38758a2802d1c6d02bf58140f8.png
# Processed 758/1685: f11e961fa28beff6552c62036a23fca4.png
# Processed 759/1685: cde90e76c22fab1a90fc2768cab84e0a.png
# Processed 760/1685: 07ab35c36779bc36114e8317f5f002d2.png
# Processed 761/1685: c3add764505d37ff19c41b4af04b4e41.png
# Processed 762/1685: 340d61fa48742cfc873aa114bd0f63dc.png
# Processed 763/1685: 3ec96944ef471a54e177762296f64d94.png
# Processed 764/1685: ccd6d3ad9a3066ef644b5d2821e7bdeb.png
# Processed 765/1685: 218218963db9d89f764644c42f8c78f2.png
# Processed 766/1685: 761fba7e2ce478450c02b3317e4cd718.png
# Processed 767/1685: 20171b8e6a08b493e474914800b3d53f.png
# Processed 768/1685: c7a760e6956a7c8cd20a8a1115e5d851.png
# Processed 769/1685: 39b12afdf2d0aed93a76ab0e78226e01.png
# Processed 770/1685: c6a221067eec508aced29c7dce616e1f.png
# Processed 771/1685: 531fbdc486cc02e5761a757777b8ffdf.png
# Processed 772/1685: 019b87b3ffb4b3c50efee461335ea9bf.png
# Processed 773/1685: 9643e87098b89014965ecda4cfb8bd92.png
# Processed 774/1685: 17bee6dd2ff0647308316fb296f9105d.png
# Processed 775/1685: cd7cf9858c96760dd0ca05d73c1f1ca2.png
# Processed 776/1685: baaa6ac98f0046cd28cb449d57cda67b.png
# Processed 777/1685: 48c572ca1203d9437ce0c05de4e8c103.png
# Processed 778/1685: 767027483522b957d09f97cb5a0ccd51.png
# Processed 779/1685: 69e75dc1c61183cefb833829f981d4c2.png
# Processed 780/1685: fa61e17edc6b60fd06fdea909b0161f7.png
# Processed 781/1685: 168e9514ee8c381daf6ad6d11db93276.png
# Processed 782/1685: 16ff2ba57413a5542dbb257a0c79f634.png
# Processed 783/1685: e5c537d99a7a3ce82913c1f6f4feed0f.png
# Processed 784/1685: 6b4e7f770502bf964d6e7e13fa158c85.png
# Processed 785/1685: dc0f6bce59bd020cfefa452cf12338bc.png
# Processed 786/1685: 686b9f71c8324a7081c01f81041bae4e.png
# Processed 787/1685: d973ba5dc372f5da84c96272363e2cdc.png
# Processed 788/1685: 83e4a3336b5b12692a8b5d2c47a44182.png
# Processed 789/1685: d9d807bc715c3389f6952bdc41921fda.png
# Processed 790/1685: c342d1f2cbfb5b614f051343c855f3a2.png
# Processed 791/1685: 77ba0d2a1851d121d2213e9f548169fc.png
# Processed 792/1685: 8ad9f90064ce66913cbef0ed73c5e232.png
# Processed 793/1685: 8acd4d89cbd6deaca9e429d1c9fe95b7.png
# Processed 794/1685: 77a45accd2ef17f5ed2bbbea1b37a011.png
# Processed 795/1685: 9e39003db14cab3ee74167451b05fd3f.png
# Processed 796/1685: 9893e753908c4cf2f4e0a2ac2a49962e.png
# Processed 797/1685: ce6a18b963524812fa832312eeb42b11.png
# Processed 798/1685: 5886a15d980ea52e6e4cca4973b65a71.png
# Processed 799/1685: 47a2f99b3588e8823e9fe1073a1ad54b.png
# Processed 800/1685: 3fe8f05c8cc49d64dfef120a51f472ec.png
# Processed 801/1685: 4214176145afc602be0f02b2f57c59bd.png
# Processed 802/1685: d6f2c3746db8439bacd72f9c517f30b5.png
# Processed 803/1685: b0bd11f8922ae90a5a94fdb5418e8a3b.png
# Processed 804/1685: a5708fdaac809100f980aec5c3f7aa25.png
# Processed 805/1685: 8fa59e516d8f257fbfbf247a8683e5c1.png
# Processed 806/1685: 1d09dbdcd65c63921c61d8fa6bf040d2.png
# Processed 807/1685: d98076d0240a4b25e040e0e28b7bf03c.png
# Processed 808/1685: ab68bc65215d524273e70d3e106ae912.png
# Processed 809/1685: c7c3e9410b73c49d423067cfe2d361e7.png
# Processed 810/1685: e52d973e232487ddb2841f06067516c2.png
# Processed 811/1685: c9bbf4f8e010545ccfc65fcf3a92d431.png
# Processed 812/1685: fe56640b22474f4050df54c1c20376f6.png
# Processed 813/1685: e977d3497805a7963e53ccd518ad74cd.png
# Processed 814/1685: 1c74674370aa845e48ef0e73509cd265.png
# Processed 815/1685: 1e8fcd3458cd7fa572193d29e7e9a746.png
# Processed 816/1685: 158d817f4229eef9393cf9417d7c8000.png
# Processed 817/1685: 13df1e0f9737c8b5fff70c7914322252.png
# Processed 818/1685: 90a4adf4e6267ea9c9b74f45c986e9b8.png
# Processed 819/1685: a51a3fd4b7360583c3b65f4b67e38c8a.png
# Processed 820/1685: 9a968ce2fd2bbc8c63a21c15b615aee8.png
# Processed 821/1685: b6261b810133cd78ada9c8ec94fdd4f0.png
# Processed 822/1685: 37db39656b80bc12e96bce3f9ad71e62.png
# Processed 823/1685: ec39ffb10af3e88f90adb08f4b26611c.png
# Processed 824/1685: 384dc5302f84b3660201be969d7e9a1f.png
# Processed 825/1685: c71238494316c0aacdaac8c71bfae0ca.png
# Processed 826/1685: 6c29e472948e8485f43ffc251f5ee079.png
# Processed 827/1685: 71d765598fe41543996d1b622fa525f5.png
# Processed 828/1685: 483437310c3de0e31ac2fe75e9d4dddc.png
# Processed 829/1685: 3b22d315b86e32a79b44788dfce56143.png
# Processed 830/1685: dc95163e4e6b94507b73396e3124cb98.png
# Processed 831/1685: 7a4dffa1cfd94789eb35026fffe252a2.png
# Processed 832/1685: 6eedf087dddd033a288bf64a6e19d1b9.png
# Processed 833/1685: e3a0278cffc5a2ae81c49466ba36c922.png
# Processed 834/1685: ee8011aaddd21c3cb3d3e18a50ee4be2.png
# Processed 835/1685: 80e26c506cf1c28d59301f31d197d05c.png
# Processed 836/1685: 2765c15abab1c6701a9102edae1b6c27.png
# Processed 837/1685: 08ea924e3cced4678890cab320e0fffb.png
# Processed 838/1685: c7dd617f9ea14a9048a72cd29c80a14b.png
# Processed 839/1685: cd8f0dafbd411b791373afdcf9feb915.png
# Processed 840/1685: 12cf4e3779538c231835110f71322815.png
# ...
# Processed 1408/1685: 47efe467b290d860ef017777b073197a.png
# Processed 1409/1685: 86df57c76da2c6e0530205e41c4f7217.png
# Processed 1410/1685: 61f3b887616ce164606a5dd773cce915.png
# Processed 1411/1685: 59496439b73d70e891741e989ec55220.png
# Processed 1412/1685: 70887e0f7ac21f64ac9e74318e1f693d.png
# Processed 1413/1685: dc92eefbbb564980c59dc1011ad658c2.png
# Processed 1414/1685: db5b11027827dd10c3b02e5a2732e7d0.png
# Processed 1415/1685: 4a168b0d3d365a65b30bd119042d989d.png
# Processed 1416/1685: 1a30d59df8d3874793e90e18a2be37db.png
# Processed 1417/1685: a5627d2f54a7d93e03e77615977b8da9.png
# Processed 1418/1685: 7e97358039e1b28a0b44fbaaefc779b7.png
# Processed 1419/1685: 1a09ab458a895f11b74f3bc99b82812e.png
# Processed 1420/1685: 79092b590003ab900fa52983823477e2.png
# Processed 1421/1685: 9e57a11b0f0e497f72e839721a5776d3.png
# Processed 1422/1685: 14b2bfeb31cbad760b73b457bc18b3da.png
# Processed 1423/1685: bfb1866f004f67357cfba6abb17e2e6a.png
# Processed 1424/1685: 5c8401d0e47730a3bad72aae33a4788c.png
# Processed 1425/1685: 575d67c072ad20075e6a1ed5d220c1cd.png
# Processed 1426/1685: f6aff3e542d4101fe9ac7cfa6ee4439a.png
# Processed 1427/1685: a0417510f1b73258119f4e4ebed3ff58.png
# Processed 1428/1685: 982e9e253a05691127925e4b660e7ebf.png
# Processed 1429/1685: f18950171abe6dcc208d24926524e5ee.png
# Processed 1430/1685: 23ad1de297064d3fb9115b3851e874cc.png
# Processed 1431/1685: 18f185b407818f8299c115eaf6b7ff51.png
# Processed 1432/1685: b334c67a3eb83f19c08825ab653bbc5e.png
# Processed 1433/1685: 92519b29c9247167ce6ba785051b0161.png
# Processed 1434/1685: b90ed5dfb5e3d249556aa78ffdf6cabb.png
# Processed 1435/1685: 96b999cd4a7e7b7567f1ea94aaa34e90.png
# Processed 1436/1685: 6a0a6d1787dafc66ae23fe78a6e8c309.png
# Processed 1437/1685: 2e4496d776be97ce4c5929eb49b35972.png
# Processed 1438/1685: a756d78b355fff2eb44cce2cce62693c.png
# Processed 1439/1685: 49ddec58a59b3de7eeec465e619bd300.png
# Processed 1440/1685: b9d69cac5898c412cbf24a9c3dfc8121.png
# Processed 1441/1685: d18c12ca711a18c303bb16e579e802bf.png
# Processed 1442/1685: 94db8d20c9a9ce461bc971478aad861e.png
# Processed 1443/1685: 06e1a904f76eb330225be20b8896972c.png
# Processed 1444/1685: 5206e812a0eccce817202589e83442d8.png
# Processed 1445/1685: d82f3e0aec65938d369cd4a26a5b1140.png
# Processed 1446/1685: 501fb5662cce3ee701430af21e055b40.png
# Processed 1447/1685: 105b3f10cbaa53c0eed32626f4160308.png
# Processed 1448/1685: f68b5148e4f478253228388230414a41.png
# Processed 1449/1685: 32091eda112507d7213d4672bfc36917.png
# Processed 1450/1685: 87aee1774f082abc56b0f0851592a4f4.png
# Processed 1451/1685: 9f2fb4fb493696c882ccb6b97ea4fc71.png
# Processed 1452/1685: bba510e0f52400d6d0a853d74216ebcc.png
# Processed 1453/1685: e06a68756933c57e7e40ac9dff11adc2.png
# Processed 1454/1685: a62a7cc1fd610ce932418186c1c13ae2.png
# Processed 1455/1685: 7e80e420f113e6f22b7b3dfa8fb22a55.png
# Processed 1456/1685: f5346ad90f716bcb27a9ca8fef0bb45e.png
# Processed 1457/1685: 91434a1438c3d9be1a5d2360c25560ec.png
# Processed 1458/1685: 0795db786cd4b66ea51a47923df4d3f1.png
# Processed 1459/1685: 171698bedc8a4e23568e1340f9805b24.png
# Processed 1460/1685: 794f62f22fb7e83ea3158fcbd014d356.png
# Processed 1461/1685: 91cbed32dc15f08a1069a61a2313d6da.png
# Processed 1462/1685: 9586938a1a6e0bad16ef77bfa77d7fdc.png
# Processed 1463/1685: 0ad031e1f4a0f6901f0b7547e5716a8a.png
# Processed 1464/1685: 96c7cd74802ba6cf431a5ce21420792f.png
# Processed 1465/1685: bb9d423c38c67077401e0db1491479e0.png
# Processed 1466/1685: 9781b5dc893969c009e43d0fbc859a64.png
# Processed 1467/1685: 3decd57fad0d0b6169a96974370908fb.png
# Processed 1468/1685: 0dfcc3866428b4409512b5f91e9ded58.png
# Processed 1469/1685: 25498880cc42bab417e4ce5fcfa0007d.png
# Processed 1470/1685: 69f3ca4794b963368b2ec896c7a88b18.png
# Processed 1471/1685: e5030a24c5567c6805c0c2e1dc138704.png
# Processed 1472/1685: f67c326b96e26301ba73e2804c745801.png
# Processed 1473/1685: 00faad24b3376fd9f864a8d4555bf0f1.png
# Processed 1474/1685: b0871d97d9c46cf39df4c047e3433a6c.png
# Processed 1475/1685: 53f7d37c3c2306f7441e4316e63e5554.png
# Processed 1476/1685: d5cdd8fac00e9c3580fd264961cb729a.png
# Processed 1477/1685: 6d0e5fad911246a8b2b91511e47781fa.png
# Processed 1478/1685: 1ecf25af567c32d9f3ce9c2a38d38210.png
# Processed 1479/1685: 3e0d8c0f0e9cc1cbc5b6cb9d2997d865.png
# Processed 1480/1685: fbb15978407487e9a34f81f662b2688b.png
# Processed 1481/1685: bfd4bd84039ba2c7ac37f6d49cd034fd.png
# Processed 1482/1685: 8237f8533de1ca7b638ccc1ae49dbf7b.png
# Processed 1483/1685: 7292b9630268f5b2f858b530eb69d628.png
# Processed 1484/1685: 8f6ff1706ce24f06e9060727eae1603a.png
# Processed 1485/1685: a1a938c5d6ad89798e23888ee7f7a9ba.png
# Processed 1486/1685: 87cc6f06b452a4c3623d57523bef7558.png
# Processed 1487/1685: 1dbe22c6792d6dd570676680ebbfa96a.png
# Processed 1488/1685: dd586d2aae10d0e2fa2b6a58f1673338.png
# Processed 1489/1685: ae5425846e49d9ecc77b8da8b09bdd92.png
# Processed 1490/1685: 50da89cbdf59bcf49b20792d4e6d94b5.png
# Processed 1491/1685: 07beb83affc32a5080972259ffc434de.png
# Processed 1492/1685: 4b597e486e580ab6f300525576dfc563.png
# Processed 1493/1685: 937eb9009cca0fc378c79b0057ee1e8b.png
# Processed 1494/1685: 7a507604013bb4b43ae33f99d1cacccb.png
# Processed 1495/1685: 6e723af3c6e3d9cc2a7eab48afe20fe7.png
# Processed 1496/1685: bff9885552e9863ce5d1e920b1eb08fa.png
# Processed 1497/1685: ca23b358a97fbdc57524fd4d43607141.png
# Processed 1498/1685: 6bb74091f1a19dababddd20512e61ca3.png
# Processed 1499/1685: d88108b0b56ded85d2ecffbeb78caaaa.png
# Processed 1500/1685: a38ff8ffc37a0a246797ae02e494d617.png
# Processed 1501/1685: 1a69adba241e3949d1b90c567fd16988.png
# Processed 1502/1685: ba37789825aeed27aa1350df367dfd4a.png
# Processed 1503/1685: 30c53e4165979c5fd812700545dc0bbe.png
# Processed 1504/1685: 986c247b9b29f6be6a5ada8d2ae7ed80.png
# Processed 1505/1685: 6ac79ca7d879afee47a8efd27a7dedac.png
# Processed 1506/1685: bbe8771aa75ddeac6df97216ab30cb29.png
# Processed 1507/1685: 6860150380dc12eeac7a21e1d6f254fb.png
# Processed 1508/1685: a9c2b3243fc9b85bee046edc6d463a0f.png
# Processed 1509/1685: 360606de81695162aaa9bfbd7f415c83.png
# Processed 1510/1685: 20c08c268e003ee73c696a640524e6f4.png
# Processed 1511/1685: 94d1989192dd6ee6843c657861c4f564.png
# Processed 1512/1685: 114cbc1a77a1f143321cba89bae004fd.png
# Processed 1513/1685: 3c3273ce0b39280adc541530dd38b929.png
# Processed 1514/1685: 2718c8f0f1d04f71a8f7e5bc59fe45a1.png
# Processed 1515/1685: 958e71b2b12063f228ecad46977f1afb.png
# Processed 1516/1685: 23532df4cc66a748bb49e16532acbf2f.png
# Processed 1517/1685: dec616c2c7ed2af79a37a420907d3af5.png
# Processed 1518/1685: ae48f8145cea1d15fcf08c3759561b4a.png
# Processed 1519/1685: 0c6df6504cf85d2ff1471fe3dbe87edf.png
# Processed 1520/1685: 85730a29929a08cf327f804fc319dc94.png
# Processed 1521/1685: a62788e7b512fd9e0bf9b03395227d38.png
# Processed 1522/1685: fd1c8bb4dc521362fc02314012d27643.png
# Processed 1523/1685: d1f91abe42ad9a80d9263ea3f24410d1.png
# Processed 1524/1685: 97ec2fa528a614e30cc98293ab99d89a.png
# Processed 1525/1685: f38d78aacad6e852732890865dc990a2.png
# Processed 1526/1685: c2dd6b167ad18b7b9595a053bd2aad38.png
# Processed 1527/1685: d3c18f7056eb3e052bcae13c42065d8c.png
# Processed 1528/1685: f72236f1ab2ddb4a7b2863019c1c943c.png
# Processed 1529/1685: d3f057ba85fdf03bf4988aa277dfc47e.png
# Processed 1530/1685: d85528e96947aebc157b534395484983.png
# Processed 1531/1685: 93adb1bf39531147c519051c2a89b4ba.png
# Processed 1532/1685: 7ce95d8701e2671e418ab1653398a5b9.png
# Processed 1533/1685: f85d6b869570028fbb3a7ceb1768dcbf.png
# Processed 1534/1685: 20ec971af5f52f7e95a53372f937bcea.png
# Processed 1535/1685: a2c72aad49de1760d2daca9dc1cde18a.png
# Processed 1536/1685: 0ea5f97e61daa3557792383c36ea77b5.png
# Processed 1537/1685: f06abe7da074a2234564fe08d4b20a7b.png
# Processed 1538/1685: 81d12f02b4f700a0e1979abe0448564d.png
# Processed 1539/1685: d9bf6183dbf45b2a38fa1a258c5f0c13.png
# Processed 1540/1685: de8269de152bb1a31a6c7fe0eb5ce60e.png
# Processed 1541/1685: 61ac0c914b7221b7d9660a5e3a54aa4f.png
# Processed 1542/1685: 22489569f010d954576de5f7fb8e55b4.png
# Processed 1543/1685: 88b63cd0d8309418fe0657cfba420b16.png
# Processed 1544/1685: 847fc75708272894c750920308a796b6.png
# Processed 1545/1685: 67785aed88330ad5fe2cabebd28ce123.png
# Processed 1546/1685: c8b360fab5a04876d3ab7de44d9fe704.png
# Processed 1547/1685: 77c1a150c95f3992ff9e486c045e4bc5.png
# Processed 1548/1685: 5630551f27256f1c610f23914cda7091.png
# Processed 1549/1685: 5a5c14b07a64149f67c4698209814f3b.png
# Processed 1550/1685: dc69ba3f98c1319de72a3e39e8e4e421.png
# Processed 1551/1685: 6e988a9c1ade6ee8f4253ef84048949a.png
# Processed 1552/1685: 1b38300952075980b220c689ed92d1d6.png
# Processed 1553/1685: 3c170c3edca9202dfe817572bb5b0a1a.png
# Processed 1554/1685: 2c067c65ba806952fea0d8857fe1ec55.png
# Processed 1555/1685: fa971a18b0d0f29747610abbd2d50218.png
# Processed 1556/1685: 0fe3265f89fc1361edcdb4d8cfd49452.png
# Processed 1557/1685: cbcc6374a44672f6332d19c4aae1cdd9.png
# Processed 1558/1685: 237ef949d0dfd361f67e44934e7aaecf.png
# Processed 1559/1685: 2795f1841197edf1bbae6807b5439f7d.png
# Processed 1560/1685: 56e39c8f8ac6eefd4c3f61149b57089d.png
# Processed 1561/1685: 4ed9a0b1a642f3d3df579f57be09c3c1.png
# Processed 1562/1685: 4351f2b9524dfaf6895a2a146cd08e20.png
# Processed 1563/1685: b888d72459d0a8309ab98a20ce2deff9.png
# Processed 1564/1685: 92ac426bf2475cde73146ee352625728.png
# Processed 1565/1685: 7289b6ccad9c793d8f402ccc534dc685.png
# Processed 1566/1685: 76a9ff8be843625e43b50621877a419b.png
# Processed 1567/1685: ff03fd51af26d801b0987809d5990790.png
# Processed 1568/1685: bc0998ef577cd42a6538bfa5589427ed.png
# Processed 1569/1685: d992ff920628768fdb75419bbc847444.png
# Processed 1570/1685: e8908ad9b7e709170be8f51b1788ba37.png
# Processed 1571/1685: 6226738017fff25836c4d0f3299b360d.png
# Processed 1572/1685: 1cb700bcd464bee3cb3934caabd0dd55.png
# Processed 1573/1685: 498a0645526f0052354fce0182876a15.png
# Processed 1574/1685: 4fe15dfc41b0222aa9360a8b3b910d13.png
# Processed 1575/1685: 09b11c80e4e523f1bc2ad0d22f57f70d.png
# Processed 1576/1685: 5e266f6ce0f286ae0a06d47026ea29bb.png
# Processed 1577/1685: a5e4aa6a2e65dd6a9787679400964387.png
# Processed 1578/1685: 41c01c193162e401252b6dd27a02c128.png
# Processed 1579/1685: 2fbdcec5c1626ec52d27bf04d977b33e.png
# Processed 1580/1685: 36aa90ec6a5b1b91896765c6e97f7de1.png
# Processed 1581/1685: cc075d74c8c232b5b6c6646c6db42e06.png
# Processed 1582/1685: a8c3ff8af534723a4c5b8b992dfabc88.png
# Processed 1583/1685: 9201777faf0ad2bafdaffeabf254bb66.png
# Processed 1584/1685: e8c1181a733debb6edba42ac3310efc6.png
# Processed 1585/1685: e2cb648f06e4e537d86805ac0f961e15.png
# Processed 1586/1685: 19ed198a0fa2c01a16007726ef210c9d.png
# Processed 1587/1685: a029d895fa0019478ce42f9f37aa1e02.png
# Processed 1588/1685: 201021eb5cd55a2c01e5ef5d1344015c.png
# Processed 1589/1685: fa8de3f01d9ddaf401240c289da2f058.png
# Processed 1590/1685: a0aa256859dfa0e79576d327c98ff64d.png
# Processed 1591/1685: bdf94d42da88cab8f92f36efb7d82185.png
# Processed 1592/1685: 8675b358fdbffec0c534f1d7fc6dda59.png
# Processed 1593/1685: 0de948a68f88d90d5d0a5708992d12b3.png
# Processed 1594/1685: 9d202100806ed378feb1ad9cfcbc739b.png
# Processed 1595/1685: 32c6d93c78808b0b8746815a12b2526d.png
# Processed 1596/1685: ac13b96cc6fa0d3d8f5bd6d16c6c277e.png
# Processed 1597/1685: cadcf78bb9f12cf32aaf3e3d18619ad1.png
# Processed 1598/1685: e081519a01f2830df370b8df8bc78007.png
# Processed 1599/1685: be6d2582c031db3fdb92cae0a0ba8012.png
# Processed 1600/1685: b4b4486087060d7b36b4b5111fd7261c.png
# Processed 1601/1685: 34ec0f65ade662319590630fd835a7df.png
# Processed 1602/1685: 3a281dab0db8e36bb96627917189cfdf.png
# Processed 1603/1685: 4970503d2a1948c73e1e944fbbf1f00d.png
# Processed 1604/1685: b61271b7ebc76606ad21b7cf56a84372.png
# Processed 1605/1685: d7bd43ed18df56d0fb3e0ae402c2c161.png
# Processed 1606/1685: 1d21aebc7b46886fc977917737dc6020.png
# Processed 1607/1685: 989fc06af7abe610863c0701fb002aab.png
# Processed 1608/1685: 56c5ffcd054f476b980672704e0f18f8.png
# Processed 1609/1685: 9689366533ebf8e44592b53a3861db7c.png
# Processed 1610/1685: 8716d196ecfbfdfc02d9c96dc24bbf5c.png
# Processed 1611/1685: 2045ee5bff584efc4c99cbbf956e41e2.png
# Processed 1612/1685: 0daaffd773d74477861012c9bcaf24a4.png
# Processed 1613/1685: b328b15760d4d25566bbcc9bcaf6b0ba.png
# Processed 1614/1685: 0c9f62ff53a78f6d0c9f6d228e4f1b32.png
# Processed 1615/1685: 7e2178f625f2b89b5290216badce51f3.png
# Processed 1616/1685: f4fd20c6a6b79ee80ee7c7d1b8d4207c.png
# Processed 1617/1685: 02b060f86333f7679a6258e1917ef6b4.png
# Processed 1618/1685: 8d243ebc62301765c13764f14d4d57b8.png
# Processed 1619/1685: ae4c036733b44bb63bbd3d83e0d8ab61.png
# Processed 1620/1685: 64241b01485866ea77de26df48cf3559.png
# Processed 1621/1685: f826f160e69c50ad1bdb4b98019f88d6.png
# Processed 1622/1685: 6c14268c086a1cf03de72e1d33a5dfb5.png
# Processed 1623/1685: fe69afb4d97150eb2c1ea7ec392c06b3.png
# Processed 1624/1685: fdb41a4d8af07d8b487b7023a72fa6d8.png
# Processed 1625/1685: 934b9e44a03db50298a2af3892adecdf.png
# Processed 1626/1685: 501617070964f2683bcee4dd31235889.png
# Processed 1627/1685: 13e5b6e8a3d1358d89216bf3757f646b.png
# Processed 1628/1685: 7796453a16d1b04f21ef45602d3c0976.png
# Processed 1629/1685: 47d669f3d2f9aa68619a14a5508968e6.png
# Processed 1630/1685: bef1c2e7e52d9ef7c6e0993037c31a01.png
# Processed 1631/1685: c3d8557427833d34ce706819527db1cd.png
# Processed 1632/1685: 412ef39ac0b57731553a8a84d130700c.png
# Processed 1633/1685: df19e4c473265fa1a2871ae576470e00.png
# Processed 1634/1685: 80cdfb0dd5b2f69e8f56b488c061416e.png
# Processed 1635/1685: 5f6dae1cf97bff5b1924d67923addf9b.png
# Processed 1636/1685: c83a698f09dc01ed751abb4ab8939ae0.png
# Processed 1637/1685: c4bbf7d2482324a70557397c8eb98a37.png
# Processed 1638/1685: 77343c0df08906586eb121a717a7a7e6.png
# Processed 1639/1685: fa357122c4a697c32863054e0261ff39.png
# Processed 1640/1685: ad04086c735cc3844570c809d35caba2.png
# Processed 1641/1685: 82aa0fb7c53aaac39a63ae0a441390f2.png
# Processed 1642/1685: 1982951758ea65ae715d9d1a95a8ecd1.png
# Processed 1643/1685: 225b58cb755f97a3f659250aa272be8c.png
# Processed 1644/1685: ecce2b978fbbe2d9c5386ed89ef6d5ab.png
# Processed 1645/1685: 37d9e7832207782784b8dc31a9c53c93.png
# Processed 1646/1685: 7eb31f6d5217d64ffbf0618dbe6262d8.png
# Processed 1647/1685: 4c7dd1b05254fb6bece46ac0a773c362.png
# Processed 1648/1685: b1863fa1ba14f3e5e73df720a52c2dd2.png
# Processed 1649/1685: fd9e8fea8aac2f1d1fd10ed28c0497f6.png
# Processed 1650/1685: 8da2e6d9ccf30b1ebe9715c3df5e0ca6.png
# Processed 1651/1685: 370377101b10f8a1c3052939f62bdc54.png
# Processed 1652/1685: ad6815dae0b870817d3c9f228156c55d.png
# Processed 1653/1685: 4039eb33ac3d6778c1db9f265fe034ba.png
# Processed 1654/1685: 9b71d41951f13dcf873565a32dae9f22.png
# Processed 1655/1685: 5f4d97ef512adf1faadfe2e8e6394659.png
# Processed 1656/1685: c98e34af9c269fc90322bdf73e1b934c.png
# Processed 1657/1685: 00f29ea96c690cb73496ebc2448bf7bc.png
# Processed 1658/1685: 141279d674ee6e0254ae0a84cf6973f2.png
# Processed 1659/1685: fea6f5d161d85cee616837d403c06964.png
# Processed 1660/1685: caaa81f30e872b915f1cf9acfc63fd89.png
# Processed 1661/1685: 423a5dea410100677846355e9a69eee4.png
# Processed 1662/1685: 0ce1d6093159bdf11f2ec70de3507555.png
# Processed 1663/1685: 29218250def0c4c3f35dc9eec6022337.png
# Processed 1664/1685: cd73f28df3977892b8f652e82f556ad0.png
# Processed 1665/1685: cbcd8808f312337cb72862d709cd83db.png
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# /tmp/ipykernel_776/205345739.py in <cell line: 8>()
#      11
#      12     # Load the image from disk and resize it to 600x600 pixels (required size for EfficientNet-B7)
# ---> 13     img = load_img(image_path, target_size=(600, 600))
#      14
#      15     # Convert the loaded PIL image to a NumPy array (height, width, channels)
#
# ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/tf_keras/src/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# IsADirectoryError: [Errno 21] Is a directory: 'test - front masked images/.ipynb_checkpoints'

# %% [markdown]
# Step 7 - Save the dictionary as a pickle file

# %%
# Define the output filename for saving the features dictionary as a pickle file
features_pickle_path = 'efficientnet_b7_front_masked_features - testA.pkl'

# Open the file in binary write mode ('wb') to prepare for writing the pickle data
with open(features_pickle_path, 'wb') as f:
    # Use pickle.dump to serialize (save) the 'features' dictionary into the file
    pickle.dump(features, f)

# Print a confirmation message to indicate that the features have been saved successfully
print(f"Features dictionary saved to: {features_pickle_path}")

# %%
import os  # Import os to work with file paths

# Create a new dictionary that will store features with only file names as keys
features_renamed = {}

# Loop over the existing dictionary items
for full_path, feature_vector in features.items():
    # Extract only the file name (e.g., "001f3a8850....png") from the full path
    filename = os.path.basename(full_path)
    
    # Store the feature vector in the new dictionary using the file name as the key
    features_renamed[filename] = feature_vector

# Replace the old dictionary with the new one (keys now are file names only)
features = features_renamed

# Optional: print a few keys to verify the change
print("Sample keys after rename:")
for i, k in enumerate(features.keys()):
    print(k)
    if i == 4:  # stop after 5 keys
        break

# %%
# Define the pickle file name (same as the original file you used before)
pickle_path = 'efficientnet_b7_front_masked_features.pkl'

# Open the pickle file in binary write mode to overwrite it with the updated dictionary
with open(pickle_path, 'wb') as f:
    # Save (serialize) the updated 'features' dictionary into the pickle file
    pickle.dump(features, f)

# Print a confirmation message showing how many entries were saved and where
print(f"Updated features dictionary with {len(features)} entries saved to: {pickle_path}")

# %%
len(features)

# %%
feature_vector.shape

# %% [markdown]
# Step 8 - Comapre file names and dictionary keys

# %%
import os  # Import os to work with the filesystem (list files, join paths, etc.)

# ---------------------------------------------
# 1. Collect image file names from the directory
# ---------------------------------------------

# Define which file extensions you consider as images
valid_extensions = {'.png', '.jpg', '.jpeg', '.bmp', '.gif'}

# Create an empty list to store image file names found in the folder
image_files_in_dir = []

# Loop through every entry in the directory
for name in os.listdir(directory):
    # Build the full path to this entry
    full_path = os.path.join(directory, name)
    
    # Check that this is a file (not a subfolder) and has a valid image extension
    if os.path.isfile(full_path) and os.path.splitext(name)[1].lower() in valid_extensions:
        # If so, add just the file name (e.g., "001f3a8....png") to our list
        image_files_in_dir.append(name)

# Convert the list of image files and dictionary keys to sets for comparison
files_set = set(image_files_in_dir)   # Set of file names in the folder
keys_set = set(features.keys())       # Set of keys in the features dictionary

# ---------------------------------------------
# 2. Compare sets
# ---------------------------------------------

# Files that exist in the folder but NOT in the dictionary keys
files_not_in_dict = files_set - keys_set

# Keys that exist in the dictionary but NOT as files in the folder
keys_not_in_folder = keys_set - files_set

# ---------------------------------------------
# 3. Print summary
# ---------------------------------------------

print(f"Number of image files in directory: {len(files_set)}")
print(f"Number of keys in features dictionary: {len(keys_set)}\n")

# Check if everything matches perfectly
if not files_not_in_dict and not keys_not_in_folder:
    print("✅ All image filenames and dictionary keys MATCH exactly.")
else:
    print("⚠ Some mismatches were found:\n")
    
    # Report files in folder but not in dictionary
    if files_not_in_dict:
        print(f"Files in directory but NOT in dictionary ({len(files_not_in_dict)}):")
        # Print just a few examples to avoid huge output
        for i, name in enumerate(sorted(files_not_in_dict)):
            print("  -", name)
            if i == 9:  # stop after 10 items
                break
        print()
    
    # Report keys in dictionary but not in folder
    if keys_not_in_folder:
        print(f"Keys in dictionary but NO corresponding file in directory ({len(keys_not_in_folder)}):")
        for i, name in enumerate(sorted(keys_not_in_folder)):
            print("  -", name)
            if i == 9:  # stop after 10 items
                break
