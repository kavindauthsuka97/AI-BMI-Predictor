# %% [markdown]
# 1. loop over each image file name in the loaded list from the s3 bucket
# 2. check the image is already in grayscale or black and white
# 3. if image is already from grayscale, keep it as it is
# 4. if image is color, convert it to grayscale
# 5. save the converted image from the same file name as a png file

# %% [markdown]
# Step 1 – Install required packages

# %%
#install boto3 and pillow 
# !pip install boto3 pillow
# Out:
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (1.40.69)
# Requirement already satisfied: pillow in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (12.0.0)
# Requirement already satisfied: botocore<1.41.0,>=1.40.69 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from boto3) (1.40.69)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from boto3) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from botocore<1.41.0,>=1.40.69->boto3) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from botocore<1.41.0,>=1.40.69->boto3) (1.26.20)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.69->boto3) (1.17.0)

# %% [markdown]
# Step 2 - Import libraries and load image names from S3

# %%
# import boto3 to access AWS S3
import boto3

# import UNSIGNED and Config to allow public S3 access without credentials
from botocore import UNSIGNED
from botocore.client import Config

# import os to work with directories and file paths
import os

# import io to work with in-memory byte streams
import io

# import Image from Pillow to handle image operations
from PIL import Image

# set the S3 bucket name
BUCKET = "amazon-bodym"

# set the prefix (folder path) inside the bucket where images are stored
PREFIX = "testB/mask/"

# create an S3 client with unsigned (public) access
s3 = boto3.client("s3", config=Config(signature_version=UNSIGNED))

# create an empty list to store image file names
image_mask = []

# create a paginator to list many objects in the S3 folder
paginator = s3.get_paginator("list_objects_v2")

# loop through each page of results from the paginator
for page in paginator.paginate(Bucket=BUCKET, Prefix=PREFIX):
    # get the list of objects on this page (or empty list if none)
    for obj in page.get("Contents", []):
        # get the full key (path + file name) of the object
        key = obj["Key"]
        # check if the key ends with a common image extension
        if key.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff", ".webp")):
            # take only the file name (last part after '/')
            filename_only = key.rsplit("/", 1)[-1]
            # add the file name to the list
            image_mask.append(filename_only)

# remove duplicates and sort the list of image names
image_mask = sorted(set(image_mask))

# print how many image names were loaded
print(len(image_mask), "names loaded")
# Out:
# 1160 names loaded

# %% [markdown]
# Step 3 - Create the output folder

# %%
# set the name of the output folder for processed images
output_folder = "test B- front masked images"

# create the folder if it does not already exist
os.makedirs(output_folder, exist_ok=True)

# print the path of the output folder
print("Output folder:", output_folder)
# Out:
# Output folder: test B- front masked images

# %% [markdown]
# Step 4 - Download, check color vs grayscale, convert if needed, and save as PNG

# %%
# loop over each image file name in the list
for filename in image_mask:
    # build the full S3 key by joining prefix and file name
    s3_key = f"{PREFIX}{filename}"
    
    # print the file being processed (optional)
    print("Processing:", s3_key)
    
    # get the image object from S3
    response = s3.get_object(Bucket=BUCKET, Key=s3_key)
    
    # read the image bytes from the response body
    img_bytes = response["Body"].read()
    
    # wrap the bytes in a BytesIO object so Pillow can open it
    img_stream = io.BytesIO(img_bytes)
    
    # open the image using Pillow
    img = Image.open(img_stream)
    
    # check if the image is already grayscale or black and white
    # "L" and "1" are common modes for grayscale / bilevel images
    if img.mode in ("L", "1"):
        # if the image is already grayscale, keep it as it is
        gray_img = img
    else:
        # if the image is color (e.g., "RGB", "RGBA"), convert it to grayscale
        gray_img = img.convert("L")
    
    # get the base name without the extension (e.g., "0001" from "0001.png")
    base_name = os.path.splitext(filename)[0]
    
    # create the new file name with .png extension
    new_filename = base_name + ".png"
    
    # build the full output path inside the output folder
    output_path = os.path.join(output_folder, new_filename)
    
    # save the grayscale image as a PNG file at the output path
    gray_img.save(output_path, format="PNG")
    
    # optional: print the saved file path
    print("Saved to:", output_path)

# print a final message when all images are done
print("All images processed and saved in:", output_folder)
# Out:
# Processing: testB/mask/003981667ee238d4fa02d98c7b77efcb.png
# Saved to: test B- front masked images/003981667ee238d4fa02d98c7b77efcb.png
# Processing: testB/mask/0188b0a27a2544b66186f051c478ff42.png
# Saved to: test B- front masked images/0188b0a27a2544b66186f051c478ff42.png
# Processing: testB/mask/01e3f680fbfe08724d493b32c1287abb.png
# Saved to: test B- front masked images/01e3f680fbfe08724d493b32c1287abb.png
# Processing: testB/mask/020ee6e3d2db84419b49e08f7da4ecbc.png
# Saved to: test B- front masked images/020ee6e3d2db84419b49e08f7da4ecbc.png
# Processing: testB/mask/022ce742064f2d66c154183acf509bf3.png
# Saved to: test B- front masked images/022ce742064f2d66c154183acf509bf3.png
# Processing: testB/mask/026777ea9c314f59f9250c258a77f2da.png
# Saved to: test B- front masked images/026777ea9c314f59f9250c258a77f2da.png
# Processing: testB/mask/037d5dd47e50fcc88508a96d8161f1d6.png
# Saved to: test B- front masked images/037d5dd47e50fcc88508a96d8161f1d6.png
# Processing: testB/mask/0390988373c40c72cd8d1ade3e63f6df.png
# Saved to: test B- front masked images/0390988373c40c72cd8d1ade3e63f6df.png
# Processing: testB/mask/03a19517c7d2e0ac093ccec656df57ca.png
# Saved to: test B- front masked images/03a19517c7d2e0ac093ccec656df57ca.png
# Processing: testB/mask/03c2f513510ab7abc696fe4180004f8a.png
# Saved to: test B- front masked images/03c2f513510ab7abc696fe4180004f8a.png
# Processing: testB/mask/03de8ab05cf2a9a5baf4b47c7e657977.png
# Saved to: test B- front masked images/03de8ab05cf2a9a5baf4b47c7e657977.png
# Processing: testB/mask/03ea49774a128e56c67c40934370c0e9.png
# Saved to: test B- front masked images/03ea49774a128e56c67c40934370c0e9.png
# Processing: testB/mask/03fe8b72853794489e1ee3733c232104.png
# Saved to: test B- front masked images/03fe8b72853794489e1ee3733c232104.png
# Processing: testB/mask/0404dd547677d8664bfa5dc60b77439f.png
# Saved to: test B- front masked images/0404dd547677d8664bfa5dc60b77439f.png
# Processing: testB/mask/04284659a1f84df1ece0ad8bf3331fa3.png
# Saved to: test B- front masked images/04284659a1f84df1ece0ad8bf3331fa3.png
# Processing: testB/mask/04360fc9aab325341f6ba0853bb2b64a.png
# Saved to: test B- front masked images/04360fc9aab325341f6ba0853bb2b64a.png
# Processing: testB/mask/048aa352a99dd2b03fa68c15d49a6324.png
# Saved to: test B- front masked images/048aa352a99dd2b03fa68c15d49a6324.png
# Processing: testB/mask/04ec2b080eaf438d5b9730b001db03b3.png
# Saved to: test B- front masked images/04ec2b080eaf438d5b9730b001db03b3.png
# Processing: testB/mask/0504b138334381f867acd7f540451516.png
# Saved to: test B- front masked images/0504b138334381f867acd7f540451516.png
# Processing: testB/mask/050845503e627e6aa3246b5d963dc884.png
# Saved to: test B- front masked images/050845503e627e6aa3246b5d963dc884.png
# Processing: testB/mask/0514ad5150305573ec6e57daae5ebf79.png
# Saved to: test B- front masked images/0514ad5150305573ec6e57daae5ebf79.png
# Processing: testB/mask/054cfb4abae8f257a63eaa236cf42543.png
# Saved to: test B- front masked images/054cfb4abae8f257a63eaa236cf42543.png
# Processing: testB/mask/0567034b481dc77636f8864a11cdcf01.png
# Saved to: test B- front masked images/0567034b481dc77636f8864a11cdcf01.png
# Processing: testB/mask/059ec25a8fe22411a8d52fc17cae3b49.png
# Saved to: test B- front masked images/059ec25a8fe22411a8d52fc17cae3b49.png
# Processing: testB/mask/05bf05a5eaa2729f70e0db6f3c8e320d.png
# Saved to: test B- front masked images/05bf05a5eaa2729f70e0db6f3c8e320d.png
# Processing: testB/mask/05ea76e0a24fd5e66b004b603505035b.png
# Saved to: test B- front masked images/05ea76e0a24fd5e66b004b603505035b.png
# Processing: testB/mask/061f791ab8419fd44e9217ade1684615.png
# Saved to: test B- front masked images/061f791ab8419fd44e9217ade1684615.png
# Processing: testB/mask/066232f2bca4a7736661b9038ef918a9.png
# Saved to: test B- front masked images/066232f2bca4a7736661b9038ef918a9.png
# Processing: testB/mask/071f479293174604f9ef19c6e709cf6a.png
# Saved to: test B- front masked images/071f479293174604f9ef19c6e709cf6a.png
# Processing: testB/mask/07568ea9064e0e7f48a4ea9df39221d0.png
# Saved to: test B- front masked images/07568ea9064e0e7f48a4ea9df39221d0.png
# Processing: testB/mask/075e85b80173b572e92ace0f44ff08bd.png
# Saved to: test B- front masked images/075e85b80173b572e92ace0f44ff08bd.png
# Processing: testB/mask/07618360946d816f1dfd37a4b793a3d1.png
# Saved to: test B- front masked images/07618360946d816f1dfd37a4b793a3d1.png
# Processing: testB/mask/077a7af0538bd58a8ac58cc684897868.png
# Saved to: test B- front masked images/077a7af0538bd58a8ac58cc684897868.png
# Processing: testB/mask/07b84c49514f406d56a150d597a3109f.png
# Saved to: test B- front masked images/07b84c49514f406d56a150d597a3109f.png
# Processing: testB/mask/07f99f5484c2aed56c63120c7e3afdac.png
# Saved to: test B- front masked images/07f99f5484c2aed56c63120c7e3afdac.png
# Processing: testB/mask/08514840d9032c1e86af4abe1e15e353.png
# Saved to: test B- front masked images/08514840d9032c1e86af4abe1e15e353.png
# Processing: testB/mask/0870d8675684285a4002a258a839bc9e.png
# Saved to: test B- front masked images/0870d8675684285a4002a258a839bc9e.png
# Processing: testB/mask/087c6ddd3ed2375230f8deb0ff15a170.png
# Saved to: test B- front masked images/087c6ddd3ed2375230f8deb0ff15a170.png
# Processing: testB/mask/0894ba94ad16b39e59b62d5a11453877.png
# Saved to: test B- front masked images/0894ba94ad16b39e59b62d5a11453877.png
# Processing: testB/mask/08f25975fa0087959b8b5a4527e7d21e.png
# Saved to: test B- front masked images/08f25975fa0087959b8b5a4527e7d21e.png
# Processing: testB/mask/090605f41513e85fbf4604b517b88951.png
# Saved to: test B- front masked images/090605f41513e85fbf4604b517b88951.png
# Processing: testB/mask/0955d0295f4502b449426f25c40c4358.png
# Saved to: test B- front masked images/0955d0295f4502b449426f25c40c4358.png
# Processing: testB/mask/09935ca1b07de6f58467d66f159edc33.png
# Saved to: test B- front masked images/09935ca1b07de6f58467d66f159edc33.png
# Processing: testB/mask/09cc78365424288d02713d4406024908.png
# Saved to: test B- front masked images/09cc78365424288d02713d4406024908.png
# Processing: testB/mask/0a07fa356b190db8a07c0fe7be238a85.png
# Saved to: test B- front masked images/0a07fa356b190db8a07c0fe7be238a85.png
# Processing: testB/mask/0a262529974fb675033f1db5ecdc47f1.png
# Saved to: test B- front masked images/0a262529974fb675033f1db5ecdc47f1.png
# Processing: testB/mask/0a39ab5e8f25c5d1452eabc9d92c3c19.png
# Saved to: test B- front masked images/0a39ab5e8f25c5d1452eabc9d92c3c19.png
# Processing: testB/mask/0a93500d052da35b75857abcfd122693.png
# Saved to: test B- front masked images/0a93500d052da35b75857abcfd122693.png
# Processing: testB/mask/0b48e829981c349462ac58bb06b87f03.png
# Saved to: test B- front masked images/0b48e829981c349462ac58bb06b87f03.png
# Processing: testB/mask/0b6ac249a22c50e90349d8a757ead644.png
# Saved to: test B- front masked images/0b6ac249a22c50e90349d8a757ead644.png
# Processing: testB/mask/0b78e7f34bd3763dcf24c999793f8a23.png
# Saved to: test B- front masked images/0b78e7f34bd3763dcf24c999793f8a23.png
# Processing: testB/mask/0b8738856d47e7cc82e5642478ca847d.png
# Saved to: test B- front masked images/0b8738856d47e7cc82e5642478ca847d.png
# Processing: testB/mask/0bd0e9b46ff6deb6e1a0b88dc655ac68.png
# Saved to: test B- front masked images/0bd0e9b46ff6deb6e1a0b88dc655ac68.png
# Processing: testB/mask/0bda071c0200507071eebe8733460588.png
# Saved to: test B- front masked images/0bda071c0200507071eebe8733460588.png
# Processing: testB/mask/0bdfc03e62876f93333a9deac4388d18.png
# Saved to: test B- front masked images/0bdfc03e62876f93333a9deac4388d18.png
# Processing: testB/mask/0bf476220d1f87e000a07885a76d414d.png
# Saved to: test B- front masked images/0bf476220d1f87e000a07885a76d414d.png
# Processing: testB/mask/0bf5db8026fba0c2727f7f0c0a718d46.png
# Saved to: test B- front masked images/0bf5db8026fba0c2727f7f0c0a718d46.png
# Processing: testB/mask/0c3e6f4b2bbd53ee3cccbf0ed1f84bb5.png
# Saved to: test B- front masked images/0c3e6f4b2bbd53ee3cccbf0ed1f84bb5.png
# Processing: testB/mask/0c961cdd30e4eb4a60bbedda79fe0070.png
# Saved to: test B- front masked images/0c961cdd30e4eb4a60bbedda79fe0070.png
# Processing: testB/mask/0cc56895218b08a07abcbc9aac41c137.png
# Saved to: test B- front masked images/0cc56895218b08a07abcbc9aac41c137.png
# Processing: testB/mask/0cd30148a3730f3c3e9c9b517d36e7c7.png
# Saved to: test B- front masked images/0cd30148a3730f3c3e9c9b517d36e7c7.png
# Processing: testB/mask/0cf8bc3ab37436850dd21e301f6a2b1a.png
# Saved to: test B- front masked images/0cf8bc3ab37436850dd21e301f6a2b1a.png
# Processing: testB/mask/0d5fe7741cc2986df2942450a7c344d7.png
# Saved to: test B- front masked images/0d5fe7741cc2986df2942450a7c344d7.png
# Processing: testB/mask/0d6051e420fd8a60d8b31838b1714f08.png
# Saved to: test B- front masked images/0d6051e420fd8a60d8b31838b1714f08.png
# Processing: testB/mask/0d8e380646db8d6e23fa0f2583292daa.png
# Saved to: test B- front masked images/0d8e380646db8d6e23fa0f2583292daa.png
# Processing: testB/mask/0db3cecf5992ff2c04d05825973c25d9.png
# Saved to: test B- front masked images/0db3cecf5992ff2c04d05825973c25d9.png
# Processing: testB/mask/0db79161e3465d929405c5b6d9e9957c.png
# Saved to: test B- front masked images/0db79161e3465d929405c5b6d9e9957c.png
# Processing: testB/mask/0e0c21fc0475dd8255ce1013cadec00c.png
# Saved to: test B- front masked images/0e0c21fc0475dd8255ce1013cadec00c.png
# Processing: testB/mask/0e1ea106793dbf140f2ed84c714296f7.png
# Saved to: test B- front masked images/0e1ea106793dbf140f2ed84c714296f7.png
# Processing: testB/mask/0e3270f03ddf0b67efd50729eaf96c1c.png
# Saved to: test B- front masked images/0e3270f03ddf0b67efd50729eaf96c1c.png
# Processing: testB/mask/0ed510afeb88026e7ddfe37186fe3095.png
# Saved to: test B- front masked images/0ed510afeb88026e7ddfe37186fe3095.png
# Processing: testB/mask/0f0bf58a069a5ed9faf2f0eeae6af89d.png
# Saved to: test B- front masked images/0f0bf58a069a5ed9faf2f0eeae6af89d.png
# Processing: testB/mask/0f148df305afea0705451d3375e00a54.png
# Saved to: test B- front masked images/0f148df305afea0705451d3375e00a54.png
# Processing: testB/mask/0f20b52f1b0294349baca4732b602ce8.png
# Saved to: test B- front masked images/0f20b52f1b0294349baca4732b602ce8.png
# Processing: testB/mask/0f98eaef9657cf725e105a5cc5dc284e.png
# Saved to: test B- front masked images/0f98eaef9657cf725e105a5cc5dc284e.png
# Processing: testB/mask/1010fa29f4cd5a773cf0b840508289a6.png
# Saved to: test B- front masked images/1010fa29f4cd5a773cf0b840508289a6.png
# Processing: testB/mask/10a6d304830e69d3efc8e09ecc2132fa.png
# Saved to: test B- front masked images/10a6d304830e69d3efc8e09ecc2132fa.png
# Processing: testB/mask/10bc33ea8a6a0c843ec4166ad68fae2a.png
# Saved to: test B- front masked images/10bc33ea8a6a0c843ec4166ad68fae2a.png
# Processing: testB/mask/10c6e04707a113542ba47a00b65dced5.png
# Saved to: test B- front masked images/10c6e04707a113542ba47a00b65dced5.png
# Processing: testB/mask/10d42d21889001561838f8f52e2d3515.png
# Saved to: test B- front masked images/10d42d21889001561838f8f52e2d3515.png
# Processing: testB/mask/112398956e21c6cb5848c4dbeb064dc1.png
# Saved to: test B- front masked images/112398956e21c6cb5848c4dbeb064dc1.png
# Processing: testB/mask/11cafff8a124f659eb1cd393477c1fcb.png
# Saved to: test B- front masked images/11cafff8a124f659eb1cd393477c1fcb.png
# Processing: testB/mask/1271a18a79f009030f30765fd85f72da.png
# Saved to: test B- front masked images/1271a18a79f009030f30765fd85f72da.png
# Processing: testB/mask/12882a30b9e1a9dc1e8bc6f24c5d8f27.png
# Saved to: test B- front masked images/12882a30b9e1a9dc1e8bc6f24c5d8f27.png
# Processing: testB/mask/129b53e312cefddab7b015af1724ed45.png
# Saved to: test B- front masked images/129b53e312cefddab7b015af1724ed45.png
# Processing: testB/mask/12d92458269f28d9e8ea005e34326719.png
# Saved to: test B- front masked images/12d92458269f28d9e8ea005e34326719.png
# Processing: testB/mask/1320018183543ed30cfd349ebc58770e.png
# Saved to: test B- front masked images/1320018183543ed30cfd349ebc58770e.png
# Processing: testB/mask/13267159ff5a8ddb8308604d23311143.png
# Saved to: test B- front masked images/13267159ff5a8ddb8308604d23311143.png
# Processing: testB/mask/133eac2b59539c7f6df5ce0eb8958c62.png
# Saved to: test B- front masked images/133eac2b59539c7f6df5ce0eb8958c62.png
# Processing: testB/mask/13491581ea099f3ad23431b6920637c6.png
# Saved to: test B- front masked images/13491581ea099f3ad23431b6920637c6.png
# Processing: testB/mask/138411c73f191dc3b636507402353c21.png
# Saved to: test B- front masked images/138411c73f191dc3b636507402353c21.png
# Processing: testB/mask/13ba0380c7727032b7cfbc1792da0758.png
# Saved to: test B- front masked images/13ba0380c7727032b7cfbc1792da0758.png
# Processing: testB/mask/13c90d1e0b47d7ad32a5ec87401b2966.png
# Saved to: test B- front masked images/13c90d1e0b47d7ad32a5ec87401b2966.png
# Processing: testB/mask/13d0e9c3fd73d5554c0903376395df92.png
# Saved to: test B- front masked images/13d0e9c3fd73d5554c0903376395df92.png
# Processing: testB/mask/142fae659b67bb825f13e73b654a55ae.png
# Saved to: test B- front masked images/142fae659b67bb825f13e73b654a55ae.png
# Processing: testB/mask/1444511731c7cef5f34e372448272de4.png
# Saved to: test B- front masked images/1444511731c7cef5f34e372448272de4.png
# Processing: testB/mask/146ad4331f8cfaa217d258b70c5ae34e.png
# Saved to: test B- front masked images/146ad4331f8cfaa217d258b70c5ae34e.png
# Processing: testB/mask/14928fcef1ceb3e31d76113fa443de5a.png
# Saved to: test B- front masked images/14928fcef1ceb3e31d76113fa443de5a.png
# Processing: testB/mask/150ffa6a4714c9c32c861fc388fab5bc.png
# Saved to: test B- front masked images/150ffa6a4714c9c32c861fc388fab5bc.png
# Processing: testB/mask/154f1875b05cb4cbc2a391a5680a7ff7.png
# Saved to: test B- front masked images/154f1875b05cb4cbc2a391a5680a7ff7.png
# Processing: testB/mask/154fcb8f02f32829fb1b32073f48d510.png
# Saved to: test B- front masked images/154fcb8f02f32829fb1b32073f48d510.png
# Processing: testB/mask/163cb4da779c0e4ca71b03470fb636b7.png
# Saved to: test B- front masked images/163cb4da779c0e4ca71b03470fb636b7.png
# Processing: testB/mask/16aaf26d2c617fad41baa0690527f7d1.png
# Saved to: test B- front masked images/16aaf26d2c617fad41baa0690527f7d1.png
# Processing: testB/mask/16b78aa434fbd88e6d465b38fd70cd4c.png
# Saved to: test B- front masked images/16b78aa434fbd88e6d465b38fd70cd4c.png
# Processing: testB/mask/17343b4cdf2f35bddd48a8f3ce1a766d.png
# Saved to: test B- front masked images/17343b4cdf2f35bddd48a8f3ce1a766d.png
# Processing: testB/mask/177646284b48a5bf7dec423b3b78221b.png
# Saved to: test B- front masked images/177646284b48a5bf7dec423b3b78221b.png
# Processing: testB/mask/1798176024b06f5dc6ea0d11970e1da2.png
# Saved to: test B- front masked images/1798176024b06f5dc6ea0d11970e1da2.png
# Processing: testB/mask/17eb51369487d1b24865ac17076769dc.png
# Saved to: test B- front masked images/17eb51369487d1b24865ac17076769dc.png
# Processing: testB/mask/181c97707a9fcecbc2dce460a5e8035f.png
# Saved to: test B- front masked images/181c97707a9fcecbc2dce460a5e8035f.png
# Processing: testB/mask/1826526e8f562659ededa49526d0c1ba.png
# Saved to: test B- front masked images/1826526e8f562659ededa49526d0c1ba.png
# Processing: testB/mask/1843d827372aa2c59774bb2a12f0b165.png
# Saved to: test B- front masked images/1843d827372aa2c59774bb2a12f0b165.png
# Processing: testB/mask/18a0f0e7da4804f158f37d172eadf9d5.png
# Saved to: test B- front masked images/18a0f0e7da4804f158f37d172eadf9d5.png
# Processing: testB/mask/18f5adb2032cd50cb02c4eb4a8661a6c.png
# Saved to: test B- front masked images/18f5adb2032cd50cb02c4eb4a8661a6c.png
# Processing: testB/mask/1902340ce2567a4de72998d381f4159a.png
# Saved to: test B- front masked images/1902340ce2567a4de72998d381f4159a.png
# Processing: testB/mask/196382286a99392f3d006386ed7784c2.png
# Saved to: test B- front masked images/196382286a99392f3d006386ed7784c2.png
# Processing: testB/mask/196b5d8b3d1d557b82cc7287d0615faf.png
# Saved to: test B- front masked images/196b5d8b3d1d557b82cc7287d0615faf.png
# Processing: testB/mask/1970bbe188765c93897802cc5fef0abe.png
# Saved to: test B- front masked images/1970bbe188765c93897802cc5fef0abe.png
# Processing: testB/mask/19885aae5fc2d72c99e7558475958039.png
# Saved to: test B- front masked images/19885aae5fc2d72c99e7558475958039.png
# Processing: testB/mask/19be84d57510cb5e81282bb634a50961.png
# Saved to: test B- front masked images/19be84d57510cb5e81282bb634a50961.png
# Processing: testB/mask/19d8f7536a2ebc2bc178705f61b382e3.png
# Saved to: test B- front masked images/19d8f7536a2ebc2bc178705f61b382e3.png
# Processing: testB/mask/1a6b461387a6dd298d0b92a861f7c41b.png
# Saved to: test B- front masked images/1a6b461387a6dd298d0b92a861f7c41b.png
# Processing: testB/mask/1abd8208d087def610f7062776bb195b.png
# Saved to: test B- front masked images/1abd8208d087def610f7062776bb195b.png
# Processing: testB/mask/1ae9957de47d195eded9e95b477ccf8d.png
# Saved to: test B- front masked images/1ae9957de47d195eded9e95b477ccf8d.png
# Processing: testB/mask/1aec65d51c6393dfaf2bf1596c62365b.png
# Saved to: test B- front masked images/1aec65d51c6393dfaf2bf1596c62365b.png
# Processing: testB/mask/1b5e2e6b2f4f2a498de11ed3ecbba744.png
# Saved to: test B- front masked images/1b5e2e6b2f4f2a498de11ed3ecbba744.png
# Processing: testB/mask/1b6ec0c1244b31286201b38dfc919065.png
# Saved to: test B- front masked images/1b6ec0c1244b31286201b38dfc919065.png
# Processing: testB/mask/1b9370835b0f5c6adb8da6bc3b94586b.png
# Saved to: test B- front masked images/1b9370835b0f5c6adb8da6bc3b94586b.png
# Processing: testB/mask/1b9d3f05ffa792cf6814ccffac1a8f2c.png
# Saved to: test B- front masked images/1b9d3f05ffa792cf6814ccffac1a8f2c.png
# Processing: testB/mask/1be7fbc3ba971595ed6b9c70544b8f34.png
# Saved to: test B- front masked images/1be7fbc3ba971595ed6b9c70544b8f34.png
# Processing: testB/mask/1c64d9298e56963dc0307d1b62fbc284.png
# Saved to: test B- front masked images/1c64d9298e56963dc0307d1b62fbc284.png
# Processing: testB/mask/1c76dd73e6285e25a2c4c55ce2c0c6d0.png
# Saved to: test B- front masked images/1c76dd73e6285e25a2c4c55ce2c0c6d0.png
# Processing: testB/mask/1cd1e4549e2156c88ac75f99c25d7873.png
# Saved to: test B- front masked images/1cd1e4549e2156c88ac75f99c25d7873.png
# Processing: testB/mask/1cd6db9de4fb6b8da7a5770f6ddc70eb.png
# Saved to: test B- front masked images/1cd6db9de4fb6b8da7a5770f6ddc70eb.png
# Processing: testB/mask/1d0b5d9bd3d28d84a6df7da33f6e7329.png
# Saved to: test B- front masked images/1d0b5d9bd3d28d84a6df7da33f6e7329.png
# Processing: testB/mask/1d661ef1cbfd6ad46c3188ca2a27bd5c.png
# Saved to: test B- front masked images/1d661ef1cbfd6ad46c3188ca2a27bd5c.png
# Processing: testB/mask/1d828095732907eea6fb6178b416b052.png
# Saved to: test B- front masked images/1d828095732907eea6fb6178b416b052.png
# Processing: testB/mask/1d989b0cce2ae93a78e319f4abb8dc5b.png
# Saved to: test B- front masked images/1d989b0cce2ae93a78e319f4abb8dc5b.png
# Processing: testB/mask/1d9d8dead13f4f27b0c2d552c1df5597.png
# Saved to: test B- front masked images/1d9d8dead13f4f27b0c2d552c1df5597.png
# Processing: testB/mask/1d9f11941e1ef71dd20dc3d3cdf6c891.png
# Saved to: test B- front masked images/1d9f11941e1ef71dd20dc3d3cdf6c891.png
# Processing: testB/mask/1dca6cfda981742a83b7225f24b77763.png
# Saved to: test B- front masked images/1dca6cfda981742a83b7225f24b77763.png
# Processing: testB/mask/1e24ff69f27df8631e45d6cf39d768f1.png
# Saved to: test B- front masked images/1e24ff69f27df8631e45d6cf39d768f1.png
# Processing: testB/mask/1e40d9e80765b812f83748d9c96342cd.png
# Saved to: test B- front masked images/1e40d9e80765b812f83748d9c96342cd.png
# Processing: testB/mask/1e5349a1da297de1a714a338093fb51d.png
# Saved to: test B- front masked images/1e5349a1da297de1a714a338093fb51d.png
# Processing: testB/mask/1e5d68b1a98e6827e873f0da8e2c5072.png
# Saved to: test B- front masked images/1e5d68b1a98e6827e873f0da8e2c5072.png
# Processing: testB/mask/1e9e497cf0e86bfd8132ee5a20947c5c.png
# Saved to: test B- front masked images/1e9e497cf0e86bfd8132ee5a20947c5c.png
# Processing: testB/mask/1eb6d74c591c508f4a032c438156164b.png
# Saved to: test B- front masked images/1eb6d74c591c508f4a032c438156164b.png
# Processing: testB/mask/1fe9b857ea166f4b6be8bebdecef7e61.png
# Saved to: test B- front masked images/1fe9b857ea166f4b6be8bebdecef7e61.png
# Processing: testB/mask/20334768e52890823bde00328c840938.png
# Saved to: test B- front masked images/20334768e52890823bde00328c840938.png
# Processing: testB/mask/20a9f12e5bd0541295bf0aeafd3abe15.png
# Saved to: test B- front masked images/20a9f12e5bd0541295bf0aeafd3abe15.png
# Processing: testB/mask/20db993f42a0e42f7715a6ba0088ef63.png
# Saved to: test B- front masked images/20db993f42a0e42f7715a6ba0088ef63.png
# Processing: testB/mask/20f6569481f3d8f6bc15f3e1dd7077ec.png
# Saved to: test B- front masked images/20f6569481f3d8f6bc15f3e1dd7077ec.png
# Processing: testB/mask/20fc64798d777869b5c2ed4cc67e317e.png
# Saved to: test B- front masked images/20fc64798d777869b5c2ed4cc67e317e.png
# Processing: testB/mask/21014549d42e920167318457cfd1a4a5.png
# Saved to: test B- front masked images/21014549d42e920167318457cfd1a4a5.png
# Processing: testB/mask/214ebe26e52cd8cde16b99fc733d056a.png
# Saved to: test B- front masked images/214ebe26e52cd8cde16b99fc733d056a.png
# Processing: testB/mask/219037e52331665aeee34e111cad2423.png
# Saved to: test B- front masked images/219037e52331665aeee34e111cad2423.png
# Processing: testB/mask/21af09c84c41837e8d1031919a7b52bd.png
# Saved to: test B- front masked images/21af09c84c41837e8d1031919a7b52bd.png
# Processing: testB/mask/21d0549ce4542dc3ccf805aa519a7151.png
# Saved to: test B- front masked images/21d0549ce4542dc3ccf805aa519a7151.png
# Processing: testB/mask/21d580241e99e8158981572e522ec5c2.png
# Saved to: test B- front masked images/21d580241e99e8158981572e522ec5c2.png
# Processing: testB/mask/21d950173205a9d6e098449652503e1b.png
# Saved to: test B- front masked images/21d950173205a9d6e098449652503e1b.png
# Processing: testB/mask/22121ddcf1956c34fee0336b3aafc034.png
# Saved to: test B- front masked images/22121ddcf1956c34fee0336b3aafc034.png
# Processing: testB/mask/222a154700f4266591c45d341b141763.png
# Saved to: test B- front masked images/222a154700f4266591c45d341b141763.png
# Processing: testB/mask/227842a66ee1ad03f1978171f9137d69.png
# Saved to: test B- front masked images/227842a66ee1ad03f1978171f9137d69.png
# Processing: testB/mask/22867f3573c4f98681471512988a7f26.png
# Saved to: test B- front masked images/22867f3573c4f98681471512988a7f26.png
# Processing: testB/mask/22b4207dd4756c17b939c6cc03ea2934.png
# Saved to: test B- front masked images/22b4207dd4756c17b939c6cc03ea2934.png
# Processing: testB/mask/22f38d7c38cd05f5dfa9842a952cad15.png
# Saved to: test B- front masked images/22f38d7c38cd05f5dfa9842a952cad15.png
# Processing: testB/mask/2304e5fdf556dfc280d83d865111c939.png
# Saved to: test B- front masked images/2304e5fdf556dfc280d83d865111c939.png
# Processing: testB/mask/23b1c1f10fdd67447a8fc2cfbe2e73da.png
# Saved to: test B- front masked images/23b1c1f10fdd67447a8fc2cfbe2e73da.png
# Processing: testB/mask/23c33fce757c161f712d3f2b12c1c466.png
# Saved to: test B- front masked images/23c33fce757c161f712d3f2b12c1c466.png
# Processing: testB/mask/2438d3df76351022b0dcc1a6dc73dee1.png
# Saved to: test B- front masked images/2438d3df76351022b0dcc1a6dc73dee1.png
# Processing: testB/mask/246fbcc677ded9140b29b0047684d770.png
# Saved to: test B- front masked images/246fbcc677ded9140b29b0047684d770.png
# Processing: testB/mask/249751074c29ca31abe4d739619e31e1.png
# Saved to: test B- front masked images/249751074c29ca31abe4d739619e31e1.png
# Processing: testB/mask/249a9b8ecb430d84506151bbf3cb83bb.png
# Saved to: test B- front masked images/249a9b8ecb430d84506151bbf3cb83bb.png
# Processing: testB/mask/249f665c0516f10442b0942f131d48d3.png
# Saved to: test B- front masked images/249f665c0516f10442b0942f131d48d3.png
# Processing: testB/mask/24a5a979f65f54dde93e39373627fc43.png
# Saved to: test B- front masked images/24a5a979f65f54dde93e39373627fc43.png
# Processing: testB/mask/24abbb13f28c4e503b688a943be542f9.png
# Saved to: test B- front masked images/24abbb13f28c4e503b688a943be542f9.png
# Processing: testB/mask/24c9af4e0d65b232f29fea8b5da3a774.png
# Saved to: test B- front masked images/24c9af4e0d65b232f29fea8b5da3a774.png
# Processing: testB/mask/24cce977ee11782a91e5b6ff447c79ce.png
# Saved to: test B- front masked images/24cce977ee11782a91e5b6ff447c79ce.png
# Processing: testB/mask/24e27a7c1f395bcfbd9a13fbb2cff993.png
# Saved to: test B- front masked images/24e27a7c1f395bcfbd9a13fbb2cff993.png
# Processing: testB/mask/25134b2d2964e55e492b3537d729a744.png
# Saved to: test B- front masked images/25134b2d2964e55e492b3537d729a744.png
# Processing: testB/mask/25239b1e2e3317f1d0a5e9d4be54d0df.png
# Saved to: test B- front masked images/25239b1e2e3317f1d0a5e9d4be54d0df.png
# Processing: testB/mask/2544832722170aa8f01e36ec3cffe047.png
# Saved to: test B- front masked images/2544832722170aa8f01e36ec3cffe047.png
# Processing: testB/mask/259e773caf2e47bea1b6c4ea36a58741.png
# Saved to: test B- front masked images/259e773caf2e47bea1b6c4ea36a58741.png
# Processing: testB/mask/25ba686cffe03dcbff785ab2ce4fcdec.png
# Saved to: test B- front masked images/25ba686cffe03dcbff785ab2ce4fcdec.png
# Processing: testB/mask/25fe482271a62671bec6d8929b920738.png
# Saved to: test B- front masked images/25fe482271a62671bec6d8929b920738.png
# Processing: testB/mask/263303cf5af748f9f017cd2dfae8b522.png
# Saved to: test B- front masked images/263303cf5af748f9f017cd2dfae8b522.png
# Processing: testB/mask/2642745376df0e097a807b2af6846da5.png
# Saved to: test B- front masked images/2642745376df0e097a807b2af6846da5.png
# Processing: testB/mask/266e72a20e7e0f4c0119bbad4825887a.png
# Saved to: test B- front masked images/266e72a20e7e0f4c0119bbad4825887a.png
# Processing: testB/mask/26a77a019f119b6b3150e505f02c5d57.png
# Saved to: test B- front masked images/26a77a019f119b6b3150e505f02c5d57.png
# Processing: testB/mask/26c932b1f62a3e966c47758f2bebbdae.png
# Saved to: test B- front masked images/26c932b1f62a3e966c47758f2bebbdae.png
# Processing: testB/mask/26e8d16b8c98976d74fb763ea4b48fc6.png
# Saved to: test B- front masked images/26e8d16b8c98976d74fb763ea4b48fc6.png
# Processing: testB/mask/2716affe1c0b72c670f368bfc857339f.png
# Saved to: test B- front masked images/2716affe1c0b72c670f368bfc857339f.png
# Processing: testB/mask/27562ea009af83ad668256c1950821c3.png
# Saved to: test B- front masked images/27562ea009af83ad668256c1950821c3.png
# Processing: testB/mask/2771acf84b0c54416a035a3d76978df4.png
# Saved to: test B- front masked images/2771acf84b0c54416a035a3d76978df4.png
# Processing: testB/mask/278b095d248d20cd6db412da7a58e328.png
# Saved to: test B- front masked images/278b095d248d20cd6db412da7a58e328.png
# Processing: testB/mask/27d4f5979c9fbd7adda83a4842f88c57.png
# Saved to: test B- front masked images/27d4f5979c9fbd7adda83a4842f88c57.png
# Processing: testB/mask/2817991529fc479be5fe2e7b1337917b.png
# Saved to: test B- front masked images/2817991529fc479be5fe2e7b1337917b.png
# Processing: testB/mask/281defeb28f6cf06e3ed299d4a0be1c6.png
# Saved to: test B- front masked images/281defeb28f6cf06e3ed299d4a0be1c6.png
# Processing: testB/mask/2862cc7200e419a345c14c00edc36d46.png
# Saved to: test B- front masked images/2862cc7200e419a345c14c00edc36d46.png
# Processing: testB/mask/28c40b00732da0ecc528a2da7156330f.png
# Saved to: test B- front masked images/28c40b00732da0ecc528a2da7156330f.png
# Processing: testB/mask/28f64f63834943470ee5dfbd611e498a.png
# Saved to: test B- front masked images/28f64f63834943470ee5dfbd611e498a.png
# Processing: testB/mask/2976a25d9836e8ab0af512b661a54f16.png
# Saved to: test B- front masked images/2976a25d9836e8ab0af512b661a54f16.png
# Processing: testB/mask/299698ed6025a2f06d37772f67ddddee.png
# Saved to: test B- front masked images/299698ed6025a2f06d37772f67ddddee.png
# Processing: testB/mask/29ad5a8456d92316d5d27b8a31c25b3c.png
# Saved to: test B- front masked images/29ad5a8456d92316d5d27b8a31c25b3c.png
# Processing: testB/mask/2a61a329a51750399ac498cafad6fb54.png
# Saved to: test B- front masked images/2a61a329a51750399ac498cafad6fb54.png
# Processing: testB/mask/2a7acb53cf6fe650f17e843eac982a0f.png
# Saved to: test B- front masked images/2a7acb53cf6fe650f17e843eac982a0f.png
# Processing: testB/mask/2a95d2e3fc70c7150a8fd1191109c8f7.png
# Saved to: test B- front masked images/2a95d2e3fc70c7150a8fd1191109c8f7.png
# Processing: testB/mask/2b60e411cbed322759c00b039a1c4577.png
# Saved to: test B- front masked images/2b60e411cbed322759c00b039a1c4577.png
# Processing: testB/mask/2ba5e0081ff6d376567b967f0f810bf5.png
# Saved to: test B- front masked images/2ba5e0081ff6d376567b967f0f810bf5.png
# Processing: testB/mask/2c1552143b367070cc500b7eca6abaaf.png
# Saved to: test B- front masked images/2c1552143b367070cc500b7eca6abaaf.png
# Processing: testB/mask/2c26f6598c904589eb7c8306d00a2157.png
# Saved to: test B- front masked images/2c26f6598c904589eb7c8306d00a2157.png
# Processing: testB/mask/2c2bc6ca18d677721ec803b903103360.png
# Saved to: test B- front masked images/2c2bc6ca18d677721ec803b903103360.png
# Processing: testB/mask/2c45a50c61a7eacdb33e9629e6524eac.png
# Saved to: test B- front masked images/2c45a50c61a7eacdb33e9629e6524eac.png
# Processing: testB/mask/2d1d9473cde159f56c7c30445e23d1ea.png
# Saved to: test B- front masked images/2d1d9473cde159f56c7c30445e23d1ea.png
# Processing: testB/mask/2d9890239731b27c3317e08703c81e07.png
# Saved to: test B- front masked images/2d9890239731b27c3317e08703c81e07.png
# Processing: testB/mask/2dd964e8d662096b70369252e6879716.png
# Saved to: test B- front masked images/2dd964e8d662096b70369252e6879716.png
# Processing: testB/mask/2e64f623c832be6c9b375cfd2ce8c033.png
# Saved to: test B- front masked images/2e64f623c832be6c9b375cfd2ce8c033.png
# Processing: testB/mask/2f1cc144d8400df0d07c98efcb0129ec.png
# Saved to: test B- front masked images/2f1cc144d8400df0d07c98efcb0129ec.png
# Processing: testB/mask/2f8b2a9bc968dec89da3db689eba3829.png
# Saved to: test B- front masked images/2f8b2a9bc968dec89da3db689eba3829.png
# Processing: testB/mask/3024ecbb0a9da528731620202199b6ce.png
# Saved to: test B- front masked images/3024ecbb0a9da528731620202199b6ce.png
# Processing: testB/mask/3079894ae08e568b37158b85cd8e8230.png
# Saved to: test B- front masked images/3079894ae08e568b37158b85cd8e8230.png
# Processing: testB/mask/30ca25703df1c0a1645abd499542e780.png
# Saved to: test B- front masked images/30ca25703df1c0a1645abd499542e780.png
# Processing: testB/mask/30ca2e9bd0cfbecd6940e437bdefc519.png
# Saved to: test B- front masked images/30ca2e9bd0cfbecd6940e437bdefc519.png
# Processing: testB/mask/30e58ff4dc18ce9adbff1d350689b4a3.png
# Saved to: test B- front masked images/30e58ff4dc18ce9adbff1d350689b4a3.png
# Processing: testB/mask/3194a074bdb40d55dd04275e6b09133e.png
# Saved to: test B- front masked images/3194a074bdb40d55dd04275e6b09133e.png
# Processing: testB/mask/31c7a7e29b8933b1287576ed45fa1c08.png
# Saved to: test B- front masked images/31c7a7e29b8933b1287576ed45fa1c08.png
# Processing: testB/mask/31ce8cb434228dd928c2e9d8e69f71dc.png
# Saved to: test B- front masked images/31ce8cb434228dd928c2e9d8e69f71dc.png
# Processing: testB/mask/31e698fbe58686c516f1de4bdf7fdb24.png
# Saved to: test B- front masked images/31e698fbe58686c516f1de4bdf7fdb24.png
# Processing: testB/mask/3227ee32479ac93843899cd9fd6faffa.png
# Saved to: test B- front masked images/3227ee32479ac93843899cd9fd6faffa.png
# Processing: testB/mask/32484c96e86d3cd040f5bf481b3a2019.png
# Saved to: test B- front masked images/32484c96e86d3cd040f5bf481b3a2019.png
# Processing: testB/mask/329622f666718d79156fc357bfe9dd58.png
# Saved to: test B- front masked images/329622f666718d79156fc357bfe9dd58.png
# Processing: testB/mask/32ec4ff35c1a43965d98ca1dba6afcf6.png
# Saved to: test B- front masked images/32ec4ff35c1a43965d98ca1dba6afcf6.png
# Processing: testB/mask/32fe89510c1c99e2c4998fe78b178fb2.png
# Saved to: test B- front masked images/32fe89510c1c99e2c4998fe78b178fb2.png
# Processing: testB/mask/331583e9647287339e79016915d644e2.png
# Saved to: test B- front masked images/331583e9647287339e79016915d644e2.png
# Processing: testB/mask/3359119b06e3e125e92bec6a2b8e974f.png
# Saved to: test B- front masked images/3359119b06e3e125e92bec6a2b8e974f.png
# Processing: testB/mask/3384546ee9c8e91629acd2ecd22ed3ff.png
# Saved to: test B- front masked images/3384546ee9c8e91629acd2ecd22ed3ff.png
# Processing: testB/mask/3388799c40b27c42f3ee4c2433b76db2.png
# Saved to: test B- front masked images/3388799c40b27c42f3ee4c2433b76db2.png
# Processing: testB/mask/338df71a4b73b870fc66a10b4feb92cc.png
# Saved to: test B- front masked images/338df71a4b73b870fc66a10b4feb92cc.png
# Processing: testB/mask/34d1eb2efb0c04e88ad7a423e113540d.png
# Saved to: test B- front masked images/34d1eb2efb0c04e88ad7a423e113540d.png
# Processing: testB/mask/34e426097193261992d134c419f26f75.png
# Saved to: test B- front masked images/34e426097193261992d134c419f26f75.png
# Processing: testB/mask/35542825aea509dcf41f025b28fe7eb9.png
# Saved to: test B- front masked images/35542825aea509dcf41f025b28fe7eb9.png
# Processing: testB/mask/35681011b900311911b59c6cfc7fb862.png
# Saved to: test B- front masked images/35681011b900311911b59c6cfc7fb862.png
# Processing: testB/mask/3569a2eab434f0fe3b7618e58802ba5d.png
# Saved to: test B- front masked images/3569a2eab434f0fe3b7618e58802ba5d.png
# Processing: testB/mask/35a8f0acad0efcea31b15ce59c631536.png
# Saved to: test B- front masked images/35a8f0acad0efcea31b15ce59c631536.png
# Processing: testB/mask/35b7f4dad512bdc57037a931a4611704.png
# Saved to: test B- front masked images/35b7f4dad512bdc57037a931a4611704.png
# Processing: testB/mask/361a16f6fb0ce859f3df094a841aeef1.png
# Saved to: test B- front masked images/361a16f6fb0ce859f3df094a841aeef1.png
# Processing: testB/mask/363f744589364dd2f17b16a8b0709f8a.png
# Saved to: test B- front masked images/363f744589364dd2f17b16a8b0709f8a.png
# Processing: testB/mask/36d545553b830e090e962e883aba13ee.png
# Saved to: test B- front masked images/36d545553b830e090e962e883aba13ee.png
# Processing: testB/mask/36ebe2e1ba676f0c83d6fb9373b08c85.png
# Saved to: test B- front masked images/36ebe2e1ba676f0c83d6fb9373b08c85.png
# Processing: testB/mask/36fd4df70911a9d8362abd79b367d9c2.png
# Saved to: test B- front masked images/36fd4df70911a9d8362abd79b367d9c2.png
# Processing: testB/mask/3779249b74ba78710674cc542ba733fc.png
# Saved to: test B- front masked images/3779249b74ba78710674cc542ba733fc.png
# Processing: testB/mask/379361ceb2b85cf2fe6b1ee5a9d830bc.png
# Saved to: test B- front masked images/379361ceb2b85cf2fe6b1ee5a9d830bc.png
# Processing: testB/mask/37a1075be266e0c36ca7fd43ed9f3639.png
# Saved to: test B- front masked images/37a1075be266e0c36ca7fd43ed9f3639.png
# Processing: testB/mask/37adae70a4af6659023d5f5a1f3abfe5.png
# Saved to: test B- front masked images/37adae70a4af6659023d5f5a1f3abfe5.png
# Processing: testB/mask/37d071c2f664fbd797a866c8f90379b6.png
# Saved to: test B- front masked images/37d071c2f664fbd797a866c8f90379b6.png
# Processing: testB/mask/37f5c26aca3dbe239757d5b8dcd9adee.png
# Saved to: test B- front masked images/37f5c26aca3dbe239757d5b8dcd9adee.png
# Processing: testB/mask/38003146107bacdcb8412feef422664e.png
# Saved to: test B- front masked images/38003146107bacdcb8412feef422664e.png
# Processing: testB/mask/38626dc8402b497be1796c5668f5f4eb.png
# Saved to: test B- front masked images/38626dc8402b497be1796c5668f5f4eb.png
# Processing: testB/mask/3874203e4614a2020d8e3d9bc27b913a.png
# Saved to: test B- front masked images/3874203e4614a2020d8e3d9bc27b913a.png
# Processing: testB/mask/38ba4afa43181697fb68d3df6e8d2572.png
# Saved to: test B- front masked images/38ba4afa43181697fb68d3df6e8d2572.png
# Processing: testB/mask/38e9a3809e57e8abb874e2c5f8643da1.png
# Saved to: test B- front masked images/38e9a3809e57e8abb874e2c5f8643da1.png
# Processing: testB/mask/3986a8553c93f50236aabd06341ae42e.png
# Saved to: test B- front masked images/3986a8553c93f50236aabd06341ae42e.png
# Processing: testB/mask/398c88cf092bfccc83c9f2465409aaf3.png
# Saved to: test B- front masked images/398c88cf092bfccc83c9f2465409aaf3.png
# Processing: testB/mask/39d415eef1701480659016fb3075090f.png
# Saved to: test B- front masked images/39d415eef1701480659016fb3075090f.png
# Processing: testB/mask/3a5dd11f1df7cdd1f20b9d90f635e4e8.png
# Saved to: test B- front masked images/3a5dd11f1df7cdd1f20b9d90f635e4e8.png
# Processing: testB/mask/3a9ef767547b43cc92c165b5edd600fd.png
# Saved to: test B- front masked images/3a9ef767547b43cc92c165b5edd600fd.png
# Processing: testB/mask/3aa17fb43faf43147529b974dbb433cb.png
# Saved to: test B- front masked images/3aa17fb43faf43147529b974dbb433cb.png
# Processing: testB/mask/3ad2776ee5a6ca900732ad02fea2a763.png
# Saved to: test B- front masked images/3ad2776ee5a6ca900732ad02fea2a763.png
# Processing: testB/mask/3af86aed73364d4d7d27a077b8c0aacf.png
# Saved to: test B- front masked images/3af86aed73364d4d7d27a077b8c0aacf.png
# Processing: testB/mask/3b44bcff450d8687a983c6ef6f979756.png
# Saved to: test B- front masked images/3b44bcff450d8687a983c6ef6f979756.png
# Processing: testB/mask/3b5b5e4c33ae4d8e9b582a67a84e1d2a.png
# Saved to: test B- front masked images/3b5b5e4c33ae4d8e9b582a67a84e1d2a.png
# Processing: testB/mask/3b68d0c94c1a687c891f3f16c508db2c.png
# Saved to: test B- front masked images/3b68d0c94c1a687c891f3f16c508db2c.png
# Processing: testB/mask/3bb6c3196aac1e88b76e0213b8259eec.png
# Saved to: test B- front masked images/3bb6c3196aac1e88b76e0213b8259eec.png
# Processing: testB/mask/3c18154b4aa151f6de6bc8f293025210.png
# Saved to: test B- front masked images/3c18154b4aa151f6de6bc8f293025210.png
# Processing: testB/mask/3c33537ea6a60f048eb12e594753b32a.png
# Saved to: test B- front masked images/3c33537ea6a60f048eb12e594753b32a.png
# Processing: testB/mask/3c84a37edbd4dfe623a24795c28131d2.png
# Saved to: test B- front masked images/3c84a37edbd4dfe623a24795c28131d2.png
# Processing: testB/mask/3d2380d9b480a07a7da1ca3850600a8f.png
# Saved to: test B- front masked images/3d2380d9b480a07a7da1ca3850600a8f.png
# Processing: testB/mask/3d7f5d30b6c1dddf854d2112bd0d0e3f.png
# Saved to: test B- front masked images/3d7f5d30b6c1dddf854d2112bd0d0e3f.png
# Processing: testB/mask/3d87933edabe81c587d7f4a59af2a918.png
# Saved to: test B- front masked images/3d87933edabe81c587d7f4a59af2a918.png
# Processing: testB/mask/3ded06ebc42974bb3073439296545837.png
# Saved to: test B- front masked images/3ded06ebc42974bb3073439296545837.png
# Processing: testB/mask/3e013f3ccdb4984a074efc7dec6293af.png
# Saved to: test B- front masked images/3e013f3ccdb4984a074efc7dec6293af.png
# Processing: testB/mask/3e4172028c752c3984934b2666436376.png
# Saved to: test B- front masked images/3e4172028c752c3984934b2666436376.png
# Processing: testB/mask/3e7bdc1609ac35ef8df04383a1e0f7bf.png
# Saved to: test B- front masked images/3e7bdc1609ac35ef8df04383a1e0f7bf.png
# Processing: testB/mask/3f8cd90a333ce7806d280b523c7739bf.png
# Saved to: test B- front masked images/3f8cd90a333ce7806d280b523c7739bf.png
# Processing: testB/mask/3fdef3a35fa74a99e2e8f918121af649.png
# Saved to: test B- front masked images/3fdef3a35fa74a99e2e8f918121af649.png
# Processing: testB/mask/3ff3a6a1a6c276ef729221dc92241c35.png
# Saved to: test B- front masked images/3ff3a6a1a6c276ef729221dc92241c35.png
# Processing: testB/mask/4049b3c6c1efbf634c3b3cd5ca6d5f7f.png
# Saved to: test B- front masked images/4049b3c6c1efbf634c3b3cd5ca6d5f7f.png
# Processing: testB/mask/4077aca20a6cd729b317759b9ecabfeb.png
# Saved to: test B- front masked images/4077aca20a6cd729b317759b9ecabfeb.png
# Processing: testB/mask/408533f7b7f185bac9f4252223231965.png
# Saved to: test B- front masked images/408533f7b7f185bac9f4252223231965.png
# Processing: testB/mask/40ac90ac67324940b9ebb119bc2c97d4.png
# Saved to: test B- front masked images/40ac90ac67324940b9ebb119bc2c97d4.png
# Processing: testB/mask/40e09d10c01ec727471fc508e264431f.png
# Saved to: test B- front masked images/40e09d10c01ec727471fc508e264431f.png
# Processing: testB/mask/41249801a15e4382cb9d3f9eac8383ed.png
# Saved to: test B- front masked images/41249801a15e4382cb9d3f9eac8383ed.png
# Processing: testB/mask/41521f150d6189ab5d945086ea82b82b.png
# Saved to: test B- front masked images/41521f150d6189ab5d945086ea82b82b.png
# Processing: testB/mask/41763e5e1ae137fc5d8b1a654b82a842.png
# Saved to: test B- front masked images/41763e5e1ae137fc5d8b1a654b82a842.png
# Processing: testB/mask/41ef8ad75f67734752216e46d680b696.png
# Saved to: test B- front masked images/41ef8ad75f67734752216e46d680b696.png
# Processing: testB/mask/42047d3096e069e278e0fc7a4de90a1e.png
# Saved to: test B- front masked images/42047d3096e069e278e0fc7a4de90a1e.png
# Processing: testB/mask/424bf24bfcb4c8447e1d892c1e49f9d4.png
# Saved to: test B- front masked images/424bf24bfcb4c8447e1d892c1e49f9d4.png
# Processing: testB/mask/4260e8f1ebc9f0eaeae830d20aa3bd8c.png
# Saved to: test B- front masked images/4260e8f1ebc9f0eaeae830d20aa3bd8c.png
# Processing: testB/mask/426b8888ac45f3298b0ee421e0e0994c.png
# Saved to: test B- front masked images/426b8888ac45f3298b0ee421e0e0994c.png
# Processing: testB/mask/4287c9bd0a8db2b9702bffc3e0ffe890.png
# Saved to: test B- front masked images/4287c9bd0a8db2b9702bffc3e0ffe890.png
# Processing: testB/mask/42a72eab832136998f09898cb819a3f7.png
# Saved to: test B- front masked images/42a72eab832136998f09898cb819a3f7.png
# Processing: testB/mask/42b6d5db1a742836ddbc76a23e43a186.png
# Saved to: test B- front masked images/42b6d5db1a742836ddbc76a23e43a186.png
# Processing: testB/mask/430b5ceb064f4e05a551ee0c5aeaf455.png
# Saved to: test B- front masked images/430b5ceb064f4e05a551ee0c5aeaf455.png
# Processing: testB/mask/44ad566bd8d20c3cc2fe32e64fd579be.png
# Saved to: test B- front masked images/44ad566bd8d20c3cc2fe32e64fd579be.png
# Processing: testB/mask/44e8a897f074218827501e29d95212e4.png
# Saved to: test B- front masked images/44e8a897f074218827501e29d95212e4.png
# Processing: testB/mask/44f22ad97586d277709aeabc3f1ff771.png
# Saved to: test B- front masked images/44f22ad97586d277709aeabc3f1ff771.png
# Processing: testB/mask/45af5387ebac27f1158bc3005ee341a9.png
# Saved to: test B- front masked images/45af5387ebac27f1158bc3005ee341a9.png
# Processing: testB/mask/45d01bddf24ffe31f9bdf7be378b14c4.png
# Saved to: test B- front masked images/45d01bddf24ffe31f9bdf7be378b14c4.png
# Processing: testB/mask/46521df8b4a971c56023c229edd15d54.png
# Saved to: test B- front masked images/46521df8b4a971c56023c229edd15d54.png
# Processing: testB/mask/4674effc98471570ad844ea5831d6353.png
# Saved to: test B- front masked images/4674effc98471570ad844ea5831d6353.png
# Processing: testB/mask/46b37958ebb55cbb9ca7e103c344f256.png
# Saved to: test B- front masked images/46b37958ebb55cbb9ca7e103c344f256.png
# Processing: testB/mask/46e5854bfb85431c389d42b546fe140b.png
# Saved to: test B- front masked images/46e5854bfb85431c389d42b546fe140b.png
# Processing: testB/mask/46f0bfaa3cba524b6ebea92230ff8b30.png
# Saved to: test B- front masked images/46f0bfaa3cba524b6ebea92230ff8b30.png
# Processing: testB/mask/46fffb79bd6204bd8309c0f42eb8c23e.png
# Saved to: test B- front masked images/46fffb79bd6204bd8309c0f42eb8c23e.png
# Processing: testB/mask/4748372f85fc26144ff5905840615b4f.png
# Saved to: test B- front masked images/4748372f85fc26144ff5905840615b4f.png
# Processing: testB/mask/4753f180d8920e6ec03328fe385e9121.png
# Saved to: test B- front masked images/4753f180d8920e6ec03328fe385e9121.png
# Processing: testB/mask/477d97b0816fc38ba8ca229e69c99514.png
# Saved to: test B- front masked images/477d97b0816fc38ba8ca229e69c99514.png
# Processing: testB/mask/47caefce626565b9a7c446e15fd9e180.png
# Saved to: test B- front masked images/47caefce626565b9a7c446e15fd9e180.png
# Processing: testB/mask/47d3b028f2d934d690a3863fc6aa74cb.png
# Saved to: test B- front masked images/47d3b028f2d934d690a3863fc6aa74cb.png
# Processing: testB/mask/47ec5d80ad50a6fe76a8ed4213607ac0.png
# Saved to: test B- front masked images/47ec5d80ad50a6fe76a8ed4213607ac0.png
# Processing: testB/mask/486f79ff6a04763dae134bf13eb7c0c8.png
# Saved to: test B- front masked images/486f79ff6a04763dae134bf13eb7c0c8.png
# Processing: testB/mask/48e1efe70da2fda90a7a8a7410407f82.png
# Saved to: test B- front masked images/48e1efe70da2fda90a7a8a7410407f82.png
# Processing: testB/mask/48ed26f9b3e51460de32d0576c9e1b84.png
# Saved to: test B- front masked images/48ed26f9b3e51460de32d0576c9e1b84.png
# Processing: testB/mask/494077a2861613354b874ee2137f4910.png
# Saved to: test B- front masked images/494077a2861613354b874ee2137f4910.png
# Processing: testB/mask/49600ad4cf7fde16179d354384a039c2.png
# Saved to: test B- front masked images/49600ad4cf7fde16179d354384a039c2.png
# Processing: testB/mask/4983d109c66c0cae180bd4a0b3a4d3e6.png
# Saved to: test B- front masked images/4983d109c66c0cae180bd4a0b3a4d3e6.png
# Processing: testB/mask/498e9a8c873e0e30dda9232d2d3aed51.png
# Saved to: test B- front masked images/498e9a8c873e0e30dda9232d2d3aed51.png
# Processing: testB/mask/4a18a4d909c03456fa0821283f797045.png
# Saved to: test B- front masked images/4a18a4d909c03456fa0821283f797045.png
# Processing: testB/mask/4a2095b878459d83a17ee86f322deb4d.png
# Saved to: test B- front masked images/4a2095b878459d83a17ee86f322deb4d.png
# Processing: testB/mask/4a4274d72d3c5e9d4035f542365a9b69.png
# Saved to: test B- front masked images/4a4274d72d3c5e9d4035f542365a9b69.png
# Processing: testB/mask/4a732a967739c7e13acebcc2593f44a1.png
# Saved to: test B- front masked images/4a732a967739c7e13acebcc2593f44a1.png
# Processing: testB/mask/4ac839208c55beb7c29bf50c201b7253.png
# Saved to: test B- front masked images/4ac839208c55beb7c29bf50c201b7253.png
# Processing: testB/mask/4b8fc694eac0775f484fafac8d072c83.png
# Saved to: test B- front masked images/4b8fc694eac0775f484fafac8d072c83.png
# Processing: testB/mask/4bff9260e4123c291281f80896c0ba92.png
# Saved to: test B- front masked images/4bff9260e4123c291281f80896c0ba92.png
# Processing: testB/mask/4daed6115c8ca73e422a2f9eb3aaddbd.png
# Saved to: test B- front masked images/4daed6115c8ca73e422a2f9eb3aaddbd.png
# Processing: testB/mask/4e02c0c8893ece12cbcf34451fae486c.png
# Saved to: test B- front masked images/4e02c0c8893ece12cbcf34451fae486c.png
# Processing: testB/mask/4e205dfee0948b4e88e67c74c1580834.png
# Saved to: test B- front masked images/4e205dfee0948b4e88e67c74c1580834.png
# Processing: testB/mask/4e33ffe232e61aad9150081f59398211.png
# Saved to: test B- front masked images/4e33ffe232e61aad9150081f59398211.png
# Processing: testB/mask/4eb09de16a9895165da4163ab43f8c3e.png
# Saved to: test B- front masked images/4eb09de16a9895165da4163ab43f8c3e.png
# Processing: testB/mask/4ee8251ae7e4ad42c75644db390fc5c5.png
# Saved to: test B- front masked images/4ee8251ae7e4ad42c75644db390fc5c5.png
# Processing: testB/mask/4f3ec67b430f37a949093c3b1ce93a53.png
# Saved to: test B- front masked images/4f3ec67b430f37a949093c3b1ce93a53.png
# Processing: testB/mask/4fb3d25d7fcbca29405aec42c51d88bd.png
# Saved to: test B- front masked images/4fb3d25d7fcbca29405aec42c51d88bd.png
# Processing: testB/mask/4febd6f04a1554d629c24b35173c44d0.png
# Saved to: test B- front masked images/4febd6f04a1554d629c24b35173c44d0.png
# Processing: testB/mask/4ffb3cce30702c9a24526bef78e552d7.png
# Saved to: test B- front masked images/4ffb3cce30702c9a24526bef78e552d7.png
# Processing: testB/mask/515e03cef7c2ab732a4d272dfc53b2ff.png
# Saved to: test B- front masked images/515e03cef7c2ab732a4d272dfc53b2ff.png
# Processing: testB/mask/5172164997526c182da6ceee47d40359.png
# Saved to: test B- front masked images/5172164997526c182da6ceee47d40359.png
# Processing: testB/mask/51e4435310961dd62122a0d2bc1f42ea.png
# Saved to: test B- front masked images/51e4435310961dd62122a0d2bc1f42ea.png
# Processing: testB/mask/52068e8bc0b86c753a3ad9bfb4de1a8f.png
# Saved to: test B- front masked images/52068e8bc0b86c753a3ad9bfb4de1a8f.png
# Processing: testB/mask/526df3cbe70b3344fc1f02d66a84dc1d.png
# Saved to: test B- front masked images/526df3cbe70b3344fc1f02d66a84dc1d.png
# Processing: testB/mask/530419c3b46dbea63cc4dc76c7b322bf.png
# Saved to: test B- front masked images/530419c3b46dbea63cc4dc76c7b322bf.png
# Processing: testB/mask/5321e270566df468ade1ae75dfecfffa.png
# Saved to: test B- front masked images/5321e270566df468ade1ae75dfecfffa.png
# Processing: testB/mask/534386bb60bf02726a9a5dd635991b5d.png
# Saved to: test B- front masked images/534386bb60bf02726a9a5dd635991b5d.png
# Processing: testB/mask/535cf2b3fb8f66f74afe3f1349989514.png
# Saved to: test B- front masked images/535cf2b3fb8f66f74afe3f1349989514.png
# Processing: testB/mask/53931bf5540f1500a568840815513f5a.png
# Saved to: test B- front masked images/53931bf5540f1500a568840815513f5a.png
# Processing: testB/mask/53aa0a4457272e7455774fc5da745982.png
# Saved to: test B- front masked images/53aa0a4457272e7455774fc5da745982.png
# Processing: testB/mask/53e2c28ffc9243cc221c47f83e22e71f.png
# Saved to: test B- front masked images/53e2c28ffc9243cc221c47f83e22e71f.png
# Processing: testB/mask/5403e49efe469c37f5105af5e28c0452.png
# ...
# Processing: testB/mask/e95787b6db7d74218b51352e1b511110.png
# Saved to: test B- front masked images/e95787b6db7d74218b51352e1b511110.png
# Processing: testB/mask/e9aaed9867a2f9b8dc3093a2001d6b1e.png
# Saved to: test B- front masked images/e9aaed9867a2f9b8dc3093a2001d6b1e.png
# Processing: testB/mask/e9ecf3296441d8a8f3a8b3042bc85224.png
# Saved to: test B- front masked images/e9ecf3296441d8a8f3a8b3042bc85224.png
# Processing: testB/mask/ea5c7d610d9890006db48d1902eaeec1.png
# Saved to: test B- front masked images/ea5c7d610d9890006db48d1902eaeec1.png
# Processing: testB/mask/ea64bcfcb28a8d8e80c9e326f8574e76.png
# Saved to: test B- front masked images/ea64bcfcb28a8d8e80c9e326f8574e76.png
# Processing: testB/mask/ea6927e984fca48252991ffe99ad09c9.png
# Saved to: test B- front masked images/ea6927e984fca48252991ffe99ad09c9.png
# Processing: testB/mask/ea83461a39aa7b57060a35b3e50c1370.png
# Saved to: test B- front masked images/ea83461a39aa7b57060a35b3e50c1370.png
# Processing: testB/mask/ea8430c39c58881ef186c0ebe40da8ed.png
# Saved to: test B- front masked images/ea8430c39c58881ef186c0ebe40da8ed.png
# Processing: testB/mask/eac47b0faa748b5b01365398d0f604f9.png
# Saved to: test B- front masked images/eac47b0faa748b5b01365398d0f604f9.png
# Processing: testB/mask/ead00d8d17166da75b07acccd5d09f76.png
# Saved to: test B- front masked images/ead00d8d17166da75b07acccd5d09f76.png
# Processing: testB/mask/ebb76cb031ee42731d624908eeebb4a6.png
# Saved to: test B- front masked images/ebb76cb031ee42731d624908eeebb4a6.png
# Processing: testB/mask/ec0d9b02968651a54ede11a71e002e40.png
# Saved to: test B- front masked images/ec0d9b02968651a54ede11a71e002e40.png
# Processing: testB/mask/ec201a6238d23eb0f3101e1e88beb9ce.png
# Saved to: test B- front masked images/ec201a6238d23eb0f3101e1e88beb9ce.png
# Processing: testB/mask/ec5823c988b9de3f6569ebf785570566.png
# Saved to: test B- front masked images/ec5823c988b9de3f6569ebf785570566.png
# Processing: testB/mask/ed00a3b10425a1f7d71ed160b0055e76.png
# Saved to: test B- front masked images/ed00a3b10425a1f7d71ed160b0055e76.png
# Processing: testB/mask/ed04c439638a78fd94b193dd23676769.png
# Saved to: test B- front masked images/ed04c439638a78fd94b193dd23676769.png
# Processing: testB/mask/ed65f8df77cec5791e3c90dcb3978306.png
# Saved to: test B- front masked images/ed65f8df77cec5791e3c90dcb3978306.png
# Processing: testB/mask/ed7fe60b99f4603c4e7e503e868cb8f8.png
# Saved to: test B- front masked images/ed7fe60b99f4603c4e7e503e868cb8f8.png
# Processing: testB/mask/ed954b254397d6dbee2b56c4be653b2e.png
# Saved to: test B- front masked images/ed954b254397d6dbee2b56c4be653b2e.png
# Processing: testB/mask/edab7688e5cb0e55509fb19cda2f548c.png
# Saved to: test B- front masked images/edab7688e5cb0e55509fb19cda2f548c.png
# Processing: testB/mask/edfe47fdda791f04a40ebb06ad29426e.png
# Saved to: test B- front masked images/edfe47fdda791f04a40ebb06ad29426e.png
# Processing: testB/mask/ee4d156c53890b1e79dee8968b4dcbd9.png
# Saved to: test B- front masked images/ee4d156c53890b1e79dee8968b4dcbd9.png
# Processing: testB/mask/ee66775a523ee09f8edd3eaeccc0a2fc.png
# Saved to: test B- front masked images/ee66775a523ee09f8edd3eaeccc0a2fc.png
# Processing: testB/mask/ee7eb3228378aac767cd9a8cbdccee26.png
# Saved to: test B- front masked images/ee7eb3228378aac767cd9a8cbdccee26.png
# Processing: testB/mask/ee93430819a0759cef31133a450c307e.png
# Saved to: test B- front masked images/ee93430819a0759cef31133a450c307e.png
# Processing: testB/mask/eeab0e35424105e96341217ab655cd66.png
# Saved to: test B- front masked images/eeab0e35424105e96341217ab655cd66.png
# Processing: testB/mask/eec202ad17c613a91a73d495325f76a4.png
# Saved to: test B- front masked images/eec202ad17c613a91a73d495325f76a4.png
# Processing: testB/mask/eed29c1ec493760862596ceb2f062430.png
# Saved to: test B- front masked images/eed29c1ec493760862596ceb2f062430.png
# Processing: testB/mask/efa17d006299ba983df083b60f938990.png
# Saved to: test B- front masked images/efa17d006299ba983df083b60f938990.png
# Processing: testB/mask/efa76aced42f58b610eed0e5f6bd7690.png
# Saved to: test B- front masked images/efa76aced42f58b610eed0e5f6bd7690.png
# Processing: testB/mask/efb29d1d903307924024f6bb7eb66f73.png
# Saved to: test B- front masked images/efb29d1d903307924024f6bb7eb66f73.png
# Processing: testB/mask/efcd31ac592c82c9136e4fa0cd532e7c.png
# Saved to: test B- front masked images/efcd31ac592c82c9136e4fa0cd532e7c.png
# Processing: testB/mask/efce5077b601761095bb863a78061bd0.png
# Saved to: test B- front masked images/efce5077b601761095bb863a78061bd0.png
# Processing: testB/mask/efff3ec624f71c18ac23fa9f18fa9be3.png
# Saved to: test B- front masked images/efff3ec624f71c18ac23fa9f18fa9be3.png
# Processing: testB/mask/f0299a292ead059bcc2d46ac71c38330.png
# Saved to: test B- front masked images/f0299a292ead059bcc2d46ac71c38330.png
# Processing: testB/mask/f04ac8ffb856e3716fa1fd56f421a0d5.png
# Saved to: test B- front masked images/f04ac8ffb856e3716fa1fd56f421a0d5.png
# Processing: testB/mask/f092478fbf9b17c7e24e3eef7b052cbd.png
# Saved to: test B- front masked images/f092478fbf9b17c7e24e3eef7b052cbd.png
# Processing: testB/mask/f0c58ad443a32c12e7c45c4ca12902a1.png
# Saved to: test B- front masked images/f0c58ad443a32c12e7c45c4ca12902a1.png
# Processing: testB/mask/f0cd34f74e10386562f7a0c5d991bd56.png
# Saved to: test B- front masked images/f0cd34f74e10386562f7a0c5d991bd56.png
# Processing: testB/mask/f0cee352ec6d655fbbafddd18076e7aa.png
# Saved to: test B- front masked images/f0cee352ec6d655fbbafddd18076e7aa.png
# Processing: testB/mask/f116e6fd2172d006ac6ccf34c7751945.png
# Saved to: test B- front masked images/f116e6fd2172d006ac6ccf34c7751945.png
# Processing: testB/mask/f13110a3d0a2c346af9c361be3e68023.png
# Saved to: test B- front masked images/f13110a3d0a2c346af9c361be3e68023.png
# Processing: testB/mask/f16648ae6fe64f0d824e59fd5604f125.png
# Saved to: test B- front masked images/f16648ae6fe64f0d824e59fd5604f125.png
# Processing: testB/mask/f17eba6b3254924940484155075da4b4.png
# Saved to: test B- front masked images/f17eba6b3254924940484155075da4b4.png
# Processing: testB/mask/f1b0550886e3320a37b39535b4fc796f.png
# Saved to: test B- front masked images/f1b0550886e3320a37b39535b4fc796f.png
# Processing: testB/mask/f1cd73767d9438168677c47f45282d6d.png
# Saved to: test B- front masked images/f1cd73767d9438168677c47f45282d6d.png
# Processing: testB/mask/f1ffd1d3f6ae94bd9dde5f35f55c4714.png
# Saved to: test B- front masked images/f1ffd1d3f6ae94bd9dde5f35f55c4714.png
# Processing: testB/mask/f234ba13ddf37ac097d85f0d165b4dbe.png
# Saved to: test B- front masked images/f234ba13ddf37ac097d85f0d165b4dbe.png
# Processing: testB/mask/f262404c5d1967612b5b3096855802f0.png
# Saved to: test B- front masked images/f262404c5d1967612b5b3096855802f0.png
# Processing: testB/mask/f2810a4d7a0bb4fa2f323e53907c9994.png
# Saved to: test B- front masked images/f2810a4d7a0bb4fa2f323e53907c9994.png
# Processing: testB/mask/f2870e6fd29aa938aa647713834f40b2.png
# Saved to: test B- front masked images/f2870e6fd29aa938aa647713834f40b2.png
# Processing: testB/mask/f2ad2201048d5881023c986b92b2e24d.png
# Saved to: test B- front masked images/f2ad2201048d5881023c986b92b2e24d.png
# Processing: testB/mask/f2bc68dde263ee31a9c91390e73e66c3.png
# Saved to: test B- front masked images/f2bc68dde263ee31a9c91390e73e66c3.png
# Processing: testB/mask/f30ae7030a32f106ef0e74c9aafaf56a.png
# Saved to: test B- front masked images/f30ae7030a32f106ef0e74c9aafaf56a.png
# Processing: testB/mask/f3142d4b32acb208fe26725867ab3366.png
# Saved to: test B- front masked images/f3142d4b32acb208fe26725867ab3366.png
# Processing: testB/mask/f370a08c1b19d7ec29de95b0c5f09d7f.png
# Saved to: test B- front masked images/f370a08c1b19d7ec29de95b0c5f09d7f.png
# Processing: testB/mask/f37b67f07f0393fe6f416ac0e16b6523.png
# Saved to: test B- front masked images/f37b67f07f0393fe6f416ac0e16b6523.png
# Processing: testB/mask/f38130c8ecbca71b6913a051c49f98f7.png
# Saved to: test B- front masked images/f38130c8ecbca71b6913a051c49f98f7.png
# Processing: testB/mask/f43ae9378e9251e1e943e1999e36c488.png
# Saved to: test B- front masked images/f43ae9378e9251e1e943e1999e36c488.png
# Processing: testB/mask/f47b42ed518616b31d19f4444c112cdd.png
# Saved to: test B- front masked images/f47b42ed518616b31d19f4444c112cdd.png
# Processing: testB/mask/f503750dde2cf0b0d9ddcf99ea0dc154.png
# Saved to: test B- front masked images/f503750dde2cf0b0d9ddcf99ea0dc154.png
# Processing: testB/mask/f5778c6914d51e01633f9b179100b633.png
# Saved to: test B- front masked images/f5778c6914d51e01633f9b179100b633.png
# Processing: testB/mask/f57abb7779ebcf9bfe8a303e646b5165.png
# Saved to: test B- front masked images/f57abb7779ebcf9bfe8a303e646b5165.png
# Processing: testB/mask/f58211bd1eedda3d0f01389d03cceb83.png
# Saved to: test B- front masked images/f58211bd1eedda3d0f01389d03cceb83.png
# Processing: testB/mask/f5a2b8f520dadc515c2e0c3f1c6a4038.png
# Saved to: test B- front masked images/f5a2b8f520dadc515c2e0c3f1c6a4038.png
# Processing: testB/mask/f5ad3542127244f6a8fa2fd28a80cb75.png
# Saved to: test B- front masked images/f5ad3542127244f6a8fa2fd28a80cb75.png
# Processing: testB/mask/f5ce1ca96c5568efb43f937644d72222.png
# Saved to: test B- front masked images/f5ce1ca96c5568efb43f937644d72222.png
# Processing: testB/mask/f5eb074c970bc065d160bb0dd4a073e2.png
# Saved to: test B- front masked images/f5eb074c970bc065d160bb0dd4a073e2.png
# Processing: testB/mask/f6113d97083a2ee5cf32e4a9ca721a1e.png
# Saved to: test B- front masked images/f6113d97083a2ee5cf32e4a9ca721a1e.png
# Processing: testB/mask/f613b8fcfbbf468409a0e6c311b9454e.png
# Saved to: test B- front masked images/f613b8fcfbbf468409a0e6c311b9454e.png
# Processing: testB/mask/f645a5a753dd3e5ddfb4c191735c159d.png
# Saved to: test B- front masked images/f645a5a753dd3e5ddfb4c191735c159d.png
# Processing: testB/mask/f66fc76d5d55d8fe4a73363571c25f68.png
# Saved to: test B- front masked images/f66fc76d5d55d8fe4a73363571c25f68.png
# Processing: testB/mask/f68af1f76f754b5ea97ab622e32cca0e.png
# Saved to: test B- front masked images/f68af1f76f754b5ea97ab622e32cca0e.png
# Processing: testB/mask/f6a928aca04ac779b585e5f40978e03b.png
# Saved to: test B- front masked images/f6a928aca04ac779b585e5f40978e03b.png
# Processing: testB/mask/f6adaa7ea881c8a039dcef64f41f8c6c.png
# Saved to: test B- front masked images/f6adaa7ea881c8a039dcef64f41f8c6c.png
# Processing: testB/mask/f6ca7fe9e39eb8707b0d5dea77c2671e.png
# Saved to: test B- front masked images/f6ca7fe9e39eb8707b0d5dea77c2671e.png
# Processing: testB/mask/f709442adc71374476cc0daf138afcf5.png
# Saved to: test B- front masked images/f709442adc71374476cc0daf138afcf5.png
# Processing: testB/mask/f71180f35a8dc76281069a383a69afe9.png
# Saved to: test B- front masked images/f71180f35a8dc76281069a383a69afe9.png
# Processing: testB/mask/f74bdfe1faa609fa23bb0fb301d4fda1.png
# Saved to: test B- front masked images/f74bdfe1faa609fa23bb0fb301d4fda1.png
# Processing: testB/mask/f795e84dc1bff4ea8e6a6ac45bc1f27f.png
# Saved to: test B- front masked images/f795e84dc1bff4ea8e6a6ac45bc1f27f.png
# Processing: testB/mask/f79cb7b5c4ef28c3bcf259e23b3c06a9.png
# Saved to: test B- front masked images/f79cb7b5c4ef28c3bcf259e23b3c06a9.png
# Processing: testB/mask/f7b20d1f54fb24b4d8d3421f390860f5.png
# Saved to: test B- front masked images/f7b20d1f54fb24b4d8d3421f390860f5.png
# Processing: testB/mask/f7dce34481e17bf92bd096f432b6ab2c.png
# Saved to: test B- front masked images/f7dce34481e17bf92bd096f432b6ab2c.png
# Processing: testB/mask/f7fc19506775e8416b06ffc8cefb8fbb.png
# Saved to: test B- front masked images/f7fc19506775e8416b06ffc8cefb8fbb.png
# Processing: testB/mask/f8098ab6433bb96bd160b868b3e7db73.png
# Saved to: test B- front masked images/f8098ab6433bb96bd160b868b3e7db73.png
# Processing: testB/mask/f820e4866465582058d85a7b0fd1fde5.png
# Saved to: test B- front masked images/f820e4866465582058d85a7b0fd1fde5.png
# Processing: testB/mask/f83d9a3947e8b59d3e8aa110a5137dbf.png
# Saved to: test B- front masked images/f83d9a3947e8b59d3e8aa110a5137dbf.png
# Processing: testB/mask/f86680076a78f6002e1a72528008beef.png
# Saved to: test B- front masked images/f86680076a78f6002e1a72528008beef.png
# Processing: testB/mask/f891db4042418d15dd481ffeb7cad7c1.png
# Saved to: test B- front masked images/f891db4042418d15dd481ffeb7cad7c1.png
# Processing: testB/mask/f8ef9e0fa44967f5022f187f9f6a5e39.png
# Saved to: test B- front masked images/f8ef9e0fa44967f5022f187f9f6a5e39.png
# Processing: testB/mask/f902a621d7559194264c3326ddde311b.png
# Saved to: test B- front masked images/f902a621d7559194264c3326ddde311b.png
# Processing: testB/mask/f937f53a11d30bc85a3ac959104a2af4.png
# Saved to: test B- front masked images/f937f53a11d30bc85a3ac959104a2af4.png
# Processing: testB/mask/f9c9d3b9889b03b1f4b127bbcb07c72d.png
# Saved to: test B- front masked images/f9c9d3b9889b03b1f4b127bbcb07c72d.png
# Processing: testB/mask/fa3663b338b8df3c52fce0f33049d7f7.png
# Saved to: test B- front masked images/fa3663b338b8df3c52fce0f33049d7f7.png
# Processing: testB/mask/fa7f2ae6a8261e22bc082bb2b605d167.png
# Saved to: test B- front masked images/fa7f2ae6a8261e22bc082bb2b605d167.png
# Processing: testB/mask/faf3b7666611f28ba76093c22a500027.png
# Saved to: test B- front masked images/faf3b7666611f28ba76093c22a500027.png
# Processing: testB/mask/faf8eb35c7f9f5c3c969f130200e747c.png
# Saved to: test B- front masked images/faf8eb35c7f9f5c3c969f130200e747c.png
# Processing: testB/mask/fb3dfd42c3982fdadadfbc517a886966.png
# Saved to: test B- front masked images/fb3dfd42c3982fdadadfbc517a886966.png
# Processing: testB/mask/fb43bda6f62ce51857c9789b1efe50d1.png
# Saved to: test B- front masked images/fb43bda6f62ce51857c9789b1efe50d1.png
# Processing: testB/mask/fb636e91c81428afc25a966fbae8b96f.png
# Saved to: test B- front masked images/fb636e91c81428afc25a966fbae8b96f.png
# Processing: testB/mask/fc242ce05f8943b532e503cc893d0d1d.png
# Saved to: test B- front masked images/fc242ce05f8943b532e503cc893d0d1d.png
# Processing: testB/mask/fc497ce9fc1d116bbde9ff39e869e93a.png
# Saved to: test B- front masked images/fc497ce9fc1d116bbde9ff39e869e93a.png
# Processing: testB/mask/fc50f26108b80d27eec517801c20ad2b.png
# Saved to: test B- front masked images/fc50f26108b80d27eec517801c20ad2b.png
# Processing: testB/mask/fc5b6f2bb07a2b65d413e07fe3c15174.png
# Saved to: test B- front masked images/fc5b6f2bb07a2b65d413e07fe3c15174.png
# Processing: testB/mask/fd1639d688cbbe24da983bbb0ffd734e.png
# Saved to: test B- front masked images/fd1639d688cbbe24da983bbb0ffd734e.png
# Processing: testB/mask/fd46cd78c63880dac01fef14ad2c40d7.png
# Saved to: test B- front masked images/fd46cd78c63880dac01fef14ad2c40d7.png
# Processing: testB/mask/fda4be9c856751d9584ada4fd3404c5a.png
# Saved to: test B- front masked images/fda4be9c856751d9584ada4fd3404c5a.png
# Processing: testB/mask/fdbad2c2006dc4fe26d32bfffab67f85.png
# Saved to: test B- front masked images/fdbad2c2006dc4fe26d32bfffab67f85.png
# Processing: testB/mask/fdc1b81a8847f65b2af65c22941c07c1.png
# Saved to: test B- front masked images/fdc1b81a8847f65b2af65c22941c07c1.png
# Processing: testB/mask/fddf4759ae19c4c58f096890324cbbab.png
# Saved to: test B- front masked images/fddf4759ae19c4c58f096890324cbbab.png
# Processing: testB/mask/fe401d2e9b20ea62938d955214d00a6f.png
# Saved to: test B- front masked images/fe401d2e9b20ea62938d955214d00a6f.png
# Processing: testB/mask/fe5be105fa09b2075f8ba55a45e6d4bf.png
# Saved to: test B- front masked images/fe5be105fa09b2075f8ba55a45e6d4bf.png
# Processing: testB/mask/fe9e32e74e1a5b6cdbed100bba947382.png
# Saved to: test B- front masked images/fe9e32e74e1a5b6cdbed100bba947382.png
# Processing: testB/mask/fea44629a6dc63b715de453242366aed.png
# Saved to: test B- front masked images/fea44629a6dc63b715de453242366aed.png
# Processing: testB/mask/feca6855641c9077d6970ac0d39b9cc4.png
# Saved to: test B- front masked images/feca6855641c9077d6970ac0d39b9cc4.png
# Processing: testB/mask/fef8cae0483b0229cf0673b23c659096.png
# Saved to: test B- front masked images/fef8cae0483b0229cf0673b23c659096.png
# Processing: testB/mask/ffb195b743b3a7426e7b209629a00e95.png
# Saved to: test B- front masked images/ffb195b743b3a7426e7b209629a00e95.png
# Processing: testB/mask/fff2bd95fb7f70e5da4761786e2c710d.png
# Saved to: test B- front masked images/fff2bd95fb7f70e5da4761786e2c710d.png
# All images processed and saved in: test B- front masked images

# %% [markdown]
# Step 5 - Compare S3 image count and local folder image count

# %%
# import os to work with directory listings
import os

# count how many image names were loaded from S3
num_s3_images = len(image_mask)  # get length of the list of S3 image names

# print the number of images found in S3
print("Number of image names from S3:", num_s3_images)

# list all files in the output folder
output_files = os.listdir(output_folder)  # get all file names in the output folder

# keep only files that end with .png (processed images)
output_images = [f for f in output_files if f.lower().endswith(".png")]  # filter only png files

# count how many processed images are in the folder
num_output_images = len(output_images)  # get length of the list of output images

# print the number of images in the output folder
print("Number of processed images in folder:", num_output_images)

# compare the counts from S3 and local folder
if num_s3_images == num_output_images:  # check if both counts are equal
    print("✅ Counts match: all images processed.")  # print success message
else:
    print("❌ Counts DO NOT match!")  # print mismatch message
    
    # calculate the difference between S3 and local counts
    diff = num_s3_images - num_output_images  # positive means missing, negative means extra
    
    # if diff is positive, some images are missing in the local folder
    if diff > 0:
        print(diff, "images are missing in the output folder.")  # report missing images
    else:
        # if diff is negative, there are extra images in the local folder
        print(-diff, "extra images are in the output folder.")  # report extra images
# Out:
# Number of image names from S3: 1160
# Number of processed images in folder: 1160
# ✅ Counts match: all images processed.

# %% [markdown]
# Step 6 - Check that file names match between S3 and local folder

# %%
# import os to work with file names and paths
import os

# create a set of base names (without extension) from S3 image list
s3_base_names = set(os.path.splitext(name)[0] for name in image_mask)

# list all files in the output folder
output_files = os.listdir(output_folder)

# keep only .png files from the output folder
output_images = [f for f in output_files if f.lower().endswith(".png")]

# create a set of base names (without extension) from local png files
local_base_names = set(os.path.splitext(name)[0] for name in output_images)

# print how many unique base names are in each set
print("Unique S3 base names:", len(s3_base_names))
print("Unique local base names:", len(local_base_names))

# check if both sets of base names are exactly the same
if s3_base_names == local_base_names:
    # if sets are equal, all file names match
    print("✅ File names match between S3 and local folder (ignoring extension).")
else:
    # if sets differ, there is some mismatch
    print("❌ File names do NOT match between S3 and local folder.")
    
    # find names present in S3 but missing locally
    missing_locally = s3_base_names - local_base_names
    # find names present locally but not in S3
    extra_locally = local_base_names - s3_base_names
    
    # if there are names missing in local folder, print them
    if missing_locally:
        print("\nNames in S3 but missing in local folder:")
        for name in sorted(missing_locally):
            print("  ", name)
    
    # if there are extra names in local folder, print them
    if extra_locally:
        print("\nNames in local folder but not in S3:")
        for name in sorted(extra_locally):
            print("  ", name)
# Out:
# Unique S3 base names: 1160
# Unique local base names: 1160
# ✅ File names match between S3 and local folder (ignoring extension).
