# %% [markdown]
# 1. loop over each image file name in the loaded list from the s3 bucket
# 2. check the image is already in grayscale or black and white
# 3. if image is already from grayscale, keep it as it is
# 4. if image is color, convert it to grayscale
# 5. save the converted image from the same file name as a png file

# %% [markdown]
# Step 1 – Install required packages

# %%
#install boto3 and pillow 
# !pip install boto3 pillow
# Out:
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (1.40.69)
# Requirement already satisfied: pillow in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (12.0.0)
# Requirement already satisfied: botocore<1.41.0,>=1.40.69 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from boto3) (1.40.69)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from boto3) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from botocore<1.41.0,>=1.40.69->boto3) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from botocore<1.41.0,>=1.40.69->boto3) (1.26.20)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.69->boto3) (1.17.0)

# %% [markdown]
# Step 2 - Import libraries and load image names from S3

# %%
# import boto3 to access AWS S3
import boto3

# import UNSIGNED and Config to allow public S3 access without credentials
from botocore import UNSIGNED
from botocore.client import Config

# import os to work with directories and file paths
import os

# import io to work with in-memory byte streams
import io

# import Image from Pillow to handle image operations
from PIL import Image

# set the S3 bucket name
BUCKET = "amazon-bodym"

# set the prefix (folder path) inside the bucket where images are stored
PREFIX = "testA/mask_left/"

# create an S3 client with unsigned (public) access
s3 = boto3.client("s3", config=Config(signature_version=UNSIGNED))

# create an empty list to store image file names
image_mask = []

# create a paginator to list many objects in the S3 folder
paginator = s3.get_paginator("list_objects_v2")

# loop through each page of results from the paginator
for page in paginator.paginate(Bucket=BUCKET, Prefix=PREFIX):
    # get the list of objects on this page (or empty list if none)
    for obj in page.get("Contents", []):
        # get the full key (path + file name) of the object
        key = obj["Key"]
        # check if the key ends with a common image extension
        if key.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff", ".webp")):
            # take only the file name (last part after '/')
            filename_only = key.rsplit("/", 1)[-1]
            # add the file name to the list
            image_mask.append(filename_only)

# remove duplicates and sort the list of image names
image_mask = sorted(set(image_mask))

# print how many image names were loaded
print(len(image_mask), "names loaded")
# Out:
# 1684 names loaded

# %% [markdown]
# Step 3 - Create the output folder

# %%
# set the name of the output folder for processed images
output_folder = "test - front masked images - side"

# create the folder if it does not already exist
os.makedirs(output_folder, exist_ok=True)

# print the path of the output folder
print("Output folder:", output_folder)
# Out:
# Output folder: test - front masked images - side

# %% [markdown]
# Step 4 - Download, check color vs grayscale, convert if needed, and save as PNG

# %%
# loop over each image file name in the list
for filename in image_mask:
    # build the full S3 key by joining prefix and file name
    s3_key = f"{PREFIX}{filename}"
    
    # print the file being processed (optional)
    print("Processing:", s3_key)
    
    # get the image object from S3
    response = s3.get_object(Bucket=BUCKET, Key=s3_key)
    
    # read the image bytes from the response body
    img_bytes = response["Body"].read()
    
    # wrap the bytes in a BytesIO object so Pillow can open it
    img_stream = io.BytesIO(img_bytes)
    
    # open the image using Pillow
    img = Image.open(img_stream)
    
    # check if the image is already grayscale or black and white
    # "L" and "1" are common modes for grayscale / bilevel images
    if img.mode in ("L", "1"):
        # if the image is already grayscale, keep it as it is
        gray_img = img
    else:
        # if the image is color (e.g., "RGB", "RGBA"), convert it to grayscale
        gray_img = img.convert("L")
    
    # get the base name without the extension (e.g., "0001" from "0001.png")
    base_name = os.path.splitext(filename)[0]
    
    # create the new file name with .png extension
    new_filename = base_name + ".png"
    
    # build the full output path inside the output folder
    output_path = os.path.join(output_folder, new_filename)
    
    # save the grayscale image as a PNG file at the output path
    gray_img.save(output_path, format="PNG")
    
    # optional: print the saved file path
    print("Saved to:", output_path)

# print a final message when all images are done
print("All images processed and saved in:", output_folder)
# Out:
# Processing: testA/mask_left/00112158c308d48307e95b841f678df8.png
# Saved to: test - front masked images - side/00112158c308d48307e95b841f678df8.png
# Processing: testA/mask_left/0048f0d9a4d0ca697e31077bab7b2471.png
# Saved to: test - front masked images - side/0048f0d9a4d0ca697e31077bab7b2471.png
# Processing: testA/mask_left/004a5121131d22f1c1d9f63828442577.png
# Saved to: test - front masked images - side/004a5121131d22f1c1d9f63828442577.png
# Processing: testA/mask_left/004e3469daa569584c9d56200fb93374.png
# Saved to: test - front masked images - side/004e3469daa569584c9d56200fb93374.png
# Processing: testA/mask_left/00aefca158a6b773b8c466c9b715ac25.png
# Saved to: test - front masked images - side/00aefca158a6b773b8c466c9b715ac25.png
# Processing: testA/mask_left/00e11c860f7b081a01e9c7f04405c40f.png
# Saved to: test - front masked images - side/00e11c860f7b081a01e9c7f04405c40f.png
# Processing: testA/mask_left/00e25ccd07165abbd859a16bbc569282.png
# Saved to: test - front masked images - side/00e25ccd07165abbd859a16bbc569282.png
# Processing: testA/mask_left/00eb5c77f79af6aea1fcf21184c1bf52.png
# Saved to: test - front masked images - side/00eb5c77f79af6aea1fcf21184c1bf52.png
# Processing: testA/mask_left/00f29ea96c690cb73496ebc2448bf7bc.png
# Saved to: test - front masked images - side/00f29ea96c690cb73496ebc2448bf7bc.png
# Processing: testA/mask_left/00faad24b3376fd9f864a8d4555bf0f1.png
# Saved to: test - front masked images - side/00faad24b3376fd9f864a8d4555bf0f1.png
# Processing: testA/mask_left/00fc44412bca19f9f1990cf79c47adef.png
# Saved to: test - front masked images - side/00fc44412bca19f9f1990cf79c47adef.png
# Processing: testA/mask_left/018cc7c1e78ba95c88795704e0dae997.png
# Saved to: test - front masked images - side/018cc7c1e78ba95c88795704e0dae997.png
# Processing: testA/mask_left/019b87b3ffb4b3c50efee461335ea9bf.png
# Saved to: test - front masked images - side/019b87b3ffb4b3c50efee461335ea9bf.png
# Processing: testA/mask_left/01b7f357ef9000d55e74891773d42d8a.png
# Saved to: test - front masked images - side/01b7f357ef9000d55e74891773d42d8a.png
# Processing: testA/mask_left/01efe9423b11496832f46a87e9d30366.png
# Saved to: test - front masked images - side/01efe9423b11496832f46a87e9d30366.png
# Processing: testA/mask_left/01f677be480a55c0d93ab446ec22270c.png
# Saved to: test - front masked images - side/01f677be480a55c0d93ab446ec22270c.png
# Processing: testA/mask_left/09c87c6611ab8539765390f57440d885.png
# Saved to: test - front masked images - side/09c87c6611ab8539765390f57440d885.png
# Processing: testA/mask_left/0a15c19f92b0471622bc7251d9e1a603.png
# Saved to: test - front masked images - side/0a15c19f92b0471622bc7251d9e1a603.png
# Processing: testA/mask_left/0a4335cbc3c6a13d09baf80adcada041.png
# Saved to: test - front masked images - side/0a4335cbc3c6a13d09baf80adcada041.png
# Processing: testA/mask_left/0a61f2df7743db47dcbe5c9d0579e7ab.png
# Saved to: test - front masked images - side/0a61f2df7743db47dcbe5c9d0579e7ab.png
# Processing: testA/mask_left/0aad7e8a4987342302961aa4cc0ccbed.png
# Saved to: test - front masked images - side/0aad7e8a4987342302961aa4cc0ccbed.png
# Processing: testA/mask_left/0ac042b94e0869b35bd437fc6eb05b04.png
# Saved to: test - front masked images - side/0ac042b94e0869b35bd437fc6eb05b04.png
# Processing: testA/mask_left/0ad031e1f4a0f6901f0b7547e5716a8a.png
# Saved to: test - front masked images - side/0ad031e1f4a0f6901f0b7547e5716a8a.png
# Processing: testA/mask_left/0af21e68710cfa7c354e3a6187398755.png
# Saved to: test - front masked images - side/0af21e68710cfa7c354e3a6187398755.png
# Processing: testA/mask_left/0b0955e1ca4b09d0e0fb101a0985a7c0.png
# Saved to: test - front masked images - side/0b0955e1ca4b09d0e0fb101a0985a7c0.png
# Processing: testA/mask_left/0b53e8be10e3d2bd06af556014131b73.png
# Saved to: test - front masked images - side/0b53e8be10e3d2bd06af556014131b73.png
# Processing: testA/mask_left/0b73679eb89c7015f1e976f6ae1f36c5.png
# Saved to: test - front masked images - side/0b73679eb89c7015f1e976f6ae1f36c5.png
# Processing: testA/mask_left/0b7e1ee5cdbafb61fcdffc50981b1993.png
# Saved to: test - front masked images - side/0b7e1ee5cdbafb61fcdffc50981b1993.png
# Processing: testA/mask_left/0b822daba6492d4ba392b4cecf7b2bec.png
# Saved to: test - front masked images - side/0b822daba6492d4ba392b4cecf7b2bec.png
# Processing: testA/mask_left/0bb67025dd6bf440b3b449079e9f669e.png
# Saved to: test - front masked images - side/0bb67025dd6bf440b3b449079e9f669e.png
# Processing: testA/mask_left/0bff2fdfd1411af75d9688cc5d48a3bb.png
# Saved to: test - front masked images - side/0bff2fdfd1411af75d9688cc5d48a3bb.png
# Processing: testA/mask_left/0c6df6504cf85d2ff1471fe3dbe87edf.png
# Saved to: test - front masked images - side/0c6df6504cf85d2ff1471fe3dbe87edf.png
# Processing: testA/mask_left/0c9f62ff53a78f6d0c9f6d228e4f1b32.png
# Saved to: test - front masked images - side/0c9f62ff53a78f6d0c9f6d228e4f1b32.png
# Processing: testA/mask_left/0cbe9be612128f3d394acfba8ca99cff.png
# Saved to: test - front masked images - side/0cbe9be612128f3d394acfba8ca99cff.png
# Processing: testA/mask_left/0ce1d6093159bdf11f2ec70de3507555.png
# Saved to: test - front masked images - side/0ce1d6093159bdf11f2ec70de3507555.png
# Processing: testA/mask_left/0d1ad1c54cdc7c08cd6653c0fff4e015.png
# Processing: testA/mask_left/10bbe1476b74829c154c21a052c71afb.png
# Saved to: test - front masked images - side/10bbe1476b74829c154c21a052c71afb.png
# Processing: testA/mask_left/10c266033125c4d63763ad2e6cebcafd.png
# Saved to: test - front masked images - side/10c266033125c4d63763ad2e6cebcafd.png
# Processing: testA/mask_left/10cb906c72e270e5faa569ab1e84bb72.png
# Saved to: test - front masked images - side/10cb906c72e270e5faa569ab1e84bb72.png
# Processing: testA/mask_left/10cfc2133d17cb891e652b6dbf3d8d6b.png
# Saved to: test - front masked images - side/10cfc2133d17cb891e652b6dbf3d8d6b.png
# Processing: testA/mask_left/10fbdb4e69011925cb772c238f855285.png
# Saved to: test - front masked images - side/10fbdb4e69011925cb772c238f855285.png
# Processing: testA/mask_left/1133e9972dabb30a39611c4109a331f4.png
# Saved to: test - front masked images - side/1133e9972dabb30a39611c4109a331f4.png
# Processing: testA/mask_left/1144ebca0f8f9352136a5772f333f4fd.png
# Saved to: test - front masked images - side/1144ebca0f8f9352136a5772f333f4fd.png
# Processing: testA/mask_left/114cbc1a77a1f143321cba89bae004fd.png
# Saved to: test - front masked images - side/114cbc1a77a1f143321cba89bae004fd.png
# Processing: testA/mask_left/11677eada1036437abb6be3cd1a7a816.png
# Saved to: test - front masked images - side/11677eada1036437abb6be3cd1a7a816.png
# Processing: testA/mask_left/11921ca147282e9960766ff469a0b91e.png
# Saved to: test - front masked images - side/11921ca147282e9960766ff469a0b91e.png
# Processing: testA/mask_left/119f20ad951b1bbb7d35aec194a058b8.png
# Saved to: test - front masked images - side/119f20ad951b1bbb7d35aec194a058b8.png
# Processing: testA/mask_left/11c57ab8acb98db3ac1690263f571963.png
# Saved to: test - front masked images - side/11c57ab8acb98db3ac1690263f571963.png
# Processing: testA/mask_left/11da4b528ccf6923acb9faa614831898.png
# Saved to: test - front masked images - side/11da4b528ccf6923acb9faa614831898.png
# Processing: testA/mask_left/121a7f93a0f91ed1d810f5534921ab69.png
# Saved to: test - front masked images - side/121a7f93a0f91ed1d810f5534921ab69.png
# Processing: testA/mask_left/12cf4e3779538c231835110f71322815.png
# Saved to: test - front masked images - side/12cf4e3779538c231835110f71322815.png
# Processing: testA/mask_left/12f6a4300d826d637259e69026a68271.png
# Saved to: test - front masked images - side/12f6a4300d826d637259e69026a68271.png
# Processing: testA/mask_left/13d080ddca94def7de1aa13603187899.png
# Saved to: test - front masked images - side/13d080ddca94def7de1aa13603187899.png
# Processing: testA/mask_left/13df1e0f9737c8b5fff70c7914322252.png
# Saved to: test - front masked images - side/13df1e0f9737c8b5fff70c7914322252.png
# Processing: testA/mask_left/13e5b6e8a3d1358d89216bf3757f646b.png
# Saved to: test - front masked images - side/13e5b6e8a3d1358d89216bf3757f646b.png
# Processing: testA/mask_left/140ecb1d2a81bd09c2085e0338399837.png
# Saved to: test - front masked images - side/140ecb1d2a81bd09c2085e0338399837.png
# Processing: testA/mask_left/141279d674ee6e0254ae0a84cf6973f2.png
# Saved to: test - front masked images - side/141279d674ee6e0254ae0a84cf6973f2.png
# Saved to: test - front masked images - side/19f506a35c3f3c401c9dc6bcd345e82d.png
# Processing: testA/mask_left/1a09ab458a895f11b74f3bc99b82812e.png
# Saved to: test - front masked images - side/1a09ab458a895f11b74f3bc99b82812e.png
# Processing: testA/mask_left/1a30d59df8d3874793e90e18a2be37db.png
# Saved to: test - front masked images - side/1a30d59df8d3874793e90e18a2be37db.png
# Processing: testA/mask_left/1a69adba241e3949d1b90c567fd16988.png
# Saved to: test - front masked images - side/1a69adba241e3949d1b90c567fd16988.png
# Processing: testA/mask_left/1a7cef1e42678cf622cd26af55fe47fb.png
# Saved to: test - front masked images - side/1a7cef1e42678cf622cd26af55fe47fb.png
# Processing: testA/mask_left/1af43409b46b0c352a83a3d322c2964f.png
# Saved to: test - front masked images - side/1af43409b46b0c352a83a3d322c2964f.png
# Processing: testA/mask_left/1b0033f1b3391c71b911d0abf28aa4b9.png
# Saved to: test - front masked images - side/1b0033f1b3391c71b911d0abf28aa4b9.png
# Processing: testA/mask_left/1b292812faf2544b1a7e7dc20b0d342e.png
# Saved to: test - front masked images - side/1b292812faf2544b1a7e7dc20b0d342e.png
# Processing: testA/mask_left/1b38300952075980b220c689ed92d1d6.png
# Saved to: test - front masked images - side/1b38300952075980b220c689ed92d1d6.png
# Processing: testA/mask_left/1b57988171874d8fae376d94f4dc7f65.png
# Saved to: test - front masked images - side/1b57988171874d8fae376d94f4dc7f65.png
# Processing: testA/mask_left/1b63d30546a32821982bd409479c4616.png
# Saved to: test - front masked images - side/1b63d30546a32821982bd409479c4616.png
# Processing: testA/mask_left/1b6907c78993aca01516f89d1ecf769b.png
# Saved to: test - front masked images - side/1b6907c78993aca01516f89d1ecf769b.png
# Processing: testA/mask_left/1b7afbc07bc3b7e225b07b92a0b52a35.png
# Saved to: test - front masked images - side/1b7afbc07bc3b7e225b07b92a0b52a35.png
# Processing: testA/mask_left/1b7ddf225ed6af9f9abee261e4f19ae7.png
# Saved to: test - front masked images - side/1b7ddf225ed6af9f9abee261e4f19ae7.png
# Processing: testA/mask_left/1c1882577f60aae088d914e930ff702c.png
# Saved to: test - front masked images - side/1c1882577f60aae088d914e930ff702c.png
# Processing: testA/mask_left/1c5a5997210b5239c8abef2bb5450f1d.png
# Saved to: test - front masked images - side/1c5a5997210b5239c8abef2bb5450f1d.png
# Processing: testA/mask_left/1c6fe922a59a5b63ec8c0e2264eb49af.png
# Saved to: test - front masked images - side/1c6fe922a59a5b63ec8c0e2264eb49af.png
# Processing: testA/mask_left/1c74674370aa845e48ef0e73509cd265.png
# Saved to: test - front masked images - side/1c74674370aa845e48ef0e73509cd265.png
# Processing: testA/mask_left/1c8e217df737d8bfbf795c9d6bf84da4.png
# Saved to: test - front masked images - side/1c8e217df737d8bfbf795c9d6bf84da4.png
# Processing: testA/mask_left/1cb700bcd464bee3cb3934caabd0dd55.png
# Saved to: test - front masked images - side/1cb700bcd464bee3cb3934caabd0dd55.png
# Saved to: test - front masked images - side/1fd8d656c6ad32451ef2effdfd8640b5.png
# Processing: testA/mask_left/1ff023a65bef1439e7269e98749485c4.png
# Saved to: test - front masked images - side/1ff023a65bef1439e7269e98749485c4.png
# Processing: testA/mask_left/201021eb5cd55a2c01e5ef5d1344015c.png
# Saved to: test - front masked images - side/201021eb5cd55a2c01e5ef5d1344015c.png
# Processing: testA/mask_left/20171b8e6a08b493e474914800b3d53f.png
# Saved to: test - front masked images - side/20171b8e6a08b493e474914800b3d53f.png
# Processing: testA/mask_left/20192a081a6e6cc01e7388070cd12441.png
# Saved to: test - front masked images - side/20192a081a6e6cc01e7388070cd12441.png
# Processing: testA/mask_left/201ebae4f346177f02c915de97a41672.png
# Saved to: test - front masked images - side/201ebae4f346177f02c915de97a41672.png
# Processing: testA/mask_left/2045ee5bff584efc4c99cbbf956e41e2.png
# Saved to: test - front masked images - side/2045ee5bff584efc4c99cbbf956e41e2.png
# Processing: testA/mask_left/2052c354142b05e9e30ec30d0acd49ce.png
# Saved to: test - front masked images - side/2052c354142b05e9e30ec30d0acd49ce.png
# Processing: testA/mask_left/2086ad6b194f78fbfca0a9fea390d546.png
# Saved to: test - front masked images - side/2086ad6b194f78fbfca0a9fea390d546.png
# Processing: testA/mask_left/20aa75de1f51616798f339898110cc9e.png
# Saved to: test - front masked images - side/20aa75de1f51616798f339898110cc9e.png
# Processing: testA/mask_left/20c08c268e003ee73c696a640524e6f4.png
# Saved to: test - front masked images - side/20c08c268e003ee73c696a640524e6f4.png
# Processing: testA/mask_left/20ec971af5f52f7e95a53372f937bcea.png
# Saved to: test - front masked images - side/20ec971af5f52f7e95a53372f937bcea.png
# Processing: testA/mask_left/20f76375d66730b3a2b18c9244e8fb0c.png
# Saved to: test - front masked images - side/20f76375d66730b3a2b18c9244e8fb0c.png
# Processing: testA/mask_left/20f7d56a4f6960eb4c5b0aedeafe437f.png
# Saved to: test - front masked images - side/20f7d56a4f6960eb4c5b0aedeafe437f.png
# Processing: testA/mask_left/211bdc1fbd34284e72f487ab01545822.png
# Saved to: test - front masked images - side/211bdc1fbd34284e72f487ab01545822.png
# Processing: testA/mask_left/212ed461f9604bb8270a2a144a96760c.png
# Saved to: test - front masked images - side/212ed461f9604bb8270a2a144a96760c.png
# Processing: testA/mask_left/213eb967373ebebf0e077306b0380835.png
# Saved to: test - front masked images - side/213eb967373ebebf0e077306b0380835.png
# Processing: testA/mask_left/215a3bb020099c9267be23cca69b73af.png
# Saved to: test - front masked images - side/215a3bb020099c9267be23cca69b73af.png
# Processing: testA/mask_left/215ace371ce8149eb88a1c63682d3bd1.png
# Saved to: test - front masked images - side/215ace371ce8149eb88a1c63682d3bd1.png
# Processing: testA/mask_left/218218963db9d89f764644c42f8c78f2.png
# Saved to: test - front masked images - side/218218963db9d89f764644c42f8c78f2.png
# Processing: testA/mask_left/21b6d2ed7b5c89fc987589ec47bc0d3b.png
# Saved to: test - front masked images - side/21b6d2ed7b5c89fc987589ec47bc0d3b.png
# Saved to: test - front masked images - side/2487263389b22f6d3c7614984abe0f81.png
# Processing: testA/mask_left/24ede86a910ae1ff658feee7b934a6ca.png
# Saved to: test - front masked images - side/24ede86a910ae1ff658feee7b934a6ca.png
# Processing: testA/mask_left/25498880cc42bab417e4ce5fcfa0007d.png
# Saved to: test - front masked images - side/25498880cc42bab417e4ce5fcfa0007d.png
# Processing: testA/mask_left/255b3ccc8bb781fb25687ccfd0775668.png
# Saved to: test - front masked images - side/255b3ccc8bb781fb25687ccfd0775668.png
# Processing: testA/mask_left/255c1696e18c714d0045bc2bbda06147.png
# Saved to: test - front masked images - side/255c1696e18c714d0045bc2bbda06147.png
# Processing: testA/mask_left/255f607850cfc30661c587cf176b49de.png
# Saved to: test - front masked images - side/255f607850cfc30661c587cf176b49de.png
# Processing: testA/mask_left/256a73e60cb5fa2706be990b7fc7f6f9.png
# Saved to: test - front masked images - side/256a73e60cb5fa2706be990b7fc7f6f9.png
# Processing: testA/mask_left/25a97ae2d0a83f5efae54f38093b4303.png
# Saved to: test - front masked images - side/25a97ae2d0a83f5efae54f38093b4303.png
# Processing: testA/mask_left/25ba0b189c02019e41c8af90191a09dc.png
# Saved to: test - front masked images - side/25ba0b189c02019e41c8af90191a09dc.png
# Processing: testA/mask_left/26111e53121ef77f4323842129748991.png
# Saved to: test - front masked images - side/26111e53121ef77f4323842129748991.png
# Processing: testA/mask_left/264c24ac9dee64d6959c41de65e47213.png
# Saved to: test - front masked images - side/264c24ac9dee64d6959c41de65e47213.png
# Processing: testA/mask_left/26b4c8d65d97cc85fd3bea3dd6ab106e.png
# Saved to: test - front masked images - side/26b4c8d65d97cc85fd3bea3dd6ab106e.png
# Processing: testA/mask_left/2703b5446db4c0e6a879a0a956b0ea3c.png
# Saved to: test - front masked images - side/2703b5446db4c0e6a879a0a956b0ea3c.png
# Processing: testA/mask_left/2718c8f0f1d04f71a8f7e5bc59fe45a1.png
# Saved to: test - front masked images - side/2718c8f0f1d04f71a8f7e5bc59fe45a1.png
# Processing: testA/mask_left/2743b22748b94a85dbf46d5fd8cc631b.png
# Saved to: test - front masked images - side/2743b22748b94a85dbf46d5fd8cc631b.png
# Processing: testA/mask_left/27489efb50985545a576e0a6de565937.png
# Saved to: test - front masked images - side/27489efb50985545a576e0a6de565937.png
# Processing: testA/mask_left/2765c15abab1c6701a9102edae1b6c27.png
# Saved to: test - front masked images - side/2765c15abab1c6701a9102edae1b6c27.png
# Processing: testA/mask_left/2795f1841197edf1bbae6807b5439f7d.png
# Saved to: test - front masked images - side/2795f1841197edf1bbae6807b5439f7d.png
# Processing: testA/mask_left/27aca640181879bc6fa0f1d118cdfd69.png
# Saved to: test - front masked images - side/27aca640181879bc6fa0f1d118cdfd69.png
# Processing: testA/mask_left/27ca2b1761b82c84658f0454d071d3c0.png
# Saved to: test - front masked images - side/27ca2b1761b82c84658f0454d071d3c0.png
# Processing: testA/mask_left/27e3239e4b54e8063359f3e8d98338ee.png
# Saved to: test - front masked images - side/2b8357aee7986fa0e94e8a511ab9785f.png
# Processing: testA/mask_left/2b96bed2eb5f31b4e23a182ea9b64668.png
# Saved to: test - front masked images - side/2b96bed2eb5f31b4e23a182ea9b64668.png
# Processing: testA/mask_left/2bae84109243176132918131a6e39ab5.png
# Saved to: test - front masked images - side/2bae84109243176132918131a6e39ab5.png
# Processing: testA/mask_left/2bbd44aa1ab58c42120a2039782fb6a4.png
# Saved to: test - front masked images - side/2bbd44aa1ab58c42120a2039782fb6a4.png
# Processing: testA/mask_left/2bd64834d2c82c1f53873da73e9f4860.png
# Saved to: test - front masked images - side/2bd64834d2c82c1f53873da73e9f4860.png
# Processing: testA/mask_left/2c067c65ba806952fea0d8857fe1ec55.png
# Saved to: test - front masked images - side/2c067c65ba806952fea0d8857fe1ec55.png
# Processing: testA/mask_left/2c31fc56ee9edb5094dd7eb52815d768.png
# Saved to: test - front masked images - side/2c31fc56ee9edb5094dd7eb52815d768.png
# Processing: testA/mask_left/2c739cd7a0e4f2ae017fdf2dde9fa234.png
# Saved to: test - front masked images - side/2c739cd7a0e4f2ae017fdf2dde9fa234.png
# Processing: testA/mask_left/2c86d3c2e7c3ff6d16e0536f5792f8ca.png
# Saved to: test - front masked images - side/2c86d3c2e7c3ff6d16e0536f5792f8ca.png
# Processing: testA/mask_left/2cb9a90a04c48257f10ad6094a702b81.png
# Saved to: test - front masked images - side/2cb9a90a04c48257f10ad6094a702b81.png
# Processing: testA/mask_left/2cc67b5c19e6983fea95b2c9c79c972f.png
# Saved to: test - front masked images - side/2cc67b5c19e6983fea95b2c9c79c972f.png
# Processing: testA/mask_left/2cdc729ca88ad1283fba138282402f8c.png
# Saved to: test - front masked images - side/2cdc729ca88ad1283fba138282402f8c.png
# Processing: testA/mask_left/2cedabde68ff752fdc7232d70adec0bc.png
# Saved to: test - front masked images - side/2cedabde68ff752fdc7232d70adec0bc.png
# Processing: testA/mask_left/2d6375eec7eb29f9665fdd9d2b49cbc9.png
# Saved to: test - front masked images - side/2d6375eec7eb29f9665fdd9d2b49cbc9.png
# Processing: testA/mask_left/2d66a730d8b339d5ebf9c40c83bd3399.png
# Saved to: test - front masked images - side/2d66a730d8b339d5ebf9c40c83bd3399.png
# Processing: testA/mask_left/2d8064b4a85e8960b0d1ad7397d7d0fe.png
# Saved to: test - front masked images - side/2d8064b4a85e8960b0d1ad7397d7d0fe.png
# Processing: testA/mask_left/2dab6443f12be502d5c119eb95d1f2f6.png
# Saved to: test - front masked images - side/2dab6443f12be502d5c119eb95d1f2f6.png
# Processing: testA/mask_left/2dba584a0541d91a2f85a060dfdef933.png
# Saved to: test - front masked images - side/2dba584a0541d91a2f85a060dfdef933.png
# Processing: testA/mask_left/2dead5a8d24cbae03e801cac3f00f32f.png
# Saved to: test - front masked images - side/2dead5a8d24cbae03e801cac3f00f32f.png
# Processing: testA/mask_left/2df21c7458b71ab0fb27a4db7e5c5af0.png
# Saved to: test - front masked images - side/2df21c7458b71ab0fb27a4db7e5c5af0.png
# Processing: testA/mask_left/2df7762767062c6475c3c607d5dd2259.png
# Saved to: test - front masked images - side/2df7762767062c6475c3c607d5dd2259.png
# Processing: testA/mask_left/2e2c6428f26c80bf286b854fe851b518.png
# Saved to: test - front masked images - side/2e2c6428f26c80bf286b854fe851b518.png
# Processing: testA/mask_left/2e4496d776be97ce4c5929eb49b35972.png
# Saved to: test - front masked images - side/2e4496d776be97ce4c5929eb49b35972.png
# Processing: testA/mask_left/2e8a9f1b8a6841486906cc5ac5c17dec.png
# Saved to: test - front masked images - side/2e8a9f1b8a6841486906cc5ac5c17dec.png
# Processing: testA/mask_left/2e8d0b7c08fdff515a14f52438c316b2.png
# Saved to: test - front masked images - side/2e8d0b7c08fdff515a14f52438c316b2.png
# Processing: testA/mask_left/2ebd110ce6e3d1f4204dbdd88c5aee98.png
# Saved to: test - front masked images - side/2ebd110ce6e3d1f4204dbdd88c5aee98.png
# Processing: testA/mask_left/2f1bb64aa1ee2738934749a75ca781a3.png
# Saved to: test - front masked images - side/2f1bb64aa1ee2738934749a75ca781a3.png
# Processing: testA/mask_left/2f3813795c12219b4939ff8b521993b5.png
# Saved to: test - front masked images - side/2f3813795c12219b4939ff8b521993b5.png
# Processing: testA/mask_left/2f3c3ffd479253edae14549292caeeef.png
# Saved to: test - front masked images - side/2f3c3ffd479253edae14549292caeeef.png
# Processing: testA/mask_left/2f499f4e7c61075f2a3e93c3595026a5.png
# Saved to: test - front masked images - side/2f499f4e7c61075f2a3e93c3595026a5.png
# Processing: testA/mask_left/2fbdcec5c1626ec52d27bf04d977b33e.png
# Saved to: test - front masked images - side/2fbdcec5c1626ec52d27bf04d977b33e.png
# Processing: testA/mask_left/3084f8cc460d803381f0f26d36032f7f.png
# Saved to: test - front masked images - side/3084f8cc460d803381f0f26d36032f7f.png
# Processing: testA/mask_left/309a6d9e3d918059bc0b730dc044af54.png
# Saved to: test - front masked images - side/309a6d9e3d918059bc0b730dc044af54.png
# Processing: testA/mask_left/30c01159493adafc50c4ff1ef5bfa7cf.png
# Saved to: test - front masked images - side/30c01159493adafc50c4ff1ef5bfa7cf.png
# Processing: testA/mask_left/30c53e4165979c5fd812700545dc0bbe.png
# Saved to: test - front masked images - side/30c53e4165979c5fd812700545dc0bbe.png
# Processing: testA/mask_left/30fe191a2fd35db4329100beb00f49de.png
# Saved to: test - front masked images - side/30fe191a2fd35db4329100beb00f49de.png
# Processing: testA/mask_left/3124743d6494910558170710939a3296.png
# Saved to: test - front masked images - side/3124743d6494910558170710939a3296.png
# Processing: testA/mask_left/312fb2fd2815f314d82e54bace909cc5.png
# Saved to: test - front masked images - side/312fb2fd2815f314d82e54bace909cc5.png
# Processing: testA/mask_left/3195cb96f24eb881a3706cdde222b077.png
# Saved to: test - front masked images - side/3195cb96f24eb881a3706cdde222b077.png
# Processing: testA/mask_left/31e2371d8842b90929dfad45c2991465.png
# Saved to: test - front masked images - side/31e2371d8842b90929dfad45c2991465.png
# Processing: testA/mask_left/32091eda112507d7213d4672bfc36917.png
# Saved to: test - front masked images - side/32091eda112507d7213d4672bfc36917.png
# Processing: testA/mask_left/324137b7ede9cf1400d21f9191350a45.png
# Saved to: test - front masked images - side/324137b7ede9cf1400d21f9191350a45.png
# Processing: testA/mask_left/325aa50c277e5ddb5706a9ec6d61cc7d.png
# Saved to: test - front masked images - side/325aa50c277e5ddb5706a9ec6d61cc7d.png
# Processing: testA/mask_left/32792e968f3dd7a74febc7899192a306.png
# Saved to: test - front masked images - side/32792e968f3dd7a74febc7899192a306.png
# Processing: testA/mask_left/328b7cf7a675ebc4e1dcd14677a2cf03.png
# Saved to: test - front masked images - side/328b7cf7a675ebc4e1dcd14677a2cf03.png
# Processing: testA/mask_left/32937dca2c17f7624e889c8b3f544ac1.png
# Saved to: test - front masked images - side/32937dca2c17f7624e889c8b3f544ac1.png
# Processing: testA/mask_left/32a8419c3f89664423ed0b43e49eabc5.png
# Saved to: test - front masked images - side/32a8419c3f89664423ed0b43e49eabc5.png
# Processing: testA/mask_left/32c6d93c78808b0b8746815a12b2526d.png
# Saved to: test - front masked images - side/32c6d93c78808b0b8746815a12b2526d.png
# Processing: testA/mask_left/33130c0719c02d71be90ddf431943b73.png
# Saved to: test - front masked images - side/33130c0719c02d71be90ddf431943b73.png
# Processing: testA/mask_left/33619c4d7e6b2c2e5b7bf69c0af60656.png
# Saved to: test - front masked images - side/33619c4d7e6b2c2e5b7bf69c0af60656.png
# Processing: testA/mask_left/336fdf747a588d108ca5e3413fc9d692.png
# Saved to: test - front masked images - side/336fdf747a588d108ca5e3413fc9d692.png
# Processing: testA/mask_left/338b820a2077242d52b79c4cdbe56404.png
# Saved to: test - front masked images - side/338b820a2077242d52b79c4cdbe56404.png
# Processing: testA/mask_left/338fc4e32934d7ceef7b984b5a70a34b.png
# ...
# Processing: testA/mask_left/ef565d5759c9fa758984c6dcc25f6b2d.png
# Saved to: test - front masked images - side/ef565d5759c9fa758984c6dcc25f6b2d.png
# Processing: testA/mask_left/ef87d8d94cb0aa2a8e3edc27fbae8bf5.png
# Saved to: test - front masked images - side/ef87d8d94cb0aa2a8e3edc27fbae8bf5.png
# Processing: testA/mask_left/efa2d4f0c8a6d519e4a8344d55802d6d.png
# Saved to: test - front masked images - side/efa2d4f0c8a6d519e4a8344d55802d6d.png
# Processing: testA/mask_left/efac3e26b585122d1cad96db5c8d41a4.png
# Saved to: test - front masked images - side/efac3e26b585122d1cad96db5c8d41a4.png
# Processing: testA/mask_left/efcf2e41ccc5cbd6dccc67a179aa28c8.png
# Saved to: test - front masked images - side/efcf2e41ccc5cbd6dccc67a179aa28c8.png
# Processing: testA/mask_left/effb2f832d2b3c1f80f8d364dd839369.png
# Saved to: test - front masked images - side/effb2f832d2b3c1f80f8d364dd839369.png
# Processing: testA/mask_left/f001cb14be39484b281bb4bdc571483b.png
# Saved to: test - front masked images - side/f001cb14be39484b281bb4bdc571483b.png
# Processing: testA/mask_left/f05ab6af719ad917e5f296a3b4a25120.png
# Saved to: test - front masked images - side/f05ab6af719ad917e5f296a3b4a25120.png
# Processing: testA/mask_left/f06abe7da074a2234564fe08d4b20a7b.png
# Saved to: test - front masked images - side/f06abe7da074a2234564fe08d4b20a7b.png
# Processing: testA/mask_left/f075a9d5adf95fcc384ae21459c6ad09.png
# Saved to: test - front masked images - side/f075a9d5adf95fcc384ae21459c6ad09.png
# Processing: testA/mask_left/f08f83c83db19e0bcd0ad509d43768bb.png
# Saved to: test - front masked images - side/f08f83c83db19e0bcd0ad509d43768bb.png
# Processing: testA/mask_left/f0b374fd249a39a136855f6c3123a9c8.png
# Saved to: test - front masked images - side/f0b374fd249a39a136855f6c3123a9c8.png
# Processing: testA/mask_left/f11e961fa28beff6552c62036a23fca4.png
# Saved to: test - front masked images - side/f11e961fa28beff6552c62036a23fca4.png
# Processing: testA/mask_left/f12a53be6c505ec2d400c93d78b040d9.png
# Saved to: test - front masked images - side/f12a53be6c505ec2d400c93d78b040d9.png
# Processing: testA/mask_left/f18950171abe6dcc208d24926524e5ee.png
# Saved to: test - front masked images - side/f18950171abe6dcc208d24926524e5ee.png
# Processing: testA/mask_left/f1fc23a15c66752aa87b8efd4f397e0f.png
# Saved to: test - front masked images - side/f1fc23a15c66752aa87b8efd4f397e0f.png
# Processing: testA/mask_left/f2aac3b3370038a433c816bd5de28cba.png
# Saved to: test - front masked images - side/f2aac3b3370038a433c816bd5de28cba.png
# Processing: testA/mask_left/f38d78aacad6e852732890865dc990a2.png
# Saved to: test - front masked images - side/f38d78aacad6e852732890865dc990a2.png
# Processing: testA/mask_left/f3fac2f83e7c2571c2769b0e9fdcf4f6.png
# Saved to: test - front masked images - side/f3fac2f83e7c2571c2769b0e9fdcf4f6.png
# Processing: testA/mask_left/f478bc2504e7db10b81e33df63a4408e.png
# Saved to: test - front masked images - side/f478bc2504e7db10b81e33df63a4408e.png
# Processing: testA/mask_left/f4878d8662459555bdcaa13f5859ec41.png
# Saved to: test - front masked images - side/f4878d8662459555bdcaa13f5859ec41.png
# Processing: testA/mask_left/f4d3a6342766aec30ea474a03ca0e6ba.png
# Saved to: test - front masked images - side/f4d3a6342766aec30ea474a03ca0e6ba.png
# Processing: testA/mask_left/f4d59c99f8079e63730ae8b2fb534d13.png
# Saved to: test - front masked images - side/f4d59c99f8079e63730ae8b2fb534d13.png
# Processing: testA/mask_left/f4df8ecbbdb67a2cc7ffaee999f0b97b.png
# Saved to: test - front masked images - side/f4df8ecbbdb67a2cc7ffaee999f0b97b.png
# Processing: testA/mask_left/f4eda0d96db0e39494e8f30726cc4d1f.png
# Saved to: test - front masked images - side/f4eda0d96db0e39494e8f30726cc4d1f.png
# Processing: testA/mask_left/f4fd20c6a6b79ee80ee7c7d1b8d4207c.png
# Saved to: test - front masked images - side/f4fd20c6a6b79ee80ee7c7d1b8d4207c.png
# Processing: testA/mask_left/f5346ad90f716bcb27a9ca8fef0bb45e.png
# Saved to: test - front masked images - side/f5346ad90f716bcb27a9ca8fef0bb45e.png
# Saved to: test - front masked images - side/f8b23ad9d22f09e5e1b3e2649094ea2b.png
# Processing: testA/mask_left/f8cd66639e70716ae373290915797b63.png
# Saved to: test - front masked images - side/f8cd66639e70716ae373290915797b63.png
# Processing: testA/mask_left/f8e9031cacf69ab44ebb5db40483166d.png
# Saved to: test - front masked images - side/f8e9031cacf69ab44ebb5db40483166d.png
# Processing: testA/mask_left/f8eac00927534ed8ed92d4289ec5f075.png
# Saved to: test - front masked images - side/f8eac00927534ed8ed92d4289ec5f075.png
# Processing: testA/mask_left/f9424260cec3f88acb8e4afe29ae592f.png
# Saved to: test - front masked images - side/f9424260cec3f88acb8e4afe29ae592f.png
# Processing: testA/mask_left/f943a369d651f02dd842bebead0d588f.png
# Saved to: test - front masked images - side/f943a369d651f02dd842bebead0d588f.png
# Processing: testA/mask_left/f95a847c3d8dfe6a365fe7c300f6986a.png
# Saved to: test - front masked images - side/f95a847c3d8dfe6a365fe7c300f6986a.png
# Processing: testA/mask_left/f95c71c46b2b0a50161572b4c9a7c529.png
# Saved to: test - front masked images - side/f95c71c46b2b0a50161572b4c9a7c529.png
# Processing: testA/mask_left/f965f197892353bf42a2f56e44abb9bb.png
# Saved to: test - front masked images - side/f965f197892353bf42a2f56e44abb9bb.png
# Processing: testA/mask_left/f9702668e143057196cd633d0698f383.png
# Saved to: test - front masked images - side/f9702668e143057196cd633d0698f383.png
# Processing: testA/mask_left/fa2cecd9b656e2c58a7c2da6a9eb0553.png
# Saved to: test - front masked images - side/fa2cecd9b656e2c58a7c2da6a9eb0553.png
# Processing: testA/mask_left/fa357122c4a697c32863054e0261ff39.png
# Saved to: test - front masked images - side/fa357122c4a697c32863054e0261ff39.png
# Processing: testA/mask_left/fa5e3d125f822d912edf0c6574a379c5.png
# Saved to: test - front masked images - side/fa5e3d125f822d912edf0c6574a379c5.png
# Processing: testA/mask_left/fa60eee68b52956afd57c4fc13c9e310.png
# Saved to: test - front masked images - side/fa60eee68b52956afd57c4fc13c9e310.png
# Processing: testA/mask_left/fa613de440d1d3dd02768dc5d31c4c40.png
# Saved to: test - front masked images - side/fa613de440d1d3dd02768dc5d31c4c40.png
# Processing: testA/mask_left/fa61e17edc6b60fd06fdea909b0161f7.png
# Saved to: test - front masked images - side/fa61e17edc6b60fd06fdea909b0161f7.png
# Processing: testA/mask_left/fa665f1f990e7a3351f71b57b7cc5676.png
# Saved to: test - front masked images - side/fa665f1f990e7a3351f71b57b7cc5676.png
# Processing: testA/mask_left/fa8de3f01d9ddaf401240c289da2f058.png
# Saved to: test - front masked images - side/fa8de3f01d9ddaf401240c289da2f058.png
# Processing: testA/mask_left/fa971a18b0d0f29747610abbd2d50218.png
# Saved to: test - front masked images - side/fa971a18b0d0f29747610abbd2d50218.png
# Processing: testA/mask_left/fa9eeb81726b3ec4705848d0f577d5f5.png
# Saved to: test - front masked images - side/fa9eeb81726b3ec4705848d0f577d5f5.png
# Processing: testA/mask_left/faa4e6b1b011c577f99b5d9605c17930.png
# Saved to: test - front masked images - side/faa4e6b1b011c577f99b5d9605c17930.png
# Processing: testA/mask_left/fad7673d1a6a81b60d8d7352a495720a.png
# Saved to: test - front masked images - side/fad7673d1a6a81b60d8d7352a495720a.png
# Processing: testA/mask_left/fb5c47c4cfbcb9b6d352f1bdf960f01f.png
# Saved to: test - front masked images - side/fb5c47c4cfbcb9b6d352f1bdf960f01f.png
# Processing: testA/mask_left/fb888e7ddcb071a29da2199b32eb6359.png
# Saved to: test - front masked images - side/fb888e7ddcb071a29da2199b32eb6359.png
# Processing: testA/mask_left/fba6f8d8157288c7f94270c32f695db2.png
# Saved to: test - front masked images - side/fba6f8d8157288c7f94270c32f695db2.png
# Processing: testA/mask_left/fbb15978407487e9a34f81f662b2688b.png
# Saved to: test - front masked images - side/fbb15978407487e9a34f81f662b2688b.png
# Processing: testA/mask_left/fbc57b8ab7b9bdcfb4fa3b8057375e5b.png
# Saved to: test - front masked images - side/fbc57b8ab7b9bdcfb4fa3b8057375e5b.png
# Processing: testA/mask_left/fc65b84d8183e3a872785b4e2eecaa66.png
# Saved to: test - front masked images - side/fc65b84d8183e3a872785b4e2eecaa66.png
# Processing: testA/mask_left/fc741c2364e2cd3dffdcf6407f3209f4.png
# Saved to: test - front masked images - side/fc741c2364e2cd3dffdcf6407f3209f4.png
# Processing: testA/mask_left/fc88eae4f0e03aaeda5624777f5c971a.png
# Saved to: test - front masked images - side/fc88eae4f0e03aaeda5624777f5c971a.png
# Processing: testA/mask_left/fc9dd446f97252290abb4ee487eb0f26.png
# Saved to: test - front masked images - side/fc9dd446f97252290abb4ee487eb0f26.png
# Processing: testA/mask_left/fca7f293d32bbbed3a6da872a258ba87.png
# Saved to: test - front masked images - side/fca7f293d32bbbed3a6da872a258ba87.png
# Processing: testA/mask_left/fcdbc56c1e9abdd20d7ecb2f82defa70.png
# Saved to: test - front masked images - side/fcdbc56c1e9abdd20d7ecb2f82defa70.png
# Processing: testA/mask_left/fd0b224acb0013906f087ecd0990fc21.png
# Saved to: test - front masked images - side/fd0b224acb0013906f087ecd0990fc21.png
# Processing: testA/mask_left/fd0fa141ab229082b1adde0c823414ec.png
# Saved to: test - front masked images - side/fd0fa141ab229082b1adde0c823414ec.png
# Processing: testA/mask_left/fd1c8bb4dc521362fc02314012d27643.png
# Saved to: test - front masked images - side/fd1c8bb4dc521362fc02314012d27643.png
# Processing: testA/mask_left/fd34579f08592c4d24b353fa7e48d122.png
# Saved to: test - front masked images - side/fd34579f08592c4d24b353fa7e48d122.png
# Processing: testA/mask_left/fd4be7654c1c4787f013f05597c80fe2.png
# Saved to: test - front masked images - side/fd4be7654c1c4787f013f05597c80fe2.png
# Processing: testA/mask_left/fd5605427dd8a648717fcf236ddb8a4b.png
# Saved to: test - front masked images - side/fd5605427dd8a648717fcf236ddb8a4b.png
# Processing: testA/mask_left/fd741e7bb681c0f5920dfbfe1ee01488.png
# Saved to: test - front masked images - side/fd741e7bb681c0f5920dfbfe1ee01488.png
# Processing: testA/mask_left/fd8d70e6de5c8313550c7afd164a3b0a.png
# Saved to: test - front masked images - side/fd8d70e6de5c8313550c7afd164a3b0a.png
# Processing: testA/mask_left/fd9e8fea8aac2f1d1fd10ed28c0497f6.png
# Saved to: test - front masked images - side/fd9e8fea8aac2f1d1fd10ed28c0497f6.png
# Processing: testA/mask_left/fdb41a4d8af07d8b487b7023a72fa6d8.png
# Saved to: test - front masked images - side/fdb41a4d8af07d8b487b7023a72fa6d8.png
# Processing: testA/mask_left/fdc14280d25dfa3023714d5742998651.png
# Saved to: test - front masked images - side/fdc14280d25dfa3023714d5742998651.png
# Processing: testA/mask_left/fe5068eb0602ffa458cd43c689ad2c94.png
# Saved to: test - front masked images - side/fe5068eb0602ffa458cd43c689ad2c94.png
# Processing: testA/mask_left/fe56640b22474f4050df54c1c20376f6.png
# Saved to: test - front masked images - side/fe56640b22474f4050df54c1c20376f6.png
# Processing: testA/mask_left/fe5ed80e9d4428082fcdc4178fb9fa25.png
# Saved to: test - front masked images - side/fe5ed80e9d4428082fcdc4178fb9fa25.png
# Processing: testA/mask_left/fe69afb4d97150eb2c1ea7ec392c06b3.png
# Saved to: test - front masked images - side/fe69afb4d97150eb2c1ea7ec392c06b3.png
# Processing: testA/mask_left/fea6f5d161d85cee616837d403c06964.png
# Saved to: test - front masked images - side/fea6f5d161d85cee616837d403c06964.png
# Processing: testA/mask_left/feabbe9e11e83cabb32f410028d658b9.png
# Saved to: test - front masked images - side/feabbe9e11e83cabb32f410028d658b9.png
# Processing: testA/mask_left/ff03fd51af26d801b0987809d5990790.png
# Saved to: test - front masked images - side/ff03fd51af26d801b0987809d5990790.png
# Processing: testA/mask_left/ff1fedf7d131cfd046b8bc0ff719357b.png
# Saved to: test - front masked images - side/ff1fedf7d131cfd046b8bc0ff719357b.png
# Processing: testA/mask_left/ff3c2cce33f7fb1b0dd560c2af0a392c.png
# Saved to: test - front masked images - side/ff3c2cce33f7fb1b0dd560c2af0a392c.png
# Processing: testA/mask_left/ff4499cb94dbd7c301e47749b53195f1.png
# Saved to: test - front masked images - side/ff4499cb94dbd7c301e47749b53195f1.png
# Processing: testA/mask_left/ff6423a2acc28152075ee024cff9ae38.png
# Saved to: test - front masked images - side/ff6423a2acc28152075ee024cff9ae38.png
# Processing: testA/mask_left/ff6a6fd1f4073c54e8d1f802ecb16d20.png
# Saved to: test - front masked images - side/ff6a6fd1f4073c54e8d1f802ecb16d20.png
# Processing: testA/mask_left/ff7f4b409608b24da7f6d678170e4600.png
# Saved to: test - front masked images - side/ff7f4b409608b24da7f6d678170e4600.png
# Processing: testA/mask_left/ff8346ed1a1cc3f5e032c74eedacb67b.png
# Saved to: test - front masked images - side/ff8346ed1a1cc3f5e032c74eedacb67b.png
# Processing: testA/mask_left/ffb17fadec69a6905de8aae9d59e98a9.png
# Saved to: test - front masked images - side/ffb17fadec69a6905de8aae9d59e98a9.png
# Processing: testA/mask_left/ffc0f3dc8a700e4044d56a4af3e119bb.png
# Saved to: test - front masked images - side/ffc0f3dc8a700e4044d56a4af3e119bb.png
# Processing: testA/mask_left/ffca3c2fadbc7d4516a7d6005f69bae5.png
# Saved to: test - front masked images - side/ffca3c2fadbc7d4516a7d6005f69bae5.png
# Processing: testA/mask_left/ffdeb035c2be539c6756bc3ba345bc47.png
# Saved to: test - front masked images - side/ffdeb035c2be539c6756bc3ba345bc47.png
# Processing: testA/mask_left/fff4390e65c88eaae6433357a959e55d.png
# Saved to: test - front masked images - side/fff4390e65c88eaae6433357a959e55d.png
# All images processed and saved in: test - front masked images - side

# %% [markdown]
# Step 5 - Compare S3 image count and local folder image count

# %%
# import os to work with directory listings
import os

# count how many image names were loaded from S3
num_s3_images = len(image_mask)  # get length of the list of S3 image names

# print the number of images found in S3
print("Number of image names from S3:", num_s3_images)

# list all files in the output folder
output_files = os.listdir(output_folder)  # get all file names in the output folder

# keep only files that end with .png (processed images)
output_images = [f for f in output_files if f.lower().endswith(".png")]  # filter only png files

# count how many processed images are in the folder
num_output_images = len(output_images)  # get length of the list of output images

# print the number of images in the output folder
print("Number of processed images in folder:", num_output_images)

# compare the counts from S3 and local folder
if num_s3_images == num_output_images:  # check if both counts are equal
    print("✅ Counts match: all images processed.")  # print success message
else:
    print("❌ Counts DO NOT match!")  # print mismatch message
    
    # calculate the difference between S3 and local counts
    diff = num_s3_images - num_output_images  # positive means missing, negative means extra
    
    # if diff is positive, some images are missing in the local folder
    if diff > 0:
        print(diff, "images are missing in the output folder.")  # report missing images
    else:
        # if diff is negative, there are extra images in the local folder
        print(-diff, "extra images are in the output folder.")  # report extra images
# Out:
# Number of image names from S3: 1684
# Number of processed images in folder: 1684
# ✅ Counts match: all images processed.

# %% [markdown]
# Step 6 - Check that file names match between S3 and local folder

# %%
# import os to work with file names and paths
import os

# create a set of base names (without extension) from S3 image list
s3_base_names = set(os.path.splitext(name)[0] for name in image_mask)

# list all files in the output folder
output_files = os.listdir(output_folder)

# keep only .png files from the output folder
output_images = [f for f in output_files if f.lower().endswith(".png")]

# create a set of base names (without extension) from local png files
local_base_names = set(os.path.splitext(name)[0] for name in output_images)

# print how many unique base names are in each set
print("Unique S3 base names:", len(s3_base_names))
print("Unique local base names:", len(local_base_names))

# check if both sets of base names are exactly the same
if s3_base_names == local_base_names:
    # if sets are equal, all file names match
    print("✅ File names match between S3 and local folder (ignoring extension).")
else:
    # if sets differ, there is some mismatch
    print("❌ File names do NOT match between S3 and local folder.")
    
    # find names present in S3 but missing locally
    missing_locally = s3_base_names - local_base_names
    # find names present locally but not in S3
    extra_locally = local_base_names - s3_base_names
    
    # if there are names missing in local folder, print them
    if missing_locally:
        print("\nNames in S3 but missing in local folder:")
        for name in sorted(missing_locally):
            print("  ", name)
    
    # if there are extra names in local folder, print them
    if extra_locally:
        print("\nNames in local folder but not in S3:")
        for name in sorted(extra_locally):
            print("  ", name)
# Out:
# Unique S3 base names: 1684
# Unique local base names: 1684
# ✅ File names match between S3 and local folder (ignoring extension).
